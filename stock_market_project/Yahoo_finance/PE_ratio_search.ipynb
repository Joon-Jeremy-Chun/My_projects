# %% [markdown]
# ## 과제
# - per 불러오기
# - 모든 주식 per 테이블 만들기
# - per 분포표만들기

# %% [markdown]
# ## I. 페키지 셋팅

# %%
# !pip install yahoo_fin
# !pip install requests_html
# Out:
# ...
#      |████████████████████████████████| 81 kB 3.6 MB/s
# ...
#      |████████████████████████████████| 83 kB 1.6 MB/s
# ...
#      |████████████████████████████████| 111 kB 58.2 MB/s
# ...
#      |████████████████████████████████| 127 kB 60.0 MB/s
# ...
#   Created wheel for fake-useragent: filename=fake_useragent-0.1.11-py3-none-any.whl size=13502 sha256=9965d6af931d2815bdc92adeff83bfaaf0d5f0aac1c079936c2506de521c0dff
#   Stored in directory: /root/.cache/pip/wheels/ed/f7/62/50ab6c9a0b5567267ab76a9daa9d06315704209b2c5d032031
# ...
#   Created wheel for parse: filename=parse-1.19.0-py3-none-any.whl size=24591 sha256=336f4462dff99bdb97ec9a9f93effac69821e1f52088b2817457ba483f171b6f
#   Stored in directory: /root/.cache/pip/wheels/9c/aa/cc/f2228050ccb40f22144b073f15a2c84f11204f29fc0dce028e
# ...
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6066 sha256=26db3ffaebe8dc6620dcef7a9804efd4593bdbc1dca9a233b7a5b12e6edcedf7
# ...

# %%
import yahoo_fin.stock_info as si
import pandas as pd

# %% [markdown]
# ## II.기타 필요자료

# %% [markdown]
# ### 매일 현재 상승 상위 100종목
# ### 하락 상위 100종목
# ### 거래량 100종목

# %%
si.get_day_gainers()
# Out:
#    Symbol                                   Name  Price (Intraday)  Change  \
# 0    NEGG                  Newegg Commerce, Inc.              7.74    0.93
# 1     ENV                        Envestnet, Inc.             81.13    8.65
# 2    GOGO                              Gogo Inc.             20.62    1.43
# 3    ACAD            ACADIA Pharmaceuticals Inc.             27.27    1.52
# 4    CYTK             Cytokinetics, Incorporated             42.41    2.06
# 5   MTNOY                      MTN Group Limited             12.36    0.57
# 6    TLRY                    Tilray Brands, Inc.              7.33    0.30
# 7      AR           Antero Resources Corporation             31.83    1.41
# 8    SMPL          The Simply Good Foods Company             40.21    1.81
# 9     RPM                 RPM International Inc.             86.92    3.80
# 10   PCRX               Pacira BioSciences, Inc.             79.90    3.29
# ...

# %%
si.get_day_losers()
# Out:
#    Symbol                          Name  Price (Intraday)  Change  % Change  \
# 0    FRGE   Forge Global Holdings, Inc.             21.51   -4.69    -17.90
# 1    KIND       Nextdoor Holdings, Inc.              5.37   -1.06    -16.49
# 2    NRGV   Energy Vault Holdings, Inc.             18.48   -3.16    -14.60
# 3     AUR       Aurora Innovation, Inc.              5.57   -0.89    -13.70
# 4    DAVE                     Dave Inc.              6.38   -0.91    -12.48
# ..    ...                           ...               ...     ...       ...
# 95     ZG            Zillow Group, Inc.             47.00   -3.49     -6.91
# 96   NVEI             Nuvei Corporation             69.89   -5.53     -7.33
# 97  LYSCF     Lynas Rare Earths Limited              7.61   -0.55     -6.68
# 98   TWST  Twist Bioscience Corporation             47.76   -3.49     -6.82
# 99  UMICY                    Umicore SA             10.29   -0.73     -6.62
#
# ...

# %%
si.get_day_most_active()
# Out:
#    Symbol                                Name  Price (Intraday)  Change  \
# 0    TWTR                       Twitter, Inc.            50.650  -0.330
# 1    TLRY                 Tilray Brands, Inc.             7.380   0.340
# 2     AMD        Advanced Micro Devices, Inc.           102.780  -4.040
# 3       F                  Ford Motor Company            15.250  -0.570
# 4    AAPL                          Apple Inc.           171.830  -3.230
# ..    ...                                 ...               ...     ...
# 95    LYG            Lloyds Banking Group plc             2.325  -0.045
# 96   ULCC       Frontier Group Holdings, Inc.            11.100  -0.820
# 97   HBAN  Huntington Bancshares Incorporated            14.120  -0.250
# 98   SIRI             Sirius XM Holdings Inc.             6.570  -0.050
# 99    DIS             The Walt Disney Company           131.470  -4.150
#
#     % Change       Volume  Avg Vol (3 month)      Market Cap  PE Ratio (TTM)
# ...

# %% [markdown]
# ## III. stats_valuation에서 per 가져오기

# %%
si.get_stats_valuation('MSFT')
# Out:
#                   Unnamed: 0 As of Date: 4/5/2022Current 12/31/2021 9/30/2021  \
# 0      Market Cap (intraday)                       2.36T      2.52T     2.12T
# 1           Enterprise Value                       2.30T      2.46T     2.05T
# 2               Trailing P/E                       33.54      37.62     35.02
# 3                Forward P/E                       29.15      36.90     31.55
# 4  PEG Ratio (5 yr expected)                        2.17       2.87      2.60
# 5          Price/Sales (ttm)                       12.90      14.48     12.76
# 6           Price/Book (mrq)                       14.76      16.60     14.91
# 7   Enterprise Value/Revenue                       12.44      47.46     45.34
# 8    Enterprise Value/EBITDA                       24.23      92.52     84.64
#
#   6/30/2021 3/31/2021
# 0     2.04T     1.78T
# 1     1.98T     1.71T
# 2     36.91     35.14
# 3     32.57     29.24
# 4      2.65      2.17
# 5     12.91     11.76
# 6     15.14     13.64
# ...
