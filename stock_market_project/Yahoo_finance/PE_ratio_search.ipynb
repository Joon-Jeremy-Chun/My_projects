# %% [markdown]
# ## 과제
# - per 불러오기
# - 모든 주식 per 테이블 만들기
# - per 분포표만들기

# %% [markdown]
# ## I. 페키지 셋팅

# %%
# !pip install yahoo_fin
# !pip install requests_html
# Out:
# ...
#      |████████████████████████████████| 81 kB 4.0 MB/s
# ...
#      |████████████████████████████████| 83 kB 1.8 MB/s
# ...
#      |████████████████████████████████| 112 kB 42.5 MB/s
# ...
#      |████████████████████████████████| 127 kB 64.0 MB/s
# ...
#   Created wheel for fake-useragent: filename=fake_useragent-0.1.11-py3-none-any.whl size=13502 sha256=7ae9a4bd1296468d58712ada63488c25ce04c1cc4e6a3aab0f2a907bb073fc7e
#   Stored in directory: /root/.cache/pip/wheels/ed/f7/62/50ab6c9a0b5567267ab76a9daa9d06315704209b2c5d032031
# ...
#   Created wheel for parse: filename=parse-1.19.0-py3-none-any.whl size=24591 sha256=0712c02e3b8050e10e1dbb5bbcf95cca6e05df059a84da04e77dda27f91bf1c0
#   Stored in directory: /root/.cache/pip/wheels/9c/aa/cc/f2228050ccb40f22144b073f15a2c84f11204f29fc0dce028e
# ...
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6066 sha256=04fda83dd9c7d2855b7e4eedbcd599fcd27c9c7a5725d066a18c203b7ac5d940
# ...

# %%
import yahoo_fin.stock_info as si
import pandas as pd

# %% [markdown]
# ## II.기타 필요자료

# %% [markdown]
# ### 매일 현재 상승 상위 100종목
# ### 하락 상위 100종목
# ### 거래량 100종목

# %%
si.get_day_gainers()
# Out:
#    Symbol                                              Name  Price (Intraday)  \
# 0   ICHBF                  Industrias CH, S. A. B. de C. V.            10.280
# 1   EGRNF                            China Evergrande Group             0.200
# 2   PHJMF                  PT Hanjaya Mandala Sampoerna Tbk             0.066
# 3     WFG                       West Fraser Timber Co. Ltd.            87.120
# 4    AVNT                                Avient Corporation            51.370
# 5     RCI                        Rogers Communications Inc.            62.270
# 6   DANOY                                       Danone S.A.            12.140
# 7   BKRKY            PT Bank Rakyat Indonesia (Persero) Tbk            16.770
# 8     OMC                                Omnicom Group Inc.            85.440
# 9   KUBTY                                Kubota Corporation            90.450
# 10    CAR                           Avis Budget Group, Inc.           300.930
# ...

# %%
si.get_day_losers()
# Out:
#    Symbol                            Name  Price (Intraday)  Change  % Change  \
# 0    NFLX                   Netflix, Inc.            227.51 -121.10    -34.74
# 1    RBLX              Roblox Corporation             36.60   -5.40    -12.85
# 2     BKR            Baker Hughes Company             32.99   -3.75    -10.21
# 3    SPOT         Spotify Technology S.A.            125.37  -12.04     -8.76
# 4   LGF-A  Lions Gate Entertainment Corp.             13.49   -1.35     -9.10
# ..    ...                             ...               ...     ...       ...
# 95     YY                       JOYY Inc.             38.42   -1.49     -3.73
# 96  LLKKF               Lake Resources NL              1.67   -0.08     -4.57
# 97   BILL         Bill.com Holdings, Inc.            198.00   -8.82     -4.26
# 98    GGR                     Gogoro Inc.              8.59   -0.35     -3.95
# 99   BRZE                     Braze, Inc.             45.15   -1.85     -3.93
#
# ...

# %%
si.get_day_most_active()
# Out:
#    Symbol                          Name  Price (Intraday)   Change  % Change  \
# 0    NFLX                 Netflix, Inc.           227.510 -121.100    -34.74
# 1       F            Ford Motor Company            16.190    0.040      0.25
# 2     AMD  Advanced Micro Devices, Inc.            95.750   -1.180     -1.22
# 3    DIDI              DiDi Global Inc.             1.968   -0.052     -2.57
# 4    AAPL                    Apple Inc.           166.760   -0.640     -0.38
# 5     WBD  Warner Bros. Discovery, Inc.            23.260   -1.230     -5.02
# 6     DIS       The Walt Disney Company           125.750   -6.150     -4.66
# 7     NIO                      NIO Inc.            18.810   -1.070     -5.36
# 8    TWTR                 Twitter, Inc.            45.560   -0.600     -1.30
# 9     BAC   Bank of America Corporation            40.130    0.560      1.43
# 10    AAL  American Airlines Group Inc.            19.590    0.000      0.01
# ...

# %% [markdown]
# ## III. stats_valuation에서 per 가져오기

# %%
si.get_stats_valuation('MSFT')
# Out:
#                   Unnamed: 0 As of Date: 4/18/2022Current 12/31/2021  \
# 0      Market Cap (intraday)                        2.10T      2.52T
# 1           Enterprise Value                        2.04T      2.46T
# 2               Trailing P/E                        29.80      37.62
# 3                Forward P/E                        25.77      36.90
# 4  PEG Ratio (5 yr expected)                         1.91       2.87
# 5          Price/Sales (ttm)                        11.46      14.48
# 6           Price/Book (mrq)                        13.11      16.60
# 7   Enterprise Value/Revenue                        11.01      47.46
# 8    Enterprise Value/EBITDA                        21.46      92.52
#
#   9/30/2021 6/30/2021 3/31/2021
# 0     2.12T     2.04T     1.78T
# 1     2.05T     1.98T     1.71T
# 2     35.02     36.91     35.14
# 3     31.55     32.57     29.24
# 4      2.60      2.65      2.17
# 5     12.76     12.91     11.76
# 6     14.91     15.14     13.64
# ...

# %%
a = si.get_analysts_info('MSFT')
print(a)

# %% [markdown]
# #IV.for문으로 여러 회사 확인하기

# %%
#Semiconductor SOXX ETF holdings (top 10)
soxx_etf_holdings = ['INTC','AVGO','TXN','NVDA','QCOM','AMAT','MU','LRCX','KLAC'] #'TSMC (ADR) fail to recall

# %%
soxx_etf_holdings
# Out:
# ['INTC', 'AVGO', 'TXN', 'NVDA', 'QCOM', 'AMAT', 'MU', 'LRCX', 'KLAC']

# %%
for i in soxx_etf_holdings:
 print( i ,si.get_stats_valuation(i))
# Out:
# INTC                   Unnamed: 0 As of Date: 4/18/2022Current 12/31/2021  \
# 0      Market Cap (intraday)                      186.73B    209.60B
# 1           Enterprise Value                      196.42B    215.27B
# 2               Trailing P/E                         9.40      10.00
# 3                Forward P/E                        13.24      14.22
# 4  PEG Ratio (5 yr expected)                         2.65       2.85
# 5          Price/Sales (ttm)                         2.36       2.69
# 6           Price/Book (mrq)                         1.96       2.33
# 7   Enterprise Value/Revenue                         2.49      10.49
# 8    Enterprise Value/EBITDA                         5.76      25.62
#
#   9/30/2021 6/30/2021 3/31/2021
# 0   216.69B   227.76B   258.43B
# 1   227.24B   241.25B   270.94B
# 2     11.84     12.62     12.96
# 3     12.02     12.67     14.06
# 4      2.06      2.53      2.81
# 5      2.83      3.02      3.48
# 6      2.54      2.85      3.19
# ...

# %%
print (si.get_stats_valuation('MSFT'))
# Out:
#                   Unnamed: 0 As of Date: 4/18/2022Current 12/31/2021  \
# 0      Market Cap (intraday)                        2.10T      2.52T
# 1           Enterprise Value                        2.04T      2.46T
# 2               Trailing P/E                        29.80      37.62
# 3                Forward P/E                        25.77      36.90
# 4  PEG Ratio (5 yr expected)                         1.91       2.87
# 5          Price/Sales (ttm)                        11.46      14.48
# 6           Price/Book (mrq)                        13.11      16.60
# 7   Enterprise Value/Revenue                        11.01      47.46
# 8    Enterprise Value/EBITDA                        21.46      92.52
#
#   9/30/2021 6/30/2021 3/31/2021
# 0     2.12T     2.04T     1.78T
# 1     2.05T     1.98T     1.71T
# 2     35.02     36.91     35.14
# 3     31.55     32.57     29.24
# 4      2.60      2.65      2.17
# 5     12.76     12.91     11.76
# 6     14.91     15.14     13.64
# ...

# %%
si.get_stats_valuation('TSMC')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-25-ef806eedc190> in <module>()
# ----> 1 si.get_stats_valuation('TSMC')
#
# /usr/local/lib/python3.7/dist-packages/yahoo_fin/stock_info.py in get_stats_valuation(ticker, headers)
#     360
#     361
# --> 362     table = tables[0].reset_index(drop = True)
#     363
#     364     return table
#
# IndexError: list index out of range
