# %% [markdown]
# # Objectives
# - Recall Earnings Per Share(EPS)
# - Create the EPS **dataframe**
# - Create the EPS charts

# %% [markdown]
# Following Objectives
# - P/E = Shareprice / Earnings per share

# %% [markdown]
# ## I. Packages

# %%
# !pip install yahoo_fin
# !pip install requests_html
# Out:
# Collecting yahoo_fin
#   Downloading yahoo_fin-0.8.9.1-py3-none-any.whl (10 kB)
# Collecting feedparser
#   Downloading feedparser-6.0.8-py3-none-any.whl (81 kB)
#      |████████████████████████████████| 81 kB 3.8 MB/s
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from yahoo_fin) (1.3.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from yahoo_fin) (2.23.0)
# Collecting requests-html
#   Downloading requests_html-0.10.0-py3-none-any.whl (13 kB)
# Collecting sgmllib3k
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->yahoo_fin) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas->yahoo_fin) (1.21.6)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->yahoo_fin) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->yahoo_fin) (1.15.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->yahoo_fin) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->yahoo_fin) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->yahoo_fin) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->yahoo_fin) (1.24.3)
# Requirement already satisfied: bs4 in /usr/local/lib/python3.7/dist-packages (from requests-html->yahoo_fin) (0.0.1)
# Collecting pyquery
#   Downloading pyquery-1.4.3-py3-none-any.whl (22 kB)
# Collecting parse
#   Downloading parse-1.19.0.tar.gz (30 kB)
# Collecting fake-useragent
#   Downloading fake-useragent-0.1.11.tar.gz (13 kB)
# Collecting pyppeteer>=0.0.14
#   Downloading pyppeteer-1.0.2-py3-none-any.whl (83 kB)
#      |████████████████████████████████| 83 kB 1.7 MB/s
# Collecting w3lib
#   Downloading w3lib-1.22.0-py2.py3-none-any.whl (20 kB)
# Collecting pyee<9.0.0,>=8.1.0
#   Downloading pyee-8.2.2-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: importlib-metadata>=1.4 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (4.11.3)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (1.4.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (4.64.0)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 39.6 MB/s
# Collecting websockets<11.0,>=10.0
#   Downloading websockets-10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (112 kB)
#      |████████████████████████████████| 112 kB 58.8 MB/s
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html->yahoo_fin) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html->yahoo_fin) (4.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from bs4->requests-html->yahoo_fin) (4.6.3)
# Requirement already satisfied: lxml>=2.1 in /usr/local/lib/python3.7/dist-packages (from pyquery->requests-html->yahoo_fin) (4.2.6)
# Collecting cssselect>0.7.9
#   Downloading cssselect-1.1.0-py2.py3-none-any.whl (16 kB)
# Building wheels for collected packages: fake-useragent, parse, sgmllib3k
#   Building wheel for fake-useragent (setup.py) ... done
#   Created wheel for fake-useragent: filename=fake_useragent-0.1.11-py3-none-any.whl size=13502 sha256=5bc3e4e07bd00cb73997fd90c3aa4d6bdda1a9f181f90a8d94779223c4211fce
#   Stored in directory: /root/.cache/pip/wheels/ed/f7/62/50ab6c9a0b5567267ab76a9daa9d06315704209b2c5d032031
#   Building wheel for parse (setup.py) ... done
#   Created wheel for parse: filename=parse-1.19.0-py3-none-any.whl size=24591 sha256=152f86a75402367d013f5a15de17ccac0d4b79d0f566bea230c12ae4051b13a0
#   Stored in directory: /root/.cache/pip/wheels/9c/aa/cc/f2228050ccb40f22144b073f15a2c84f11204f29fc0dce028e
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6066 sha256=13dd5cb826da76bb5c20058c4b263a6092b27b781e35cf686394d7b6c849ea18
#   Stored in directory: /root/.cache/pip/wheels/73/ad/a4/0dff4a6ef231fc0dfa12ffbac2a36cebfdddfe059f50e019aa
# Successfully built fake-useragent parse sgmllib3k
# Installing collected packages: websockets, urllib3, pyee, cssselect, w3lib, sgmllib3k, pyquery, pyppeteer, parse, fake-useragent, requests-html, feedparser, yahoo-fin
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed cssselect-1.1.0 fake-useragent-0.1.11 feedparser-6.0.8 parse-1.19.0 pyee-8.2.2 pyppeteer-1.0.2 pyquery-1.4.3 requests-html-0.10.0 sgmllib3k-1.0.0 urllib3-1.25.11 w3lib-1.22.0 websockets-10.3 yahoo-fin-0.8.9.1
# Requirement already satisfied: requests_html in /usr/local/lib/python3.7/dist-packages (0.10.0)
# Requirement already satisfied: fake-useragent in /usr/local/lib/python3.7/dist-packages (from requests_html) (0.1.11)
# Requirement already satisfied: bs4 in /usr/local/lib/python3.7/dist-packages (from requests_html) (0.0.1)
# Requirement already satisfied: parse in /usr/local/lib/python3.7/dist-packages (from requests_html) (1.19.0)
# Requirement already satisfied: pyppeteer>=0.0.14 in /usr/local/lib/python3.7/dist-packages (from requests_html) (1.0.2)
# Requirement already satisfied: pyquery in /usr/local/lib/python3.7/dist-packages (from requests_html) (1.4.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from requests_html) (2.23.0)
# Requirement already satisfied: w3lib in /usr/local/lib/python3.7/dist-packages (from requests_html) (1.22.0)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests_html) (1.4.4)
# Requirement already satisfied: urllib3<2.0.0,>=1.25.8 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests_html) (1.25.11)
# Requirement already satisfied: pyee<9.0.0,>=8.1.0 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests_html) (8.2.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests_html) (4.64.0)
# Requirement already satisfied: certifi>=2021 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests_html) (2021.10.8)
# Requirement already satisfied: websockets<11.0,>=10.0 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests_html) (10.3)
# Requirement already satisfied: importlib-metadata>=1.4 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests_html) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests_html) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests_html) (4.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from bs4->requests_html) (4.6.3)
# Requirement already satisfied: cssselect>0.7.9 in /usr/local/lib/python3.7/dist-packages (from pyquery->requests_html) (1.1.0)
# Requirement already satisfied: lxml>=2.1 in /usr/local/lib/python3.7/dist-packages (from pyquery->requests_html) (4.2.6)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->requests_html) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->requests_html) (2.10)
# Requirement already satisfied: six>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from w3lib->requests_html) (1.15.0)

# %%
import yahoo_fin.stock_info as si
import pandas as pd

# %% [markdown]
# ## II.Other necessary materials

# %% [markdown]
# ### 매일 현재 상승 상위 100종목
# ### 하락 상위 100종목
# ### 거래량 100종목

# %%
si.get_day_gainers()
# Out:
#    Symbol                          Name  Price (Intraday)  Change  % Change  \
# 0   UNEGF   United Energy Group Limited            0.1210  0.0230     23.47
# 1     YMM  Full Truck Alliance Co. Ltd.            6.0300  1.0300     20.60
# 2   DLPTF       Liaoning Port Co., Ltd.            0.0938  0.0144     18.21
# 3    FRGE   Forge Global Holdings, Inc.           18.9000  2.5900     15.88
# 4    NUTX            Nutex Health, Inc.            9.4200  1.2800     15.72
# ..    ...                           ...               ...     ...       ...
# 86    MGP     MGM Growth Properties LLC           41.6400  1.2600      3.12
# 87   CVAC                  CureVac N.V.           17.0900  0.5100      3.08
# 88  HELFY                 HelloFresh SE           10.4800  0.3100      3.05
# 89     YY                     JOYY Inc.           39.5700  1.1700      3.05
# 90   BIDU                   Baidu, Inc.          124.1700  3.6200      3.00
#
#         Volume  Avg Vol (3 month)    Market Cap  PE Ratio (TTM)
# 0      39177.0             4073.0  3.181000e+09           17.29
# 1   11562000.0          7673000.0  6.684000e+09             NaN
# 2      19700.0              511.0  5.198000e+09            7.22
# 3    1721000.0          1293000.0  3.198000e+09             NaN
# 4   10315000.0          7686000.0  6.064000e+09             NaN
# ..         ...                ...           ...             ...
# 86   3587000.0          1038000.0  1.116600e+10           30.62
# 87    524066.0           512805.0  3.196000e+09             NaN
# 88     31692.0            33878.0  7.282000e+09           28.04
# 89    765444.0           923068.0  2.914000e+09             NaN
# 90   5516000.0          4426000.0  4.600900e+10           29.31
#
# [91 rows x 9 columns]

# %%
si.get_day_losers()
# Out:
#    Symbol                       Name  Price (Intraday)  Change  % Change  \
# 0   SMBMF        Sembcorp Marine Ltd              0.08   -0.02    -20.00
# 1   CBGPF   Close Brothers Group plc             13.94   -3.39    -19.57
# 2    VRSN             VeriSign, Inc.            178.69  -29.73    -14.26
# 3    AMZN           Amazon.com, Inc.           2485.63 -406.30    -14.05
# 4    TEAM  Atlassian Corporation Plc            224.83  -35.15    -13.52
# ..    ...                        ...               ...     ...       ...
# 95   FISV               Fiserv, Inc.             97.92   -6.82     -6.51
# 96    HCP            HashiCorp, Inc.             47.08   -3.27     -6.49
# 97   MELI         MercadoLibre, Inc.            973.63  -66.37     -6.38
# 98   RAMP    LiveRamp Holdings, Inc.             31.32   -2.13     -6.37
# 99   FTNT             Fortinet, Inc.            289.01  -19.64     -6.36
#
#         Volume  Avg Vol (3 month)     Market Cap  PE Ratio (TTM)
# 0      34009.0             9787.0   2511000000.0             NaN
# 1     104300.0             1709.0   2098000000.0            8.29
# 2    2316000.0           634208.0  19610000000.0           25.53
# 3   13633000.0          3863000.0         1.264T           38.35
# 4    4479000.0          1839000.0  56991000000.0             NaN
# ..         ...                ...            ...             ...
# 95   4687000.0          3640000.0  63527000000.0           49.21
# 96    844789.0          1127000.0   8638000000.0             NaN
# 97    544168.0           611383.0  49050000000.0          583.01
# 98    496366.0           469843.0   2135000000.0             NaN
# 99   1203000.0          1268000.0  46477000000.0           79.62
#
# [100 rows x 9 columns]

# %%
si.get_day_most_active()
# Out:
#    Symbol                          Name  Price (Intraday)  Change  % Change  \
# 0    AAPL                    Apple Inc.            157.65   -5.99     -3.66
# 1       F            Ford Motor Company             14.16   -0.46     -3.15
# 2     AMD  Advanced Micro Devices, Inc.             85.52   -4.12     -4.60
# 3    DIDI              DiDi Global Inc.              1.88    0.07      3.87
# 4    INTC             Intel Corporation             43.59   -3.25     -6.94
# ..    ...                           ...               ...     ...       ...
# 95    FTI                TechnipFMC plc              6.92   -0.63     -8.34
# 96   QCOM         QUALCOMM Incorporated            139.69   -8.50     -5.74
# 97   AMZN              Amazon.com, Inc.           2485.63 -406.30    -14.05
# 98    DAL         Delta Air Lines, Inc.             43.03   -1.30     -2.93
# 99     SQ                   Block, Inc.             99.54   -5.10     -4.87
#
#          Volume  Avg Vol (3 month)      Market Cap  PE Ratio (TTM)
# 0   131748000.0         88744000.0          2.573T           26.21
# 1    82610000.0         78392000.0   56920000000.0            3.18
# 2    82648000.0        102836000.0  139172000000.0           33.28
# 3    72896000.0         54318000.0    9068000000.0             NaN
# 4    70766000.0         36202000.0  178226000000.0            8.97
# ..          ...                ...             ...             ...
# 95   14003000.0         11091000.0    3129000000.0          266.15
# 96   13693000.0         11666000.0  156453000000.0           16.01
# 97   13633000.0          3863000.0          1.264T           38.35
# 98   13385000.0         16579000.0   27585000000.0           97.80
# 99   13248000.0         20793000.0   57772000000.0          301.64
#
# [100 rows x 9 columns]

# %% [markdown]
# ## III.  EPS recalling

# %% [markdown]
# ### 1) get_stats_valuation()
# - current PE ratio

# %%
si.get_stats_valuation('MSFT')
# Out:
#                   Unnamed: 0 As of Date: 4/30/2022Current 3/31/2022  \
# 0      Market Cap (intraday)                        2.08T     2.31T
# 1           Enterprise Value                        2.03T     2.25T
# 2               Trailing P/E                        28.97     32.83
# 3                Forward P/E                        25.77     28.57
# 4  PEG Ratio (5 yr expected)                         1.91      2.12
# 5          Price/Sales (ttm)                        10.89     12.63
# 6           Price/Book (mrq)                        12.74     14.42
# 7   Enterprise Value/Revenue                        10.55     45.50
# 8    Enterprise Value/EBITDA                        20.61     91.79
#
#   12/31/2021 9/30/2021 6/30/2021 3/31/2021
# 0      2.52T     2.12T     2.04T     1.78T
# 1      2.46T     2.05T     1.98T     1.71T
# 2      37.62     35.02     36.91     35.14
# 3      36.90     31.55     32.57     29.24
# 4       2.87      2.60      2.65      2.17
# 5      14.48     12.76     12.91     11.76
# 6      16.60     14.91     15.14     13.64
# 7      47.46     45.34     42.88     41.09
# 8      92.52     84.64     84.92     82.37

# %%
a = si.get_analysts_info('MSFT')
print(a)
# Out:
# {'Earnings Estimate':   Earnings Estimate  Current Qtr. (Jun 2022)  Next Qtr. (Sep 2022)  \
# 0   No. of Analysts                    28.00                 26.00
# 1     Avg. Estimate                     2.33                  2.50
# 2      Low Estimate                     2.29                  2.28
# 3     High Estimate                     2.39                  2.61
# 4      Year Ago EPS                     2.17                  2.27
#
#    Current Year (2022)  Next Year (2023)
# 0                23.00             33.00
# 1                 9.32             10.75
# 2                 9.27              9.57
# 3                 9.43             11.29
# 4                 8.05              9.32  , 'Revenue Estimate':           Revenue Estimate Current Qtr. (Jun 2022) Next Qtr. (Sep 2022)  \
# 0          No. of Analysts                      26                   22
# 1            Avg. Estimate                  52.89B               51.98B
# 2             Low Estimate                  52.65B               50.57B
# 3            High Estimate                  53.41B               53.44B
# 4           Year Ago Sales                  46.15B                  NaN
# 5  Sales Growth (year/est)                  14.60%                  NaN
#
#   Current Year (2022) Next Year (2023)
# 0                  32               33
# 1             199.32B          227.83B
# 2             198.31B          212.32B
# 3             200.13B          236.41B
# 4             168.09B          199.32B
# 5              18.60%           14.30%  , 'Earnings History':   Earnings History 6/29/2021 9/29/2021 12/30/2021 3/30/2022
# 0         EPS Est.      1.92      2.07       2.31      2.18
# 1       EPS Actual      2.17      2.27       2.48      2.22
# 2       Difference      0.25       0.2       0.17      0.04
# 3       Surprise %    13.00%     9.70%      7.40%     1.80%, 'EPS Trend':           EPS Trend  Current Qtr. (Jun 2022)  Next Qtr. (Sep 2022)  \
# 0  Current Estimate                     2.33                  2.50
# 1        7 Days Ago                     2.35                  2.51
# 2       30 Days Ago                     2.36                  2.51
# 3       60 Days Ago                     2.36                  2.51
# 4       90 Days Ago                     2.36                  2.51
#
#    Current Year (2022)  Next Year (2023)
# 0                 9.32             10.75
# 1                 9.33             10.73
# 2                 9.34             10.74
# 3                 9.35             10.75
# 4                 9.34             10.75  , 'EPS Revisions':        EPS Revisions  Current Qtr. (Jun 2022)  Next Qtr. (Sep 2022)  \
# 0     Up Last 7 Days                      NaN                   8.0
# 1    Up Last 30 Days                      7.0                   9.0
# 2   Down Last 7 Days                      NaN                   NaN
# 3  Down Last 30 Days                      1.0                  11.0
#
#    Current Year (2022)  Next Year (2023)
# 0                  1.0               2.0
# 1                 12.0              19.0
# 2                  NaN               NaN
# 3                  2.0               1.0  , 'Growth Estimates':            Growth Estimates    MSFT  Industry  Sector(s)  S&P 500
# 0              Current Qtr.   7.40%       NaN        NaN      NaN
# 1                 Next Qtr.  10.10%       NaN        NaN      NaN
# 2              Current Year  15.80%       NaN        NaN      NaN
# 3                 Next Year  15.30%       NaN        NaN      NaN
# 4  Next 5 Years (per annum)  16.23%       NaN        NaN      NaN
# 5  Past 5 Years (per annum)  18.17%       NaN        NaN      NaN}

# %% [markdown]
# ### 2) get_next_earnings_date()
# - It will returns the upcoming earnings date

# %%
si.get_next_earnings_date('MSFT')
# Out:
# datetime.datetime(2022, 7, 25, 10, 59)

# %%
si.get_next_earnings_date('AAPL')
# Out:
# datetime.datetime(2022, 7, 25, 20, 0)

# %% [markdown]
# ### 3) get_earnings()
# - the command will recalls the earnings of campany

# %%
si.get_earnings('MSFT')
# Out:
# {'quarterly_results':      date  actual  estimate
#  0  2Q2021    2.17      1.92
#  1  3Q2021    2.27      2.07
#  2  4Q2021    2.48      2.31
#  3  1Q2022    2.22      2.18,
#  'quarterly_revenue_earnings':      date      revenue     earnings
#  0  1Q2021  41706000000  15457000000
#  1  2Q2021  46152000000  16458000000
#  2  3Q2021  45317000000  20505000000
#  3  4Q2021  51728000000  18765000000,
#  'yearly_revenue_earnings':    date       revenue     earnings
#  0  2018  110360000000  16571000000
#  1  2019  125843000000  39240000000
#  2  2020  143015000000  44281000000
#  3  2021  168088000000  61271000000}

# %% [markdown]
# ### 4)get_earnings_history()
# - recalls the company's earnings data
# - data frame fromat -> dictionary in list
# - X[n]['key'] n=0 the most future one

# %%
TSLA_per_his = si.get_earnings_history('TSLA')

# %%
MSFT_per_his = si.get_earnings_history('MSFT')

# %%
print('eps(actual)   :' , MSFT_per_his[99]['epsactual'])
print('eps(estimate) :' , MSFT_per_his[99]['epsestimate'])
print('date :', MSFT_per_his[99]['startdatetime'],MSFT_per_his[99]['timeZoneShortName'])
# Out:
# eps(actual)   : 0.11
# eps(estimate) : 0.1
# date : 1998-01-21T05:00:00.000Z EST

# %%
print(len(MSFT_per_his))
print(len(TSLA_per_his))
# Out:
# 100
# 49

# %%
range(len(TSLA_per_his))
# Out:
# range(0, 49)

# %%
for i in range(len(MSFT_per_his)):
  print('eps(actual)   :' , MSFT_per_his[i]['epsactual'])
  print('eps(estimate) :' , MSFT_per_his[i]['epsestimate'])
  print('date :', MSFT_per_his[i]['startdatetime'],MSFT_per_his[i]['timeZoneShortName'])
  print('\n')
# Out:
# eps(actual)   : None
# eps(estimate) : None
# date : 2022-10-24T10:59:00.000Z EDT
#
#
# eps(actual)   : None
# eps(estimate) : 2.33
# date : 2022-07-25T10:59:00.000Z EDT
#
#
# eps(actual)   : 2.22
# eps(estimate) : 2.19
# date : 2022-04-26T16:04:00.000Z EDT
#
#
# eps(actual)   : 2.48
# eps(estimate) : 2.31
# date : 2022-01-25T16:04:00.000Z EST
#
#
# eps(actual)   : 2.27
# eps(estimate) : 2.08
# date : 2021-10-26T16:05:00.000Z EDT
#
#
# eps(actual)   : 2.17
# eps(estimate) : 1.92
# date : 2021-07-27T16:02:00.000Z EDT
#
#
# eps(actual)   : 2.03
# eps(estimate) : 1.78
# date : 2021-04-27T16:03:00.000Z EDT
#
#
# eps(actual)   : 2.03
# eps(estimate) : 1.64
# date : 2021-01-26T16:04:00.000Z EST
#
#
# eps(actual)   : 1.82
# eps(estimate) : 1.54
# date : 2020-10-27T16:13:00.000Z EDT
#
#
# eps(actual)   : 1.46
# eps(estimate) : 1.34
# date : 2020-07-22T16:03:00.000Z EDT
#
#
# eps(actual)   : 1.4
# eps(estimate) : 1.26
# date : 2020-04-29T16:03:00.000Z EDT
#
#
# eps(actual)   : 1.51
# eps(estimate) : 1.32
# date : 2020-01-29T16:05:00.000Z EST
#
#
# eps(actual)   : 1.38
# eps(estimate) : 1.25
# date : 2019-10-23T16:08:00.000Z EDT
#
#
# eps(actual)   : 1.37
# eps(estimate) : 1.21
# date : 2019-07-18T16:07:00.000Z EDT
#
#
# eps(actual)   : 1.14
# eps(estimate) : 1
# date : 2019-04-24T16:07:00.000Z EDT
#
#
# eps(actual)   : 1.1
# eps(estimate) : 1.09
# date : 2019-01-30T16:06:00.000Z EST
#
#
# eps(actual)   : 1.14
# eps(estimate) : 0.96
# date : 2018-10-24T16:07:00.000Z EDT
#
#
# eps(actual)   : 1.13
# eps(estimate) : 1.08
# date : 2018-07-19T16:05:00.000Z EDT
#
#
# eps(actual)   : 0.95
# eps(estimate) : 0.85
# date : 2018-04-26T16:04:00.000Z EDT
#
#
# eps(actual)   : 0.96
# eps(estimate) : 0.87
# date : 2018-01-31T16:05:00.000Z EST
#
#
# eps(actual)   : 0.84
# eps(estimate) : 0.72
# date : 2017-10-26T16:02:00.000Z EDT
#
#
# eps(actual)   : 0.98
# eps(estimate) : 0.71
# date : 2017-07-20T16:06:00.000Z EDT
#
#
# eps(actual)   : 0.73
# eps(estimate) : 0.7
# date : 2017-04-27T16:05:00.000Z EDT
#
#
# eps(actual)   : 0.83
# eps(estimate) : 0.79
# date : 2017-01-26T16:09:00.000Z EST
#
#
# eps(actual)   : 0.76
# eps(estimate) : 0.68
# date : 2016-10-20T16:05:00.000Z EDT
#
#
# eps(actual)   : 0.69
# eps(estimate) : 0.58
# date : 2016-07-19T16:05:00.000Z EDT
#
#
# eps(actual)   : 0.62
# eps(estimate) : 0.64
# date : 2016-04-21T16:05:00.000Z EDT
#
#
# eps(actual)   : 0.78
# eps(estimate) : 0.71
# date : 2016-01-28T16:06:00.000Z EST
#
#
# eps(actual)   : 0.67
# eps(estimate) : 0.59
# date : 2015-10-22T16:05:00.000Z EDT
#
#
# eps(actual)   : 0.6
# eps(estimate) : 0.56
# date : 2015-07-21T16:05:00.000Z EDT
#
#
# eps(actual)   : 0.61
# eps(estimate) : 0.51
# date : 2015-04-23T16:02:00.000Z EDT
#
#
# eps(actual)   : 0.71
# eps(estimate) : 0.71
# date : 2015-01-26T16:10:00.000Z EST
#
#
# eps(actual)   : 0.54
# eps(estimate) : 0.49
# date : 2014-10-23T16:02:00.000Z EDT
#
#
# eps(actual)   : 0.55
# eps(estimate) : 0.6
# date : 2014-07-22T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.68
# eps(estimate) : 0.63
# date : 2014-04-24T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.78
# eps(estimate) : 0.68
# date : 2014-01-23T05:00:00.000Z EST
#
#
# eps(actual)   : 0.62
# eps(estimate) : 0.54
# date : 2013-10-24T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.66
# eps(estimate) : 0.75
# date : 2013-07-18T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.72
# eps(estimate) : 0.68
# date : 2013-04-18T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.76
# eps(estimate) : 0.75
# date : 2013-01-24T05:00:00.000Z EST
#
#
# eps(actual)   : 0.53
# eps(estimate) : 0.56
# date : 2012-10-18T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.67
# eps(estimate) : 0.62
# date : 2012-07-19T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.6
# eps(estimate) : 0.57
# date : 2012-04-19T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.78
# eps(estimate) : 0.76
# date : 2012-01-19T05:00:00.000Z EST
#
#
# eps(actual)   : 0.68
# eps(estimate) : 0.68
# date : 2011-10-20T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.69
# eps(estimate) : 0.58
# date : 2011-07-21T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.61
# eps(estimate) : 0.56
# date : 2011-04-28T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.77
# eps(estimate) : 0.68
# date : 2011-01-27T05:00:00.000Z EST
#
#
# eps(actual)   : 0.62
# eps(estimate) : 0.55
# date : 2010-10-28T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.51
# eps(estimate) : 0.46
# date : 2010-07-22T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.45
# eps(estimate) : 0.42
# date : 2010-04-22T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.74
# eps(estimate) : 0.59
# date : 2010-01-28T05:00:00.000Z EST
#
#
# eps(actual)   : 0.4
# eps(estimate) : 0.32
# date : 2009-10-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.36
# eps(estimate) : 0.36
# date : 2009-07-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.39
# eps(estimate) : 0.39
# date : 2009-04-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.47
# eps(estimate) : 0.49
# date : 2009-01-22T05:00:00.000Z EST
#
#
# eps(actual)   : 0.48
# eps(estimate) : 0.47
# date : 2008-10-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.46
# eps(estimate) : 0.47
# date : 2008-07-17T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.47
# eps(estimate) : 0.44
# date : 2008-04-24T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.5
# eps(estimate) : 0.46
# date : 2008-01-24T05:00:00.000Z EST
#
#
# eps(actual)   : 0.45
# eps(estimate) : 0.39
# date : 2007-10-25T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.39
# eps(estimate) : 0.39
# date : 2007-07-19T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.49
# eps(estimate) : 0.46
# date : 2007-04-26T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.26
# eps(estimate) : 0.23
# date : 2007-01-25T05:00:00.000Z EST
#
#
# eps(actual)   : 0.35
# eps(estimate) : 0.31
# date : 2006-10-26T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.31
# eps(estimate) : 0.3
# date : 2006-07-20T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.32
# eps(estimate) : 0.33
# date : 2006-04-27T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.33
# eps(estimate) : 0.33
# date : 2006-01-26T05:00:00.000Z EST
#
#
# eps(actual)   : 0.31
# eps(estimate) : 0.3
# date : 2005-10-27T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.32
# eps(estimate) : 0.31
# date : 2005-07-21T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.32
# eps(estimate) : 0.32
# date : 2005-04-28T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.35
# eps(estimate) : 0.33
# date : 2005-01-27T05:00:00.000Z EST
#
#
# eps(actual)   : 0.31
# eps(estimate) : 0.3
# date : 2004-10-21T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.28
# eps(estimate) : 0.29
# date : 2004-07-22T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.34
# eps(estimate) : 0.29
# date : 2004-04-22T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.34
# eps(estimate) : 0.3
# date : 2004-01-22T05:00:00.000Z EST
#
#
# eps(actual)   : 0.3
# eps(estimate) : 0.29
# date : 2003-10-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.23
# eps(estimate) : 0.24
# date : 2003-07-17T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.27
# eps(estimate) : 0.24
# date : 2003-04-15T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.27
# eps(estimate) : 0.23
# date : 2003-01-16T05:00:00.000Z EST
#
#
# eps(actual)   : 0.28
# eps(estimate) : 0.21
# date : 2002-10-17T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.21
# eps(estimate) : 0.21
# date : 2002-07-18T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.25
# eps(estimate) : 0.25
# date : 2002-04-18T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.25
# eps(estimate) : 0.21
# date : 2002-01-17T05:00:00.000Z EST
#
#
# eps(actual)   : 0.22
# eps(estimate) : 0.2
# date : 2001-10-18T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.22
# eps(estimate) : 0.21
# date : 2001-07-19T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.22
# eps(estimate) : 0.21
# date : 2001-04-19T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.24
# eps(estimate) : 0.23
# date : 2001-01-18T05:00:00.000Z EST
#
#
# eps(actual)   : 0.23
# eps(estimate) : 0.21
# date : 2000-10-18T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.22
# eps(estimate) : 0.21
# date : 2000-07-18T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.22
# eps(estimate) : 0.2
# date : 2000-04-20T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.24
# eps(estimate) : 0.21
# date : 2000-01-18T05:00:00.000Z EST
#
#
# eps(actual)   : 0.19
# eps(estimate) : 0.17
# date : 1999-10-19T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.2
# eps(estimate) : 0.18
# date : 1999-07-19T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.19
# eps(estimate) : 0.16
# date : 1999-04-20T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.18
# eps(estimate) : 0.15
# date : 1999-01-19T05:00:00.000Z EST
#
#
# eps(actual)   : 0.14
# eps(estimate) : 0.12
# date : 1998-10-20T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.13
# eps(estimate) : 0.12
# date : 1998-07-16T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.13
# eps(estimate) : 0.12
# date : 1998-04-22T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.11
# eps(estimate) : 0.1
# date : 1998-01-21T05:00:00.000Z EST

# %%
si.get_earnings_history('MSFT')
# Out:
# [{'companyshortname': 'Microsoft Corp',
#   'epsactual': None,
#   'epsestimate': None,
#   'epssurprisepct': None,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2022-10-24T10:59:00.000Z',
#   'startdatetimetype': 'TNS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corp',
#   'epsactual': None,
#   'epsestimate': 2.33,
#   'epssurprisepct': None,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2022-07-25T10:59:00.000Z',
#   'startdatetimetype': 'TNS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 2.22,
#   'epsestimate': 2.19,
#   'epssurprisepct': 1.6,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2022-04-26T16:04:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 2.48,
#   'epsestimate': 2.31,
#   'epssurprisepct': 7.27,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2022-01-25T16:04:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 2.27,
#   'epsestimate': 2.08,
#   'epssurprisepct': 9.4,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2021-10-26T16:05:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 2.17,
#   'epsestimate': 1.92,
#   'epssurprisepct': 13.26,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2021-07-27T16:02:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 2.03,
#   'epsestimate': 1.78,
#   'epssurprisepct': 14.11,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2021-04-27T16:03:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 2.03,
#   'epsestimate': 1.64,
#   'epssurprisepct': 23.63,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2021-01-26T16:04:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 1.82,
#   'epsestimate': 1.54,
#   'epssurprisepct': 17.88,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2020-10-27T16:13:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 1.46,
#   'epsestimate': 1.34,
#   'epssurprisepct': 8.71,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2020-07-22T16:03:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 1.4,
#   'epsestimate': 1.26,
#   'epssurprisepct': 10.67,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2020-04-29T16:03:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 1.51,
#   'epsestimate': 1.32,
#   'epssurprisepct': 14.48,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2020-01-29T16:05:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 1.38,
#   'epsestimate': 1.25,
#   'epssurprisepct': 10.84,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2019-10-23T16:08:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 1.37,
#   'epsestimate': 1.21,
#   'epssurprisepct': 12.94,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2019-07-18T16:07:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 1.14,
#   'epsestimate': 1,
#   'epssurprisepct': 14.11,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2019-04-24T16:07:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 1.1,
#   'epsestimate': 1.09,
#   'epssurprisepct': 0.73,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2019-01-30T16:06:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 1.14,
#   'epsestimate': 0.96,
#   'epssurprisepct': 18.38,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2018-10-24T16:07:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 1.13,
#   'epsestimate': 1.08,
#   'epssurprisepct': 5.02,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2018-07-19T16:05:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.95,
#   'epsestimate': 0.85,
#   'epssurprisepct': 11.9,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2018-04-26T16:04:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.96,
#   'epsestimate': 0.87,
#   'epssurprisepct': 10.98,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2018-01-31T16:05:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.84,
#   'epsestimate': 0.72,
#   'epssurprisepct': 16.5,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2017-10-26T16:02:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.98,
#   'epsestimate': 0.71,
#   'epssurprisepct': 39.01,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2017-07-20T16:06:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.73,
#   'epsestimate': 0.7,
#   'epssurprisepct': 4.73,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2017-04-27T16:05:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.83,
#   'epsestimate': 0.79,
#   'epssurprisepct': 4.93,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2017-01-26T16:09:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.76,
#   'epsestimate': 0.68,
#   'epssurprisepct': 11.27,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2016-10-20T16:05:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.69,
#   'epsestimate': 0.58,
#   'epssurprisepct': 18.76,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2016-07-19T16:05:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.62,
#   'epsestimate': 0.64,
#   'epssurprisepct': -2.67,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2016-04-21T16:05:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.78,
#   'epsestimate': 0.71,
#   'epssurprisepct': 9.4,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2016-01-28T16:06:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.67,
#   'epsestimate': 0.59,
#   'epssurprisepct': 14.33,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2015-10-22T16:05:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.6,
#   'epsestimate': 0.56,
#   'epssurprisepct': 6.57,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2015-07-21T16:05:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.61,
#   'epsestimate': 0.51,
#   'epssurprisepct': 20.55,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2015-04-23T16:02:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.71,
#   'epsestimate': 0.71,
#   'epssurprisepct': -0.42,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2015-01-26T16:10:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.54,
#   'epsestimate': 0.49,
#   'epssurprisepct': 11.11,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2014-10-23T16:02:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.55,
#   'epsestimate': 0.6,
#   'epssurprisepct': -8.65,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2014-07-22T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.68,
#   'epsestimate': 0.63,
#   'epssurprisepct': 8.02,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2014-04-24T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.78,
#   'epsestimate': 0.68,
#   'epssurprisepct': 14.83,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2014-01-23T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.62,
#   'epsestimate': 0.54,
#   'epssurprisepct': 15.1,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2013-10-24T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.66,
#   'epsestimate': 0.75,
#   'epssurprisepct': -11.96,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2013-07-18T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.72,
#   'epsestimate': 0.68,
#   'epssurprisepct': 5.97,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2013-04-18T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.76,
#   'epsestimate': 0.75,
#   'epssurprisepct': 1.93,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2013-01-24T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.53,
#   'epsestimate': 0.56,
#   'epssurprisepct': -5.47,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2012-10-18T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.67,
#   'epsestimate': 0.62,
#   'epssurprisepct': 8.48,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2012-07-19T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.6,
#   'epsestimate': 0.57,
#   'epssurprisepct': 4.38,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2012-04-19T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.78,
#   'epsestimate': 0.76,
#   'epssurprisepct': 2.93,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2012-01-19T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.68,
#   'epsestimate': 0.68,
#   'epssurprisepct': 0.38,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2011-10-20T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.69,
#   'epsestimate': 0.58,
#   'epssurprisepct': 19.88,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2011-07-21T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.61,
#   'epsestimate': 0.56,
#   'epssurprisepct': 9.74,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2011-04-28T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.77,
#   'epsestimate': 0.68,
#   'epssurprisepct': 12.57,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2011-01-27T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.62,
#   'epsestimate': 0.55,
#   'epssurprisepct': 12.98,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2010-10-28T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.51,
#   'epsestimate': 0.46,
#   'epssurprisepct': 9.82,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2010-07-22T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.45,
#   'epsestimate': 0.42,
#   'epssurprisepct': 6.95,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2010-04-22T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.74,
#   'epsestimate': 0.59,
#   'epssurprisepct': 24.79,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2010-01-28T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.4,
#   'epsestimate': 0.32,
#   'epssurprisepct': 25.76,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2009-10-23T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.36,
#   'epsestimate': 0.36,
#   'epssurprisepct': 0.22,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2009-07-23T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.39,
#   'epsestimate': 0.39,
#   'epssurprisepct': 0.26,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2009-04-23T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.47,
#   'epsestimate': 0.49,
#   'epssurprisepct': -4.84,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2009-01-22T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.48,
#   'epsestimate': 0.47,
#   'epssurprisepct': 1.84,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2008-10-23T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.46,
#   'epsestimate': 0.47,
#   'epssurprisepct': -2.13,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2008-07-17T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.47,
#   'epsestimate': 0.44,
#   'epssurprisepct': 6.74,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2008-04-24T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.5,
#   'epsestimate': 0.46,
#   'epssurprisepct': 9.33,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2008-01-24T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.45,
#   'epsestimate': 0.39,
#   'epssurprisepct': 15.38,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2007-10-25T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.39,
#   'epsestimate': 0.39,
#   'epssurprisepct': 0.3,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2007-07-19T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.49,
#   'epsestimate': 0.46,
#   'epssurprisepct': 6.86,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2007-04-26T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.26,
#   'epsestimate': 0.23,
#   'epssurprisepct': 11.48,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2007-01-25T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.35,
#   'epsestimate': 0.31,
#   'epssurprisepct': 13.02,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2006-10-26T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.31,
#   'epsestimate': 0.3,
#   'epssurprisepct': 2.63,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2006-07-20T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.32,
#   'epsestimate': 0.33,
#   'epssurprisepct': -2.93,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2006-04-27T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.33,
#   'epsestimate': 0.33,
#   'epssurprisepct': -0.08,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2006-01-26T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.31,
#   'epsestimate': 0.3,
#   'epssurprisepct': 4.14,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2005-10-27T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.32,
#   'epsestimate': 0.31,
#   'epssurprisepct': 2.4,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2005-07-21T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.32,
#   'epsestimate': 0.32,
#   'epssurprisepct': 0.93,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2005-04-28T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.35,
#   'epsestimate': 0.33,
#   'epssurprisepct': 6.81,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2005-01-27T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.31,
#   'epsestimate': 0.3,
#   'epssurprisepct': 2.89,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2004-10-21T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.28,
#   'epsestimate': 0.29,
#   'epssurprisepct': -1.87,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2004-07-22T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.34,
#   'epsestimate': 0.29,
#   'epssurprisepct': 19.1,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2004-04-22T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.34,
#   'epsestimate': 0.3,
#   'epssurprisepct': 13.46,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2004-01-22T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.3,
#   'epsestimate': 0.29,
#   'epssurprisepct': 3.56,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2003-10-23T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.23,
#   'epsestimate': 0.24,
#   'epssurprisepct': -2.84,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2003-07-17T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.27,
#   'epsestimate': 0.24,
#   'epssurprisepct': 13.16,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2003-04-15T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.27,
#   'epsestimate': 0.23,
#   'epssurprisepct': 14.22,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2003-01-16T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.28,
#   'epsestimate': 0.21,
#   'epssurprisepct': 29.06,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2002-10-17T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.21,
#   'epsestimate': 0.21,
#   'epssurprisepct': 0.8,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2002-07-18T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.25,
#   'epsestimate': 0.25,
#   'epssurprisepct': -3.56,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2002-04-18T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.25,
#   'epsestimate': 0.21,
#   'epssurprisepct': 15.25,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2002-01-17T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.22,
#   'epsestimate': 0.2,
#   'epssurprisepct': 9.5,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2001-10-18T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.22,
#   'epsestimate': 0.21,
#   'epssurprisepct': 0.75,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2001-07-19T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.22,
#   'epsestimate': 0.21,
#   'epssurprisepct': 5.33,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2001-04-19T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.24,
#   'epsestimate': 0.23,
#   'epssurprisepct': 1.44,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2001-01-18T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.23,
#   'epsestimate': 0.21,
#   'epssurprisepct': 11.48,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2000-10-18T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.22,
#   'epsestimate': 0.21,
#   'epssurprisepct': 5.81,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2000-07-18T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.22,
#   'epsestimate': 0.2,
#   'epssurprisepct': 5.27,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2000-04-20T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.24,
#   'epsestimate': 0.21,
#   'epssurprisepct': 11.27,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2000-01-18T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.19,
#   'epsestimate': 0.17,
#   'epssurprisepct': 10.38,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '1999-10-19T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.2,
#   'epsestimate': 0.18,
#   'epssurprisepct': 12.03,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '1999-07-19T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.19,
#   'epsestimate': 0.16,
#   'epssurprisepct': 21.78,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '1999-04-20T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.18,
#   'epsestimate': 0.15,
#   'epssurprisepct': 23.47,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '1999-01-19T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.14,
#   'epsestimate': 0.12,
#   'epssurprisepct': 13.84,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '1998-10-20T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.13,
#   'epsestimate': 0.12,
#   'epssurprisepct': 4.99,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '1998-07-16T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.13,
#   'epsestimate': 0.12,
#   'epssurprisepct': 5.72,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '1998-04-22T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.11,
#   'epsestimate': 0.1,
#   'epssurprisepct': 3.85,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '1998-01-21T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'}]

# %% [markdown]
# ##IV.Checking multiple companies by using 'for' statment

# %%
#Semiconductor SOXX ETF holdings (top 10)
soxx_etf_holdings = ['INTC','AVGO','TXN','NVDA','QCOM','AMAT','MU','LRCX','KLAC'] #'TSMC (ADR) fail to recall

# %%
soxx_etf_holdings
# Out:
# ['INTC', 'AVGO', 'TXN', 'NVDA', 'QCOM', 'AMAT', 'MU', 'LRCX', 'KLAC']

# %% [markdown]
# ### 1) To get the current PE ratio by 'for' statement

# %%
for i in soxx_etf_holdings:
 print( i ,si.get_stats_valuation(i))
# Out:
# INTC                   Unnamed: 0 As of Date: 5/1/2022Current 3/31/2022 12/31/2021  \
# 0      Market Cap (intraday)                     178.23B   202.64B    209.60B
# 1           Enterprise Value                     187.91B   212.32B    215.27B
# 2               Trailing P/E                        8.97     10.20      10.00
# 3                Forward P/E                       12.58       NaN      14.22
# 4  PEG Ratio (5 yr expected)                        2.52      2.87       2.85
# 5          Price/Sales (ttm)                        2.26       NaN       2.69
# 6           Price/Book (mrq)                        1.87      2.12       2.33
# 7   Enterprise Value/Revenue                        2.42     11.57      10.49
# 8    Enterprise Value/EBITDA                        5.60     32.78      25.62
#
#   9/30/2021 6/30/2021 3/31/2021
# 0   216.69B   227.76B   258.43B
# 1   227.24B   241.25B   270.94B
# 2     11.84     12.62     12.96
# 3     12.02     12.67     14.06
# 4      2.06      2.53      2.81
# 5      2.83      3.02      3.48
# 6      2.54      2.85      3.19
# 7     11.84     12.29     13.77
# 8     22.81     27.63     38.72
# AVGO                   Unnamed: 0 As of Date: 5/1/2022Current 1/31/2022 10/31/2021  \
# 0      Market Cap (intraday)                     226.35B   240.21B    218.84B
# 1           Enterprise Value                     255.66B   267.80B    248.22B
# 2               Trailing P/E                       31.61     39.06      39.38
# 3                Forward P/E                       15.77     17.79      17.39
# 4  PEG Ratio (5 yr expected)                        1.11      1.11       1.21
# 5          Price/Sales (ttm)                        8.35      9.16       8.58
# 6           Price/Book (mrq)                        9.85      9.62       9.02
# 7   Enterprise Value/Revenue                        8.97     34.75      33.51
# 8    Enterprise Value/EBITDA                       16.40     61.13      60.48
#
#   7/31/2021 4/30/2021
# 0   199.14B   186.27B
# 1   230.09B   218.67B
# 2     45.11     52.74
# 3     16.26     16.95
# 4      1.14      1.25
# 5      8.09      7.82
# 6      8.32      7.77
# 7     33.95     33.08
# 8     63.14     63.27
# TXN                   Unnamed: 0 As of Date: 4/30/2022Current 3/31/2022  \
# 0      Market Cap (intraday)                      156.99B   169.17B
# 1           Enterprise Value                      154.91B   167.55B
# 2               Trailing P/E                        19.48     22.21
# 3                Forward P/E                        18.90     19.96
# 4  PEG Ratio (5 yr expected)                         2.39      2.41
# 5          Price/Sales (ttm)                         8.40      9.36
# 6           Price/Book (mrq)                        11.20     12.69
# 7   Enterprise Value/Revenue                         8.17     34.16
# 8    Enterprise Value/EBITDA                        14.58     60.01
#
#   12/31/2021 9/30/2021 6/30/2021 3/31/2021
# 0    174.15B   177.49B   177.51B   174.48B
# 1    172.10B   176.35B   177.07B   174.96B
# 2      24.19     26.81     29.14     31.66
# 3      22.47     23.31     26.95     28.82
# 4       2.11      2.13      2.49      2.87
# 5      10.02     10.70     11.61     12.19
# 6      14.33     15.91     17.46     18.99
# 7      35.62     37.98     38.66     40.79
# 8      63.16     68.54     69.91     78.60
# NVDA                   Unnamed: 0 As of Date: 4/30/2022Current 1/31/2022  \
# 0      Market Cap (intraday)                      540.23B   613.62B
# 1           Enterprise Value                      530.71B   606.15B
# 2               Trailing P/E                        48.17     75.46
# 3                Forward P/E                        33.22     47.62
# 4  PEG Ratio (5 yr expected)                         2.44      2.61
# 5          Price/Sales (ttm)                        17.47     25.55
# 6           Price/Book (mrq)                        17.45     25.78
# 7   Enterprise Value/Revenue                        19.72     79.31
# 8    Enterprise Value/EBITDA                        46.75    187.37
#
#   10/31/2021 7/31/2021 4/30/2021
# 0    639.17B   485.92B   373.67B
# 1    632.31B   480.99B   369.82B
# 2      91.47     92.19     87.01
# 3      54.95     50.00     43.48
# 4       3.84      3.50      3.73
# 5      29.52     25.54     22.61
# 6      30.25     25.88     22.12
# 7      89.02     73.92     65.33
# 8     210.91    175.54    155.52
# QCOM                   Unnamed: 0 As of Date: 5/1/2022Current 3/31/2022 12/31/2021  \
# 0      Market Cap (intraday)                     156.45B       NaN    205.73B
# 1           Enterprise Value                     160.59B   175.90B    209.06B
# 2               Trailing P/E                       14.31       NaN      23.24
# 3                Forward P/E                       11.56     13.14      17.30
# 4  PEG Ratio (5 yr expected)                        0.68       NaN       1.07
# 5          Price/Sales (ttm)                        4.06      4.86       6.26
# 6           Price/Book (mrq)                       11.74     15.13      20.68
# 7   Enterprise Value/Revenue                        4.09       NaN      19.53
# 8    Enterprise Value/EBITDA                       10.67       NaN      47.41
#
#   9/30/2021 6/30/2021 3/31/2021
# 0   145.10B   161.23B   149.69B
# 1   147.94B   165.43B   153.13B
# 2     16.12     20.51     22.70
# 3     14.12     16.45     18.05
# 4      0.64      0.66      0.76
# 5      4.55      5.58      5.70
# 6     17.75     21.72     20.28
# 7     15.85     20.53     19.30
# 8     38.44     59.06     57.63
# AMAT                   Unnamed: 0 As of Date: 4/30/2022Current 1/31/2022  \
# 0      Market Cap (intraday)                       97.48B   122.07B
# 1           Enterprise Value                       97.50B   122.36B
# 2               Trailing P/E                        15.37     21.59
# 3                Forward P/E                        13.61     16.92
# 4  PEG Ratio (5 yr expected)                         1.66      1.95
# 5          Price/Sales (ttm)                         4.16      5.51
# 6           Price/Book (mrq)                         8.20      9.97
# 7   Enterprise Value/Revenue                         4.03     19.51
# 8    Enterprise Value/EBITDA                        12.05     58.71
#
#   10/31/2021 7/31/2021 4/30/2021
# 0    123.39B   127.89B   121.78B
# 1    122.59B   126.83B   120.86B
# 2      23.77     29.15     31.75
# 3      17.42     18.83     22.22
# 4       1.08      1.22      1.77
# 5       5.83      6.52      6.73
# 6      10.11     10.66     10.61
# 7      20.02     20.47     21.65
# 8      56.55     59.41     70.97
# MU                   Unnamed: 0 As of Date: 5/1/2022Current 2/28/2022 11/30/2021  \
# 0      Market Cap (intraday)                      76.15B    99.50B     94.09B
# 1           Enterprise Value                      73.63B    97.47B     92.74B
# 2               Trailing P/E                        8.58     13.73      16.34
# 3                Forward P/E                        7.32      9.66       9.13
# 4  PEG Ratio (5 yr expected)                        0.86      1.04       1.02
# 5          Price/Sales (ttm)                        2.49      3.42       3.46
# 6           Price/Book (mrq)                        1.59      2.17       2.14
# 7   Enterprise Value/Revenue                        2.36     12.52      12.06
# 8    Enterprise Value/EBITDA                        4.45     22.64      21.89
#
#   8/31/2021 5/31/2021 2/28/2021
# 0    82.97B    94.36B   102.39B
# 1    81.85B    94.32B   102.52B
# 2     20.36     29.94     34.54
# 3      6.88      8.26     21.83
# 4      0.27      0.38      1.02
# 5      3.29      4.06      4.70
# 6      1.96      2.32      2.57
# 7      9.89     12.71     16.44
# 8     17.78     27.67     46.05
# LRCX                   Unnamed: 0 As of Date: 4/30/2022Current 3/31/2022  \
# 0      Market Cap (intraday)                       64.61B    74.57B
# 1           Enterprise Value                       65.26B    74.24B
# 2               Trailing P/E                        14.56     16.77
# 3                Forward P/E                        12.45     13.83
# 4  PEG Ratio (5 yr expected)                         0.96      1.01
# 5          Price/Sales (ttm)                         3.95      4.65
# 6           Price/Book (mrq)                        10.72     11.52
# 7   Enterprise Value/Revenue                         3.90     18.28
# 8    Enterprise Value/EBITDA                        11.54     58.65
#
#   12/31/2021 9/30/2021 6/30/2021 3/31/2021
# 0    100.88B    80.14B    92.73B    84.89B
# 1    101.26B    79.41B    92.75B    84.67B
# 2      24.31     21.16     27.51     29.57
# 3      20.45     16.72     20.33     21.28
# 4       1.51      1.42      0.95      1.24
# 5       6.58      5.65      7.17      7.34
# 6      17.33     13.30     17.25     15.41
# 7      23.96     18.45     22.38     22.01
# 8      68.21     54.08     64.46     65.55
# KLAC                   Unnamed: 0 As of Date: 5/1/2022Current 3/31/2022 12/31/2021  \
# 0      Market Cap (intraday)                      48.12B    55.17B     64.88B
# 1           Enterprise Value                      49.24B    55.90B     65.80B
# 2               Trailing P/E                       16.43     18.84      24.38
# 3                Forward P/E                       13.66       NaN      20.58
# 4  PEG Ratio (5 yr expected)                        1.28      1.47       1.85
# 5          Price/Sales (ttm)                        6.02      6.90       8.91
# 6           Price/Book (mrq)                       11.89     13.63      16.80
# 7   Enterprise Value/Revenue                        5.69     24.42      27.97
# 8    Enterprise Value/EBITDA                       13.12     57.13      62.65
#
#   9/30/2021 6/30/2021 3/31/2021
# 0    50.76B    49.53B    50.67B
# 1    51.81B    50.63B    51.94B
# 2     25.02     27.24     37.72
# 3     17.99     19.49     22.37
# 4      1.83      1.56      2.10
# 5      7.52      7.83      8.51
# 6     15.03     15.90     17.26
# 7     24.86     26.30     28.80
# 8     58.25     60.75     68.00

# %% [markdown]
# ### 2) To get the date of coming earnings by 'for' statement
# - get_next_earnings_date()

# %%
for i in soxx_etf_holdings:
 print( i ,si.get_next_earnings_date(i))
# Out:
# INTC 2022-07-20 20:00:00
# AVGO 2022-06-01 10:59:00
# TXN 2022-07-19 10:59:00
# NVDA 2022-05-25 23:00:00
# QCOM 2022-07-26 10:59:00
# AMAT 2022-05-19 20:00:00
# MU 2022-06-28 10:59:00
# LRCX 2022-07-26 20:00:00
# KLAC 2022-07-27 10:59:00

# %% [markdown]
# ### 3)To get the date of earnings by 'for' satement
# - get_earnings()

# %%
for i in soxx_etf_holdings:
  print( i, si.get_earnings(i))
# Out:
# INTC {'quarterly_results':      date  actual  estimate
# 0  2Q2021    1.28      1.06
# 1  3Q2021    1.71      1.11
# 2  4Q2021    1.09      0.91
# 3  1Q2022    0.87      0.80, 'yearly_revenue_earnings':    date      revenue     earnings
# 0  2018  70848000000  21053000000
# 1  2019  71965000000  21048000000
# 2  2020  77867000000  20899000000
# 3  2021  79024000000  19868000000, 'quarterly_revenue_earnings':      date      revenue    earnings
# 0  1Q2021  19673000000  3361000000
# 1  2Q2021  19631000000  5061000000
# 2  3Q2021  19192000000  6823000000
# 3  4Q2021  20528000000  4623000000}
# AVGO {'quarterly_results':      date  actual  estimate
# 0  2Q2021    6.62      6.42
# 1  3Q2021    6.96      6.88
# 2  4Q2021    7.81      7.74
# 3  1Q2022    8.39      8.08, 'yearly_revenue_earnings':    date      revenue     earnings
# 0  2018  20848000000  12259000000
# 1  2019  22597000000   2724000000
# 2  2020  23888000000   2960000000
# 3  2021  27450000000   6736000000, 'quarterly_revenue_earnings':      date     revenue    earnings
# 0  2Q2021  6610000000  1493000000
# 1  3Q2021  6778000000  1876000000
# 2  4Q2021  7407000000  1989000000
# 3  1Q2022  7706000000  2472000000}
# TXN {'quarterly_results':      date  actual  estimate
# 0  2Q2021    2.05      1.83
# 1  3Q2021    2.07      2.05
# 2  4Q2021    2.27      1.94
# 3  1Q2022    2.35      2.18, 'yearly_revenue_earnings':    date      revenue    earnings
# 0  2018  15784000000  5580000000
# 1  2019  14383000000  5017000000
# 2  2020  14461000000  5595000000
# 3  2021  18344000000  7769000000, 'quarterly_revenue_earnings':      date     revenue    earnings
# 0  1Q2021  4289000000  1753000000
# 1  2Q2021  4580000000  1931000000
# 2  3Q2021  4643000000  1947000000
# 3  4Q2021  4832000000  2138000000}
# NVDA {'quarterly_results':      date  actual  estimate
# 0  2Q2021    0.91      0.82
# 1  3Q2021    1.04      1.01
# 2  4Q2021    1.17      1.11
# 3  1Q2022    1.32      1.22, 'yearly_revenue_earnings':    date      revenue    earnings
# 0  2019  11716000000  4141000000
# 1  2020  10918000000  2796000000
# 2  2021  16675000000  4332000000
# 3  2022  26914000000  9752000000, 'quarterly_revenue_earnings':      date     revenue    earnings
# 0  2Q2021  5661000000  1912000000
# 1  3Q2021  6507000000  2374000000
# 2  4Q2021  7103000000  2464000000
# 3  1Q2022  7643000000  3003000000}
# QCOM {'quarterly_results':      date  actual  estimate
# 0  4Q2020    2.17      2.10
# 1  1Q2021    1.90      1.67
# 2  2Q2021    1.92      1.68
# 3  3Q2021    2.55      2.26, 'yearly_revenue_earnings':    date      revenue    earnings
# 0  2018  22611000000 -4964000000
# 1  2019  24273000000  4386000000
# 2  2020  23531000000  5198000000
# 3  2021  33566000000  9043000000, 'quarterly_revenue_earnings':      date      revenue    earnings
# 0  1Q2021   7935000000  1762000000
# 1  2Q2021   8060000000  2027000000
# 2  3Q2021   9336000000  2798000000
# 3  4Q2021  10705000000  3399000000}
# AMAT {'quarterly_results':      date  actual  estimate
# 0  1Q2021    1.39      1.28
# 1  2Q2021    1.63      1.51
# 2  3Q2021    1.90      1.77
# 3  4Q2021    1.94      1.95, 'yearly_revenue_earnings':    date      revenue    earnings
# 0  2018  16705000000  3038000000
# 1  2019  14608000000  2706000000
# 2  2020  17202000000  3619000000
# 3  2021  23063000000  5888000000, 'quarterly_revenue_earnings':      date     revenue    earnings
# 0  1Q2021  5162000000  1130000000
# 1  2Q2021  5582000000  1330000000
# 2  3Q2021  6196000000  1716000000
# 3  4Q2021  6123000000  1712000000}
# MU {'quarterly_results':      date  actual  estimate
# 0  1Q2021    0.98      0.95
# 1  2Q2021    1.88      1.72
# 2  3Q2021    2.42      2.33
# 3  4Q2021    2.16      2.11, 'yearly_revenue_earnings':    date      revenue     earnings
# 0  2018  30391000000  14135000000
# 1  2019  23406000000   6313000000
# 2  2020  21435000000   2687000000
# 3  2021  27705000000   5861000000, 'quarterly_revenue_earnings':      date     revenue    earnings
# 0  1Q2021  6236000000   603000000
# 1  2Q2021  7422000000  1735000000
# 2  3Q2021  8274000000  2720000000
# 3  4Q2021  7687000000  2306000000}
# LRCX {'quarterly_results':      date  actual  estimate
# 0  4Q2020    6.03      5.72
# 1  1Q2021    7.49      6.62
# 2  2Q2021    8.09      7.55
# 3  3Q2021    8.36      8.21, 'yearly_revenue_earnings':    date      revenue    earnings
# 0  2018  11076998000  2380681000
# 1  2019   9653559000  2191430000
# 2  2020  10044736000  2251753000
# 3  2021  14626150000  3908458000, 'quarterly_revenue_earnings':      date     revenue    earnings
# 0  4Q2020  3456237000   869229000
# 1  1Q2021  3847654000  1071121000
# 2  2Q2021  4145179000  1144657000
# 3  3Q2021  4304465000  1179744000}
# KLAC {'quarterly_results':      date  actual  estimate
# 0  2Q2021    4.43      3.99
# 1  3Q2021    4.64      4.52
# 2  4Q2021    5.59      5.45
# 3  1Q2022    5.13      4.82, 'yearly_revenue_earnings':    date     revenue    earnings
# 0  2018  4036701000   802265000
# 1  2019  4568904000  1175617000
# 2  2020  5806424000  1216785000
# 3  2021  6918734000  2078292000, 'quarterly_revenue_earnings':      date     revenue    earnings
# 0  1Q2021  1803773000   567496000
# 1  2Q2021  1925471000   632978000
# 2  3Q2021  2083838000  1068417000
# 3  4Q2021  2352630000   717444000}
