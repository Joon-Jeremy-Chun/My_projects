# %% [markdown]
# # Objectives
# - Recall Earnings Per Share(EPS)
# - Create the EPS **dataframe**
# - Store the data
# - Create the EPS charts

# %% [markdown]
# Following Objectives
# - P/E = Shareprice / Earnings per share

# %% [markdown]
# ## I. Packages, mount Google drive

# %%
# !pip install yahoo_fin
# !pip install yahoo_fin --upgrade
# !pip install requests_html
# Out:
# Collecting yahoo_fin
#   Downloading yahoo_fin-0.8.9.1-py3-none-any.whl (10 kB)
# Collecting requests-html
#   Downloading requests_html-0.10.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from yahoo_fin) (2.23.0)
# Collecting feedparser
#   Downloading feedparser-6.0.10-py3-none-any.whl (81 kB)
#      |████████████████████████████████| 81 kB 6.7 MB/s
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from yahoo_fin) (1.3.5)
# Collecting sgmllib3k
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas->yahoo_fin) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->yahoo_fin) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->yahoo_fin) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->yahoo_fin) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->yahoo_fin) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->yahoo_fin) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->yahoo_fin) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->yahoo_fin) (2021.10.8)
# Collecting w3lib
#   Downloading w3lib-1.22.0-py2.py3-none-any.whl (20 kB)
# Collecting parse
#   Downloading parse-1.19.0.tar.gz (30 kB)
# Collecting pyppeteer>=0.0.14
#   Downloading pyppeteer-1.0.2-py3-none-any.whl (83 kB)
#      |████████████████████████████████| 83 kB 1.9 MB/s
# Requirement already satisfied: bs4 in /usr/local/lib/python3.7/dist-packages (from requests-html->yahoo_fin) (0.0.1)
# Collecting pyquery
#   Downloading pyquery-1.4.3-py3-none-any.whl (22 kB)
# Collecting fake-useragent
#   Downloading fake-useragent-0.1.11.tar.gz (13 kB)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 41.6 MB/s
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (4.64.0)
# Collecting websockets<11.0,>=10.0
#   Downloading websockets-10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (112 kB)
#      |████████████████████████████████| 112 kB 67.0 MB/s
# Collecting pyee<9.0.0,>=8.1.0
#   Downloading pyee-8.2.2-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: importlib-metadata>=1.4 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (4.11.3)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (1.4.4)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html->yahoo_fin) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html->yahoo_fin) (4.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from bs4->requests-html->yahoo_fin) (4.6.3)
# Requirement already satisfied: lxml>=2.1 in /usr/local/lib/python3.7/dist-packages (from pyquery->requests-html->yahoo_fin) (4.2.6)
# Collecting cssselect>0.7.9
#   Downloading cssselect-1.1.0-py2.py3-none-any.whl (16 kB)
# Building wheels for collected packages: fake-useragent, parse, sgmllib3k
#   Building wheel for fake-useragent (setup.py) ... done
#   Created wheel for fake-useragent: filename=fake_useragent-0.1.11-py3-none-any.whl size=13502 sha256=6fa071d3bfcff6742edbfabbe9a3a0f586a4107ba218170d30163d22f9545c83
#   Stored in directory: /root/.cache/pip/wheels/ed/f7/62/50ab6c9a0b5567267ab76a9daa9d06315704209b2c5d032031
#   Building wheel for parse (setup.py) ... done
#   Created wheel for parse: filename=parse-1.19.0-py3-none-any.whl size=24591 sha256=42c97e7284c57b757da9efbd20504b8cafbd53caff812f89ec6b9b8c15ab74c4
#   Stored in directory: /root/.cache/pip/wheels/9c/aa/cc/f2228050ccb40f22144b073f15a2c84f11204f29fc0dce028e
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6066 sha256=2a3d411833c9d3bd854b32812ebe2f3d5c37867a6677c035e053738e0711b18e
#   Stored in directory: /root/.cache/pip/wheels/73/ad/a4/0dff4a6ef231fc0dfa12ffbac2a36cebfdddfe059f50e019aa
# Successfully built fake-useragent parse sgmllib3k
# Installing collected packages: websockets, urllib3, pyee, cssselect, w3lib, sgmllib3k, pyquery, pyppeteer, parse, fake-useragent, requests-html, feedparser, yahoo-fin
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed cssselect-1.1.0 fake-useragent-0.1.11 feedparser-6.0.10 parse-1.19.0 pyee-8.2.2 pyppeteer-1.0.2 pyquery-1.4.3 requests-html-0.10.0 sgmllib3k-1.0.0 urllib3-1.25.11 w3lib-1.22.0 websockets-10.3 yahoo-fin-0.8.9.1
# Requirement already satisfied: yahoo_fin in /usr/local/lib/python3.7/dist-packages (0.8.9.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from yahoo_fin) (2.23.0)
# Requirement already satisfied: requests-html in /usr/local/lib/python3.7/dist-packages (from yahoo_fin) (0.10.0)
# Requirement already satisfied: feedparser in /usr/local/lib/python3.7/dist-packages (from yahoo_fin) (6.0.10)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from yahoo_fin) (1.3.5)
# Requirement already satisfied: sgmllib3k in /usr/local/lib/python3.7/dist-packages (from feedparser->yahoo_fin) (1.0.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->yahoo_fin) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas->yahoo_fin) (1.21.6)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->yahoo_fin) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->yahoo_fin) (1.15.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->yahoo_fin) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->yahoo_fin) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->yahoo_fin) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->yahoo_fin) (3.0.4)
# Requirement already satisfied: bs4 in /usr/local/lib/python3.7/dist-packages (from requests-html->yahoo_fin) (0.0.1)
# Requirement already satisfied: parse in /usr/local/lib/python3.7/dist-packages (from requests-html->yahoo_fin) (1.19.0)
# Requirement already satisfied: pyppeteer>=0.0.14 in /usr/local/lib/python3.7/dist-packages (from requests-html->yahoo_fin) (1.0.2)
# Requirement already satisfied: w3lib in /usr/local/lib/python3.7/dist-packages (from requests-html->yahoo_fin) (1.22.0)
# Requirement already satisfied: fake-useragent in /usr/local/lib/python3.7/dist-packages (from requests-html->yahoo_fin) (0.1.11)
# Requirement already satisfied: pyquery in /usr/local/lib/python3.7/dist-packages (from requests-html->yahoo_fin) (1.4.3)
# Requirement already satisfied: websockets<11.0,>=10.0 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (10.3)
# Requirement already satisfied: importlib-metadata>=1.4 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (4.11.3)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (1.4.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (4.64.0)
# Requirement already satisfied: pyee<9.0.0,>=8.1.0 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (8.2.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html->yahoo_fin) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html->yahoo_fin) (4.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from bs4->requests-html->yahoo_fin) (4.6.3)
# Requirement already satisfied: lxml>=2.1 in /usr/local/lib/python3.7/dist-packages (from pyquery->requests-html->yahoo_fin) (4.2.6)
# Requirement already satisfied: cssselect>0.7.9 in /usr/local/lib/python3.7/dist-packages (from pyquery->requests-html->yahoo_fin) (1.1.0)
# Requirement already satisfied: requests_html in /usr/local/lib/python3.7/dist-packages (0.10.0)
# Requirement already satisfied: pyppeteer>=0.0.14 in /usr/local/lib/python3.7/dist-packages (from requests_html) (1.0.2)
# Requirement already satisfied: bs4 in /usr/local/lib/python3.7/dist-packages (from requests_html) (0.0.1)
# Requirement already satisfied: parse in /usr/local/lib/python3.7/dist-packages (from requests_html) (1.19.0)
# Requirement already satisfied: w3lib in /usr/local/lib/python3.7/dist-packages (from requests_html) (1.22.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from requests_html) (2.23.0)
# Requirement already satisfied: fake-useragent in /usr/local/lib/python3.7/dist-packages (from requests_html) (0.1.11)
# Requirement already satisfied: pyquery in /usr/local/lib/python3.7/dist-packages (from requests_html) (1.4.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests_html) (4.64.0)
# Requirement already satisfied: websockets<11.0,>=10.0 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests_html) (10.3)
# Requirement already satisfied: urllib3<2.0.0,>=1.25.8 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests_html) (1.25.11)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests_html) (1.4.4)
# Requirement already satisfied: pyee<9.0.0,>=8.1.0 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests_html) (8.2.2)
# Requirement already satisfied: certifi>=2021 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests_html) (2021.10.8)
# Requirement already satisfied: importlib-metadata>=1.4 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests_html) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests_html) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests_html) (4.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from bs4->requests_html) (4.6.3)
# Requirement already satisfied: lxml>=2.1 in /usr/local/lib/python3.7/dist-packages (from pyquery->requests_html) (4.2.6)
# Requirement already satisfied: cssselect>0.7.9 in /usr/local/lib/python3.7/dist-packages (from pyquery->requests_html) (1.1.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->requests_html) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->requests_html) (2.10)
# Requirement already satisfied: six>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from w3lib->requests_html) (1.15.0)

# %%
import yahoo_fin.stock_info as si
import pandas as pd
import random
from time import sleep

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## II.Other necessary materials

# %% [markdown]
# ### 매일 현재 상승 상위 100종목
# ### 하락 상위 100종목
# ### 거래량 100종목

# %%
si.get_day_gainers()
# Out:
#    Symbol                                            Name  Price (Intraday)  \
# 0   KREVF                                     Keppel REIT              0.92
# 1    DECK                     Deckers Outdoor Corporation            255.28
# 2   SSAAY                                  SSAB AB (publ)              2.95
# 3   CLPXF  China Longyuan Power Group Corporation Limited              1.98
# 4    PANW                        Palo Alto Networks, Inc.            478.68
# ..    ...                                             ...               ...
# 95    CIG            Companhia Energética de Minas Gerais              2.36
# 96   YUMC                        Yum China Holdings, Inc.             42.19
# 97     UI                                   Ubiquiti Inc.            249.88
# 98   INSM                             Insmed Incorporated             20.25
# 99     ZS                                   Zscaler, Inc.            136.89
#
#      Change  % Change     Volume  Avg Vol (3 month)    Market Cap  \
# 0    0.1200     15.00    29110.0             6185.0  3.424000e+09
# 1   28.4900     12.56  2103000.0           471720.0  6.954000e+09
# 2    0.2900     10.90    15300.0             2337.0  6.076000e+09
# 3    0.1799      9.99   200780.0             4469.0  2.352500e+10
# 4   42.3100      9.70  5900000.0          1887000.0  4.714300e+10
# ..      ...       ...        ...                ...           ...
# 95   0.0800      3.51  4638000.0          6268000.0  5.359000e+09
# 96   1.4300      3.51  3704000.0          2823000.0  1.778000e+10
# 97   8.4400      3.50    68490.0            94283.0  1.509700e+10
# 98   0.6800      3.47  1214000.0          1080000.0  2.420000e+09
# 99   4.5900      3.47  3807000.0          2812000.0  1.931300e+10
#
#     PE Ratio (TTM)
# 0            20.44
# 1            15.70
# 2              NaN
# 3            20.20
# 4              NaN
# ..             ...
# 95            5.41
# 96           21.29
# 97           35.31
# 98             NaN
# 99             NaN
#
# [100 rows x 9 columns]

# %%
si.get_day_losers()
# Out:
#    Symbol                                Name  Price (Intraday)  Change  \
# 0    ROST                   Ross Stores, Inc.             71.87  -20.83
# 1    FRGE         Forge Global Holdings, Inc.             17.71   -3.16
# 2    BURL             Burlington Stores, Inc.            150.71  -26.49
# 3      DE                     Deere & Company            313.31  -51.31
# 4    UPST              Upstart Holdings, Inc.             44.70   -6.88
# ..    ...                                 ...               ...     ...
# 95   LAZR          Luminar Technologies, Inc.              9.67   -0.40
# 96    AIG  American International Group, Inc.             55.62   -2.28
# 97    CRI                      Carter's, Inc.             75.45   -3.06
# 98   PLNT                Planet Fitness, Inc.             65.19   -2.63
# 99   AMAT             Applied Materials, Inc.            106.46   -4.28
#
#     % Change      Volume  Avg Vol (3 month)    Market Cap  PE Ratio (TTM)
# 0     -22.47  34575000.0          3644000.0  2.525500e+10           15.97
# 1     -15.14    731166.0          1634000.0  2.997000e+09             NaN
# 2     -14.95   4006000.0          1063000.0  9.962000e+09           25.12
# 3     -14.07   8814000.0          2182000.0  9.611800e+10           16.35
# 4     -13.34  23575000.0         13605000.0  3.789000e+09           27.11
# ..       ...         ...                ...           ...             ...
# 95     -3.97   6379000.0          4821000.0  3.381000e+09             NaN
# 96     -3.94   8977000.0          5034000.0  4.406200e+10            4.86
# 97     -3.90   1055000.0           622296.0  3.040000e+09           10.03
# 98     -3.88   1405000.0          1009000.0  5.937000e+09          103.48
# 99     -3.86  15835000.0          8071000.0  9.404600e+10           14.22
#
# [100 rows x 9 columns]

# %%
si.get_day_most_active()
# Out:
#    Symbol                                Name  Price (Intraday)  Change  \
# 0    ZNGA                          Zynga Inc.              8.18   -0.17
# 1     AMD        Advanced Micro Devices, Inc.             93.50   -3.17
# 2    AAPL                          Apple Inc.            137.59    0.24
# 3     NIO                            NIO Inc.             16.44   -0.22
# 4    DIDI                    DiDi Global Inc.              1.50   -0.11
# ..    ...                                 ...               ...     ...
# 95   TELL                      Tellurian Inc.              4.47   -0.10
# 96     CS              Credit Suisse Group AG              6.78    0.03
# 97   HBAN  Huntington Bancshares Incorporated             13.02   -0.09
# 98     UA                  Under Armour, Inc.              8.48    0.30
# 99   VTRS                        Viatris Inc.             11.80    0.11
#
#     % Change       Volume  Avg Vol (3 month)      Market Cap  PE Ratio (TTM)
# 0      -2.04  227574000.0         29898000.0    9303000000.0             NaN
# 1      -3.28  163879000.0        110820000.0  151518000000.0           35.08
# 2       0.17  137426000.0         98186000.0          2.227T           22.42
# 3      -1.32   85448000.0         76460000.0   28820000000.0             NaN
# 4      -6.83   74056000.0         55830000.0    7281000000.0             NaN
# ..       ...          ...                ...             ...             ...
# 95     -2.19   14294000.0         24889000.0    2540000000.0             NaN
# 96      0.44   14116000.0         14066000.0   17330000000.0             NaN
# 97     -0.69   14065000.0         13253000.0   18738000000.0           16.74
# 98      3.67   10487000.0          4678000.0    4173000000.0           18.04
# 99      0.94   13834000.0         15583000.0   14305000000.0           84.89
#
# [100 rows x 9 columns]

# %% [markdown]
# ## III.  EPS recalling

# %% [markdown]
# ### 0) get_analysts_info()
# - get the analysts' predictions

# %%
a = si.get_analysts_info('MSFT')
print(a)
# Out:
# {'Earnings Estimate':   Earnings Estimate  Current Qtr. (Jun 2022)  Next Qtr. (Sep 2022)  \
# 0   No. of Analysts                    29.00                 28.00
# 1     Avg. Estimate                     2.33                  2.51
# 2      Low Estimate                     2.29                  2.28
# 3     High Estimate                     2.39                  2.62
# 4      Year Ago EPS                     2.17                  2.27
#
#    Current Year (2022)  Next Year (2023)
# 0                24.00             40.00
# 1                 9.32             10.78
# 2                 9.27              9.57
# 3                 9.46             11.29
# 4                 8.05              9.32  , 'Revenue Estimate':           Revenue Estimate Current Qtr. (Jun 2022) Next Qtr. (Sep 2022)  \
# 0          No. of Analysts                      28                   24
# 1            Avg. Estimate                  52.87B               51.97B
# 2             Low Estimate                  52.54B               50.57B
# 3            High Estimate                  53.41B               53.44B
# 4           Year Ago Sales                  46.15B                  NaN
# 5  Sales Growth (year/est)                  14.60%                  NaN
#
#   Current Year (2022) Next Year (2023)
# 0                  38               39
# 1             199.24B          227.92B
# 2             195.03B          212.32B
# 3             200.13B          236.41B
# 4             168.09B          199.24B
# 5              18.50%           14.40%  , 'Earnings History':   Earnings History 6/29/2021 9/29/2021 12/30/2021 3/30/2022
# 0         EPS Est.      1.92      2.07       2.31      2.18
# 1       EPS Actual      2.17      2.27       2.48      2.22
# 2       Difference      0.25       0.2       0.17      0.04
# 3       Surprise %    13.00%     9.70%      7.40%     1.80%, 'EPS Trend':           EPS Trend  Current Qtr. (Jun 2022)  Next Qtr. (Sep 2022)  \
# 0  Current Estimate                     2.33                  2.51
# 1        7 Days Ago                     2.33                  2.51
# 2       30 Days Ago                     2.35                  2.51
# 3       60 Days Ago                     2.36                  2.51
# 4       90 Days Ago                     2.36                  2.51
#
#    Current Year (2022)  Next Year (2023)
# 0                 9.32             10.78
# 1                 9.32             10.78
# 2                 9.33             10.72
# 3                 9.35             10.75
# 4                 9.35             10.75  , 'EPS Revisions':        EPS Revisions  Current Qtr. (Jun 2022)  Next Qtr. (Sep 2022)  \
# 0     Up Last 7 Days                      NaN                   NaN
# 1    Up Last 30 Days                      7.0                  10.0
# 2   Down Last 7 Days                      NaN                   NaN
# 3  Down Last 30 Days                      NaN                   NaN
#
#    Current Year (2022)  Next Year (2023)
# 0                  NaN               NaN
# 1                 15.0              23.0
# 2                  NaN               NaN
# 3                  NaN               NaN  , 'Growth Estimates':            Growth Estimates    MSFT  Industry  Sector(s)  S&P 500
# 0              Current Qtr.   7.40%       NaN        NaN      NaN
# 1                 Next Qtr.  10.60%       NaN        NaN      NaN
# 2              Current Year  15.80%       NaN        NaN      NaN
# 3                 Next Year  15.70%       NaN        NaN      NaN
# 4  Next 5 Years (per annum)  16.23%       NaN        NaN      NaN
# 5  Past 5 Years (per annum)  18.17%       NaN        NaN      NaN}

# %% [markdown]
# ### 1) get_stats_valuation()
# - current PE ratio

# %%
si.get_stats_valuation('MSFT')
# Out:
#                   Unnamed: 0 As of Date: 5/19/2022Current 3/31/2022  \
# 0      Market Cap (intraday)                        1.90T     2.31T
# 1           Enterprise Value                        1.86T     2.25T
# 2               Trailing P/E                        26.52     32.83
# 3                Forward P/E                        23.58     28.57
# 4  PEG Ratio (5 yr expected)                         1.74      2.12
# 5          Price/Sales (ttm)                         9.97     12.63
# 6           Price/Book (mrq)                        11.66     14.42
# 7   Enterprise Value/Revenue                         9.64     45.50
# 8    Enterprise Value/EBITDA                        18.84     91.79
#
#   12/31/2021 9/30/2021 6/30/2021 3/31/2021
# 0      2.52T     2.12T     2.04T     1.78T
# 1      2.46T     2.05T     1.98T     1.71T
# 2      37.62     35.02     36.91     35.14
# 3      36.90     31.55     32.57     29.24
# 4       2.87      2.60      2.65      2.17
# 5      14.48     12.76     12.91     11.76
# 6      16.60     14.91     15.14     13.64
# 7      47.46     45.34     42.88     41.09
# 8      92.52     84.64     84.92     82.37

# %% [markdown]
# ### 2) get_next_earnings_date()
# - It will returns the upcoming earnings date

# %%
si.get_next_earnings_date('MSFT')
# Out:
# datetime.datetime(2022, 7, 25, 10, 59)

# %%
si.get_next_earnings_date('AAPL')
# Out:
# datetime.datetime(2022, 7, 25, 20, 0)

# %% [markdown]
# ### 3) get_earnings()
# - the command will recalls the earnings of campany

# %%
si.get_earnings('MSFT')
# Out:
# {'quarterly_results':      date  actual  estimate
#  0  2Q2021    2.17      1.92
#  1  3Q2021    2.27      2.07
#  2  4Q2021    2.48      2.31
#  3  1Q2022    2.22      2.18,
#  'quarterly_revenue_earnings':      date      revenue     earnings
#  0  2Q2021  46152000000  16458000000
#  1  3Q2021  45317000000  20505000000
#  2  4Q2021  51728000000  18765000000
#  3  1Q2022  49360000000  16728000000,
#  'yearly_revenue_earnings':    date       revenue     earnings
#  0  2018  110360000000  16571000000
#  1  2019  125843000000  39240000000
#  2  2020  143015000000  44281000000
#  3  2021  168088000000  61271000000}

# %% [markdown]
# ### 4) get_earnings_history()
# - recalls the company's earnings data
# - data frame fromat -> dictionary in list
# - X[n]['key'] n=0 the most future one

# %%
TSLA_per_his = si.get_earnings_history('TSLA')
MSFT_per_his = si.get_earnings_history('MSFT')
BRKB_per_his = si.get_earnings_history('BRKB')

# %%
BRKB_per_his
# Out:
# [{'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 3420,
#   'epsestimate': 3517.8,
#   'epssurprisepct': -2.78,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2020-08-08T08:10:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 3617.38,
#   'epsestimate': 3866.63,
#   'epssurprisepct': -6.45,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2020-05-02T08:09:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 2714.99,
#   'epsestimate': 3612.56,
#   'epssurprisepct': -24.85,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2020-02-22T08:17:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 3.07,
#   'epsestimate': 2.84,
#   'epssurprisepct': 7.98,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2019-11-03T21:13:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 4699.29,
#   'epsestimate': 4405.16,
#   'epssurprisepct': 6.68,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2019-11-02T06:46:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 3754.74,
#   'epsestimate': 3851.28,
#   'epssurprisepct': -2.51,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2019-08-03T08:29:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 3387.47,
#   'epsestimate': 3399.3,
#   'epssurprisepct': -0.35,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2019-05-04T08:20:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 3484.3,
#   'epsestimate': 3349.04,
#   'epssurprisepct': 4.04,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2019-02-23T08:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 4185.89,
#   'epsestimate': 3827.05,
#   'epssurprisepct': 9.38,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2018-11-03T08:06:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 4190.13,
#   'epsestimate': 3386.62,
#   'epssurprisepct': 23.73,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2018-08-04T08:15:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 3214.67,
#   'epsestimate': 3115.57,
#   'epssurprisepct': 3.18,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2018-05-05T08:07:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 2029,
#   'epsestimate': 2622.23,
#   'epssurprisepct': -22.62,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2018-02-24T08:29:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 2094,
#   'epsestimate': 2402.47,
#   'epssurprisepct': -12.84,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2017-11-03T16:15:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 2505,
#   'epsestimate': 2791.04,
#   'epssurprisepct': -10.25,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2017-08-04T17:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 2163,
#   'epsestimate': 2665.94,
#   'epssurprisepct': -18.87,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2017-05-05T17:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 2665,
#   'epsestimate': 2716.6,
#   'epssurprisepct': -1.9,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2017-02-25T08:05:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 2951,
#   'epsestimate': 3058.1,
#   'epssurprisepct': -3.5,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2016-11-04T16:48:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 2803,
#   'epsestimate': 2910.79,
#   'epssurprisepct': -3.7,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2016-08-05T16:24:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 2274,
#   'epsestimate': 2579.44,
#   'epssurprisepct': -11.84,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2016-05-06T18:31:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 2843,
#   'epsestimate': 2813.89,
#   'epssurprisepct': 1.03,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2016-02-27T08:02:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 2769,
#   'epsestimate': 2720.6,
#   'epssurprisepct': 1.78,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2015-11-06T16:15:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 2367,
#   'epsestimate': 3038.16,
#   'epssurprisepct': -22.09,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2015-08-07T17:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 2583,
#   'epsestimate': 2372.75,
#   'epssurprisepct': 8.86,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2015-05-01T17:05:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 2412,
#   'epsestimate': 2700.63,
#   'epssurprisepct': -10.69,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2015-02-28T08:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 2876,
#   'epsestimate': 2593.85,
#   'epssurprisepct': 10.88,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2014-11-07T17:05:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 2634,
#   'epsestimate': 2481.98,
#   'epssurprisepct': 6.12,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2014-08-01T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 2149,
#   'epsestimate': 2172.04,
#   'epssurprisepct': -1.06,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2014-05-02T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 2297,
#   'epsestimate': 2203.91,
#   'epssurprisepct': 4.22,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2014-03-01T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 2228,
#   'epsestimate': 2402.23,
#   'epssurprisepct': -7.25,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2013-11-01T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 2385,
#   'epsestimate': 2169.53,
#   'epssurprisepct': 9.93,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2013-08-02T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 2302,
#   'epsestimate': 1995.5,
#   'epssurprisepct': 15.36,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2013-05-03T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 1704,
#   'epsestimate': 1755.12,
#   'epssurprisepct': -2.91,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2013-03-01T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 2057,
#   'epsestimate': 2062.56,
#   'epssurprisepct': -0.27,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2012-11-02T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 2252,
#   'epsestimate': 1776.64,
#   'epssurprisepct': 26.76,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2012-08-03T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 1615,
#   'epsestimate': 1779.89,
#   'epssurprisepct': -9.26,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2012-05-04T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 1615,
#   'epsestimate': 1850.67,
#   'epssurprisepct': -12.73,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2012-02-27T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 2309,
#   'epsestimate': 1796,
#   'epssurprisepct': 28.56,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2011-11-04T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 1640,
#   'epsestimate': 1663.67,
#   'epssurprisepct': -1.42,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2011-08-05T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 966,
#   'epsestimate': 1163,
#   'epssurprisepct': -16.94,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2011-05-06T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 1826,
#   'epsestimate': 1691.67,
#   'epssurprisepct': 7.94,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2011-02-26T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 1692,
#   'epsestimate': 1676.67,
#   'epssurprisepct': 0.91,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2010-11-05T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 1866,
#   'epsestimate': 1360.44,
#   'epssurprisepct': 37.16,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2010-08-06T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 1390,
#   'epsestimate': 1101.83,
#   'epssurprisepct': 26.15,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2010-05-07T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 1308,
#   'epsestimate': 1208.33,
#   'epssurprisepct': 8.25,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2010-02-27T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 1325,
#   'epsestimate': 1308.25,
#   'epssurprisepct': 1.28,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2009-11-06T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 1147,
#   'epsestimate': 1238.38,
#   'epssurprisepct': -7.38,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2009-08-07T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 1100,
#   'epsestimate': 1443,
#   'epssurprisepct': -23.77,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2009-05-08T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 2175,
#   'epsestimate': 1486.5,
#   'epssurprisepct': 46.32,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2009-02-25T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 1336,
#   'epsestimate': 1429.19,
#   'epssurprisepct': -6.52,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2008-11-07T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 1465,
#   'epsestimate': 1370.33,
#   'epssurprisepct': 6.91,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2008-08-08T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 1247,
#   'epsestimate': 1476.98,
#   'epssurprisepct': -15.57,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2008-05-02T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 1518,
#   'epsestimate': 1606,
#   'epssurprisepct': -5.48,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2008-02-29T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 1655,
#   'epsestimate': 1509.33,
#   'epssurprisepct': 9.65,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2007-11-02T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 1625,
#   'epsestimate': 1457.78,
#   'epssurprisepct': 11.47,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2007-08-03T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 1434,
#   'epsestimate': 1447.22,
#   'epssurprisepct': -0.91,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2007-05-04T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 1859,
#   'epsestimate': 1452.36,
#   'epssurprisepct': 28,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2007-03-01T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 1685,
#   'epsestimate': 1243.69,
#   'epssurprisepct': 35.48,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2006-11-03T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 1332,
#   'epsestimate': 1084,
#   'epssurprisepct': 22.88,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2006-08-04T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 1160,
#   'epsestimate': 1102,
#   'epssurprisepct': 5.26,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2006-05-05T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 1196,
#   'epsestimate': 932.5,
#   'epssurprisepct': 28.26,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2006-03-04T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 69,
#   'epsestimate': 1006,
#   'epssurprisepct': -93.14,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2005-11-04T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 1045,
#   'epsestimate': 941.5,
#   'epssurprisepct': 10.99,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2005-08-05T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 886,
#   'epsestimate': 910,
#   'epssurprisepct': -2.64,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2005-05-09T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 1197,
#   'epsestimate': 914,
#   'epssurprisepct': 30.96,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2005-03-15T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 402,
#   'epsestimate': 748.5,
#   'epssurprisepct': -46.29,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2004-11-05T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 946,
#   'epsestimate': 844.5,
#   'epssurprisepct': 12.02,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2004-08-06T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 738,
#   'epsestimate': 924,
#   'epssurprisepct': -20.13,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2004-05-07T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 1004,
#   'epsestimate': 867,
#   'epssurprisepct': 15.8,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2004-03-01T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 881,
#   'epsestimate': 787,
#   'epssurprisepct': 11.94,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2003-11-07T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 862,
#   'epsestimate': 779.5,
#   'epssurprisepct': 10.58,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2003-08-08T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 784,
#   'epsestimate': 705,
#   'epssurprisepct': 11.21,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2003-05-09T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 610,
#   'epsestimate': 717.5,
#   'epssurprisepct': -14.98,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2003-03-08T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 726,
#   'epsestimate': 603,
#   'epssurprisepct': 20.4,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2002-11-08T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 673,
#   'epsestimate': 550,
#   'epssurprisepct': 22.36,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2002-08-09T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 534,
#   'epsestimate': 446.5,
#   'epssurprisepct': 19.6,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2002-05-10T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 22,
#   'epsestimate': -4,
#   'epssurprisepct': 650,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2002-03-12T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': -586,
#   'epsestimate': 310,
#   'epssurprisepct': -289.03,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2001-11-09T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 231,
#   'epsestimate': 290,
#   'epssurprisepct': -20.34,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2001-08-10T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 197,
#   'epsestimate': 162,
#   'epssurprisepct': 21.6,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2000-11-10T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'},
#  {'companyshortname': 'Berkshire Hathaway Inc.',
#   'epsactual': 161,
#   'epsestimate': 180,
#   'epssurprisepct': -10.56,
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2000-08-11T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'BRKB',
#   'timeZoneShortName': 'UTC'}]

# %%
print('eps(actual)   :' , MSFT_per_his[99]['epsactual'])
print('eps(estimate) :' , MSFT_per_his[99]['epsestimate'])
print('date :', MSFT_per_his[99]['startdatetime'],MSFT_per_his[99]['timeZoneShortName'])
# Out:
# eps(actual)   : 0.13
# eps(estimate) : 0.12
# date : 1998-07-16T04:00:00.000Z EDT

# %%
print(len(MSFT_per_his))
print(len(TSLA_per_his))
# Out:
# 100
# 51

# %% [markdown]
# -Get t

# %%
for i in range(len(BRKB_per_his)):
  print('eps(actual)   :' , MSFT_per_his[i]['epsactual'])
  print('eps(estimate) :' , MSFT_per_his[i]['epsestimate'])
  print('date :', MSFT_per_his[i]['startdatetime'],MSFT_per_his[i]['timeZoneShortName'])
  print('\n')
# Out:
# eps(actual)   : None
# eps(estimate) : None
# date : 2023-04-24T10:59:00.000Z EDT
#
#
# eps(actual)   : None
# eps(estimate) : None
# date : 2023-01-23T10:59:00.000Z EST
#
#
# eps(actual)   : None
# eps(estimate) : None
# date : 2022-10-24T10:59:00.000Z EDT
#
#
# eps(actual)   : None
# eps(estimate) : 2.33
# date : 2022-07-25T10:59:00.000Z EDT
#
#
# eps(actual)   : 2.22
# eps(estimate) : 2.19
# date : 2022-04-26T16:04:00.000Z EDT
#
#
# eps(actual)   : 2.48
# eps(estimate) : 2.31
# date : 2022-01-25T16:04:00.000Z EST
#
#
# eps(actual)   : 2.27
# eps(estimate) : 2.08
# date : 2021-10-26T16:05:00.000Z EDT
#
#
# eps(actual)   : 2.17
# eps(estimate) : 1.92
# date : 2021-07-27T16:02:00.000Z EDT
#
#
# eps(actual)   : 2.03
# eps(estimate) : 1.78
# date : 2021-04-27T16:03:00.000Z EDT
#
#
# eps(actual)   : 2.03
# eps(estimate) : 1.64
# date : 2021-01-26T16:04:00.000Z EST
#
#
# eps(actual)   : 1.82
# eps(estimate) : 1.54
# date : 2020-10-27T16:13:00.000Z EDT
#
#
# eps(actual)   : 1.46
# eps(estimate) : 1.34
# date : 2020-07-22T16:03:00.000Z EDT
#
#
# eps(actual)   : 1.4
# eps(estimate) : 1.26
# date : 2020-04-29T16:03:00.000Z EDT
#
#
# eps(actual)   : 1.51
# eps(estimate) : 1.32
# date : 2020-01-29T16:05:00.000Z EST
#
#
# eps(actual)   : 1.38
# eps(estimate) : 1.25
# date : 2019-10-23T16:08:00.000Z EDT
#
#
# eps(actual)   : 1.37
# eps(estimate) : 1.21
# date : 2019-07-18T16:07:00.000Z EDT
#
#
# eps(actual)   : 1.14
# eps(estimate) : 1
# date : 2019-04-24T16:07:00.000Z EDT
#
#
# eps(actual)   : 1.1
# eps(estimate) : 1.09
# date : 2019-01-30T16:06:00.000Z EST
#
#
# eps(actual)   : 1.14
# eps(estimate) : 0.96
# date : 2018-10-24T16:07:00.000Z EDT
#
#
# eps(actual)   : 1.13
# eps(estimate) : 1.08
# date : 2018-07-19T16:05:00.000Z EDT
#
#
# eps(actual)   : 0.95
# eps(estimate) : 0.85
# date : 2018-04-26T16:04:00.000Z EDT
#
#
# eps(actual)   : 0.96
# eps(estimate) : 0.87
# date : 2018-01-31T16:05:00.000Z EST
#
#
# eps(actual)   : 0.84
# eps(estimate) : 0.72
# date : 2017-10-26T16:02:00.000Z EDT
#
#
# eps(actual)   : 0.98
# eps(estimate) : 0.71
# date : 2017-07-20T16:06:00.000Z EDT
#
#
# eps(actual)   : 0.73
# eps(estimate) : 0.7
# date : 2017-04-27T16:05:00.000Z EDT
#
#
# eps(actual)   : 0.83
# eps(estimate) : 0.79
# date : 2017-01-26T16:09:00.000Z EST
#
#
# eps(actual)   : 0.76
# eps(estimate) : 0.68
# date : 2016-10-20T16:05:00.000Z EDT
#
#
# eps(actual)   : 0.69
# eps(estimate) : 0.58
# date : 2016-07-19T16:05:00.000Z EDT
#
#
# eps(actual)   : 0.62
# eps(estimate) : 0.64
# date : 2016-04-21T16:05:00.000Z EDT
#
#
# eps(actual)   : 0.78
# eps(estimate) : 0.71
# date : 2016-01-28T16:06:00.000Z EST
#
#
# eps(actual)   : 0.67
# eps(estimate) : 0.59
# date : 2015-10-22T16:05:00.000Z EDT
#
#
# eps(actual)   : 0.6
# eps(estimate) : 0.56
# date : 2015-07-21T16:05:00.000Z EDT
#
#
# eps(actual)   : 0.61
# eps(estimate) : 0.51
# date : 2015-04-23T16:02:00.000Z EDT
#
#
# eps(actual)   : 0.71
# eps(estimate) : 0.71
# date : 2015-01-26T16:10:00.000Z EST
#
#
# eps(actual)   : 0.54
# eps(estimate) : 0.49
# date : 2014-10-23T16:02:00.000Z EDT
#
#
# eps(actual)   : 0.55
# eps(estimate) : 0.6
# date : 2014-07-22T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.68
# eps(estimate) : 0.63
# date : 2014-04-24T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.78
# eps(estimate) : 0.68
# date : 2014-01-23T05:00:00.000Z EST
#
#
# eps(actual)   : 0.62
# eps(estimate) : 0.54
# date : 2013-10-24T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.66
# eps(estimate) : 0.75
# date : 2013-07-18T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.72
# eps(estimate) : 0.68
# date : 2013-04-18T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.76
# eps(estimate) : 0.75
# date : 2013-01-24T05:00:00.000Z EST
#
#
# eps(actual)   : 0.53
# eps(estimate) : 0.56
# date : 2012-10-18T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.67
# eps(estimate) : 0.62
# date : 2012-07-19T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.6
# eps(estimate) : 0.57
# date : 2012-04-19T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.78
# eps(estimate) : 0.76
# date : 2012-01-19T05:00:00.000Z EST
#
#
# eps(actual)   : 0.68
# eps(estimate) : 0.68
# date : 2011-10-20T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.69
# eps(estimate) : 0.58
# date : 2011-07-21T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.61
# eps(estimate) : 0.56
# date : 2011-04-28T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.77
# eps(estimate) : 0.68
# date : 2011-01-27T05:00:00.000Z EST
#
#
# eps(actual)   : 0.62
# eps(estimate) : 0.55
# date : 2010-10-28T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.51
# eps(estimate) : 0.46
# date : 2010-07-22T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.45
# eps(estimate) : 0.42
# date : 2010-04-22T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.74
# eps(estimate) : 0.59
# date : 2010-01-28T05:00:00.000Z EST
#
#
# eps(actual)   : 0.4
# eps(estimate) : 0.32
# date : 2009-10-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.36
# eps(estimate) : 0.36
# date : 2009-07-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.39
# eps(estimate) : 0.39
# date : 2009-04-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.47
# eps(estimate) : 0.49
# date : 2009-01-22T05:00:00.000Z EST
#
#
# eps(actual)   : 0.48
# eps(estimate) : 0.47
# date : 2008-10-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.46
# eps(estimate) : 0.47
# date : 2008-07-17T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.47
# eps(estimate) : 0.44
# date : 2008-04-24T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.5
# eps(estimate) : 0.46
# date : 2008-01-24T05:00:00.000Z EST
#
#
# eps(actual)   : 0.45
# eps(estimate) : 0.39
# date : 2007-10-25T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.39
# eps(estimate) : 0.39
# date : 2007-07-19T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.49
# eps(estimate) : 0.46
# date : 2007-04-26T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.26
# eps(estimate) : 0.23
# date : 2007-01-25T05:00:00.000Z EST
#
#
# eps(actual)   : 0.35
# eps(estimate) : 0.31
# date : 2006-10-26T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.31
# eps(estimate) : 0.3
# date : 2006-07-20T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.32
# eps(estimate) : 0.33
# date : 2006-04-27T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.33
# eps(estimate) : 0.33
# date : 2006-01-26T05:00:00.000Z EST
#
#
# eps(actual)   : 0.31
# eps(estimate) : 0.3
# date : 2005-10-27T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.32
# eps(estimate) : 0.31
# date : 2005-07-21T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.32
# eps(estimate) : 0.32
# date : 2005-04-28T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.35
# eps(estimate) : 0.33
# date : 2005-01-27T05:00:00.000Z EST
#
#
# eps(actual)   : 0.31
# eps(estimate) : 0.3
# date : 2004-10-21T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.28
# eps(estimate) : 0.29
# date : 2004-07-22T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.34
# eps(estimate) : 0.29
# date : 2004-04-22T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.34
# eps(estimate) : 0.3
# date : 2004-01-22T05:00:00.000Z EST
#
#
# eps(actual)   : 0.3
# eps(estimate) : 0.29
# date : 2003-10-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.23
# eps(estimate) : 0.24
# date : 2003-07-17T04:00:00.000Z EDT

# %%
for i in range(len(TSLA_per_his)):
  print('eps(actual)   :' , TSLA_per_his[i]['epsactual'])
  print('eps(estimate) :' , TSLA_per_his[i]['epsestimate'])
  print('date :', TSLA_per_his[i]['startdatetime'],TSLA_per_his[i]['timeZoneShortName'])
  print('\n')
# Out:
# eps(actual)   : None
# eps(estimate) : None
# date : 2023-04-18T10:59:00.000Z EDT
#
#
# eps(actual)   : None
# eps(estimate) : None
# date : 2023-01-24T10:59:00.000Z EST
#
#
# eps(actual)   : None
# eps(estimate) : None
# date : 2022-10-18T10:59:00.000Z EDT
#
#
# eps(actual)   : None
# eps(estimate) : 2.19
# date : 2022-07-25T10:59:00.000Z EDT
#
#
# eps(actual)   : 3.22
# eps(estimate) : 2.26
# date : 2022-04-20T16:09:00.000Z EDT
#
#
# eps(actual)   : 2.54
# eps(estimate) : 2.37
# date : 2022-01-26T16:07:00.000Z EST
#
#
# eps(actual)   : 1.86
# eps(estimate) : 1.59
# date : 2021-10-20T16:08:00.000Z EDT
#
#
# eps(actual)   : 1.45
# eps(estimate) : 0.98
# date : 2021-07-26T16:07:00.000Z EDT
#
#
# eps(actual)   : 0.93
# eps(estimate) : 0.79
# date : 2021-04-26T16:00:00.000Z EDT
#
#
# eps(actual)   : 0.8
# eps(estimate) : 1.03
# date : 2021-01-27T16:08:00.000Z EST
#
#
# eps(actual)   : 0.76
# eps(estimate) : 0.58
# date : 2020-10-21T16:07:00.000Z EDT
#
#
# eps(actual)   : 0.44
# eps(estimate) : -0.04
# date : 2020-07-22T16:23:00.000Z EDT
#
#
# eps(actual)   : 0.23
# eps(estimate) : -0.06
# date : 2020-04-29T16:12:00.000Z EDT
#
#
# eps(actual)   : 0.41
# eps(estimate) : 0.35
# date : 2020-01-29T16:17:00.000Z EST
#
#
# eps(actual)   : 0.37
# eps(estimate) : -0.08
# date : 2019-10-23T16:54:00.000Z EDT
#
#
# eps(actual)   : -0.22
# eps(estimate) : -0.07
# date : 2019-07-24T16:48:00.000Z EDT
#
#
# eps(actual)   : -0.58
# eps(estimate) : -0.14
# date : 2019-04-24T17:17:00.000Z EDT
#
#
# eps(actual)   : 0.39
# eps(estimate) : 0.44
# date : 2019-01-30T16:13:00.000Z EST
#
#
# eps(actual)   : 0.58
# eps(estimate) : -0.04
# date : 2018-10-24T16:23:00.000Z EDT
#
#
# eps(actual)   : -3.06
# eps(estimate) : -2.92
# date : 2018-08-01T16:06:00.000Z EDT
#
#
# eps(actual)   : -3.35
# eps(estimate) : -3.58
# date : 2018-05-02T16:13:00.000Z EDT
#
#
# eps(actual)   : -3.04
# eps(estimate) : -3.09
# date : 2018-02-07T16:13:00.000Z EST
#
#
# eps(actual)   : -2.92
# eps(estimate) : -2.2
# date : 2017-11-01T16:16:00.000Z EDT
#
#
# eps(actual)   : -1.33
# eps(estimate) : -1.82
# date : 2017-08-02T16:13:00.000Z EDT
#
#
# eps(actual)   : -1.33
# eps(estimate) : -0.81
# date : 2017-05-03T16:05:00.000Z EDT
#
#
# eps(actual)   : -0.69
# eps(estimate) : -0.43
# date : 2017-02-22T14:41:00.000Z EST
#
#
# eps(actual)   : 0.71
# eps(estimate) : -0.54
# date : 2016-10-26T16:05:00.000Z EDT
#
#
# eps(actual)   : -1.61
# eps(estimate) : -0.51
# date : 2016-08-03T16:01:00.000Z EDT
#
#
# eps(actual)   : -1.45
# eps(estimate) : -0.58
# date : 2016-05-04T16:03:00.000Z EDT
#
#
# eps(actual)   : -0.87
# eps(estimate) : 0.1
# date : 2016-02-10T16:15:00.000Z EST
#
#
# eps(actual)   : -0.58
# eps(estimate) : -0.49
# date : 2015-11-03T16:04:00.000Z EST
#
#
# eps(actual)   : -0.48
# eps(estimate) : -0.6
# date : 2015-08-05T16:44:00.000Z EDT
#
#
# eps(actual)   : -0.36
# eps(estimate) : -0.5
# date : 2015-05-06T16:26:00.000Z EDT
#
#
# eps(actual)   : -0.13
# eps(estimate) : 0.31
# date : 2015-02-11T16:05:00.000Z EST
#
#
# eps(actual)   : 0.02
# eps(estimate) : -0.01
# date : 2014-11-05T17:00:00.000Z EST
#
#
# eps(actual)   : 0.11
# eps(estimate) : 0.04
# date : 2014-07-31T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.12
# eps(estimate) : 0.1
# date : 2014-05-07T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.33
# eps(estimate) : 0.21
# date : 2014-02-19T05:00:00.000Z EST
#
#
# eps(actual)   : 0.12
# eps(estimate) : 0.11
# date : 2013-11-05T05:00:00.000Z EST
#
#
# eps(actual)   : 0.2
# eps(estimate) : -0.17
# date : 2013-08-07T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.12
# eps(estimate) : 0.04
# date : 2013-05-08T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.65
# eps(estimate) : -0.53
# date : 2013-02-20T05:00:00.000Z EST
#
#
# eps(actual)   : -0.92
# eps(estimate) : -0.9
# date : 2012-11-05T05:00:00.000Z EST
#
#
# eps(actual)   : -0.89
# eps(estimate) : -0.92
# date : 2012-07-25T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.76
# eps(estimate) : -0.69
# date : 2012-05-09T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.69
# eps(estimate) : -0.63
# date : 2012-02-15T05:00:00.000Z EST
#
#
# eps(actual)   : -0.55
# eps(estimate) : -0.59
# date : 2011-11-02T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.53
# eps(estimate) : -0.51
# date : 2011-08-03T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.44
# eps(estimate) : -0.51
# date : 2011-05-04T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.47
# eps(estimate) : -0.5
# date : 2011-02-15T05:00:00.000Z EST
#
#
# eps(actual)   : -0.37
# eps(estimate) : -0.43
# date : 2010-11-09T05:00:00.000Z EST

# %%
si.get_earnings_history('MSFT')
# Out:
# [{'companyshortname': 'Microsoft Corp',
#   'epsactual': None,
#   'epsestimate': None,
#   'epssurprisepct': None,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2023-04-24T10:59:00.000Z',
#   'startdatetimetype': 'TNS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corp',
#   'epsactual': None,
#   'epsestimate': None,
#   'epssurprisepct': None,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2023-01-23T10:59:00.000Z',
#   'startdatetimetype': 'TNS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corp',
#   'epsactual': None,
#   'epsestimate': None,
#   'epssurprisepct': None,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2022-10-24T10:59:00.000Z',
#   'startdatetimetype': 'TNS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corp',
#   'epsactual': None,
#   'epsestimate': 2.33,
#   'epssurprisepct': None,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2022-07-25T10:59:00.000Z',
#   'startdatetimetype': 'TNS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 2.22,
#   'epsestimate': 2.19,
#   'epssurprisepct': 1.6,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2022-04-26T16:04:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 2.48,
#   'epsestimate': 2.31,
#   'epssurprisepct': 7.27,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2022-01-25T16:04:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 2.27,
#   'epsestimate': 2.08,
#   'epssurprisepct': 9.4,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2021-10-26T16:05:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 2.17,
#   'epsestimate': 1.92,
#   'epssurprisepct': 13.26,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2021-07-27T16:02:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 2.03,
#   'epsestimate': 1.78,
#   'epssurprisepct': 14.11,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2021-04-27T16:03:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 2.03,
#   'epsestimate': 1.64,
#   'epssurprisepct': 23.63,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2021-01-26T16:04:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 1.82,
#   'epsestimate': 1.54,
#   'epssurprisepct': 17.88,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2020-10-27T16:13:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 1.46,
#   'epsestimate': 1.34,
#   'epssurprisepct': 8.71,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2020-07-22T16:03:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 1.4,
#   'epsestimate': 1.26,
#   'epssurprisepct': 10.67,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2020-04-29T16:03:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 1.51,
#   'epsestimate': 1.32,
#   'epssurprisepct': 14.48,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2020-01-29T16:05:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 1.38,
#   'epsestimate': 1.25,
#   'epssurprisepct': 10.84,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2019-10-23T16:08:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 1.37,
#   'epsestimate': 1.21,
#   'epssurprisepct': 12.94,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2019-07-18T16:07:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 1.14,
#   'epsestimate': 1,
#   'epssurprisepct': 14.11,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2019-04-24T16:07:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 1.1,
#   'epsestimate': 1.09,
#   'epssurprisepct': 0.73,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2019-01-30T16:06:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 1.14,
#   'epsestimate': 0.96,
#   'epssurprisepct': 18.38,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2018-10-24T16:07:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 1.13,
#   'epsestimate': 1.08,
#   'epssurprisepct': 5.02,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2018-07-19T16:05:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.95,
#   'epsestimate': 0.85,
#   'epssurprisepct': 11.9,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2018-04-26T16:04:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.96,
#   'epsestimate': 0.87,
#   'epssurprisepct': 10.98,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2018-01-31T16:05:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.84,
#   'epsestimate': 0.72,
#   'epssurprisepct': 16.5,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2017-10-26T16:02:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.98,
#   'epsestimate': 0.71,
#   'epssurprisepct': 39.01,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2017-07-20T16:06:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.73,
#   'epsestimate': 0.7,
#   'epssurprisepct': 4.73,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2017-04-27T16:05:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.83,
#   'epsestimate': 0.79,
#   'epssurprisepct': 4.93,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2017-01-26T16:09:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.76,
#   'epsestimate': 0.68,
#   'epssurprisepct': 11.27,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2016-10-20T16:05:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.69,
#   'epsestimate': 0.58,
#   'epssurprisepct': 18.76,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2016-07-19T16:05:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.62,
#   'epsestimate': 0.64,
#   'epssurprisepct': -2.67,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2016-04-21T16:05:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.78,
#   'epsestimate': 0.71,
#   'epssurprisepct': 9.4,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2016-01-28T16:06:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.67,
#   'epsestimate': 0.59,
#   'epssurprisepct': 14.33,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2015-10-22T16:05:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.6,
#   'epsestimate': 0.56,
#   'epssurprisepct': 6.57,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2015-07-21T16:05:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.61,
#   'epsestimate': 0.51,
#   'epssurprisepct': 20.55,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2015-04-23T16:02:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.71,
#   'epsestimate': 0.71,
#   'epssurprisepct': -0.42,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2015-01-26T16:10:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.54,
#   'epsestimate': 0.49,
#   'epssurprisepct': 11.11,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2014-10-23T16:02:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.55,
#   'epsestimate': 0.6,
#   'epssurprisepct': -8.65,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2014-07-22T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.68,
#   'epsestimate': 0.63,
#   'epssurprisepct': 8.02,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2014-04-24T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.78,
#   'epsestimate': 0.68,
#   'epssurprisepct': 14.83,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2014-01-23T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.62,
#   'epsestimate': 0.54,
#   'epssurprisepct': 15.1,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2013-10-24T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.66,
#   'epsestimate': 0.75,
#   'epssurprisepct': -11.96,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2013-07-18T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.72,
#   'epsestimate': 0.68,
#   'epssurprisepct': 5.97,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2013-04-18T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.76,
#   'epsestimate': 0.75,
#   'epssurprisepct': 1.93,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2013-01-24T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.53,
#   'epsestimate': 0.56,
#   'epssurprisepct': -5.47,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2012-10-18T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.67,
#   'epsestimate': 0.62,
#   'epssurprisepct': 8.48,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2012-07-19T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.6,
#   'epsestimate': 0.57,
#   'epssurprisepct': 4.38,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2012-04-19T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.78,
#   'epsestimate': 0.76,
#   'epssurprisepct': 2.93,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2012-01-19T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.68,
#   'epsestimate': 0.68,
#   'epssurprisepct': 0.38,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2011-10-20T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.69,
#   'epsestimate': 0.58,
#   'epssurprisepct': 19.88,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2011-07-21T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.61,
#   'epsestimate': 0.56,
#   'epssurprisepct': 9.74,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2011-04-28T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.77,
#   'epsestimate': 0.68,
#   'epssurprisepct': 12.57,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2011-01-27T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.62,
#   'epsestimate': 0.55,
#   'epssurprisepct': 12.98,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2010-10-28T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.51,
#   'epsestimate': 0.46,
#   'epssurprisepct': 9.82,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2010-07-22T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.45,
#   'epsestimate': 0.42,
#   'epssurprisepct': 6.95,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2010-04-22T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.74,
#   'epsestimate': 0.59,
#   'epssurprisepct': 24.79,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2010-01-28T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.4,
#   'epsestimate': 0.32,
#   'epssurprisepct': 25.76,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2009-10-23T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.36,
#   'epsestimate': 0.36,
#   'epssurprisepct': 0.22,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2009-07-23T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.39,
#   'epsestimate': 0.39,
#   'epssurprisepct': 0.26,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2009-04-23T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.47,
#   'epsestimate': 0.49,
#   'epssurprisepct': -4.84,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2009-01-22T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.48,
#   'epsestimate': 0.47,
#   'epssurprisepct': 1.84,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2008-10-23T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.46,
#   'epsestimate': 0.47,
#   'epssurprisepct': -2.13,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2008-07-17T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.47,
#   'epsestimate': 0.44,
#   'epssurprisepct': 6.74,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2008-04-24T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.5,
#   'epsestimate': 0.46,
#   'epssurprisepct': 9.33,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2008-01-24T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.45,
#   'epsestimate': 0.39,
#   'epssurprisepct': 15.38,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2007-10-25T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.39,
#   'epsestimate': 0.39,
#   'epssurprisepct': 0.3,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2007-07-19T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.49,
#   'epsestimate': 0.46,
#   'epssurprisepct': 6.86,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2007-04-26T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.26,
#   'epsestimate': 0.23,
#   'epssurprisepct': 11.48,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2007-01-25T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.35,
#   'epsestimate': 0.31,
#   'epssurprisepct': 13.02,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2006-10-26T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.31,
#   'epsestimate': 0.3,
#   'epssurprisepct': 2.63,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2006-07-20T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.32,
#   'epsestimate': 0.33,
#   'epssurprisepct': -2.93,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2006-04-27T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.33,
#   'epsestimate': 0.33,
#   'epssurprisepct': -0.08,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2006-01-26T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.31,
#   'epsestimate': 0.3,
#   'epssurprisepct': 4.14,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2005-10-27T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.32,
#   'epsestimate': 0.31,
#   'epssurprisepct': 2.4,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2005-07-21T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.32,
#   'epsestimate': 0.32,
#   'epssurprisepct': 0.93,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2005-04-28T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.35,
#   'epsestimate': 0.33,
#   'epssurprisepct': 6.81,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2005-01-27T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.31,
#   'epsestimate': 0.3,
#   'epssurprisepct': 2.89,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2004-10-21T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.28,
#   'epsestimate': 0.29,
#   'epssurprisepct': -1.87,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2004-07-22T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.34,
#   'epsestimate': 0.29,
#   'epssurprisepct': 19.1,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2004-04-22T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.34,
#   'epsestimate': 0.3,
#   'epssurprisepct': 13.46,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2004-01-22T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.3,
#   'epsestimate': 0.29,
#   'epssurprisepct': 3.56,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2003-10-23T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.23,
#   'epsestimate': 0.24,
#   'epssurprisepct': -2.84,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2003-07-17T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.27,
#   'epsestimate': 0.24,
#   'epssurprisepct': 13.16,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2003-04-15T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.27,
#   'epsestimate': 0.23,
#   'epssurprisepct': 14.22,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2003-01-16T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.28,
#   'epsestimate': 0.21,
#   'epssurprisepct': 29.06,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2002-10-17T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.21,
#   'epsestimate': 0.21,
#   'epssurprisepct': 0.8,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2002-07-18T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.25,
#   'epsestimate': 0.25,
#   'epssurprisepct': -3.56,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2002-04-18T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.25,
#   'epsestimate': 0.21,
#   'epssurprisepct': 15.25,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2002-01-17T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.22,
#   'epsestimate': 0.2,
#   'epssurprisepct': 9.5,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2001-10-18T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.22,
#   'epsestimate': 0.21,
#   'epssurprisepct': 0.75,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2001-07-19T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.22,
#   'epsestimate': 0.21,
#   'epssurprisepct': 5.33,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2001-04-19T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.24,
#   'epsestimate': 0.23,
#   'epssurprisepct': 1.44,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2001-01-18T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.23,
#   'epsestimate': 0.21,
#   'epssurprisepct': 11.48,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2000-10-18T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.22,
#   'epsestimate': 0.21,
#   'epssurprisepct': 5.81,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2000-07-18T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.22,
#   'epsestimate': 0.2,
#   'epssurprisepct': 5.27,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2000-04-20T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.24,
#   'epsestimate': 0.21,
#   'epssurprisepct': 11.27,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2000-01-18T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.19,
#   'epsestimate': 0.17,
#   'epssurprisepct': 10.38,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '1999-10-19T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.2,
#   'epsestimate': 0.18,
#   'epssurprisepct': 12.03,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '1999-07-19T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.19,
#   'epsestimate': 0.16,
#   'epssurprisepct': 21.78,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '1999-04-20T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.18,
#   'epsestimate': 0.15,
#   'epssurprisepct': 23.47,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '1999-01-19T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.14,
#   'epsestimate': 0.12,
#   'epssurprisepct': 13.84,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '1998-10-20T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.13,
#   'epsestimate': 0.12,
#   'epssurprisepct': 4.99,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '1998-07-16T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'}]

# %% [markdown]
# ##IV.Checking multiple companies by using 'for' statment

# %%
#Semiconductor SOXX ETF holdings (top 15)
soxx_etf_holdings = ['AVGO','AMD','NVDA','INTC','QCOM','TXN','ADI','KLAC','MCHP','NXPI','LRCX','AMAT','MRVL','MU','TSM'] # 'TSMC'(ADR) fail to recall
#Semiconductor SOXX ETF holdings (top 15)
# soxx_etf_holdings = ['INTC','AVGO','TXN','NVDA','QCOM','AMAT','MU','LRCX','KLAC','AMD'] #'TSMC (ADR) fail to recall

# %% [markdown]
# ### 1) To get the current PE ratio by 'for' statement

# %%
error_N = 0

for i in soxx_etf_holdings:
  try:
    sleep(random.uniform(1,2))
    print( i ,si.get_stats_valuation(i))
  except IndexError as e :
    print('cannot recall for now :',f'{i}')
    error_N +=1
    print('N of Eerror = ', error_N)
# Out:
# AVGO                   Unnamed: 0 As of Date: 5/19/2022Current 1/31/2022  \
# 0      Market Cap (intraday)                      232.95B   240.21B
# 1           Enterprise Value                      262.26B   267.80B
# 2               Trailing P/E                        32.53     39.06
# 3                Forward P/E                        16.23     17.79
# 4  PEG Ratio (5 yr expected)                         1.14      1.11
# 5          Price/Sales (ttm)                         8.59      9.16
# 6           Price/Book (mrq)                        10.14      9.62
# 7   Enterprise Value/Revenue                         9.20     34.75
# 8    Enterprise Value/EBITDA                        16.83     61.13
#
#   10/31/2021 7/31/2021 4/30/2021
# 0    218.84B   199.14B   186.27B
# 1    248.22B   230.09B   218.67B
# 2      39.38     45.11     52.74
# 3      17.39     16.26     16.95
# 4       1.21      1.14      1.25
# 5       8.58      8.09      7.82
# 6       9.02      8.32      7.77
# 7      33.51     33.95     33.08
# 8      60.48     63.14     63.27
# AMD                   Unnamed: 0 As of Date: 5/19/2022Current 3/31/2022  \
# 0      Market Cap (intraday)                      156.02B   177.13B
# 1           Enterprise Value                      151.65B   174.18B
# 2               Trailing P/E                        35.93     42.54
# 3                Forward P/E                        23.42     26.95
# 4  PEG Ratio (5 yr expected)                         1.15      1.39
# 5          Price/Sales (ttm)                         6.50      8.18
# 6           Price/Book (mrq)                         2.82     23.63
# 7   Enterprise Value/Revenue                         8.03     29.59
# 8    Enterprise Value/EBITDA                        30.67    113.33
#
#   12/31/2021 9/30/2021 6/30/2021 3/31/2021
# 0    173.69B   124.71B   113.94B    95.38B
# 1    170.66B   121.47B   111.37B    93.62B
# 2      44.28     36.49     39.63     38.11
# 3      43.67     34.60     43.48     41.15
# 4       1.27      1.01      1.43      1.46
# 5      11.86      9.33      9.94      9.70
# 6      24.34     17.65     17.59     16.34
# 7      35.36     28.16     28.93     27.18
# 8     126.89    108.27    118.36    123.51
# NVDA                   Unnamed: 0 As of Date: 5/19/2022Current 1/31/2022  \
# 0      Market Cap (intraday)                      424.13B   613.62B
# 1           Enterprise Value                      414.61B   606.15B
# 2               Trailing P/E                        43.99     75.46
# 3                Forward P/E                        29.94     47.62
# 4  PEG Ratio (5 yr expected)                         2.21      2.61
# 5          Price/Sales (ttm)                        15.95     25.55
# 6           Price/Book (mrq)                        15.94     25.78
# 7   Enterprise Value/Revenue                        15.40     79.31
# 8    Enterprise Value/EBITDA                        36.53    187.37
#
#   10/31/2021 7/31/2021 4/30/2021
# 0    639.17B   485.92B   373.67B
# 1    632.31B   480.99B   369.82B
# 2      91.47     92.19     87.01
# 3      54.95     50.00     43.48
# 4       3.84      3.50      3.73
# 5      29.52     25.54     22.61
# 6      30.25     25.88     22.12
# 7      89.02     73.92     65.33
# 8     210.91    175.54    155.52
# INTC                   Unnamed: 0 As of Date: 5/20/2022Current 3/31/2022  \
# 0      Market Cap (intraday)                      171.78B   202.64B
# 1           Enterprise Value                      170.33B   212.32B
# 2               Trailing P/E                         6.98     10.20
# 3                Forward P/E                        11.71     14.37
# 4  PEG Ratio (5 yr expected)                         2.34      2.87
# 5          Price/Sales (ttm)                         2.21      2.57
# 6           Price/Book (mrq)                         1.67      2.12
# 7   Enterprise Value/Revenue                         2.19     11.57
# 8    Enterprise Value/EBITDA                         4.23     16.17
#
#   12/31/2021 9/30/2021 6/30/2021 3/31/2021
# 0    209.60B   216.69B   227.76B   258.43B
# 1    215.27B   227.24B   241.25B   270.94B
# 2      10.00     11.84     12.62     12.96
# 3      14.22     12.02     12.67     14.06
# 4       2.85      2.06      2.53      2.81
# 5       2.69      2.83      3.02      3.48
# 6       2.33      2.54      2.85      3.19
# 7      10.49     11.84     12.29     13.77
# 8      25.62     22.81     27.63     38.72
# QCOM                   Unnamed: 0 As of Date: 5/20/2022Current 3/31/2022  \
# 0      Market Cap (intraday)                      146.24B   171.46B
# 1           Enterprise Value                      150.37B   175.90B
# 2               Trailing P/E                        13.38     17.51
# 3                Forward P/E                        10.75     13.14
# 4  PEG Ratio (5 yr expected)                         0.64      0.83
# 5          Price/Sales (ttm)                         3.80      4.86
# 6           Price/Book (mrq)                        10.97     15.13
# 7   Enterprise Value/Revenue                         3.83     15.76
# 8    Enterprise Value/EBITDA                         9.99     44.11
#
#   12/31/2021 9/30/2021 6/30/2021 3/31/2021
# 0    205.73B   145.10B   161.23B   149.69B
# 1    209.06B   147.94B   165.43B   153.13B
# 2      23.24     16.12     20.51     22.70
# 3      17.30     14.12     16.45     18.05
# 4       1.07      0.64      0.66      0.76
# 5       6.26      4.55      5.58      5.70
# 6      20.68     17.75     21.72     20.28
# 7      19.53     15.85     20.53     19.30
# 8      47.41     38.44     59.06     57.63
# TXN                   Unnamed: 0 As of Date: 5/19/2022Current 3/31/2022  \
# 0      Market Cap (intraday)                      157.04B   169.17B
# 1           Enterprise Value                      154.96B   167.55B
# 2               Trailing P/E                        19.49     22.21
# 3                Forward P/E                        18.90     19.96
# 4  PEG Ratio (5 yr expected)                         2.40      2.41
# 5          Price/Sales (ttm)                         8.40      9.36
# 6           Price/Book (mrq)                        11.20     12.69
# 7   Enterprise Value/Revenue                         8.17     34.16
# 8    Enterprise Value/EBITDA                        14.59     60.01
#
#   12/31/2021 9/30/2021 6/30/2021 3/31/2021
# 0    174.15B   177.49B   177.51B   174.48B
# 1    172.10B   176.35B   177.07B   174.96B
# 2      24.19     26.81     29.14     31.66
# 3      22.47     23.31     26.95     28.82
# 4       2.11      2.13      2.49      2.87
# 5      10.02     10.70     11.61     12.19
# 6      14.33     15.91     17.46     18.99
# 7      35.62     37.98     38.66     40.79
# 8      63.16     68.54     69.91     78.60
# ADI                   Unnamed: 0 As of Date: 5/19/2022Current 1/31/2022  \
# 0      Market Cap (intraday)                       83.69B    85.81B
# 1           Enterprise Value                       88.15B    90.65B
# 2               Trailing P/E                        54.21     47.39
# 3                Forward P/E                        19.34     21.74
# 4  PEG Ratio (5 yr expected)                         1.79      2.08
# 5          Price/Sales (ttm)                         8.34      8.99
# 6           Price/Book (mrq)                         2.24      2.26
# 7   Enterprise Value/Revenue                        10.44     33.77
# 8    Enterprise Value/EBITDA                        30.90     95.90
#
#   10/31/2021 7/31/2021 4/30/2021
# 0     93.27B    61.75B    56.50B
# 1     96.94B    65.59B    60.60B
# 2      37.96     39.96     40.63
# 3      23.87     23.81     24.69
# 4       1.87      2.04      2.13
# 5       9.93     10.05      9.73
# 6       7.43      5.07      4.67
# 7      41.44     37.29     36.47
# 8     256.86     80.67     84.49
# KLAC                   Unnamed: 0 As of Date: 5/20/2022Current 3/31/2022  \
# 0      Market Cap (intraday)                       50.52B    54.68B
# 1           Enterprise Value                       51.73B    55.41B
# 2               Trailing P/E                        16.43     18.84
# 3                Forward P/E                        13.91     15.67
# 4  PEG Ratio (5 yr expected)                         1.28      1.47
# 5          Price/Sales (ttm)                         5.98      6.90
# 6           Price/Book (mrq)                        12.38     13.51
# 7   Enterprise Value/Revenue                         5.98     24.21
# 8    Enterprise Value/EBITDA                        13.79     56.63
#
#   12/31/2021 9/30/2021 6/30/2021 3/31/2021
# 0     64.88B    50.76B    49.53B    50.67B
# 1     65.80B    51.81B    50.63B    51.94B
# 2      24.38     25.02     27.24     37.72
# 3      20.58     17.99     19.49     22.37
# 4       1.85      1.83      1.56      2.10
# 5       8.91      7.52      7.83      8.51
# 6      16.80     15.03     15.90     17.26
# 7      27.97     24.86     26.30     28.80
# 8      62.65     58.25     60.75     68.00
# MCHP                   Unnamed: 0 As of Date: 5/19/2022Current 3/31/2022  \
# 0      Market Cap (intraday)                       36.77B    41.78B
# 1           Enterprise Value                       44.14B    49.37B
# 2               Trailing P/E                        29.14     44.07
# 3                Forward P/E                        12.36     14.39
# 4  PEG Ratio (5 yr expected)                         1.29      0.99
# 5          Price/Sales (ttm)                         5.49      6.59
# 6           Price/Book (mrq)                         6.24      7.20
# 7   Enterprise Value/Revenue                         6.47     26.77
# 8    Enterprise Value/EBITDA                        16.10     63.77
#
#   12/31/2021 9/30/2021 6/30/2021 3/31/2021
# 0     48.40B    42.58B    41.03B    42.46B
# 1     56.38B    50.87B    49.82B    51.27B
# 2      76.70     90.29    116.08    123.19
# 3      17.51     17.99     19.38     20.28
# 4       1.67      1.82      1.63      1.47
# 5       8.09      7.46      7.45      7.75
# 6       8.49      7.71      7.69      8.02
# 7      32.08     30.83     31.75     34.94
# 8      71.47     83.79     77.66    100.48
# NXPI                   Unnamed: 0 As of Date: 5/19/2022Current 3/31/2022  \
# 0      Market Cap (intraday)                       46.05B    48.59B
# 1           Enterprise Value                       53.94B    56.34B
# 2               Trailing P/E                        21.87     27.26
# 3                Forward P/E                        12.79     14.58
# 4  PEG Ratio (5 yr expected)                         1.15      1.36
# 5          Price/Sales (ttm)                         4.09      4.61
# 6           Price/Book (mrq)                         7.08      7.44
# 7   Enterprise Value/Revenue                         4.64     17.96
# 8    Enterprise Value/EBITDA                        12.97     47.66
#
#   12/31/2021 9/30/2021 6/30/2021 3/31/2021
# 0     60.35B    51.93B    56.73B    55.52B
# 1     67.64B    58.61B    62.50B    60.85B
# 2      40.17     53.08    136.24     1.12k
# 3      18.98     17.18     21.46     21.79
# 4       1.17      1.03      1.37      1.41
# 5       6.11      5.61      6.39      6.64
# 6       8.96      6.98      6.83      6.21
# 7      22.26     20.49     24.07     23.71
# 8      62.06     57.46     72.00     73.05
# LRCX                   Unnamed: 0 As of Date: 5/19/2022Current 3/31/2022  \
# 0      Market Cap (intraday)                       66.23B    74.57B
# 1           Enterprise Value                       66.89B    74.24B
# 2               Trailing P/E                        14.93     16.77
# 3                Forward P/E                        12.77     13.83
# 4  PEG Ratio (5 yr expected)                         0.99      1.01
# 5          Price/Sales (ttm)                         4.05      4.65
# 6           Price/Book (mrq)                        10.99     11.52
# 7   Enterprise Value/Revenue                         4.00     18.28
# 8    Enterprise Value/EBITDA                        11.82     58.65
#
#   12/31/2021 9/30/2021 6/30/2021 3/31/2021
# 0    100.88B    80.14B    92.73B    84.89B
# 1    101.26B    79.41B    92.75B    84.67B
# 2      24.31     21.16     27.51     29.57
# 3      20.45     16.72     20.33     21.28
# 4       1.51      1.42      0.95      1.24
# 5       6.58      5.65      7.17      7.34
# 6      17.33     13.30     17.25     15.41
# 7      23.96     18.45     22.38     22.01
# 8      68.21     54.08     64.46     65.55
# AMAT                   Unnamed: 0 As of Date: 5/19/2022Current 1/31/2022  \
# 0      Market Cap (intraday)                       98.36B   122.07B
# 1           Enterprise Value                       98.38B   122.36B
# 2               Trailing P/E                        15.51     21.59
# 3                Forward P/E                        13.74     16.92
# 4  PEG Ratio (5 yr expected)                         1.67      1.95
# 5          Price/Sales (ttm)                         4.20      5.51
# 6           Price/Book (mrq)                         8.27      9.97
# 7   Enterprise Value/Revenue                         4.07     19.51
# 8    Enterprise Value/EBITDA                        12.16     58.71
#
#   10/31/2021 7/31/2021 4/30/2021
# 0    123.39B   127.89B   121.78B
# 1    122.59B   126.83B   120.86B
# 2      23.77     29.15     31.75
# 3      17.42     18.83     22.22
# 4       1.08      1.22      1.77
# 5       5.83      6.52      6.73
# 6      10.11     10.66     10.61
# 7      20.02     20.47     21.65
# 8      56.55     59.41     70.97
# MRVL                   Unnamed: 0 As of Date: 5/19/2022Current 1/31/2022  \
# 0      Market Cap (intraday)                       46.80B    60.45B
# 1           Enterprise Value                       50.91B    64.68B
# 2               Trailing P/E                        22.15       NaN
# 3                Forward P/E                        24.21     31.15
# 4  PEG Ratio (5 yr expected)                         1.44      1.37
# 5          Price/Sales (ttm)                         9.82     13.75
# 6           Price/Book (mrq)                         2.98      3.85
# 7   Enterprise Value/Revenue                        11.41     48.16
# 8    Enterprise Value/EBITDA                        56.49    158.50
#
#   10/31/2021 7/31/2021 4/30/2021
# 0     56.42B    49.81B    30.87B
# 1     60.75B    54.38B    31.45B
# 2        NaN       NaN       NaN
# 3      33.56     42.37     33.00
# 4       1.72      2.59      2.21
# 5      14.16     13.17     10.18
# 6       3.91      3.35      3.66
# 7      50.15     50.55     37.79
# 8     190.60    727.52    315.74
# MU                   Unnamed: 0 As of Date: 5/19/2022Current 2/28/2022  \
# 0      Market Cap (intraday)                       79.34B    99.50B
# 1           Enterprise Value                       76.83B    97.47B
# 2               Trailing P/E                         8.94     13.73
# 3                Forward P/E                         6.06      9.66
# 4  PEG Ratio (5 yr expected)                         0.73      1.04
# 5          Price/Sales (ttm)                         2.59      3.42
# 6           Price/Book (mrq)                         1.66      2.17
# 7   Enterprise Value/Revenue                         2.46     12.52
# 8    Enterprise Value/EBITDA                         4.64     22.64
#
#   11/30/2021 8/31/2021 5/31/2021 2/28/2021
# 0     94.09B    82.97B    94.36B   102.39B
# 1     92.74B    81.85B    94.32B   102.52B
# 2      16.34     20.36     29.94     34.54
# 3       9.13      6.88      8.26     21.83
# 4       1.02      0.27      0.38      1.02
# 5       3.46      3.29      4.06      4.70
# 6       2.14      1.96      2.32      2.57
# 7      12.06      9.89     12.71     16.44
# 8      21.89     17.78     27.67     46.05
# TSM                   Unnamed: 0 As of Date: 5/19/2022Current 3/31/2022  \
# 0      Market Cap (intraday)                      470.73B   542.12B
# 1           Enterprise Value                      453.90B   526.15B
# 2               Trailing P/E                        21.31     25.88
# 3                Forward P/E                        16.29     20.37
# 4  PEG Ratio (5 yr expected)                         0.98      1.22
# 5          Price/Sales (ttm)                         8.14      9.73
# 6           Price/Book (mrq)                         6.03      7.18
# 7   Enterprise Value/Revenue                         0.26      1.07
# 8    Enterprise Value/EBITDA                         0.39      1.55
#
#   12/31/2021 9/30/2021 6/30/2021 3/31/2021
# 0    575.95B   540.17B   552.88B   534.62B
# 1    561.98B   526.73B   539.47B   519.27B
# 2      30.53     30.21     32.59     33.73
# 3      25.64     24.33     29.94     31.15
# 4       1.91      1.85      2.27      2.38
# 5      11.44     11.59     12.50     13.04
# 6       8.32      8.31      8.97      9.44
# 7       1.28      1.27      1.45      1.43
# 8       1.92      1.87      2.12      2.02

# %% [markdown]
# ### 2) To get the date of coming earnings for multiple companies
# - get_next_earnings_date()

# %%
error_N=0
for i in soxx_etf_holdings:
  try:
    sleep(random.uniform(1,2))
    print( i ,si.get_next_earnings_date(i))
  except IndexError as e:
    print('cannot recall the data : ', f'{i}')
    error_N +=1
    print('error_N = ', error_N)
# Out:
# AVGO 2022-06-02 20:00:00
# AMD 2022-07-25 10:59:00
# NVDA 2022-05-25 23:00:00
# INTC 2022-07-20 20:00:00
# QCOM 2022-07-26 10:59:00
# TXN 2022-07-19 10:59:00
# ADI 2022-08-16 07:00:00
# KLAC 2022-07-27 10:59:00
# MCHP 2022-08-01 10:59:00
# NXPI 2022-07-25 20:00:00
# LRCX 2022-07-26 20:00:00
# AMAT 2022-08-18 20:00:00
# MRVL 2022-06-06 20:00:00
# MU 2022-06-28 10:59:00
# cannot recall the data :  TSM
# error_N =  1

# %% [markdown]
# ### 3)To get the date of earnings by 'for' satement
# - get_earnings()

# %%
for i in soxx_etf_holdings:
  sleep(random.uniform(1,2))
  print( i, si.get_earnings(i))
# Out:
# AVGO {'quarterly_results':      date  actual  estimate
# 0  2Q2021    6.62      6.42
# 1  3Q2021    6.96      6.88
# 2  4Q2021    7.81      7.74
# 3  1Q2022    8.39      8.08, 'yearly_revenue_earnings':    date      revenue     earnings
# 0  2018  20848000000  12259000000
# 1  2019  22597000000   2724000000
# 2  2020  23888000000   2960000000
# 3  2021  27450000000   6736000000, 'quarterly_revenue_earnings':      date     revenue    earnings
# 0  2Q2021  6610000000  1493000000
# 1  3Q2021  6778000000  1876000000
# 2  4Q2021  7407000000  1989000000
# 3  1Q2022  7706000000  2472000000}
# AMD {'quarterly_results':      date  actual  estimate
# 0  2Q2021    0.63      0.54
# 1  3Q2021    0.73      0.67
# 2  4Q2021    0.92      0.76
# 3  1Q2022    1.13      0.91, 'yearly_revenue_earnings':    date      revenue    earnings
# 0  2018   6475000000   337000000
# 1  2019   6731000000   341000000
# 2  2020   9763000000  2490000000
# 3  2021  16434000000  3162000000, 'quarterly_revenue_earnings':      date     revenue   earnings
# 0  2Q2021  3850000000  710000000
# 1  3Q2021  4313000000  923000000
# 2  4Q2021  4826000000  974000000
# 3  1Q2022           0          0}
# NVDA {'quarterly_results':      date  actual  estimate
# 0  2Q2021    0.91      0.82
# 1  3Q2021    1.04      1.01
# 2  4Q2021    1.17      1.11
# 3  1Q2022    1.32      1.22, 'yearly_revenue_earnings':    date      revenue    earnings
# 0  2019  11716000000  4141000000
# 1  2020  10918000000  2796000000
# 2  2021  16675000000  4332000000
# 3  2022  26914000000  9752000000, 'quarterly_revenue_earnings':      date     revenue    earnings
# 0  2Q2021  5661000000  1912000000
# 1  3Q2021  6507000000  2374000000
# 2  4Q2021  7103000000  2464000000
# 3  1Q2022  7643000000  3003000000}
# INTC {'quarterly_results':      date  actual  estimate
# 0  2Q2021    1.28      1.06
# 1  3Q2021    1.71      1.11
# 2  4Q2021    1.09      0.91
# 3  1Q2022    0.87      0.80, 'yearly_revenue_earnings':    date      revenue     earnings
# 0  2018  70848000000  21053000000
# 1  2019  71965000000  21048000000
# 2  2020  77867000000  20899000000
# 3  2021  79024000000  19868000000, 'quarterly_revenue_earnings':      date      revenue    earnings
# 0  2Q2021  19631000000  5061000000
# 1  3Q2021  19192000000  6823000000
# 2  4Q2021  20528000000  4623000000
# 3  2Q2022  18353000000  8113000000}
# QCOM {'quarterly_results':      date  actual  estimate
# 0  2Q2021    1.92      1.68
# 1  3Q2021    2.55      2.26
# 2  4Q2021    3.23      3.01
# 3  1Q2022    3.21      2.91, 'yearly_revenue_earnings':    date      revenue    earnings
# 0  2018  22611000000 -4964000000
# 1  2019  24273000000  4386000000
# 2  2020  23531000000  5198000000
# 3  2021  33566000000  9043000000, 'quarterly_revenue_earnings':      date      revenue    earnings
# 0  2Q2021   8060000000  2027000000
# 1  3Q2021   9336000000  2798000000
# 2  4Q2021  10705000000  3399000000
# 3  1Q2022  11164000000  2934000000}
# TXN {'quarterly_results':      date  actual  estimate
# 0  2Q2021    2.05      1.83
# 1  3Q2021    2.07      2.05
# 2  4Q2021    2.27      1.94
# 3  1Q2022    2.35      2.18, 'yearly_revenue_earnings':    date      revenue    earnings
# 0  2018  15784000000  5580000000
# 1  2019  14383000000  5017000000
# 2  2020  14461000000  5595000000
# 3  2021  18344000000  7769000000, 'quarterly_revenue_earnings':      date     revenue    earnings
# 0  2Q2021  4580000000  1931000000
# 1  3Q2021  4643000000  1947000000
# 2  4Q2021  4832000000  2138000000
# 3  1Q2022  4905000000  2201000000}
# ADI {'quarterly_results':      date  actual  estimate
# 0  3Q2021    1.72      1.63
# 1  4Q2021    1.73      1.70
# 2  1Q2022    1.94      1.78
# 3  2Q2022    2.40      2.11, 'yearly_revenue_earnings':    date     revenue    earnings
# 0  2018  6224689000  1506980000
# 1  2019  5991065000  1363011000
# 2  2020  5603056000  1220761000
# 3  2021  7318286000  1390422000, 'quarterly_revenue_earnings':      date     revenue   earnings
# 0  3Q2021  1758853000  503311000
# 1  4Q2021  2339568000   75687000
# 2  1Q2022  2684293000  280077000
# 3  2Q2022  2972064000  783273000}
# KLAC {'quarterly_results':      date  actual  estimate
# 0  2Q2021    4.43      3.99
# 1  3Q2021    4.64      4.52
# 2  4Q2021    5.59      5.45
# 3  1Q2022    5.13      4.82, 'yearly_revenue_earnings':    date     revenue    earnings
# 0  2018  4036701000   802265000
# 1  2019  4568904000  1175617000
# 2  2020  5806424000  1216785000
# 3  2021  6918734000  2078292000, 'quarterly_revenue_earnings':      date     revenue    earnings
# 0  2Q2021  1925471000   632978000
# 1  3Q2021  2083838000  1068417000
# 2  4Q2021  2352630000   717444000
# 3  1Q2022  2288676000   730572000}
# MCHP {'quarterly_results':      date  actual  estimate
# 0  2Q2021    0.99      0.95
# 1  3Q2021    1.07      1.06
# 2  4Q2021    1.20      1.17
# 3  1Q2022    1.35      1.25, 'yearly_revenue_earnings':    date     revenue    earnings
# 0  2019  5349500000   355900000
# 1  2020  5274200000   570600000
# 2  2021  5438400000   349400000
# 3  2022  6820900000  1285500000, 'quarterly_revenue_earnings':      date     revenue   earnings
# 0  2Q2021  1569400000  252800000
# 1  3Q2021  1649800000  242000000
# 2  4Q2021  1757500000  352800000
# 3  1Q2022  1844200000  437900000}
# NXPI {'quarterly_results':      date  actual  estimate
# 0  2Q2021    2.44      2.31
# 1  3Q2021    2.84      2.72
# 2  4Q2021    3.20      2.99
# 3  1Q2022    3.34      3.17, 'yearly_revenue_earnings':    date      revenue    earnings
# 0  2018   9407000000  2208000000
# 1  2019   8877000000   243000000
# 2  2020   8612000000    52000000
# 3  2021  11063000000  1871000000, 'quarterly_revenue_earnings':      date     revenue   earnings
# 0  3Q2021  2596000000  397000000
# 1  4Q2021  2861000000  519000000
# 2  4Q2021  3039000000  602000000
# 3  2Q2022           0          0}
# LRCX {'quarterly_results':      date  actual  estimate
# 0  2Q2021    8.09      7.55
# 1  3Q2021    8.36      8.21
# 2  4Q2021    8.53      8.51
# 3  1Q2022    7.40      7.51, 'yearly_revenue_earnings':    date      revenue    earnings
# 0  2018  11076998000  2380681000
# 1  2019   9653559000  2191430000
# 2  2020  10044736000  2251753000
# 3  2021  14626150000  3908458000, 'quarterly_revenue_earnings':      date     revenue    earnings
# 0  2Q2021  4145179000  1144657000
# 1  3Q2021  4304465000  1179744000
# 2  4Q2021  4226604000  1194830000
# 3  1Q2022  4060416000  1021778000}
# AMAT {'quarterly_results':      date  actual  estimate
# 0  3Q2021    1.90      1.77
# 1  4Q2021    1.94      1.95
# 2  1Q2022    1.89      1.85
# 3  2Q2022    1.85      1.90, 'yearly_revenue_earnings':    date      revenue    earnings
# 0  2018  16705000000  3038000000
# 1  2019  14608000000  2706000000
# 2  2020  17202000000  3619000000
# 3  2021  23063000000  5888000000, 'quarterly_revenue_earnings':      date     revenue    earnings
# 0  3Q2021  6196000000  1716000000
# 1  4Q2021  6123000000  1712000000
# 2  1Q2022  6271000000  1792000000
# 3  2Q2022  6245000000  1536000000}
# MRVL {'quarterly_results':      date  actual  estimate
# 0  2Q2021    0.29      0.27
# 1  3Q2021    0.34      0.31
# 2  4Q2021    0.43      0.38
# 3  1Q2022    0.50      0.48, 'yearly_revenue_earnings':    date     revenue    earnings
# 0  2019  2865791000  -179094000
# 1  2020  2699161000  1584391000
# 2  2021  2968900000  -277298000
# 3  2022  4462383000  -421034000, 'quarterly_revenue_earnings':      date     revenue   earnings
# 0  2Q2021   832279000  -88242000
# 1  3Q2021  1075881000 -276428000
# 2  4Q2021  1211245000  -62532000
# 3  1Q2022  1342978000    6168000}
# MU {'quarterly_results':      date  actual  estimate
# 0  2Q2021    1.88      1.72
# 1  3Q2021    2.42      2.33
# 2  4Q2021    2.16      2.11
# 3  1Q2022    2.14      1.97, 'yearly_revenue_earnings':    date      revenue     earnings
# 0  2018  30391000000  14135000000
# 1  2019  23406000000   6313000000
# 2  2020  21435000000   2687000000
# 3  2021  27705000000   5861000000, 'quarterly_revenue_earnings':      date     revenue    earnings
# 0  2Q2021  7422000000  1735000000
# 1  3Q2021  8274000000  2720000000
# 2  4Q2021  7687000000  2306000000
# 3  1Q2022  7786000000  2263000000}
# TSM {'quarterly_results':      date  actual  estimate
# 0  2Q2021    0.93      0.93
# 1  3Q2021    1.08      1.04
# 2  4Q2021    1.15      1.14
# 3  1Q2022    1.39      1.33, 'yearly_revenue_earnings':    date        revenue      earnings
# 0  2018  1031473557000  351130884000
# 1  2019  1069985448000  345263668000
# 2  2020  1339254811000  517885387000
# 3  2021  1587415037000  596540013000, 'quarterly_revenue_earnings':      date       revenue      earnings
# 0  2Q2021  372145122000  134358942000
# 1  3Q2021  414670379000  156258287000
# 2  4Q2021  438189306000  166232291000
# 3  1Q2022  491075873000  202732975000}

# %% [markdown]
# ### 4) To get earnings history for mulitple companies

# %%
test_Co = ['AVGO','AMD','NVDA','INTC','QCOM','TXN','ADI','KLAC','MCHP','NXPI','LRCX','AMAT','MRVL','MU','TSM']

error_N = 0
for j in test_Co:
  try:
    sleep(random.uniform(1,2)) 
    company_eps = si.get_earnings_history(f'{j}')
    print('------company abbreviation : ', j,'------')
    print('total data N : ' , len(company_eps))
    print('\n')


    for i in range(len(company_eps)):

        print('eps(actual)   :' , company_eps[i]['epsactual'])
        print('eps(estimate) :' , company_eps[i]['epsestimate'])
        print('date :', company_eps[i]['startdatetime'],company_eps[i]['timeZoneShortName'])
        print('\n')
  except IndexError as e :
    print(f'{j}', '<--error') 
    error_N +=1
    print('error_number = ', error_N)
# Out:
# Streaming output truncated to the last 5000 lines.
# eps(actual)   : 0.89
# eps(estimate) : 0.82
# date : 2012-11-07T05:00:00.000Z EST
#
#
# eps(actual)   : 0.85
# eps(estimate) : 0.86
# date : 2012-07-18T04:00:00.000Z EDT
#
#
# eps(actual)   : 1.01
# eps(estimate) : 0.96
# date : 2012-04-18T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.97
# eps(estimate) : 0.9
# date : 2012-02-01T05:00:00.000Z EST
#
#
# eps(actual)   : 0.8
# eps(estimate) : 0.78
# date : 2011-11-02T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.73
# eps(estimate) : 0.71
# date : 2011-07-20T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.86
# eps(estimate) : 0.8
# date : 2011-04-20T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.82
# eps(estimate) : 0.72
# date : 2011-01-26T05:00:00.000Z EST
#
#
# eps(actual)   : 0.68
# eps(estimate) : 0.59
# date : 2010-11-03T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.57
# eps(estimate) : 0.54
# date : 2010-07-21T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.59
# eps(estimate) : 0.56
# date : 2010-04-21T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.62
# eps(estimate) : 0.56
# date : 2010-01-27T05:00:00.000Z EST
#
#
# eps(actual)   : 0.64
# eps(estimate) : 0.52
# date : 2009-11-04T05:00:00.000Z EST
#
#
# eps(actual)   : 0.54
# eps(estimate) : 0.52
# date : 2009-07-22T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.41
# eps(estimate) : 0.41
# date : 2009-04-27T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.31
# eps(estimate) : 0.47
# date : 2009-01-28T05:00:00.000Z EST
#
#
# eps(actual)   : 0.63
# eps(estimate) : 0.6
# date : 2008-11-06T05:00:00.000Z EST
#
#
# eps(actual)   : 0.55
# eps(estimate) : 0.55
# date : 2008-07-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.54
# eps(estimate) : 0.52
# date : 2008-04-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.52
# eps(estimate) : 0.53
# date : 2008-01-23T05:00:00.000Z EST
#
#
# eps(actual)   : 0.54
# eps(estimate) : 0.53
# date : 2007-11-08T05:00:00.000Z EST
#
#
# eps(actual)   : 0.55
# eps(estimate) : 0.52
# date : 2007-07-25T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.5
# eps(estimate) : 0.48
# date : 2007-04-25T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.43
# eps(estimate) : 0.42
# date : 2007-01-24T05:00:00.000Z EST
#
#
# eps(actual)   : 0.42
# eps(estimate) : 0.41
# date : 2006-11-02T05:00:00.000Z EST
#
#
# eps(actual)   : 0.42
# eps(estimate) : 0.42
# date : 2006-07-19T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.41
# eps(estimate) : 0.4
# date : 2006-04-19T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.39
# eps(estimate) : 0.38
# date : 2006-01-25T05:00:00.000Z EST
#
#
# eps(actual)   : 0.32
# eps(estimate) : 0.33
# date : 2005-11-02T05:00:00.000Z EST
#
#
# eps(actual)   : 0.28
# eps(estimate) : 0.25
# date : 2005-07-20T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.29
# eps(estimate) : 0.27
# date : 2005-04-20T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.28
# eps(estimate) : 0.27
# date : 2005-01-19T05:00:00.000Z EST
#
#
# eps(actual)   : 0.29
# eps(estimate) : 0.29
# date : 2004-11-03T05:00:00.000Z EST
#
#
# eps(actual)   : 0.28
# eps(estimate) : 0.26
# date : 2004-07-21T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.27
# eps(estimate) : 0.24
# date : 2004-04-21T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.26
# eps(estimate) : 0.24
# date : 2004-01-21T05:00:00.000Z EST
#
#
# eps(actual)   : 0.14
# eps(estimate) : 0.14
# date : 2003-11-05T05:00:00.000Z EST
#
#
# eps(actual)   : 0.17
# eps(estimate) : 0.15
# date : 2003-07-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.19
# eps(estimate) : 0.18
# date : 2003-04-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.21
# eps(estimate) : 0.19
# date : 2003-01-22T05:00:00.000Z EST
#
#
# eps(actual)   : 0.16
# eps(estimate) : 0.14
# date : 2002-11-07T05:00:00.000Z EST
#
#
# eps(actual)   : 0.12
# eps(estimate) : 0.11
# date : 2002-07-25T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.1
# eps(estimate) : 0.1
# date : 2002-04-24T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.12
# eps(estimate) : 0.11
# date : 2002-01-24T05:00:00.000Z EST
#
#
# eps(actual)   : 0.12
# eps(estimate) : 0.12
# date : 2001-11-06T05:00:00.000Z EST
#
#
# eps(actual)   : 0.11
# eps(estimate) : 0.1
# date : 2001-07-26T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.14
# eps(estimate) : 0.15
# date : 2001-04-25T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.14
# eps(estimate) : 0.14
# date : 2001-01-25T05:00:00.000Z EST
#
#
# eps(actual)   : 0.13
# eps(estimate) : 0.14
# date : 2000-11-02T05:00:00.000Z EST
#
#
# eps(actual)   : 0.14
# eps(estimate) : 0.14
# date : 2000-07-19T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.13
# eps(estimate) : 0.12
# date : 2000-04-18T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.13
# eps(estimate) : 0.12
# date : 2000-01-25T05:00:00.000Z EST
#
#
# eps(actual)   : 0.11
# eps(estimate) : 0.11
# date : 1999-11-02T05:00:00.000Z EST
#
#
# eps(actual)   : 0.09
# eps(estimate) : 0.08
# date : 1999-07-19T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.05
# eps(estimate) : 0.04
# date : 1999-04-20T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.04
# eps(estimate) : 0.04
# date : 1999-01-19T05:00:00.000Z EST
#
#
# eps(actual)   : 0.03
# eps(estimate) : 0.03
# date : 1998-11-03T05:00:00.000Z EST
#
#
# eps(actual)   : 0.02
# eps(estimate) : 0.02
# date : 1998-07-21T04:00:00.000Z EDT
#
#
# ------company abbreviation :  TXN ------
# total data N :  100
#
#
# eps(actual)   : None
# eps(estimate) : None
# date : 2023-04-24T10:59:00.000Z EDT
#
#
# eps(actual)   : None
# eps(estimate) : None
# date : 2023-01-23T10:59:00.000Z EST
#
#
# eps(actual)   : None
# eps(estimate) : None
# date : 2022-10-24T10:59:00.000Z EDT
#
#
# eps(actual)   : None
# eps(estimate) : 2.09
# date : 2022-07-19T10:59:00.000Z EDT
#
#
# eps(actual)   : 2.35
# eps(estimate) : 2.18
# date : 2022-04-26T16:01:00.000Z EDT
#
#
# eps(actual)   : 2.27
# eps(estimate) : 1.94
# date : 2022-01-25T16:01:00.000Z EST
#
#
# eps(actual)   : 2.07
# eps(estimate) : 2.05
# date : 2021-10-26T16:01:00.000Z EDT
#
#
# eps(actual)   : 2.05
# eps(estimate) : 1.84
# date : 2021-07-21T16:03:00.000Z EDT
#
#
# eps(actual)   : 1.87
# eps(estimate) : 1.58
# date : 2021-04-27T16:01:00.000Z EDT
#
#
# eps(actual)   : 1.64
# eps(estimate) : 1.34
# date : 2021-01-26T16:01:00.000Z EST
#
#
# eps(actual)   : 1.45
# eps(estimate) : 1.28
# date : 2020-10-20T16:01:00.000Z EDT
#
#
# eps(actual)   : 1.48
# eps(estimate) : 0.88
# date : 2020-07-21T16:01:00.000Z EDT
#
#
# eps(actual)   : 1.24
# eps(estimate) : 1
# date : 2020-04-21T16:01:00.000Z EDT
#
#
# eps(actual)   : 1.12
# eps(estimate) : 1.02
# date : 2020-01-22T16:01:00.000Z EST
#
#
# eps(actual)   : 1.49
# eps(estimate) : 1.42
# date : 2019-10-22T16:01:00.000Z EDT
#
#
# eps(actual)   : 1.36
# eps(estimate) : 1.22
# date : 2019-07-23T16:01:00.000Z EDT
#
#
# eps(actual)   : 1.26
# eps(estimate) : 1.13
# date : 2019-04-23T16:01:00.000Z EDT
#
#
# eps(actual)   : 1.27
# eps(estimate) : 1.24
# date : 2019-01-23T16:02:00.000Z EST
#
#
# eps(actual)   : 1.58
# eps(estimate) : 1.53
# date : 2018-10-23T16:01:00.000Z EDT
#
#
# eps(actual)   : 1.4
# eps(estimate) : 1.32
# date : 2018-07-24T16:01:00.000Z EDT
#
#
# eps(actual)   : 1.35
# eps(estimate) : 1.11
# date : 2018-04-24T16:01:00.000Z EDT
#
#
# eps(actual)   : 1.09
# eps(estimate) : 1.09
# date : 2018-01-23T16:01:00.000Z EST
#
#
# eps(actual)   : 1.26
# eps(estimate) : 1.12
# date : 2017-10-24T16:01:00.000Z EDT
#
#
# eps(actual)   : 1.03
# eps(estimate) : 0.96
# date : 2017-07-25T16:01:00.000Z EDT
#
#
# eps(actual)   : 0.97
# eps(estimate) : 0.83
# date : 2017-04-25T16:30:00.000Z EDT
#
#
# eps(actual)   : 0.87
# eps(estimate) : 0.82
# date : 2017-01-24T16:30:00.000Z EST
#
#
# eps(actual)   : 0.94
# eps(estimate) : 0.86
# date : 2016-10-26T16:30:00.000Z EDT
#
#
# eps(actual)   : 0.76
# eps(estimate) : 0.73
# date : 2016-07-25T16:30:00.000Z EDT
#
#
# eps(actual)   : 0.65
# eps(estimate) : 0.62
# date : 2016-04-27T16:30:00.000Z EDT
#
#
# eps(actual)   : 0.8
# eps(estimate) : 0.69
# date : 2016-01-27T16:30:00.000Z EST
#
#
# eps(actual)   : 0.76
# eps(estimate) : 0.68
# date : 2015-10-21T16:30:00.000Z EDT
#
#
# eps(actual)   : 0.65
# eps(estimate) : 0.65
# date : 2015-07-22T16:30:00.000Z EDT
#
#
# eps(actual)   : 0.61
# eps(estimate) : 0.62
# date : 2015-04-22T16:30:00.000Z EDT
#
#
# eps(actual)   : 0.76
# eps(estimate) : 0.69
# date : 2015-01-26T16:30:00.000Z EST
#
#
# eps(actual)   : 0.76
# eps(estimate) : 0.71
# date : 2014-10-20T16:30:00.000Z EDT
#
#
# eps(actual)   : 0.62
# eps(estimate) : 0.59
# date : 2014-07-21T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.42
# eps(estimate) : 0.41
# date : 2014-04-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.46
# eps(estimate) : 0.46
# date : 2014-01-21T05:00:00.000Z EST
#
#
# eps(actual)   : 0.56
# eps(estimate) : 0.53
# date : 2013-10-21T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.58
# eps(estimate) : 0.41
# date : 2013-07-22T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.32
# eps(estimate) : 0.3
# date : 2013-04-22T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.36
# eps(estimate) : 0.34
# date : 2013-01-22T05:00:00.000Z EST
#
#
# eps(actual)   : 0.52
# eps(estimate) : 0.46
# date : 2012-10-22T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.44
# eps(estimate) : 0.41
# date : 2012-07-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.32
# eps(estimate) : 0.29
# date : 2012-04-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.48
# eps(estimate) : 0.39
# date : 2012-01-23T05:00:00.000Z EST
#
#
# eps(actual)   : 0.51
# eps(estimate) : 0.57
# date : 2011-10-24T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.56
# eps(estimate) : 0.53
# date : 2011-07-25T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.55
# eps(estimate) : 0.58
# date : 2011-04-18T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.64
# eps(estimate) : 0.63
# date : 2011-01-24T05:00:00.000Z EST
#
#
# eps(actual)   : 0.71
# eps(estimate) : 0.69
# date : 2010-10-25T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.62
# eps(estimate) : 0.62
# date : 2010-07-19T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.52
# eps(estimate) : 0.51
# date : 2010-04-26T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.52
# eps(estimate) : 0.49
# date : 2010-01-25T05:00:00.000Z EST
#
#
# eps(actual)   : 0.42
# eps(estimate) : 0.39
# date : 2009-10-19T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.2
# eps(estimate) : 0.19
# date : 2009-07-20T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.01
# eps(estimate) : -0.02
# date : 2009-04-20T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.21
# eps(estimate) : 0.13
# date : 2009-01-26T05:00:00.000Z EST
#
#
# eps(actual)   : 0.43
# eps(estimate) : 0.44
# date : 2008-10-20T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.44
# eps(estimate) : 0.46
# date : 2008-07-21T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.49
# eps(estimate) : 0.43
# date : 2008-04-21T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.54
# eps(estimate) : 0.52
# date : 2008-01-22T05:00:00.000Z EST
#
#
# eps(actual)   : 0.52
# eps(estimate) : 0.5
# date : 2007-10-22T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.42
# eps(estimate) : 0.42
# date : 2007-07-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.35
# eps(estimate) : 0.31
# date : 2007-04-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.45
# eps(estimate) : 0.38
# date : 2007-01-22T05:00:00.000Z EST
#
#
# eps(actual)   : 0.45
# eps(estimate) : 0.45
# date : 2006-10-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.47
# eps(estimate) : 0.46
# date : 2006-07-24T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.33
# eps(estimate) : 0.32
# date : 2006-04-18T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.43
# eps(estimate) : 0.42
# date : 2006-01-23T05:00:00.000Z EST
#
#
# eps(actual)   : 0.41
# eps(estimate) : 0.4
# date : 2005-10-24T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.32
# eps(estimate) : 0.29
# date : 2005-07-25T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.24
# eps(estimate) : 0.23
# date : 2005-04-18T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.28
# eps(estimate) : 0.26
# date : 2005-01-25T05:00:00.000Z EST
#
#
# eps(actual)   : 0.32
# eps(estimate) : 0.27
# date : 2004-10-18T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.25
# eps(estimate) : 0.25
# date : 2004-07-20T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.21
# eps(estimate) : 0.21
# date : 2004-04-14T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.22
# eps(estimate) : 0.19
# date : 2004-01-26T05:00:00.000Z EST
#
#
# eps(actual)   : 0.12
# eps(estimate) : 0.09
# date : 2003-10-20T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.07
# eps(estimate) : 0.06
# date : 2003-07-21T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.07
# eps(estimate) : 0.06
# date : 2003-04-15T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.06
# eps(estimate) : 0.03
# date : 2003-01-22T05:00:00.000Z EST
#
#
# eps(actual)   : 0.09
# eps(estimate) : 0.1
# date : 2002-10-21T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.06
# eps(estimate) : 0.06
# date : 2002-07-22T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.01
# eps(estimate) : 0
# date : 2002-04-15T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.06
# eps(estimate) : -0.09
# date : 2002-01-28T05:00:00.000Z EST
#
#
# eps(actual)   : -0.03
# eps(estimate) : -0.04
# date : 2001-10-17T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.03
# eps(estimate) : 0.02
# date : 2001-07-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.18
# eps(estimate) : 0.18
# date : 2001-04-17T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.31
# eps(estimate) : 0.34
# date : 2001-01-22T05:00:00.000Z EST
#
#
# eps(actual)   : 0.33
# eps(estimate) : 0.33
# date : 2000-10-18T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.31
# eps(estimate) : 0.3
# date : 2000-07-24T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.28
# eps(estimate) : 0.27
# date : 2000-04-17T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.26
# eps(estimate) : 0.24
# date : 2000-01-24T05:00:00.000Z EST
#
#
# eps(actual)   : 0.26
# eps(estimate) : 0.21
# date : 1999-10-19T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.23
# eps(estimate) : 0.2
# date : 1999-07-20T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.16
# eps(estimate) : 0.15
# date : 1999-04-20T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.15
# eps(estimate) : 0.14
# date : 1999-01-20T05:00:00.000Z EST
#
#
# eps(actual)   : 0.1
# eps(estimate) : 0.07
# date : 1998-10-20T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.09
# eps(estimate) : 0.09
# date : 1998-07-21T04:00:00.000Z EDT
#
#
# ------company abbreviation :  ADI ------
# total data N :  100
#
#
# eps(actual)   : None
# eps(estimate) : None
# date : 2023-02-14T07:00:00.000Z EST
#
#
# eps(actual)   : None
# eps(estimate) : None
# date : 2022-11-21T07:00:00.000Z EST
#
#
# eps(actual)   : None
# eps(estimate) : 2.43
# date : 2022-08-16T07:00:00.000Z EDT
#
#
# eps(actual)   : 2.4
# eps(estimate) : 2.11
# date : 2022-05-18T07:00:00.000Z EDT
#
#
# eps(actual)   : 1.94
# eps(estimate) : 1.78
# date : 2022-02-16T07:00:00.000Z EST
#
#
# eps(actual)   : 1.73
# eps(estimate) : 1.7
# date : 2021-11-23T07:00:00.000Z EST
#
#
# eps(actual)   : 1.72
# eps(estimate) : 1.63
# date : 2021-08-18T07:00:00.000Z EDT
#
#
# eps(actual)   : 1.54
# eps(estimate) : 1.45
# date : 2021-05-19T07:00:00.000Z EDT
#
#
# eps(actual)   : 1.44
# eps(estimate) : 1.32
# date : 2021-02-17T08:00:00.000Z EST
#
#
# eps(actual)   : 1.44
# eps(estimate) : 1.33
# date : 2020-11-24T08:00:00.000Z EST
#
#
# eps(actual)   : 1.36
# eps(estimate) : 1.28
# date : 2020-08-19T08:00:00.000Z EDT
#
#
# eps(actual)   : 1.08
# eps(estimate) : 1.03
# date : 2020-05-20T07:30:00.000Z EDT
#
#
# eps(actual)   : 1.03
# eps(estimate) : 1
# date : 2020-02-19T08:00:00.000Z EST
#
#
# eps(actual)   : 1.19
# eps(estimate) : 1.22
# date : 2019-11-26T08:00:00.000Z EST
#
#
# eps(actual)   : 1.26
# eps(estimate) : 1.22
# date : 2019-08-21T08:00:00.000Z EDT
#
#
# eps(actual)   : 1.36
# eps(estimate) : 1.3
# date : 2019-05-22T07:32:00.000Z EDT
#
#
# eps(actual)   : 1.33
# eps(estimate) : 1.28
# date : 2019-02-20T08:00:00.000Z EST
#
#
# eps(actual)   : 1.55
# eps(estimate) : 1.52
# date : 2018-11-20T08:00:00.000Z EST
#
#
# eps(actual)   : 1.53
# eps(estimate) : 1.46
# date : 2018-08-22T08:00:00.000Z EDT
#
#
# eps(actual)   : 1.45
# eps(estimate) : 1.38
# date : 2018-05-30T08:00:00.000Z EDT
#
#
# eps(actual)   : 1.42
# eps(estimate) : 1.29
# date : 2018-02-28T09:06:00.000Z EST
#
#
# eps(actual)   : 1.45
# eps(estimate) : 1.36
# date : 2017-11-21T08:00:00.000Z EST
#
#
# eps(actual)   : 1.26
# eps(estimate) : 1.15
# date : 2017-08-30T08:00:00.000Z EDT
#
#
# eps(actual)   : 1.03
# eps(estimate) : 0.84
# date : 2017-05-31T08:00:00.000Z EDT
#
#
# eps(actual)   : 0.94
# eps(estimate) : 0.74
# date : 2017-02-15T08:00:00.000Z EST
#
#
# eps(actual)   : 1.05
# eps(estimate) : 0.89
# date : 2016-11-22T08:00:00.000Z EST
#
#
# eps(actual)   : 0.82
# eps(estimate) : 0.76
# date : 2016-08-17T08:00:00.000Z EDT
#
#
# eps(actual)   : 0.64
# eps(estimate) : 0.62
# date : 2016-05-18T08:00:00.000Z EDT
#
#
# eps(actual)   : 0.56
# eps(estimate) : 0.53
# date : 2016-02-17T08:00:00.000Z EST
#
#
# eps(actual)   : 1.03
# eps(estimate) : 0.83
# date : 2015-11-24T08:00:00.000Z EST
#
#
# eps(actual)   : 0.77
# eps(estimate) : 0.74
# date : 2015-08-18T16:01:00.000Z EDT
#
#
# eps(actual)   : 0.73
# eps(estimate) : 0.72
# date : 2015-05-19T16:00:00.000Z EDT
#
#
# eps(actual)   : 0.63
# eps(estimate) : 0.61
# date : 2015-02-17T16:05:00.000Z EST
#
#
# eps(actual)   : 0.69
# eps(estimate) : 0.68
# date : 2014-11-25T16:00:00.000Z EST
#
#
# eps(actual)   : 0.63
# eps(estimate) : 0.63
# date : 2014-08-26T16:00:00.000Z EDT
#
#
# eps(actual)   : 0.59
# eps(estimate) : 0.56
# date : 2014-05-20T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.49
# eps(estimate) : 0.48
# date : 2014-02-18T05:00:00.000Z EST
#
#
# eps(actual)   : 0.63
# eps(estimate) : 0.58
# date : 2013-11-26T05:00:00.000Z EST
#
#
# eps(actual)   : 0.57
# eps(estimate) : 0.54
# date : 2013-08-20T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.51
# eps(estimate) : 0.52
# date : 2013-05-21T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.44
# eps(estimate) : 0.45
# date : 2013-02-20T05:00:00.000Z EST
#
#
# eps(actual)   : 0.58
# eps(estimate) : 0.56
# date : 2012-11-27T05:00:00.000Z EST
#
#
# eps(actual)   : 0.56
# eps(estimate) : 0.56
# date : 2012-08-21T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.53
# eps(estimate) : 0.51
# date : 2012-05-22T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.46
# eps(estimate) : 0.48
# date : 2012-02-22T05:00:00.000Z EST
#
#
# eps(actual)   : 0.6
# eps(estimate) : 0.63
# date : 2011-11-21T05:00:00.000Z EST
#
#
# eps(actual)   : 0.71
# eps(estimate) : 0.73
# date : 2011-08-16T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.75
# eps(estimate) : 0.68
# date : 2011-05-17T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.66
# eps(estimate) : 0.65
# date : 2011-02-15T05:00:00.000Z EST
#
#
# eps(actual)   : 0.73
# eps(estimate) : 0.7
# date : 2010-11-22T05:00:00.000Z EST
#
#
# eps(actual)   : 0.65
# eps(estimate) : 0.6
# date : 2010-08-17T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.55
# eps(estimate) : 0.5
# date : 2010-05-18T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.43
# eps(estimate) : 0.38
# date : 2010-02-17T05:00:00.000Z EST
#
#
# eps(actual)   : 0.36
# eps(estimate) : 0.26
# date : 2009-11-23T05:00:00.000Z EST
#
#
# eps(actual)   : 0.22
# eps(estimate) : 0.2
# date : 2009-08-18T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.21
# eps(estimate) : 0.09
# date : 2009-05-19T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.18
# eps(estimate) : 0.16
# date : 2009-02-18T05:00:00.000Z EST
#
#
# eps(actual)   : 0.49
# eps(estimate) : 0.43
# date : 2008-11-24T05:00:00.000Z EST
#
#
# eps(actual)   : 0.44
# eps(estimate) : 0.45
# date : 2008-08-19T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.44
# eps(estimate) : 0.41
# date : 2008-05-20T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.4
# eps(estimate) : 0.39
# date : 2008-02-20T05:00:00.000Z EST
#
#
# eps(actual)   : 0.31
# eps(estimate) : 0.39
# date : 2007-11-27T05:00:00.000Z EST
#
#
# eps(actual)   : 0.37
# eps(estimate) : 0.36
# date : 2007-08-21T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.37
# eps(estimate) : 0.35
# date : 2007-05-22T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.44
# eps(estimate) : 0.41
# date : 2007-02-21T05:00:00.000Z EST
#
#
# eps(actual)   : 0.39
# eps(estimate) : 0.4
# date : 2006-11-14T05:00:00.000Z EST
#
#
# eps(actual)   : 0.43
# eps(estimate) : 0.45
# date : 2006-08-10T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.41
# eps(estimate) : 0.4
# date : 2006-05-11T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.37
# eps(estimate) : 0.36
# date : 2006-02-09T05:00:00.000Z EST
#
#
# eps(actual)   : 0.36
# eps(estimate) : 0.34
# date : 2005-11-15T05:00:00.000Z EST
#
#
# eps(actual)   : 0.32
# eps(estimate) : 0.31
# date : 2005-08-11T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.31
# eps(estimate) : 0.3
# date : 2005-05-12T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.28
# eps(estimate) : 0.29
# date : 2005-02-10T05:00:00.000Z EST
#
#
# eps(actual)   : 0.34
# eps(estimate) : 0.33
# date : 2004-11-23T05:00:00.000Z EST
#
#
# eps(actual)   : 0.43
# eps(estimate) : 0.45
# date : 2004-08-12T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.39
# eps(estimate) : 0.35
# date : 2004-05-13T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.3
# eps(estimate) : 0.28
# date : 2004-02-12T05:00:00.000Z EST
#
#
# eps(actual)   : 0.25
# eps(estimate) : 0.23
# date : 2003-11-18T05:00:00.000Z EST
#
#
# eps(actual)   : 0.21
# eps(estimate) : 0.21
# date : 2003-08-14T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.19
# eps(estimate) : 0.18
# date : 2003-05-14T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.16
# eps(estimate) : 0.16
# date : 2003-02-13T05:00:00.000Z EST
#
#
# eps(actual)   : 0.16
# eps(estimate) : 0.16
# date : 2002-11-19T05:00:00.000Z EST
#
#
# eps(actual)   : 0.15
# eps(estimate) : 0.15
# date : 2002-08-15T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.13
# eps(estimate) : 0.12
# date : 2002-05-16T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.11
# eps(estimate) : 0.11
# date : 2002-02-14T05:00:00.000Z EST
#
#
# eps(actual)   : 0.14
# eps(estimate) : 0.12
# date : 2001-11-20T05:00:00.000Z EST
#
#
# eps(actual)   : 0.17
# eps(estimate) : 0.17
# date : 2001-08-16T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.31
# eps(estimate) : 0.31
# date : 2001-05-17T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.5
# eps(estimate) : 0.5
# date : 2001-02-15T05:00:00.000Z EST
#
#
# eps(actual)   : 0.54
# eps(estimate) : 0.5
# date : 2000-11-14T05:00:00.000Z EST
#
#
# eps(actual)   : 0.43
# eps(estimate) : 0.37
# date : 2000-08-15T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.32
# eps(estimate) : 0.29
# date : 2000-05-17T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.25
# eps(estimate) : 0.22
# date : 2000-02-16T05:00:00.000Z EST
#
#
# eps(actual)   : 0.2
# eps(estimate) : 0.18
# date : 1999-12-01T05:00:00.000Z EST
#
#
# eps(actual)   : 0.15
# eps(estimate) : 0.15
# date : 1999-08-18T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.13
# eps(estimate) : 0.11
# date : 1999-05-19T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.1
# eps(estimate) : 0.09
# date : 1999-02-17T05:00:00.000Z EST
#
#
# eps(actual)   : 0.08
# eps(estimate) : 0.07
# date : 1998-12-02T05:00:00.000Z EST
#
#
# eps(actual)   : 0.08
# eps(estimate) : 0.1
# date : 1998-08-19T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.14
# eps(estimate) : 0.16
# date : 1998-05-20T04:00:00.000Z EDT
#
#
# ------company abbreviation :  KLAC ------
# total data N :  100
#
#
# eps(actual)   : None
# eps(estimate) : None
# date : 2023-04-26T10:59:00.000Z EDT
#
#
# eps(actual)   : None
# eps(estimate) : None
# date : 2023-01-25T10:59:00.000Z EST
#
#
# eps(actual)   : None
# eps(estimate) : None
# date : 2022-10-25T10:59:00.000Z EDT
#
#
# eps(actual)   : None
# eps(estimate) : 5.51
# date : 2022-07-27T10:59:00.000Z EDT
#
#
# eps(actual)   : 5.13
# eps(estimate) : 4.82
# date : 2022-04-28T16:05:00.000Z EDT
#
#
# eps(actual)   : 5.59
# eps(estimate) : 5.45
# date : 2022-01-27T16:05:00.000Z EST
#
#
# eps(actual)   : 4.64
# eps(estimate) : 4.52
# date : 2021-10-27T16:05:00.000Z EDT
#
#
# eps(actual)   : 4.43
# eps(estimate) : 3.99
# date : 2021-07-29T16:05:00.000Z EDT
#
#
# eps(actual)   : 3.85
# eps(estimate) : 3.62
# date : 2021-04-29T16:05:00.000Z EDT
#
#
# eps(actual)   : 3.24
# eps(estimate) : 3.2
# date : 2021-02-03T16:05:00.000Z EST
#
#
# eps(actual)   : 3.03
# eps(estimate) : 2.77
# date : 2020-10-28T16:05:00.000Z EDT
#
#
# eps(actual)   : 2.73
# eps(estimate) : 2.42
# date : 2020-08-03T16:05:00.000Z EDT
#
#
# eps(actual)   : 2.47
# eps(estimate) : 2.28
# date : 2020-05-05T16:05:00.000Z EDT
#
#
# eps(actual)   : 2.66
# eps(estimate) : 2.59
# date : 2020-02-04T16:05:00.000Z EST
#
#
# eps(actual)   : 2.48
# eps(estimate) : 2.2
# date : 2019-10-30T16:05:00.000Z EDT
#
#
# eps(actual)   : 1.78
# eps(estimate) : 1.74
# date : 2019-08-05T16:15:00.000Z EDT
#
#
# eps(actual)   : 1.8
# eps(estimate) : 1.67
# date : 2019-05-06T16:15:00.000Z EDT
#
#
# eps(actual)   : 2.44
# eps(estimate) : 2.2
# date : 2019-01-29T16:15:00.000Z EST
#
#
# eps(actual)   : 2.46
# eps(estimate) : 2.21
# date : 2018-10-29T16:15:00.000Z EDT
#
#
# eps(actual)   : 2.22
# eps(estimate) : 2.14
# date : 2018-07-30T16:26:00.000Z EDT
#
#
# eps(actual)   : 2.02
# eps(estimate) : 1.99
# date : 2018-04-26T16:15:00.000Z EDT
#
#
# eps(actual)   : 1.97
# eps(estimate) : 1.73
# date : 2018-01-25T16:15:00.000Z EST
#
#
# eps(actual)   : 1.8
# eps(estimate) : 1.64
# date : 2017-10-26T16:15:00.000Z EDT
#
#
# eps(actual)   : 1.64
# eps(estimate) : 1.59
# date : 2017-07-27T16:15:00.000Z EDT
#
#
# eps(actual)   : 1.62
# eps(estimate) : 1.55
# date : 2017-04-27T16:15:00.000Z EDT
#
#
# eps(actual)   : 1.52
# eps(estimate) : 1.39
# date : 2017-01-26T16:15:00.000Z EST
#
#
# eps(actual)   : 1.16
# eps(estimate) : 1.03
# date : 2016-10-20T16:15:00.000Z EDT
#
#
# eps(actual)   : 1.77
# eps(estimate) : 1.42
# date : 2016-07-28T08:30:00.000Z EDT
#
#
# eps(actual)   : 1.15
# eps(estimate) : 0.98
# date : 2016-04-26T16:15:00.000Z EDT
#
#
# eps(actual)   : 1.04
# eps(estimate) : 0.86
# date : 2016-01-28T16:16:00.000Z EST
#
#
# eps(actual)   : 0.71
# eps(estimate) : 0.56
# date : 2015-10-21T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.99
# eps(estimate) : 0.91
# date : 2015-07-30T16:15:00.000Z EDT
#
#
# eps(actual)   : 0.84
# eps(estimate) : 0.76
# date : 2015-04-23T16:15:00.000Z EDT
#
#
# eps(actual)   : 0.68
# eps(estimate) : 0.52
# date : 2015-01-22T16:15:00.000Z EST
#
#
# eps(actual)   : 0.47
# eps(estimate) : 0.46
# date : 2014-10-23T16:15:00.000Z EDT
#
#
# eps(actual)   : 0.8
# eps(estimate) : 0.86
# date : 2014-07-24T04:00:00.000Z EDT
#
#
# eps(actual)   : 1.23
# eps(estimate) : 1.12
# date : 2014-04-24T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.85
# eps(estimate) : 0.8
# date : 2014-01-23T05:00:00.000Z EST
#
#
# eps(actual)   : 0.68
# eps(estimate) : 0.66
# date : 2013-10-24T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.82
# eps(estimate) : 0.79
# date : 2013-07-25T04:00:00.000Z EDT
#
#
# eps(actual)   : 1.01
# eps(estimate) : 0.86
# date : 2013-04-25T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.63
# eps(estimate) : 0.56
# date : 2013-01-24T05:00:00.000Z EST
#
#
# eps(actual)   : 0.84
# eps(estimate) : 0.89
# date : 2012-10-25T04:00:00.000Z EDT
#
#
# eps(actual)   : 1.49
# eps(estimate) : 1.31
# date : 2012-07-26T04:00:00.000Z EDT
#
#
# eps(actual)   : 1.27
# eps(estimate) : 1.1
# date : 2012-04-26T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.72
# eps(estimate) : 0.66
# date : 2012-01-26T05:00:00.000Z EST
#
#
# eps(actual)   : 1.17
# eps(estimate) : 1.17
# date : 2011-10-27T04:00:00.000Z EDT
#
#
# eps(actual)   : 1.5
# eps(estimate) : 1.37
# date : 2011-07-28T04:00:00.000Z EDT
#
#
# eps(actual)   : 1.31
# eps(estimate) : 1.24
# date : 2011-04-28T04:00:00.000Z EDT
#
#
# eps(actual)   : 1.1
# eps(estimate) : 1.05
# date : 2011-01-27T05:00:00.000Z EST
#
#
# eps(actual)   : 0.99
# eps(estimate) : 0.86
# date : 2010-10-28T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.7
# eps(estimate) : 0.6
# date : 2010-07-29T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.41
# eps(estimate) : 0.35
# date : 2010-04-29T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.28
# eps(estimate) : 0.27
# date : 2010-01-28T05:00:00.000Z EST
#
#
# eps(actual)   : 0.15
# eps(estimate) : 0.02
# date : 2009-10-29T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.09
# eps(estimate) : -0.15
# date : 2009-07-23T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.34
# eps(estimate) : -0.26
# date : 2009-04-23T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.12
# eps(estimate) : -0.07
# date : 2009-01-29T05:00:00.000Z EST
#
#
# eps(actual)   : 0.32
# eps(estimate) : 0.34
# date : 2008-10-30T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.6
# eps(estimate) : 0.57
# date : 2008-07-31T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.67
# eps(estimate) : 0.63
# date : 2008-04-24T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.75
# eps(estimate) : 0.7
# date : 2008-01-24T05:00:00.000Z EST
#
#
# eps(actual)   : 0.76
# eps(estimate) : 0.76
# date : 2007-10-25T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.9
# eps(estimate) : 0.85
# date : 2007-07-26T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.84
# eps(estimate) : 0.78
# date : 2007-04-26T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.72
# eps(estimate) : 0.71
# date : 2007-02-05T05:00:00.000Z EST
#
#
# eps(actual)   : 0.65
# eps(estimate) : 0.61
# date : 2007-01-29T05:00:00.000Z EST
#
#
# eps(actual)   : 0.63
# eps(estimate) : 0.56
# date : 2006-04-27T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.5
# eps(estimate) : 0.47
# date : 2006-01-26T05:00:00.000Z EST
#
#
# eps(actual)   : 0.5
# eps(estimate) : 0.48
# date : 2005-10-27T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.52
# eps(estimate) : 0.48
# date : 2005-07-28T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.61
# eps(estimate) : 0.56
# date : 2005-04-28T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.61
# eps(estimate) : 0.59
# date : 2005-01-20T05:00:00.000Z EST
#
#
# eps(actual)   : 0.58
# eps(estimate) : 0.57
# date : 2004-10-21T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.48
# eps(estimate) : 0.45
# date : 2004-07-29T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.33
# eps(estimate) : 0.29
# date : 2004-04-21T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.22
# eps(estimate) : 0.19
# date : 2004-01-22T05:00:00.000Z EST
#
#
# eps(actual)   : 0.18
# eps(estimate) : 0.17
# date : 2003-10-22T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.15
# eps(estimate) : 0.15
# date : 2003-07-24T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.14
# eps(estimate) : 0.12
# date : 2003-04-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.15
# eps(estimate) : 0.14
# date : 2003-01-23T05:00:00.000Z EST
#
#
# eps(actual)   : 0.23
# eps(estimate) : 0.23
# date : 2002-10-22T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.23
# eps(estimate) : 0.2
# date : 2002-07-30T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.17
# eps(estimate) : 0.15
# date : 2002-04-18T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.25
# eps(estimate) : 0.24
# date : 2002-01-23T05:00:00.000Z EST
#
#
# eps(actual)   : 0.44
# eps(estimate) : 0.43
# date : 2001-10-18T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.29
# eps(estimate) : 0.26
# date : 2001-07-31T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.48
# eps(estimate) : 0.44
# date : 2001-04-18T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.57
# eps(estimate) : 0.55
# date : 2001-01-17T05:00:00.000Z EST
#
#
# eps(actual)   : 0.54
# eps(estimate) : 0.51
# date : 2000-10-12T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.47
# eps(estimate) : 0.43
# date : 2000-07-27T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.38
# eps(estimate) : 0.32
# date : 2000-04-13T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.26
# eps(estimate) : 0.24
# date : 2000-01-13T05:00:00.000Z EST
#
#
# eps(actual)   : 0.19
# eps(estimate) : 0.16
# date : 1999-10-14T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.14
# eps(estimate) : 0.13
# date : 1999-07-28T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.12
# eps(estimate) : 0.07
# date : 1999-04-14T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.06
# eps(estimate) : 0.05
# date : 1999-01-19T05:00:00.000Z EST
#
#
# eps(actual)   : 0.06
# eps(estimate) : 0.07
# date : 1998-10-15T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.12
# eps(estimate) : 0.12
# date : 1998-07-28T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.18
# eps(estimate) : 0.17
# date : 1998-04-16T04:00:00.000Z EDT
#
#
# ------company abbreviation :  MCHP ------
# total data N :  100
#
#
# eps(actual)   : None
# eps(estimate) : None
# date : 2023-05-08T20:00:00.000Z EDT
#
#
# eps(actual)   : None
# eps(estimate) : None
# date : 2023-02-01T10:59:00.000Z EST
#
#
# eps(actual)   : None
# eps(estimate) : None
# date : 2022-11-02T10:59:00.000Z EDT
#
#
# eps(actual)   : None
# eps(estimate) : 1.34
# date : 2022-08-01T10:59:00.000Z EDT
#
#
# eps(actual)   : 1.35
# eps(estimate) : 1.25
# date : 2022-05-09T16:15:00.000Z EDT
#
#
# eps(actual)   : 1.2
# eps(estimate) : 1.17
# date : 2022-02-03T16:26:00.000Z EST
#
#
# eps(actual)   : 1.07
# eps(estimate) : 1.06
# date : 2021-11-04T17:02:00.000Z EDT
#
#
# eps(actual)   : 0.99
# eps(estimate) : 0.95
# date : 2021-08-03T16:27:00.000Z EDT
#
#
# eps(actual)   : 0.93
# eps(estimate) : 0.87
# date : 2021-05-06T16:15:00.000Z EDT
#
#
# eps(actual)   : 0.81
# eps(estimate) : 0.79
# date : 2021-02-04T15:46:00.000Z EST
#
#
# eps(actual)   : 0.78
# eps(estimate) : 0.72
# date : 2020-11-05T16:41:00.000Z EST
#
#
# eps(actual)   : 0.78
# eps(estimate) : 0.72
# date : 2020-08-04T16:26:00.000Z EDT
#
#
# eps(actual)   : 0.73
# eps(estimate) : 0.68
# date : 2020-05-07T16:14:00.000Z EDT
#
#
# eps(actual)   : 0.66
# eps(estimate) : 0.63
# date : 2020-02-04T16:15:00.000Z EST
#
#
# eps(actual)   : 0.72
# eps(estimate) : 0.72
# date : 2019-11-05T16:10:00.000Z EST
#
#
# eps(actual)   : 1.41
# eps(estimate) : 1.37
# date : 2019-08-06T16:10:00.000Z EDT
#
#
# eps(actual)   : 1.48
# eps(estimate) : 1.4
# date : 2019-05-07T20:45:00.000Z EDT
#
#
# eps(actual)   : 1.66
# eps(estimate) : 1.58
# date : 2019-02-05T16:10:00.000Z EST
#
#
# eps(actual)   : 1.81
# eps(estimate) : 1.73
# date : 2018-11-07T18:16:00.000Z EST
#
#
# eps(actual)   : 1.61
# eps(estimate) : 1.48
# date : 2018-08-09T16:15:00.000Z EDT
#
#
# eps(actual)   : 1.4
# eps(estimate) : 1.34
# date : 2018-05-08T08:00:00.000Z EDT
#
#
# eps(actual)   : 1.36
# eps(estimate) : 1.35
# date : 2018-02-06T17:00:00.000Z EST
#
#
# eps(actual)   : 1.41
# eps(estimate) : 1.35
# date : 2017-11-06T16:00:00.000Z EST
#
#
# eps(actual)   : 1.31
# eps(estimate) : 1.23
# date : 2017-08-03T17:00:00.000Z EDT
#
#
# eps(actual)   : 1.16
# eps(estimate) : 1.06
# date : 2017-05-09T16:27:00.000Z EDT
#
#
# eps(actual)   : 1.05
# eps(estimate) : 0.86
# date : 2017-02-07T16:15:00.000Z EST
#
#
# eps(actual)   : 0.94
# eps(estimate) : 0.87
# date : 2016-11-07T16:00:00.000Z EST
#
#
# eps(actual)   : 0.84
# eps(estimate) : 0.75
# date : 2016-08-08T17:39:00.000Z EDT
#
#
# eps(actual)   : 0.7
# eps(estimate) : 0.68
# date : 2016-05-04T16:15:00.000Z EDT
#
#
# eps(actual)   : 0.64
# eps(estimate) : 0.62
# date : 2016-02-03T16:15:00.000Z EST
#
#
# eps(actual)   : 0.66
# eps(estimate) : 0.63
# date : 2015-11-04T16:15:00.000Z EST
#
#
# eps(actual)   : 0.69
# eps(estimate) : 0.71
# date : 2015-08-03T16:45:00.000Z EDT
#
#
# eps(actual)   : 0.68
# eps(estimate) : 0.67
# date : 2015-05-07T16:05:00.000Z EDT
#
#
# eps(actual)   : 0.64
# eps(estimate) : 0.62
# date : 2015-01-29T16:15:00.000Z EST
#
#
# eps(actual)   : 0.67
# eps(estimate) : 0.67
# date : 2014-10-30T16:15:00.000Z EDT
#
#
# eps(actual)   : 0.68
# eps(estimate) : 0.66
# date : 2014-07-31T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.64
# eps(estimate) : 0.61
# date : 2014-05-06T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.61
# eps(estimate) : 0.6
# date : 2014-01-30T05:00:00.000Z EST
#
#
# eps(actual)   : 0.63
# eps(estimate) : 0.6
# date : 2013-10-30T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.57
# eps(estimate) : 0.54
# date : 2013-07-31T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.52
# eps(estimate) : 0.47
# date : 2013-05-02T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.41
# eps(estimate) : 0.37
# date : 2013-02-07T05:00:00.000Z EST
#
#
# eps(actual)   : 0.48
# eps(estimate) : 0.48
# date : 2012-11-08T05:00:00.000Z EST
#
#
# eps(actual)   : 0.48
# eps(estimate) : 0.48
# date : 2012-08-02T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.46
# eps(estimate) : 0.45
# date : 2012-05-01T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.42
# eps(estimate) : 0.42
# date : 2012-02-02T05:00:00.000Z EST
#
#
# eps(actual)   : 0.46
# eps(estimate) : 0.46
# date : 2011-11-03T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.55
# eps(estimate) : 0.54
# date : 2011-08-04T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.59
# eps(estimate) : 0.57
# date : 2011-05-05T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.58
# eps(estimate) : 0.57
# date : 2011-01-27T05:00:00.000Z EST
#
#
# eps(actual)   : 0.63
# eps(estimate) : 0.58
# date : 2010-11-04T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.58
# eps(estimate) : 0.51
# date : 2010-08-05T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.4
# eps(estimate) : 0.37
# date : 2010-05-05T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.37
# eps(estimate) : 0.29
# date : 2010-02-03T05:00:00.000Z EST
#
#
# eps(actual)   : 0.24
# eps(estimate) : 0.21
# date : 2009-11-04T05:00:00.000Z EST
#
#
# eps(actual)   : 0.15
# eps(estimate) : 0.13
# date : 2009-08-06T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.11
# eps(estimate) : 0.11
# date : 2009-05-07T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.19
# eps(estimate) : 0.22
# date : 2009-01-29T05:00:00.000Z EST
#
#
# eps(actual)   : 0.41
# eps(estimate) : 0.41
# date : 2008-10-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.4
# eps(estimate) : 0.4
# date : 2008-07-24T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.38
# eps(estimate) : 0.37
# date : 2008-04-28T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.35
# eps(estimate) : 0.35
# date : 2008-01-24T05:00:00.000Z EST
#
#
# eps(actual)   : 0.35
# eps(estimate) : 0.35
# date : 2007-10-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.36
# eps(estimate) : 0.36
# date : 2007-07-26T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.34
# eps(estimate) : 0.33
# date : 2007-04-26T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.33
# eps(estimate) : 0.33
# date : 2007-01-31T05:00:00.000Z EST
#
#
# eps(actual)   : 0.36
# eps(estimate) : 0.36
# date : 2006-10-25T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.35
# eps(estimate) : 0.36
# date : 2006-07-20T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.35
# eps(estimate) : 0.35
# date : 2006-04-25T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.33
# eps(estimate) : 0.32
# date : 2006-01-19T05:00:00.000Z EST
#
#
# eps(actual)   : 0.31
# eps(estimate) : 0.3
# date : 2005-10-20T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.29
# eps(estimate) : 0.28
# date : 2005-07-26T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.27
# eps(estimate) : 0.25
# date : 2005-04-27T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.25
# eps(estimate) : 0.25
# date : 2005-01-25T05:00:00.000Z EST
#
#
# eps(actual)   : 0.29
# eps(estimate) : 0.29
# date : 2004-10-21T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.27
# eps(estimate) : 0.26
# date : 2004-07-20T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.22
# eps(estimate) : 0.2
# date : 2004-04-22T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.19
# eps(estimate) : 0.19
# date : 2004-01-22T05:00:00.000Z EST
#
#
# eps(actual)   : 0.17
# eps(estimate) : 0.17
# date : 2003-10-16T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.16
# eps(estimate) : 0.15
# date : 2003-07-17T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.16
# eps(estimate) : 0.16
# date : 2003-04-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.18
# eps(estimate) : 0.17
# date : 2003-01-23T05:00:00.000Z EST
#
#
# eps(actual)   : 0.17
# eps(estimate) : 0.17
# date : 2002-10-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.15
# eps(estimate) : 0.15
# date : 2002-07-17T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.13
# eps(estimate) : 0.13
# date : 2002-04-25T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.11
# eps(estimate) : 0.11
# date : 2002-01-22T05:00:00.000Z EST
#
#
# eps(actual)   : 0.11
# eps(estimate) : 0.11
# date : 2001-10-24T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.11
# eps(estimate) : 0.1
# date : 2001-07-20T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.13
# eps(estimate) : 0.15
# date : 2001-04-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.23
# eps(estimate) : 0.22
# date : 2001-01-25T05:00:00.000Z EST
#
#
# eps(actual)   : 0.22
# eps(estimate) : 0.18
# date : 2000-10-12T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.2
# eps(estimate) : 0.18
# date : 2000-07-13T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.11
# eps(estimate) : 0.16
# date : 2000-04-19T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.15
# eps(estimate) : 0.14
# date : 2000-01-13T05:00:00.000Z EST
#
#
# eps(actual)   : 0.13
# eps(estimate) : 0.12
# date : 1999-10-14T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.11
# eps(estimate) : 0.11
# date : 1999-07-15T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.11
# eps(estimate) : 0.1
# date : 1999-04-22T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.1
# eps(estimate) : 0.1
# date : 1999-01-14T05:00:00.000Z EST
#
#
# eps(actual)   : 0.1
# eps(estimate) : 0.1
# date : 1998-10-13T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.09
# eps(estimate) : 0.09
# date : 1998-07-20T04:00:00.000Z EDT
#
#
# ------company abbreviation :  NXPI ------
# total data N :  51
#
#
# eps(actual)   : None
# eps(estimate) : None
# date : 2023-05-01T10:59:00.000Z EDT
#
#
# eps(actual)   : None
# eps(estimate) : None
# date : 2023-01-30T21:00:00.000Z EST
#
#
# eps(actual)   : None
# eps(estimate) : None
# date : 2022-10-31T15:00:00.000Z EDT
#
#
# eps(actual)   : None
# eps(estimate) : 3.39
# date : 2022-07-25T20:00:00.000Z EDT
#
#
# eps(actual)   : 3.34
# eps(estimate) : 3.17
# date : 2022-05-02T16:10:00.000Z EDT
#
#
# eps(actual)   : 3.2
# eps(estimate) : 2.99
# date : 2022-01-31T16:13:00.000Z EST
#
#
# eps(actual)   : 2.84
# eps(estimate) : 2.72
# date : 2021-11-01T16:07:00.000Z EDT
#
#
# eps(actual)   : 2.44
# eps(estimate) : 2.31
# date : 2021-08-02T16:07:00.000Z EDT
#
#
# eps(actual)   : 2.31
# eps(estimate) : 2.21
# date : 2021-04-26T18:01:00.000Z EDT
#
#
# eps(actual)   : 2.22
# eps(estimate) : 2.1
# date : 2021-02-01T16:01:00.000Z EST
#
#
# eps(actual)   : 1.62
# eps(estimate) : 1.54
# date : 2020-10-26T17:00:00.000Z EDT
#
#
# eps(actual)   : 0.94
# eps(estimate) : 0.85
# date : 2020-07-27T17:00:00.000Z EDT
#
#
# eps(actual)   : 1.38
# eps(estimate) : 1.38
# date : 2020-04-27T17:00:00.000Z EDT
#
#
# eps(actual)   : 1.99
# eps(estimate) : 2.02
# date : 2020-02-03T17:00:00.000Z EST
#
#
# eps(actual)   : 2.02
# eps(estimate) : 1.93
# date : 2019-10-28T17:00:00.000Z EDT
#
#
# eps(actual)   : 1.91
# eps(estimate) : 1.78
# date : 2019-07-29T20:00:00.000Z EDT
#
#
# eps(actual)   : 1.66
# eps(estimate) : 1.55
# date : 2019-04-29T20:00:00.000Z EDT
#
#
# eps(actual)   : 2.13
# eps(estimate) : 2.08
# date : 2019-02-06T20:00:00.000Z EST
#
#
# eps(actual)   : 2.01
# eps(estimate) : 1.9
# date : 2018-10-31T20:00:00.000Z EDT
#
#
# eps(actual)   : 1.5
# eps(estimate) : 1.65
# date : 2018-07-26T05:06:00.000Z EDT
#
#
# eps(actual)   : 1.55
# eps(estimate) : 1.61
# date : 2018-05-03T06:32:00.000Z EDT
#
#
# eps(actual)   : 1.96
# eps(estimate) : 1.8
# date : 2018-02-07T20:00:00.000Z EST
#
#
# eps(actual)   : 1.85
# eps(estimate) : 1.69
# date : 2017-10-25T20:00:00.000Z EDT
#
#
# eps(actual)   : 1.51
# eps(estimate) : 1.52
# date : 2017-08-02T20:00:00.000Z EDT
#
#
# eps(actual)   : 1.4
# eps(estimate) : 1.35
# date : 2017-05-03T20:01:00.000Z EDT
#
#
# eps(actual)   : 1.75
# eps(estimate) : 1.65
# date : 2017-02-01T20:01:00.000Z EST
#
#
# eps(actual)   : 1.65
# eps(estimate) : 1.6
# date : 2016-10-26T20:00:00.000Z EDT
#
#
# eps(actual)   : 1.39
# eps(estimate) : 1.35
# date : 2016-07-27T20:01:00.000Z EDT
#
#
# eps(actual)   : 1.14
# eps(estimate) : 1.09
# date : 2016-04-25T20:02:00.000Z EDT
#
#
# eps(actual)   : 1.25
# eps(estimate) : 1.07
# date : 2016-02-03T20:00:00.000Z EST
#
#
# eps(actual)   : 1.57
# eps(estimate) : 1.5
# date : 2015-10-28T20:00:00.000Z EDT
#
#
# eps(actual)   : 1.44
# eps(estimate) : 1.38
# date : 2015-07-29T20:00:00.000Z EDT
#
#
# eps(actual)   : 1.35
# eps(estimate) : 1.3
# date : 2015-04-29T20:00:00.000Z EDT
#
#
# eps(actual)   : 1.35
# eps(estimate) : 1.32
# date : 2015-02-04T20:04:00.000Z EST
#
#
# eps(actual)   : 1.35
# eps(estimate) : 1.3
# date : 2014-10-22T20:00:00.000Z EDT
#
#
# eps(actual)   : 1.09
# eps(estimate) : 1.05
# date : 2014-07-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.98
# eps(estimate) : 0.91
# date : 2014-04-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.99
# eps(estimate) : 0.95
# date : 2014-02-05T05:00:00.000Z EST
#
#
# eps(actual)   : 0.85
# eps(estimate) : 0.82
# date : 2013-10-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.71
# eps(estimate) : 0.66
# date : 2013-07-31T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.66
# eps(estimate) : 0.49
# date : 2013-04-22T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.5
# eps(estimate) : 0.47
# date : 2013-01-30T05:00:00.000Z EST
#
#
# eps(actual)   : 0.56
# eps(estimate) : 0.56
# date : 2012-10-24T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.45
# eps(estimate) : 0.4
# date : 2012-07-24T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.19
# eps(estimate) : 0.18
# date : 2012-04-26T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.24
# eps(estimate) : 0.24
# date : 2012-02-09T05:00:00.000Z EST
#
#
# eps(actual)   : 0.5
# eps(estimate) : 0.51
# date : 2011-11-01T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.51
# eps(estimate) : 0.52
# date : 2011-07-28T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.46
# eps(estimate) : 0.42
# date : 2011-05-04T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.37
# eps(estimate) : 0.47
# date : 2011-02-15T05:00:00.000Z EST
#
#
# eps(actual)   : 0.49
# eps(estimate) : 0.46
# date : 2010-11-02T04:00:00.000Z EDT
#
#
# ------company abbreviation :  LRCX ------
# total data N :  100
#
#
# eps(actual)   : None
# eps(estimate) : None
# date : 2023-04-18T10:59:00.000Z EDT
#
#
# eps(actual)   : None
# eps(estimate) : None
# date : 2023-01-24T10:59:00.000Z EST
#
#
# eps(actual)   : None
# eps(estimate) : None
# date : 2022-10-17T20:00:00.000Z EDT
#
#
# eps(actual)   : None
# eps(estimate) : 7.33
# date : 2022-07-26T20:00:00.000Z EDT
#
#
# eps(actual)   : 7.4
# eps(estimate) : 7.51
# date : 2022-04-20T16:05:00.000Z EDT
#
#
# eps(actual)   : 8.53
# eps(estimate) : 8.51
# date : 2022-01-26T16:05:00.000Z EST
#
#
# eps(actual)   : 8.36
# eps(estimate) : 8.21
# date : 2021-10-20T16:05:00.000Z EDT
#
#
# eps(actual)   : 8.09
# eps(estimate) : 7.55
# date : 2021-07-28T16:05:00.000Z EDT
#
#
# eps(actual)   : 7.49
# eps(estimate) : 6.62
# date : 2021-04-21T16:05:00.000Z EDT
#
#
# eps(actual)   : 6.03
# eps(estimate) : 5.73
# date : 2021-01-27T16:05:00.000Z EST
#
#
# eps(actual)   : 5.67
# eps(estimate) : 5.2
# date : 2020-10-21T16:05:00.000Z EDT
#
#
# eps(actual)   : 4.78
# eps(estimate) : 4.05
# date : 2020-07-29T16:05:00.000Z EDT
#
#
# eps(actual)   : 3.98
# eps(estimate) : 3.98
# date : 2020-04-22T16:12:00.000Z EDT
#
#
# eps(actual)   : 4.01
# eps(estimate) : 3.85
# date : 2020-01-29T16:05:00.000Z EST
#
#
# eps(actual)   : 3.18
# eps(estimate) : 3.01
# date : 2019-10-23T16:05:00.000Z EDT
#
#
# eps(actual)   : 3.62
# eps(estimate) : 3.42
# date : 2019-07-31T16:05:00.000Z EDT
#
#
# eps(actual)   : 3.7
# eps(estimate) : 3.38
# date : 2019-04-24T16:05:00.000Z EDT
#
#
# eps(actual)   : 3.87
# eps(estimate) : 3.66
# date : 2019-01-23T16:05:00.000Z EST
#
#
# eps(actual)   : 3.36
# eps(estimate) : 3.22
# date : 2018-10-16T16:05:00.000Z EDT
#
#
# eps(actual)   : 5.31
# eps(estimate) : 4.94
# date : 2018-07-26T16:31:00.000Z EDT
#
#
# eps(actual)   : 4.79
# eps(estimate) : 4.38
# date : 2018-04-17T16:30:00.000Z EDT
#
#
# eps(actual)   : 4.34
# eps(estimate) : 3.68
# date : 2018-01-24T16:08:00.000Z EST
#
#
# eps(actual)   : 3.46
# eps(estimate) : 3.28
# date : 2017-10-17T16:05:00.000Z EDT
#
#
# eps(actual)   : 3.11
# eps(estimate) : 3.03
# date : 2017-07-26T16:05:00.000Z EDT
#
#
# eps(actual)   : 2.8
# eps(estimate) : 2.55
# date : 2017-04-18T16:03:00.000Z EDT
#
#
# eps(actual)   : 2.24
# eps(estimate) : 2.19
# date : 2017-01-25T16:00:00.000Z EST
#
#
# eps(actual)   : 1.81
# eps(estimate) : 1.78
# date : 2016-10-19T16:05:00.000Z EDT
#
#
# eps(actual)   : 1.8
# eps(estimate) : 1.64
# date : 2016-07-27T16:05:00.000Z EDT
#
#
# eps(actual)   : 1.18
# eps(estimate) : 1.1
# date : 2016-04-20T16:05:00.000Z EDT
#
#
# eps(actual)   : 1.57
# eps(estimate) : 1.43
# date : 2016-01-27T16:05:00.000Z EST
#
#
# eps(actual)   : 1.82
# eps(estimate) : 1.71
# date : 2015-10-21T04:00:00.000Z EDT
#
#
# eps(actual)   : 1.5
# eps(estimate) : 1.47
# date : 2015-07-29T16:05:00.000Z EDT
#
#
# eps(actual)   : 1.4
# eps(estimate) : 1.3
# date : 2015-04-20T16:05:00.000Z EDT
#
#
# eps(actual)   : 1.19
# eps(estimate) : 1.13
# date : 2015-01-28T16:05:00.000Z EST
#
#
# eps(actual)   : 0.96
# eps(estimate) : 0.93
# date : 2014-10-22T16:05:00.000Z EDT
#
#
# eps(actual)   : 1.25
# eps(estimate) : 1.23
# date : 2014-07-30T04:00:00.000Z EDT
#
#
# eps(actual)   : 1.26
# eps(estimate) : 1.17
# date : 2014-04-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 1.1
# eps(estimate) : 1.03
# date : 2014-01-29T05:00:00.000Z EST
#
#
# eps(actual)   : 0.81
# eps(estimate) : 0.71
# date : 2013-10-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.8
# eps(estimate) : 0.71
# date : 2013-07-31T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.44
# eps(estimate) : 0.37
# date : 2013-04-24T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.45
# eps(estimate) : 0.44
# date : 2013-01-23T05:00:00.000Z EST
#
#
# eps(actual)   : 0.53
# eps(estimate) : 0.41
# date : 2012-10-17T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.6
# eps(estimate) : 0.64
# date : 2012-07-25T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.5
# eps(estimate) : 0.46
# date : 2012-04-18T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.34
# eps(estimate) : 0.3
# date : 2012-01-25T05:00:00.000Z EST
#
#
# eps(actual)   : 0.63
# eps(estimate) : 0.65
# date : 2011-10-19T04:00:00.000Z EDT
#
#
# eps(actual)   : 1.14
# eps(estimate) : 1.09
# date : 2011-07-27T04:00:00.000Z EDT
#
#
# eps(actual)   : 1.45
# eps(estimate) : 1.36
# date : 2011-04-20T04:00:00.000Z EDT
#
#
# eps(actual)   : 1.74
# eps(estimate) : 1.57
# date : 2011-01-26T05:00:00.000Z EST
#
#
# eps(actual)   : 1.52
# eps(estimate) : 1.38
# date : 2010-10-20T04:00:00.000Z EDT
#
#
# eps(actual)   : 1.17
# eps(estimate) : 0.97
# date : 2010-07-28T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.94
# eps(estimate) : 0.82
# date : 2010-04-21T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.47
# eps(estimate) : 0.4
# date : 2010-01-27T05:00:00.000Z EST
#
#
# eps(actual)   : 0.03
# eps(estimate) : -0.08
# date : 2009-10-21T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.45
# eps(estimate) : -0.46
# date : 2009-07-29T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.71
# eps(estimate) : -0.66
# date : 2009-04-22T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.09
# eps(estimate) : -0.05
# date : 2009-01-28T05:00:00.000Z EST
#
#
# eps(actual)   : 0.26
# eps(estimate) : 0.25
# date : 2008-10-22T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.6
# eps(estimate) : 0.4
# date : 2008-07-29T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.87
# eps(estimate) : 0.94
# date : 2008-04-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 1.28
# eps(estimate) : 1.28
# date : 2008-03-31T04:00:00.000Z EDT
#
#
# eps(actual)   : 1.15
# eps(estimate) : 1.06
# date : 2007-04-12T04:00:00.000Z EDT
#
#
# eps(actual)   : 1.15
# eps(estimate) : 1.11
# date : 2007-01-17T05:00:00.000Z EST
#
#
# eps(actual)   : 1.13
# eps(estimate) : 1.03
# date : 2006-10-11T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.96
# eps(estimate) : 0.83
# date : 2006-07-19T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.65
# eps(estimate) : 0.62
# date : 2006-04-12T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.55
# eps(estimate) : 0.38
# date : 2006-01-18T05:00:00.000Z EST
#
#
# eps(actual)   : 0.35
# eps(estimate) : 0.3
# date : 2005-10-12T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.47
# eps(estimate) : 0.44
# date : 2005-07-20T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.44
# eps(estimate) : 0.43
# date : 2005-04-13T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.59
# eps(estimate) : 0.53
# date : 2005-01-20T05:00:00.000Z EST
#
#
# eps(actual)   : 0.64
# eps(estimate) : 0.58
# date : 2004-10-13T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.37
# eps(estimate) : 0.26
# date : 2004-07-21T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.14
# eps(estimate) : 0.1
# date : 2004-04-14T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.07
# eps(estimate) : 0.05
# date : 2004-01-21T05:00:00.000Z EST
#
#
# eps(actual)   : 0.04
# eps(estimate) : 0.03
# date : 2003-10-15T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.02
# eps(estimate) : 0.02
# date : 2003-07-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.03
# eps(estimate) : 0
# date : 2003-04-16T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.02
# eps(estimate) : 0
# date : 2003-01-22T05:00:00.000Z EST
#
#
# eps(actual)   : 0.02
# eps(estimate) : 0
# date : 2002-10-17T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.06
# eps(estimate) : -0.07
# date : 2002-07-23T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.12
# eps(estimate) : -0.17
# date : 2002-04-17T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.03
# eps(estimate) : 0
# date : 2002-01-24T05:00:00.000Z EST
#
#
# eps(actual)   : 0.21
# eps(estimate) : 0.15
# date : 2001-10-09T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.28
# eps(estimate) : 0.14
# date : 2001-07-25T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.33
# eps(estimate) : 0.37
# ...
#
#
# eps(actual)   : 0.01
# eps(estimate) : 0.01
# date : 2001-02-22T05:00:00.000Z EST
#
#
# eps(actual)   : 0.01
# eps(estimate) : 0.01
# date : 2000-11-16T05:00:00.000Z EST
#
#
# eps(actual)   : 0
# eps(estimate) : 0
# date : 2000-08-24T04:00:00.000Z EDT
#
#
# ------company abbreviation :  MU ------
# total data N :  100
#
#
# eps(actual)   : None
# eps(estimate) : None
# date : 2023-03-27T10:59:00.000Z EDT
#
#
# eps(actual)   : None
# eps(estimate) : None
# date : 2022-12-19T16:03:00.000Z EST
#
#
# eps(actual)   : None
# eps(estimate) : None
# date : 2022-09-26T10:59:00.000Z EDT
#
#
# eps(actual)   : None
# eps(estimate) : 2.46
# date : 2022-06-28T10:59:00.000Z EDT
#
#
# eps(actual)   : 2.14
# eps(estimate) : 1.97
# date : 2022-03-29T16:06:00.000Z EDT
#
#
# eps(actual)   : 2.16
# eps(estimate) : 2.11
# date : 2021-12-20T16:02:00.000Z EST
#
#
# eps(actual)   : 2.42
# eps(estimate) : 2.33
# date : 2021-09-28T16:01:00.000Z EDT
#
#
# eps(actual)   : 1.88
# eps(estimate) : 1.72
# date : 2021-06-30T16:08:00.000Z EDT
#
#
# eps(actual)   : 0.98
# eps(estimate) : 0.95
# date : 2021-03-31T16:05:00.000Z EDT
#
#
# eps(actual)   : 0.78
# eps(estimate) : 0.71
# date : 2021-01-07T16:03:00.000Z EST
#
#
# eps(actual)   : 1.08
# eps(estimate) : 0.99
# date : 2020-09-29T16:04:00.000Z EDT
#
#
# eps(actual)   : 0.82
# eps(estimate) : 0.78
# date : 2020-06-29T16:01:00.000Z EDT
#
#
# eps(actual)   : 0.45
# eps(estimate) : 0.37
# date : 2020-03-25T16:01:00.000Z EDT
#
#
# eps(actual)   : 0.48
# eps(estimate) : 0.47
# date : 2019-12-18T16:01:00.000Z EST
#
#
# eps(actual)   : 0.56
# eps(estimate) : 0.49
# date : 2019-09-26T16:01:00.000Z EDT
#
#
# eps(actual)   : 1.05
# eps(estimate) : 0.79
# date : 2019-06-25T16:05:00.000Z EDT
#
#
# eps(actual)   : 1.71
# eps(estimate) : 1.67
# date : 2019-03-20T16:01:00.000Z EDT
#
#
# eps(actual)   : 2.97
# eps(estimate) : 2.96
# date : 2018-12-18T16:01:00.000Z EST
#
#
# eps(actual)   : 3.53
# eps(estimate) : 3.34
# date : 2018-09-20T16:01:00.000Z EDT
#
#
# eps(actual)   : 3.15
# eps(estimate) : 3.14
# date : 2018-06-20T16:01:00.000Z EDT
#
#
# eps(actual)   : 2.82
# eps(estimate) : 2.73
# date : 2018-03-22T16:00:00.000Z EDT
#
#
# eps(actual)   : 2.45
# eps(estimate) : 2.21
# date : 2017-12-19T16:00:00.000Z EST
#
#
# eps(actual)   : 2.02
# eps(estimate) : 1.84
# date : 2017-09-26T16:00:00.000Z EDT
#
#
# eps(actual)   : 1.62
# eps(estimate) : 1.51
# date : 2017-06-29T16:00:00.000Z EDT
#
#
# eps(actual)   : 0.9
# eps(estimate) : 0.86
# date : 2017-03-23T16:04:00.000Z EDT
#
#
# eps(actual)   : 0.32
# eps(estimate) : 0.28
# date : 2016-12-21T16:05:00.000Z EST
#
#
# eps(actual)   : -0.05
# eps(estimate) : -0.12
# date : 2016-10-04T16:03:00.000Z EDT
#
#
# eps(actual)   : -0.08
# eps(estimate) : -0.09
# date : 2016-06-30T16:07:00.000Z EDT
#
#
# eps(actual)   : -0.05
# eps(estimate) : -0.08
# date : 2016-03-30T16:04:00.000Z EDT
#
#
# eps(actual)   : 0.24
# eps(estimate) : 0.23
# date : 2015-12-22T16:03:00.000Z EST
#
#
# eps(actual)   : 0.37
# eps(estimate) : 0.32
# date : 2015-10-01T16:03:00.000Z EDT
#
#
# eps(actual)   : 0.54
# eps(estimate) : 0.56
# date : 2015-06-25T16:03:00.000Z EDT
#
#
# eps(actual)   : 0.81
# eps(estimate) : 0.73
# date : 2015-04-01T16:02:00.000Z EDT
#
#
# eps(actual)   : 0.97
# eps(estimate) : 0.92
# date : 2015-01-06T16:01:00.000Z EST
#
#
# eps(actual)   : 0.82
# eps(estimate) : 0.81
# date : 2014-09-25T16:01:00.000Z EDT
#
#
# eps(actual)   : 0.79
# eps(estimate) : 0.7
# date : 2014-06-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.85
# eps(estimate) : 0.76
# date : 2014-04-03T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.72
# eps(estimate) : 0.43
# date : 2014-01-07T05:00:00.000Z EST
#
#
# eps(actual)   : 0.2
# eps(estimate) : 0.25
# date : 2013-10-10T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.04
# eps(estimate) : 0.02
# date : 2013-06-19T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.28
# eps(estimate) : -0.19
# date : 2013-03-21T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.27
# eps(estimate) : -0.2
# date : 2012-12-20T05:00:00.000Z EST
#
#
# eps(actual)   : -0.24
# eps(estimate) : -0.23
# date : 2012-09-27T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.32
# eps(estimate) : -0.2
# date : 2012-06-20T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.29
# eps(estimate) : -0.19
# date : 2012-03-22T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.19
# eps(estimate) : -0.08
# date : 2011-12-21T05:00:00.000Z EST
#
#
# eps(actual)   : -0.14
# eps(estimate) : 0.01
# date : 2011-09-29T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.07
# eps(estimate) : 0.16
# date : 2011-06-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.07
# eps(estimate) : 0.02
# date : 2011-03-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.15
# eps(estimate) : 0.28
# date : 2010-12-22T05:00:00.000Z EST
#
#
# eps(actual)   : 0.32
# eps(estimate) : 0.38
# date : 2010-10-07T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.45
# eps(estimate) : 0.43
# date : 2010-06-28T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.39
# eps(estimate) : 0.24
# date : 2010-03-31T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.23
# eps(estimate) : 0.07
# date : 2009-12-22T05:00:00.000Z EST
#
#
# eps(actual)   : -0.09
# eps(estimate) : -0.18
# date : 2009-09-29T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.57
# eps(estimate) : -0.43
# date : 2009-06-25T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.82
# eps(estimate) : -0.64
# date : 2009-04-02T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.72
# eps(estimate) : -0.45
# date : 2008-12-23T05:00:00.000Z EST
#
#
# eps(actual)   : -0.27
# eps(estimate) : -0.24
# date : 2008-10-01T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.3
# eps(estimate) : -0.28
# date : 2008-06-26T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.41
# eps(estimate) : -0.36
# date : 2008-04-02T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.34
# eps(estimate) : -0.2
# date : 2007-12-20T05:00:00.000Z EST
#
#
# eps(actual)   : -0.21
# eps(estimate) : -0.22
# date : 2007-10-02T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.29
# eps(estimate) : -0.24
# date : 2007-06-28T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.07
# eps(estimate) : -0.01
# date : 2007-04-04T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.15
# eps(estimate) : 0.2
# date : 2006-12-21T05:00:00.000Z EST
#
#
# eps(actual)   : 0.08
# eps(estimate) : 0.14
# date : 2006-10-05T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.12
# eps(estimate) : 0.09
# date : 2006-06-28T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.04
# eps(estimate) : 0.06
# date : 2006-04-10T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.09
# eps(estimate) : 0.11
# date : 2005-12-21T05:00:00.000Z EST
#
#
# eps(actual)   : 0.07
# eps(estimate) : -0.08
# date : 2005-09-29T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.2
# eps(estimate) : 0.02
# date : 2005-06-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.17
# eps(estimate) : 0.15
# date : 2005-03-29T05:00:00.000Z EST
#
#
# eps(actual)   : 0.23
# eps(estimate) : 0.22
# date : 2004-12-22T05:00:00.000Z EST
#
#
# eps(actual)   : 0.14
# eps(estimate) : 0.2
# date : 2004-09-29T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.13
# eps(estimate) : 0.09
# date : 2004-06-23T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.04
# eps(estimate) : -0.06
# date : 2004-03-24T05:00:00.000Z EST
#
#
# eps(actual)   : 0
# eps(estimate) : -0.06
# date : 2003-12-23T05:00:00.000Z EST
#
#
# eps(actual)   : -0.2
# eps(estimate) : -0.25
# date : 2003-09-24T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.36
# eps(estimate) : -0.52
# date : 2003-06-18T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.83
# eps(estimate) : -0.46
# date : 2003-03-20T05:00:00.000Z EST
#
#
# eps(actual)   : -0.52
# eps(estimate) : -0.23
# date : 2002-12-17T05:00:00.000Z EST
#
#
# eps(actual)   : -0.18
# eps(estimate) : -0.18
# date : 2002-09-24T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.04
# eps(estimate) : 0.06
# date : 2002-06-25T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.05
# eps(estimate) : -0.05
# date : 2002-03-21T05:00:00.000Z EST
#
#
# eps(actual)   : -0.44
# eps(estimate) : -0.39
# date : 2001-12-18T05:00:00.000Z EST
#
#
# eps(actual)   : -0.28
# eps(estimate) : -0.34
# date : 2001-09-25T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.23
# eps(estimate) : -0.15
# date : 2001-06-21T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.01
# eps(estimate) : -0.02
# date : 2001-03-29T05:00:00.000Z EST
#
#
# eps(actual)   : 0.58
# eps(estimate) : 0.58
# date : 2000-12-20T05:00:00.000Z EST
#
#
# eps(actual)   : 1.2
# eps(estimate) : 0.96
# date : 2000-10-04T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.47
# eps(estimate) : 0.35
# date : 2000-06-22T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.29
# eps(estimate) : 0.36
# date : 2000-03-21T05:00:00.000Z EST
#
#
# eps(actual)   : 0.6
# eps(estimate) : 0.4
# date : 1999-12-22T05:00:00.000Z EST
#
#
# eps(actual)   : -0.04
# eps(estimate) : -0.09
# date : 1999-10-04T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.05
# eps(estimate) : 0.01
# date : 1999-06-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.04
# eps(estimate) : 0
# date : 1999-03-24T05:00:00.000Z EST
#
#
# eps(actual)   : -0.09
# eps(estimate) : -0.15
# date : 1998-12-23T05:00:00.000Z EST
#
#
# eps(actual)   : -0.21
# eps(estimate) : -0.27
# date : 1998-09-28T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.2
# eps(estimate) : -0.22
# date : 1998-06-18T04:00:00.000Z EDT
#
#
# ------company abbreviation :  TSM ------
# total data N :  95
#
#
# eps(actual)   : 1.39
# eps(estimate) : 1.33
# date : 2022-04-14T04:38:00.000Z EDT
#
#
# eps(actual)   : 1.15
# eps(estimate) : 1.14
# date : 2022-01-28T13:07:00.000Z EST
#
#
# eps(actual)   : 1.08
# eps(estimate) : 1.04
# date : 2021-10-14T03:20:00.000Z EDT
#
#
# eps(actual)   : 0.93
# eps(estimate) : 0.93
# date : 2021-07-15T05:15:00.000Z EDT
#
#
# eps(actual)   : 0.96
# eps(estimate) : 0.94
# date : 2021-04-15T09:10:00.000Z EDT
#
#
# eps(actual)   : 0.97
# eps(estimate) : 0.95
# date : 2021-01-14T23:57:00.000Z EST
#
#
# eps(actual)   : 0.9
# eps(estimate) : 0.77
# date : 2020-10-15T03:54:00.000Z EDT
#
#
# eps(actual)   : 0.78
# eps(estimate) : 0.77
# date : 2020-07-16T22:21:00.000Z EDT
#
#
# eps(actual)   : 0.75
# eps(estimate) : 0.73
# date : 2020-04-16T18:58:00.000Z EDT
#
#
# eps(actual)   : 0.73
# eps(estimate) : 0.73
# date : 2020-01-16T13:57:00.000Z EST
#
#
# eps(actual)   : 0.62
# eps(estimate) : 0.63
# date : 2019-11-08T17:10:00.000Z EST
#
#
# eps(actual)   : 0.41
# eps(estimate) : 0.41
# date : 2019-07-25T14:59:00.000Z EDT
#
#
# eps(actual)   : 0.39
# eps(estimate) : 0.38
# date : 2019-04-19T04:32:00.000Z EDT
#
#
# eps(actual)   : 0.63
# eps(estimate) : 0.63
# date : 2019-01-22T02:26:00.000Z EST
#
#
# eps(actual)   : 0.56
# eps(estimate) : 0.56
# date : 2018-10-18T06:31:00.000Z EDT
#
#
# eps(actual)   : 0.47
# eps(estimate) : 0.47
# date : 2018-07-20T04:01:00.000Z EDT
#
#
# eps(actual)   : 0.59
# eps(estimate) : 0.6
# date : 2018-04-19T04:47:00.000Z EDT
#
#
# eps(actual)   : 0.64
# eps(estimate) : 0.62
# date : 2018-01-18T03:45:00.000Z EST
#
#
# eps(actual)   : 0.57
# eps(estimate) : 0.57
# date : 2017-10-19T21:45:00.000Z EDT
#
#
# eps(actual)   : 0.43
# eps(estimate) : 0.42
# date : 2017-08-14T17:30:00.000Z EDT
#
#
# eps(actual)   : 0.54
# eps(estimate) : 0.54
# date : 2017-04-13T21:55:00.000Z EDT
#
#
# eps(actual)   : 0.61
# eps(estimate) : 0.59
# date : 2017-01-12T22:17:00.000Z EST
#
#
# eps(actual)   : 0.59
# eps(estimate) : 0.57
# date : 2016-10-13T17:40:00.000Z EDT
#
#
# eps(actual)   : 0.43
# eps(estimate) : 0.41
# date : 2016-07-14T21:54:00.000Z EDT
#
#
# eps(actual)   : 0.38
# eps(estimate) : 0.38
# date : 2016-04-19T22:06:00.000Z EDT
#
#
# eps(actual)   : 0.43
# eps(estimate) : 0.4
# date : 2016-01-14T17:01:00.000Z EST
#
#
# eps(actual)   : 0.46
# eps(estimate) : 0.45
# date : 2015-10-16T05:42:00.000Z EDT
#
#
# eps(actual)   : 0.5
# eps(estimate) : 0.47
# date : 2015-08-11T17:28:00.000Z EDT
#
#
# eps(actual)   : 0.48
# eps(estimate) : 0.48
# date : 2015-04-16T17:05:00.000Z EDT
#
#
# eps(actual)   : 0.5
# eps(estimate) : 0.49
# date : 2015-01-15T20:45:00.000Z EST
#
#
# eps(actual)   : 0.49
# eps(estimate) : 0.48
# date : 2014-10-16T11:44:00.000Z EDT
#
#
# eps(actual)   : 0.38
# eps(estimate) : 0.37
# date : 2014-07-16T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.31
# eps(estimate) : 0.3
# date : 2014-04-17T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.29
# eps(estimate) : 0.27
# date : 2014-01-16T05:00:00.000Z EST
#
#
# eps(actual)   : 0.34
# eps(estimate) : 0.33
# date : 2013-10-17T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.33
# eps(estimate) : 0.32
# date : 2013-07-18T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.26
# eps(estimate) : 0.25
# date : 2013-04-18T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.28
# eps(estimate) : 0.28
# date : 2013-01-17T05:00:00.000Z EST
#
#
# eps(actual)   : 0.32
# eps(estimate) : 0.31
# date : 2012-10-25T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.27
# eps(estimate) : 0.27
# date : 2012-07-19T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.22
# eps(estimate) : 0.19
# date : 2012-04-26T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.2
# eps(estimate) : 0.2
# date : 2012-01-18T05:00:00.000Z EST
#
#
# eps(actual)   : 0.2
# eps(estimate) : 0.2
# date : 2011-10-27T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.24
# eps(estimate) : 0.25
# date : 2011-07-28T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.24
# eps(estimate) : 0.24
# date : 2011-04-29T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.26
# eps(estimate) : 0.26
# date : 2011-02-03T05:00:00.000Z EST
#
#
# eps(actual)   : 0.28
# eps(estimate) : 0.24
# date : 2010-10-28T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.24
# eps(estimate) : 0.23
# date : 2010-07-30T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.2
# eps(estimate) : 0.19
# date : 2010-04-28T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.19
# eps(estimate) : 0.19
# date : 2010-01-28T05:00:00.000Z EST
#
#
# eps(actual)   : 0.18
# eps(estimate) : 0.18
# date : 2009-10-29T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.14
# eps(estimate) : 0.13
# date : 2009-07-30T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.01
# eps(estimate) : 0
# date : 2009-04-30T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.07
# eps(estimate) : 0.07
# date : 2009-01-22T05:00:00.000Z EST
#
#
# eps(actual)   : 0.19
# eps(estimate) : 0.2
# date : 2008-10-30T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.18
# eps(estimate) : 0.18
# date : 2008-07-31T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.17
# eps(estimate) : 0.16
# date : 2008-04-29T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.2
# eps(estimate) : 0.19
# date : 2008-01-31T05:00:00.000Z EST
#
#
# eps(actual)   : 0.17
# eps(estimate) : 0.18
# date : 2007-10-25T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.15
# eps(estimate) : 0.14
# date : 2007-07-26T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.11
# eps(estimate) : 0.11
# date : 2007-04-26T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.16
# eps(estimate) : 0.15
# date : 2007-01-25T05:00:00.000Z EST
#
#
# eps(actual)   : 0.19
# eps(estimate) : 0.19
# date : 2006-10-26T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.2
# eps(estimate) : 0.19
# date : 2006-07-27T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.19
# eps(estimate) : 0.17
# date : 2006-04-27T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.2
# eps(estimate) : 0.19
# date : 2006-01-26T05:00:00.000Z EST
#
#
# eps(actual)   : 0.14
# eps(estimate) : 0.14
# date : 2005-10-27T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.11
# eps(estimate) : 0.11
# date : 2005-07-26T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.1
# eps(estimate) : 0.1
# date : 2005-04-26T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.14
# eps(estimate) : 0.12
# date : 2005-01-27T05:00:00.000Z EST
#
#
# eps(actual)   : 0.16
# eps(estimate) : 0.14
# date : 2004-10-26T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.14
# eps(estimate) : 0.12
# date : 2004-07-29T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.11
# eps(estimate) : 0.1
# date : 2004-04-21T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.1
# eps(estimate) : 0.09
# date : 2004-01-29T05:00:00.000Z EST
#
#
# eps(actual)   : 0.09
# eps(estimate) : 0.08
# date : 2003-10-28T05:00:00.000Z EST
#
#
# eps(actual)   : 0.06
# eps(estimate) : 0.05
# date : 2003-07-24T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.02
# eps(estimate) : 0.01
# date : 2003-04-29T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.01
# eps(estimate) : 0.02
# date : 2003-01-28T05:00:00.000Z EST
#
#
# eps(actual)   : 0.01
# eps(estimate) : 0.04
# date : 2002-10-22T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.05
# eps(estimate) : 0.06
# date : 2002-07-25T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.04
# eps(estimate) : 0.04
# date : 2002-05-09T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.03
# eps(estimate) : 0.03
# date : 2002-01-28T05:00:00.000Z EST
#
#
# eps(actual)   : 0.01
# eps(estimate) : 0.01
# date : 2001-10-26T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.14
# eps(estimate) : 0.13
# date : 2001-03-30T05:00:00.000Z EST
#
#
# eps(actual)   : 0.13
# eps(estimate) : 0.12
# date : 2000-10-19T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.1
# eps(estimate) : 0.08
# date : 2000-07-31T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.08
# eps(estimate) : 0.07
# date : 2000-04-27T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.06
# eps(estimate) : 0.06
# date : 2000-01-27T05:00:00.000Z EST
#
#
# eps(actual)   : 0.05
# eps(estimate) : 0.05
# date : 1999-10-25T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.05
# eps(estimate) : 0.04
# date : 1999-09-10T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.04
# eps(estimate) : 0.02
# date : 1999-04-21T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.03
# eps(estimate) : 0.02
# date : 1999-01-27T05:00:00.000Z EST
#
#
# eps(actual)   : 0.03
# eps(estimate) : 0.03
# date : 1999-01-11T05:00:00.000Z EST
#
#
# eps(actual)   : 0.04
# eps(estimate) : 0.04
# date : 1998-04-27T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.04
# eps(estimate) : 0.03
# date : 1998-03-11T05:00:00.000Z EST

# %% [markdown]
# ## V.Create and store earnings history of multiple companies

# %% [markdown]
# ### - checking

# %%
MSFT_per_his = si.get_earnings_history('MSFT')

# %%
MSFT_per_his
# Out:
# [{'companyshortname': 'Microsoft Corp',
#   'epsactual': None,
#   'epsestimate': None,
#   'epssurprisepct': None,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2023-04-24T10:59:00.000Z',
#   'startdatetimetype': 'TNS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corp',
#   'epsactual': None,
#   'epsestimate': None,
#   'epssurprisepct': None,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2023-01-23T10:59:00.000Z',
#   'startdatetimetype': 'TNS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corp',
#   'epsactual': None,
#   'epsestimate': None,
#   'epssurprisepct': None,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2022-10-24T10:59:00.000Z',
#   'startdatetimetype': 'TNS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corp',
#   'epsactual': None,
#   'epsestimate': 2.33,
#   'epssurprisepct': None,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2022-07-25T10:59:00.000Z',
#   'startdatetimetype': 'TNS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 2.22,
#   'epsestimate': 2.19,
#   'epssurprisepct': 1.6,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2022-04-26T16:04:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 2.48,
#   'epsestimate': 2.31,
#   'epssurprisepct': 7.27,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2022-01-25T16:04:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 2.27,
#   'epsestimate': 2.08,
#   'epssurprisepct': 9.4,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2021-10-26T16:05:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 2.17,
#   'epsestimate': 1.92,
#   'epssurprisepct': 13.26,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2021-07-27T16:02:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 2.03,
#   'epsestimate': 1.78,
#   'epssurprisepct': 14.11,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2021-04-27T16:03:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 2.03,
#   'epsestimate': 1.64,
#   'epssurprisepct': 23.63,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2021-01-26T16:04:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 1.82,
#   'epsestimate': 1.54,
#   'epssurprisepct': 17.88,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2020-10-27T16:13:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 1.46,
#   'epsestimate': 1.34,
#   'epssurprisepct': 8.71,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2020-07-22T16:03:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 1.4,
#   'epsestimate': 1.26,
#   'epssurprisepct': 10.67,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2020-04-29T16:03:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 1.51,
#   'epsestimate': 1.32,
#   'epssurprisepct': 14.48,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2020-01-29T16:05:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 1.38,
#   'epsestimate': 1.25,
#   'epssurprisepct': 10.84,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2019-10-23T16:08:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 1.37,
#   'epsestimate': 1.21,
#   'epssurprisepct': 12.94,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2019-07-18T16:07:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 1.14,
#   'epsestimate': 1,
#   'epssurprisepct': 14.11,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2019-04-24T16:07:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 1.1,
#   'epsestimate': 1.09,
#   'epssurprisepct': 0.73,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2019-01-30T16:06:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 1.14,
#   'epsestimate': 0.96,
#   'epssurprisepct': 18.38,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2018-10-24T16:07:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 1.13,
#   'epsestimate': 1.08,
#   'epssurprisepct': 5.02,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2018-07-19T16:05:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.95,
#   'epsestimate': 0.85,
#   'epssurprisepct': 11.9,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2018-04-26T16:04:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.96,
#   'epsestimate': 0.87,
#   'epssurprisepct': 10.98,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2018-01-31T16:05:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.84,
#   'epsestimate': 0.72,
#   'epssurprisepct': 16.5,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2017-10-26T16:02:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.98,
#   'epsestimate': 0.71,
#   'epssurprisepct': 39.01,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2017-07-20T16:06:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.73,
#   'epsestimate': 0.7,
#   'epssurprisepct': 4.73,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2017-04-27T16:05:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.83,
#   'epsestimate': 0.79,
#   'epssurprisepct': 4.93,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2017-01-26T16:09:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.76,
#   'epsestimate': 0.68,
#   'epssurprisepct': 11.27,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2016-10-20T16:05:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.69,
#   'epsestimate': 0.58,
#   'epssurprisepct': 18.76,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2016-07-19T16:05:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.62,
#   'epsestimate': 0.64,
#   'epssurprisepct': -2.67,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2016-04-21T16:05:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.78,
#   'epsestimate': 0.71,
#   'epssurprisepct': 9.4,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2016-01-28T16:06:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.67,
#   'epsestimate': 0.59,
#   'epssurprisepct': 14.33,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2015-10-22T16:05:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.6,
#   'epsestimate': 0.56,
#   'epssurprisepct': 6.57,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2015-07-21T16:05:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.61,
#   'epsestimate': 0.51,
#   'epssurprisepct': 20.55,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2015-04-23T16:02:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.71,
#   'epsestimate': 0.71,
#   'epssurprisepct': -0.42,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2015-01-26T16:10:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.54,
#   'epsestimate': 0.49,
#   'epssurprisepct': 11.11,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2014-10-23T16:02:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.55,
#   'epsestimate': 0.6,
#   'epssurprisepct': -8.65,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2014-07-22T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.68,
#   'epsestimate': 0.63,
#   'epssurprisepct': 8.02,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2014-04-24T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.78,
#   'epsestimate': 0.68,
#   'epssurprisepct': 14.83,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2014-01-23T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.62,
#   'epsestimate': 0.54,
#   'epssurprisepct': 15.1,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2013-10-24T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.66,
#   'epsestimate': 0.75,
#   'epssurprisepct': -11.96,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2013-07-18T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.72,
#   'epsestimate': 0.68,
#   'epssurprisepct': 5.97,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2013-04-18T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.76,
#   'epsestimate': 0.75,
#   'epssurprisepct': 1.93,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2013-01-24T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.53,
#   'epsestimate': 0.56,
#   'epssurprisepct': -5.47,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2012-10-18T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.67,
#   'epsestimate': 0.62,
#   'epssurprisepct': 8.48,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2012-07-19T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.6,
#   'epsestimate': 0.57,
#   'epssurprisepct': 4.38,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2012-04-19T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.78,
#   'epsestimate': 0.76,
#   'epssurprisepct': 2.93,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2012-01-19T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.68,
#   'epsestimate': 0.68,
#   'epssurprisepct': 0.38,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2011-10-20T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.69,
#   'epsestimate': 0.58,
#   'epssurprisepct': 19.88,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2011-07-21T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.61,
#   'epsestimate': 0.56,
#   'epssurprisepct': 9.74,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2011-04-28T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.77,
#   'epsestimate': 0.68,
#   'epssurprisepct': 12.57,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2011-01-27T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.62,
#   'epsestimate': 0.55,
#   'epssurprisepct': 12.98,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2010-10-28T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.51,
#   'epsestimate': 0.46,
#   'epssurprisepct': 9.82,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2010-07-22T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.45,
#   'epsestimate': 0.42,
#   'epssurprisepct': 6.95,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2010-04-22T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.74,
#   'epsestimate': 0.59,
#   'epssurprisepct': 24.79,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2010-01-28T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.4,
#   'epsestimate': 0.32,
#   'epssurprisepct': 25.76,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2009-10-23T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.36,
#   'epsestimate': 0.36,
#   'epssurprisepct': 0.22,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2009-07-23T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.39,
#   'epsestimate': 0.39,
#   'epssurprisepct': 0.26,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2009-04-23T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.47,
#   'epsestimate': 0.49,
#   'epssurprisepct': -4.84,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2009-01-22T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.48,
#   'epsestimate': 0.47,
#   'epssurprisepct': 1.84,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2008-10-23T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.46,
#   'epsestimate': 0.47,
#   'epssurprisepct': -2.13,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2008-07-17T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.47,
#   'epsestimate': 0.44,
#   'epssurprisepct': 6.74,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2008-04-24T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.5,
#   'epsestimate': 0.46,
#   'epssurprisepct': 9.33,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2008-01-24T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.45,
#   'epsestimate': 0.39,
#   'epssurprisepct': 15.38,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2007-10-25T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.39,
#   'epsestimate': 0.39,
#   'epssurprisepct': 0.3,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2007-07-19T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.49,
#   'epsestimate': 0.46,
#   'epssurprisepct': 6.86,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2007-04-26T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.26,
#   'epsestimate': 0.23,
#   'epssurprisepct': 11.48,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2007-01-25T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.35,
#   'epsestimate': 0.31,
#   'epssurprisepct': 13.02,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2006-10-26T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.31,
#   'epsestimate': 0.3,
#   'epssurprisepct': 2.63,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2006-07-20T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.32,
#   'epsestimate': 0.33,
#   'epssurprisepct': -2.93,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2006-04-27T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.33,
#   'epsestimate': 0.33,
#   'epssurprisepct': -0.08,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2006-01-26T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.31,
#   'epsestimate': 0.3,
#   'epssurprisepct': 4.14,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2005-10-27T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.32,
#   'epsestimate': 0.31,
#   'epssurprisepct': 2.4,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2005-07-21T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.32,
#   'epsestimate': 0.32,
#   'epssurprisepct': 0.93,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2005-04-28T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.35,
#   'epsestimate': 0.33,
#   'epssurprisepct': 6.81,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2005-01-27T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.31,
#   'epsestimate': 0.3,
#   'epssurprisepct': 2.89,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2004-10-21T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.28,
#   'epsestimate': 0.29,
#   'epssurprisepct': -1.87,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2004-07-22T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.34,
#   'epsestimate': 0.29,
#   'epssurprisepct': 19.1,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2004-04-22T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.34,
#   'epsestimate': 0.3,
#   'epssurprisepct': 13.46,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2004-01-22T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.3,
#   'epsestimate': 0.29,
#   'epssurprisepct': 3.56,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2003-10-23T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.23,
#   'epsestimate': 0.24,
#   'epssurprisepct': -2.84,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2003-07-17T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.27,
#   'epsestimate': 0.24,
#   'epssurprisepct': 13.16,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2003-04-15T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.27,
#   'epsestimate': 0.23,
#   'epssurprisepct': 14.22,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2003-01-16T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.28,
#   'epsestimate': 0.21,
#   'epssurprisepct': 29.06,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2002-10-17T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.21,
#   'epsestimate': 0.21,
#   'epssurprisepct': 0.8,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2002-07-18T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.25,
#   'epsestimate': 0.25,
#   'epssurprisepct': -3.56,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2002-04-18T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.25,
#   'epsestimate': 0.21,
#   'epssurprisepct': 15.25,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2002-01-17T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.22,
#   'epsestimate': 0.2,
#   'epssurprisepct': 9.5,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2001-10-18T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.22,
#   'epsestimate': 0.21,
#   'epssurprisepct': 0.75,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2001-07-19T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.22,
#   'epsestimate': 0.21,
#   'epssurprisepct': 5.33,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2001-04-19T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.24,
#   'epsestimate': 0.23,
#   'epssurprisepct': 1.44,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2001-01-18T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.23,
#   'epsestimate': 0.21,
#   'epssurprisepct': 11.48,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2000-10-18T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.22,
#   'epsestimate': 0.21,
#   'epssurprisepct': 5.81,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2000-07-18T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.22,
#   'epsestimate': 0.2,
#   'epssurprisepct': 5.27,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2000-04-20T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.24,
#   'epsestimate': 0.21,
#   'epssurprisepct': 11.27,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2000-01-18T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.19,
#   'epsestimate': 0.17,
#   'epssurprisepct': 10.38,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '1999-10-19T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.2,
#   'epsestimate': 0.18,
#   'epssurprisepct': 12.03,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '1999-07-19T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.19,
#   'epsestimate': 0.16,
#   'epssurprisepct': 21.78,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '1999-04-20T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.18,
#   'epsestimate': 0.15,
#   'epssurprisepct': 23.47,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '1999-01-19T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.14,
#   'epsestimate': 0.12,
#   'epssurprisepct': 13.84,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '1998-10-20T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.13,
#   'epsestimate': 0.12,
#   'epssurprisepct': 4.99,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '1998-07-16T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'}]

# %% [markdown]
# ### 1) create dataframe - single company
# -define empty array
#
# -add on the data
#
# -define DataFrame

# %%
eps_his_msft_array = []

company_eps = si.get_earnings_history('MSFT')

for i in range(len(company_eps)):

      # print('eps(actual)   :' , company_eps[i]['epsactual'])
      # print('eps(estimate) :' , company_eps[i]['epsestimate'])
      # print('date :', company_eps[i]['startdatetime'],company_eps[i]['timeZoneShortName'])
      # print('\n')

      a = company_eps[i]['startdatetime']
      b = company_eps[i]['epsactual']
      c = company_eps[i]['epsestimate']
      X = [a,b,c]
      eps_his_msft_array.append(X)
MSFT_eps_his = pd.DataFrame(eps_his_msft_array)
MSFT_eps_his.columns = ['date','actual_eps','estimate_eps']

# %%
MSFT_eps_his
# Out:
#                         date  actual_eps  estimate_eps
# 0   2023-04-24T10:59:00.000Z         NaN           NaN
# 1   2023-01-23T10:59:00.000Z         NaN           NaN
# 2   2022-10-24T10:59:00.000Z         NaN           NaN
# 3   2022-07-25T10:59:00.000Z         NaN          2.33
# 4   2022-04-26T16:04:00.000Z        2.22          2.19
# ..                       ...         ...           ...
# 95  1999-07-19T04:00:00.000Z        0.20          0.18
# 96  1999-04-20T04:00:00.000Z        0.19          0.16
# 97  1999-01-19T05:00:00.000Z        0.18          0.15
# 98  1998-10-20T04:00:00.000Z        0.14          0.12
# 99  1998-07-16T04:00:00.000Z        0.13          0.12
#
# [100 rows x 3 columns]

# %% [markdown]
# ### 2) create dataframe - multiple companies

# %%
test_Co = ['AVGO','AMD','NVDA','INTC','QCOM','TXN','ADI','KLAC','MCHP','NXPI','LRCX','AMAT','MRVL','MU','TSM']    

for j in test_Co:
  
    eps_his_array = []
    sleep(random.uniform(1,2))
    company_eps = si.get_earnings_history(j)
    print('------company abbreviation : ', j,'------')
    print('total data N : ' , len(company_eps))

    for i in range(len(company_eps)):


          # print('eps(actual)   :' , company_eps[i]['epsactual'])
          # print('eps(estimate) :' , company_eps[i]['epsestimate'])
          # print('date :', company_eps[i]['startdatetime'],company_eps[i]['timeZoneShortName'])
          # print('\n')

          a = company_eps[i]['startdatetime']
          b = company_eps[i]['epsactual']
          c = company_eps[i]['epsestimate']
          X = [a,b,c]
          eps_his_array.append(X)

    globals()[f'{j}_eps_his'] = pd.DataFrame(eps_his_array)
    globals()[f'{j}_eps_his'].columns = ['date','actual_eps','estimate_eps']
    print('complete creating dataframe: ', f'{j}_eps_his')
    print('\n')
# Out:
# ------company abbreviation :  AVGO ------
# total data N :  54
# complete creating dataframe:  AVGO_eps_his
#
#
# ------company abbreviation :  AMD ------
# total data N :  100
# complete creating dataframe:  AMD_eps_his
#
#
# ------company abbreviation :  NVDA ------
# total data N :  95
# complete creating dataframe:  NVDA_eps_his
#
#
# ------company abbreviation :  INTC ------
# total data N :  100
# complete creating dataframe:  INTC_eps_his
#
#
# ------company abbreviation :  QCOM ------
# total data N :  100
# complete creating dataframe:  QCOM_eps_his
#
#
# ------company abbreviation :  TXN ------
# total data N :  100
# complete creating dataframe:  TXN_eps_his
#
#
# ------company abbreviation :  ADI ------
# total data N :  100
# complete creating dataframe:  ADI_eps_his
#
#
# ------company abbreviation :  KLAC ------
# total data N :  100
# complete creating dataframe:  KLAC_eps_his
#
#
# ------company abbreviation :  MCHP ------
# total data N :  100
# complete creating dataframe:  MCHP_eps_his
#
#
# ------company abbreviation :  NXPI ------
# total data N :  51
# complete creating dataframe:  NXPI_eps_his
#
#
# ------company abbreviation :  LRCX ------
# total data N :  100
# complete creating dataframe:  LRCX_eps_his
#
#
# ------company abbreviation :  AMAT ------
# total data N :  100
# complete creating dataframe:  AMAT_eps_his
#
#
# ------company abbreviation :  MRVL ------
# total data N :  88
# complete creating dataframe:  MRVL_eps_his
#
#
# ------company abbreviation :  MU ------
# total data N :  100
# complete creating dataframe:  MU_eps_his
#
#
# ------company abbreviation :  TSM ------
# total data N :  95
# complete creating dataframe:  TSM_eps_his

# %% [markdown]
# ### 3) storing the data

# %%
test_Co = ['AVGO','AMD','NVDA','INTC','QCOM','TXN','ADI','KLAC','MCHP','NXPI','LRCX','AMAT','MRVL','MU','TSM']  

for j in test_Co:
  
    eps_his_array = []
    sleep(random.uniform(1,2))
    company_eps = si.get_earnings_history(j)
    print('------company abbreviation : ', j,'------')
    print('total data N : ' , len(company_eps))

    for i in range(len(company_eps)):
      
        try:


          # print('eps(actual)   :' , company_eps[i]['epsactual'])
          # print('eps(estimate) :' , company_eps[i]['epsestimate'])
          # print('date :', company_eps[i]['startdatetime'],company_eps[i]['timeZoneShortName'])
          # print('\n')

          a = company_eps[i]['startdatetime']
          b = company_eps[i]['epsactual']
          c = company_eps[i]['epsestimate']
          X = [a,b,c]
          eps_his_array.append(X)

        except IndexError as e:
          print(f'{j}', 'error')

    globals()[f'{j}_eps_his'] = pd.DataFrame(eps_his_array)
    globals()[f'{j}_eps_his'].columns = ['date','actual_eps','estimate_eps']
    globals()[f'{j}_eps_his'].to_csv(f'/content/drive/MyDrive/Colab Notebooks/datasets/stock_market/companies_eps_his/{j}_eps_his.csv')
    print('complete creating dataframe: ', f'{j}_eps_his')
    print('storning dataframe in (csv): ', f'{j}_eps_his')
    print('\n')
# Out:
# ------company abbreviation :  AVGO ------
# total data N :  52
# complete creating dataframe:  AVGO_eps_his
# storning dataframe in (csv):  AVGO_eps_his
#
#
# ------company abbreviation :  AMD ------
# total data N :  100
# complete creating dataframe:  AMD_eps_his
# storning dataframe in (csv):  AMD_eps_his
#
#
# ------company abbreviation :  NVDA ------
# total data N :  93
# complete creating dataframe:  NVDA_eps_his
# storning dataframe in (csv):  NVDA_eps_his
#
#
# ------company abbreviation :  INTC ------
# total data N :  100
# complete creating dataframe:  INTC_eps_his
# storning dataframe in (csv):  INTC_eps_his
#
#
# ------company abbreviation :  QCOM ------
# total data N :  100
# complete creating dataframe:  QCOM_eps_his
# storning dataframe in (csv):  QCOM_eps_his
#
#
# ------company abbreviation :  TXN ------
# total data N :  100
# complete creating dataframe:  TXN_eps_his
# storning dataframe in (csv):  TXN_eps_his
#
#
# ------company abbreviation :  ADI ------
# total data N :  100
# complete creating dataframe:  ADI_eps_his
# storning dataframe in (csv):  ADI_eps_his
#
#
# ------company abbreviation :  KLAC ------
# total data N :  100
# complete creating dataframe:  KLAC_eps_his
# storning dataframe in (csv):  KLAC_eps_his
#
#
# ------company abbreviation :  MCHP ------
# total data N :  100
# complete creating dataframe:  MCHP_eps_his
# storning dataframe in (csv):  MCHP_eps_his
#
#
# ------company abbreviation :  NXPI ------
# total data N :  49
# complete creating dataframe:  NXPI_eps_his
# storning dataframe in (csv):  NXPI_eps_his
#
#
# ------company abbreviation :  LRCX ------
# total data N :  100
# complete creating dataframe:  LRCX_eps_his
# storning dataframe in (csv):  LRCX_eps_his
#
#
# ------company abbreviation :  AMAT ------
# total data N :  100
# complete creating dataframe:  AMAT_eps_his
# storning dataframe in (csv):  AMAT_eps_his
#
#
# ------company abbreviation :  MRVL ------
# total data N :  85
# complete creating dataframe:  MRVL_eps_his
# storning dataframe in (csv):  MRVL_eps_his
#
#
# ------company abbreviation :  MU ------
# total data N :  100
# complete creating dataframe:  MU_eps_his
# storning dataframe in (csv):  MU_eps_his
#
#
# ------company abbreviation :  TSM ------
# total data N :  95
# complete creating dataframe:  TSM_eps_his
# storning dataframe in (csv):  TSM_eps_his

# %% [markdown]
# ## VI.Visualiztion

# %% [markdown]
# - create X:data , Y: actual estimate eps chart

# %% [markdown]
# ### 1)-2 PE ratio calculation

# %%
si.get_stats_valuation('KLAC')
# Out:
#                   Unnamed: 0 As of Date: 5/20/2022Current 3/31/2022  \
# 0      Market Cap (intraday)                       50.52B    54.68B
# 1           Enterprise Value                       51.73B    55.41B
# 2               Trailing P/E                        16.43     18.84
# 3                Forward P/E                        13.91     15.67
# 4  PEG Ratio (5 yr expected)                         1.28      1.47
# 5          Price/Sales (ttm)                         5.98      6.90
# 6           Price/Book (mrq)                        12.38     13.51
# 7   Enterprise Value/Revenue                         5.98     24.21
# 8    Enterprise Value/EBITDA                        13.79     56.63
#
#   12/31/2021 9/30/2021 6/30/2021 3/31/2021
# 0     64.88B    50.76B    49.53B    50.67B
# 1     65.80B    51.81B    50.63B    51.94B
# 2      24.38     25.02     27.24     37.72
# 3      20.58     17.99     19.49     22.37
# 4       1.85      1.83      1.56      2.10
# 5       8.91      7.52      7.83      8.51
# 6      16.80     15.03     15.90     17.26
# 7      27.97     24.86     26.30     28.80
# 8      62.65     58.25     60.75     68.00

# %%
test_Co = ['AVGO','AMD','NVDA','INTC','QCOM','TXN','ADI','KLAC','MCHP','NXPI','LRCX','AMAT','MRVL','MU','TSM']  

per_array = []
success_N = 0
error_N = 0
for j in test_Co:
  
    try:
#      sleep(random.uniform(1,2))
      company_per = si.get_stats_valuation(j)
      print('------company abbreviation : ', j,'------')
      print(company_per.iloc[2,1])
      print('\n')

      a = j
      b = float(company_per.iloc[2,1])

      X = [a,b]
      per_array.append(X)

      success_N +=1

    except IndexError as e:
      print(f'{j}', 'error')
      error_N +=1

print('recalled_data_N = ', success_N)
print('error_N = ', error_N)




    #       a = company_eps[i]['startdatetime']
    #       b = company_eps[i]['epsactual']
    #       c = company_eps[i]['epsestimate']
    #       X = [a,b,c]
    #       eps_his_array.append(X)

    # globals()[f'{j}_eps_his'] = pd.DataFrame(eps_his_array)
    # globals()[f'{j}_eps_his'].columns = ['date','actual_eps','estimate_eps']
    # globals()[f'{j}_eps_his'].to_csv(f'/content/drive/MyDrive/Colab Notebooks/datasets/stock_market/companies_eps_his/{j}_eps_his.csv')
    # print('complete creating dataframe: ', f'{j}_eps_his')
    # print('storning dataframe in (csv): ', f'{j}_eps_his')
    # print('\n')
# Out:
# AVGO error
# ------company abbreviation :  AMD ------
# 35.93
#
#
# ------company abbreviation :  NVDA ------
# 43.99
#
#
# ------company abbreviation :  INTC ------
# 6.98
#
#
# ------company abbreviation :  QCOM ------
# 13.38
#
#
# ------company abbreviation :  TXN ------
# 19.49
#
#
# ------company abbreviation :  ADI ------
# 54.21
#
#
# ------company abbreviation :  KLAC ------
# 16.43
#
#
# ------company abbreviation :  MCHP ------
# 29.14
#
#
# ------company abbreviation :  NXPI ------
# 21.87
#
#
# ------company abbreviation :  LRCX ------
# 14.93
#
#
# ------company abbreviation :  AMAT ------
# 15.51
#
#
# ------company abbreviation :  MRVL ------
# 22.15
#
#
# ------company abbreviation :  MU ------
# 8.94
#
#
# ------company abbreviation :  TSM ------
# 21.31
#
#
# recalled_data_N =  14
# error_N =  1

# %%
per_array
# Out:
# [['AMD', 35.93],
#  ['NVDA', 43.99],
#  ['INTC', 6.98],
#  ['QCOM', 13.38],
#  ['TXN', 19.49],
#  ['ADI', 54.21],
#  ['KLAC', 16.43],
#  ['MCHP', 29.14],
#  ['NXPI', 21.87],
#  ['LRCX', 14.93],
#  ['AMAT', 15.51],
#  ['MRVL', 22.15],
#  ['MU', 8.94],
#  ['TSM', 21.31]]

# %%
df = pd.DataFrame(per_array)

# %%
globals()[f'{j}_eps_his'].columns = ['date','actual_eps','estimate_eps']

# %%
df.clumns = ['abb','per']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   """Entry point for launching an IPython kernel.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       14 non-null     object
#  1   1       14 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 352.0+ bytes

# %%
df.describe()
# Out:
#                1
# count  14.000000
# mean   23.161429
# std    13.438171
# min     6.980000
# 25%    15.075000
# 50%    20.400000
# 75%    27.392500
# max    54.210000
