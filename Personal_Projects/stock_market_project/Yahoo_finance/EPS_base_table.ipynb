# %% [markdown]
# # Objectives
# - Recall Earnings Per Share(EPS)
# - Create the EPS **dataframe**
# - Store the data
# - Create the EPS charts

# %% [markdown]
# Following Objectives
# - P/E = Shareprice / Earnings per share

# %% [markdown]
# - note
# ITA (Aerospace & Defense)
#
# (RTX) Raytheon Technologies Corporation (33/ BB /ooo)
# (LMT) Lockheed Martin Corporation (18.5 / AA /ooo)
# (BA)  Boeing Company ( - / C / oxx)
# (NOC) Northrop Grumman Corp. (12.73 / AA / ooo)
# (GD)  General Dynamics Corporation (18.78 / BBB/ ooo)
# (LHX) L3Harris Technologies Inc ( 25.62 / A / ooo)
# (TXT) Textron Inc (17.46 / BB / ooo)
# (HWM) Howmet Aerospace Inc (44 / BB / ooo)
# (TDG) TransDigm Group Incorporated ( 36.64 / A / ooo)
# (HII) Huntington Ingalls Industries, Inc ( 16.2 / A / ooo)
# (HEI) HEICO Corporation Class A ( 53.66 / AA / ooo)
# (AXON) Axon Enterprise Inc (187.37 / AA / ooo)

# %% [markdown]
# ## I. Packages, mount Google drive

# %%
# !pip install yahoo_fin
# !pip install yahoo_fin --upgrade
# !pip install requests_html
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting yahoo_fin
#   Downloading yahoo_fin-0.8.9.1-py3-none-any.whl (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from yahoo_fin) (1.3.5)
# Collecting requests-html
#   Downloading requests_html-0.10.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from yahoo_fin) (2.23.0)
# Collecting feedparser
#   Downloading feedparser-6.0.10-py3-none-any.whl (81 kB)
#      |████████████████████████████████| 81 kB 7.5 MB/s
# Collecting sgmllib3k
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->yahoo_fin) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas->yahoo_fin) (1.21.6)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->yahoo_fin) (2022.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->yahoo_fin) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->yahoo_fin) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->yahoo_fin) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->yahoo_fin) (2022.9.24)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->yahoo_fin) (1.24.3)
# Collecting w3lib
#   Downloading w3lib-2.0.1-py3-none-any.whl (20 kB)
# Collecting pyquery
#   Downloading pyquery-1.4.3-py3-none-any.whl (22 kB)
# Requirement already satisfied: bs4 in /usr/local/lib/python3.7/dist-packages (from requests-html->yahoo_fin) (0.0.1)
# Collecting fake-useragent
#   Downloading fake-useragent-0.1.11.tar.gz (13 kB)
# Collecting parse
#   Downloading parse-1.19.0.tar.gz (30 kB)
# Collecting pyppeteer>=0.0.14
#   Downloading pyppeteer-1.0.2-py3-none-any.whl (83 kB)
#      |████████████████████████████████| 83 kB 2.2 MB/s
# Collecting websockets<11.0,>=10.0
#   Downloading websockets-10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (112 kB)
#      |████████████████████████████████| 112 kB 75.9 MB/s
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (1.4.4)
# Collecting pyee<9.0.0,>=8.1.0
#   Downloading pyee-8.2.2-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (4.64.1)
# Requirement already satisfied: importlib-metadata>=1.4 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (4.13.0)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 102.5 MB/s
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html->yahoo_fin) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html->yahoo_fin) (3.9.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from bs4->requests-html->yahoo_fin) (4.6.3)
# Requirement already satisfied: lxml>=2.1 in /usr/local/lib/python3.7/dist-packages (from pyquery->requests-html->yahoo_fin) (4.9.1)
# Collecting cssselect>0.7.9
#   Downloading cssselect-1.1.0-py2.py3-none-any.whl (16 kB)
# Building wheels for collected packages: fake-useragent, parse, sgmllib3k
#   Building wheel for fake-useragent (setup.py) ... done
#   Created wheel for fake-useragent: filename=fake_useragent-0.1.11-py3-none-any.whl size=13502 sha256=1668511a5ee6844586253e692abee1e4e81e96f1f2b921aa230eca867ab2b4a1
#   Stored in directory: /root/.cache/pip/wheels/ed/f7/62/50ab6c9a0b5567267ab76a9daa9d06315704209b2c5d032031
#   Building wheel for parse (setup.py) ... done
#   Created wheel for parse: filename=parse-1.19.0-py3-none-any.whl size=24591 sha256=dbbb318aede9e85556ebb71a85d4b068424bc5814f5eb681beccc3210efcecf5
#   Stored in directory: /root/.cache/pip/wheels/9c/aa/cc/f2228050ccb40f22144b073f15a2c84f11204f29fc0dce028e
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6066 sha256=68220b8feeb610071e891c5f045df9b39bc7a5673df1f61b132803085f1d42c1
#   Stored in directory: /root/.cache/pip/wheels/73/ad/a4/0dff4a6ef231fc0dfa12ffbac2a36cebfdddfe059f50e019aa
# Successfully built fake-useragent parse sgmllib3k
# Installing collected packages: websockets, urllib3, pyee, cssselect, w3lib, sgmllib3k, pyquery, pyppeteer, parse, fake-useragent, requests-html, feedparser, yahoo-fin
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# Successfully installed cssselect-1.1.0 fake-useragent-0.1.11 feedparser-6.0.10 parse-1.19.0 pyee-8.2.2 pyppeteer-1.0.2 pyquery-1.4.3 requests-html-0.10.0 sgmllib3k-1.0.0 urllib3-1.25.11 w3lib-2.0.1 websockets-10.3 yahoo-fin-0.8.9.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: yahoo_fin in /usr/local/lib/python3.7/dist-packages (0.8.9.1)
# Requirement already satisfied: feedparser in /usr/local/lib/python3.7/dist-packages (from yahoo_fin) (6.0.10)
# Requirement already satisfied: requests-html in /usr/local/lib/python3.7/dist-packages (from yahoo_fin) (0.10.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from yahoo_fin) (1.3.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from yahoo_fin) (2.23.0)
# Requirement already satisfied: sgmllib3k in /usr/local/lib/python3.7/dist-packages (from feedparser->yahoo_fin) (1.0.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->yahoo_fin) (2022.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->yahoo_fin) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas->yahoo_fin) (1.21.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->yahoo_fin) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->yahoo_fin) (2022.9.24)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->yahoo_fin) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->yahoo_fin) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->yahoo_fin) (1.25.11)
# Requirement already satisfied: pyppeteer>=0.0.14 in /usr/local/lib/python3.7/dist-packages (from requests-html->yahoo_fin) (1.0.2)
# Requirement already satisfied: pyquery in /usr/local/lib/python3.7/dist-packages (from requests-html->yahoo_fin) (1.4.3)
# Requirement already satisfied: bs4 in /usr/local/lib/python3.7/dist-packages (from requests-html->yahoo_fin) (0.0.1)
# Requirement already satisfied: w3lib in /usr/local/lib/python3.7/dist-packages (from requests-html->yahoo_fin) (2.0.1)
# Requirement already satisfied: parse in /usr/local/lib/python3.7/dist-packages (from requests-html->yahoo_fin) (1.19.0)
# Requirement already satisfied: fake-useragent in /usr/local/lib/python3.7/dist-packages (from requests-html->yahoo_fin) (0.1.11)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (1.4.4)
# Requirement already satisfied: importlib-metadata>=1.4 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (4.13.0)
# Requirement already satisfied: websockets<11.0,>=10.0 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (10.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (4.64.1)
# Requirement already satisfied: pyee<9.0.0,>=8.1.0 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (8.2.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html->yahoo_fin) (3.9.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html->yahoo_fin) (4.1.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from bs4->requests-html->yahoo_fin) (4.6.3)
# Requirement already satisfied: cssselect>0.7.9 in /usr/local/lib/python3.7/dist-packages (from pyquery->requests-html->yahoo_fin) (1.1.0)
# Requirement already satisfied: lxml>=2.1 in /usr/local/lib/python3.7/dist-packages (from pyquery->requests-html->yahoo_fin) (4.9.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: requests_html in /usr/local/lib/python3.7/dist-packages (0.10.0)
# Requirement already satisfied: fake-useragent in /usr/local/lib/python3.7/dist-packages (from requests_html) (0.1.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from requests_html) (2.23.0)
# Requirement already satisfied: bs4 in /usr/local/lib/python3.7/dist-packages (from requests_html) (0.0.1)
# Requirement already satisfied: w3lib in /usr/local/lib/python3.7/dist-packages (from requests_html) (2.0.1)
# Requirement already satisfied: pyppeteer>=0.0.14 in /usr/local/lib/python3.7/dist-packages (from requests_html) (1.0.2)
# Requirement already satisfied: parse in /usr/local/lib/python3.7/dist-packages (from requests_html) (1.19.0)
# Requirement already satisfied: pyquery in /usr/local/lib/python3.7/dist-packages (from requests_html) (1.4.3)
# Requirement already satisfied: certifi>=2021 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests_html) (2022.9.24)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests_html) (1.4.4)
# Requirement already satisfied: urllib3<2.0.0,>=1.25.8 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests_html) (1.25.11)
# Requirement already satisfied: importlib-metadata>=1.4 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests_html) (4.13.0)
# Requirement already satisfied: pyee<9.0.0,>=8.1.0 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests_html) (8.2.2)
# Requirement already satisfied: websockets<11.0,>=10.0 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests_html) (10.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests_html) (4.64.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests_html) (3.9.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests_html) (4.1.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from bs4->requests_html) (4.6.3)
# Requirement already satisfied: cssselect>0.7.9 in /usr/local/lib/python3.7/dist-packages (from pyquery->requests_html) (1.1.0)
# Requirement already satisfied: lxml>=2.1 in /usr/local/lib/python3.7/dist-packages (from pyquery->requests_html) (4.9.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->requests_html) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->requests_html) (2.10)

# %%
import yahoo_fin.stock_info as si
import pandas as pd
import random
from time import sleep

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## II.Other necessary materials

# %%
#Semiconductor SOXX ETF holdings (top 15)
soxx_etf_holdings = ['AVGO','AMD','NVDA','INTC','QCOM','TXN','ADI','KLAC','MCHP','NXPI','LRCX','AMAT','MRVL','MU','TSM'] # 'TSMC'(ADR) fail to recall
#Semiconductor SOXX ETF holdings (top 15)
# soxx_etf_holdings = ['INTC','AVGO','TXN','NVDA','QCOM','AMAT','MU','LRCX','KLAC','AMD'] #'TSMC (ADR) fail to recall 

faang_etf_holdings = ['FB','AAPL','AMZN','NFLX','GOOG','NVDA','TSAL','TWTR','BABA','BIDU']

# %% [markdown]
# ### 매일 현재 상승 상위 100종목
# ### 하락 상위 100종목
# ### 거래량 100종목

# %%
si.get_day_gainers()
# Out:
#    Symbol                                     Name  Price (Intraday)  Change  \
# 0    LEGN               Legend Biotech Corporation             45.91    5.71
# 1    CRCT                             Cricut, Inc.             10.27    1.05
# 2     CUK               Carnival Corporation & plc              7.16    0.70
# 3     CCL               Carnival Corporation & plc              8.08    0.81
# 4    NTCO                  Natura &Co Holding S.A.              5.42    0.54
# ..    ...                                      ...               ...     ...
# 95    BAH  Booz Allen Hamilton Holding Corporation            100.88    4.45
# 96   GLOB                             Globant S.A.            181.81    7.79
# 97     KD                   Kyndryl Holdings, Inc.              9.11    0.42
# 98   TRMD                                 TORM plc             24.74    1.05
# 99  AMKBY                  A.P. Møller - Mærsk A/S             10.48    0.44
#
#     % Change       Volume  Avg Vol (3 month)    Market Cap  PE Ratio (TTM)
# 0      14.20    2486000.0           801390.0  7.685000e+09             NaN
# 1      11.39     332968.0           172581.0  2.282000e+09           29.34
# 2      10.84    5500000.0          2824000.0  9.080000e+09             NaN
# 3      11.14  114959000.0         62057000.0  1.049400e+10             NaN
# 4      11.07    1749000.0           671095.0  3.913000e+09           30.11
# ..       ...          ...                ...           ...             ...
# 95      4.61    1440000.0           804400.0  1.334900e+10           26.55
# 96      4.48     294796.0           335639.0  7.595000e+09           58.27
# 97      4.83    2065000.0          2732000.0  2.066000e+09             NaN
# 98      4.43     357330.0           303850.0  2.032000e+09           21.51
# 99      4.38     303416.0           237039.0  3.628600e+10            1.46
#
# [100 rows x 9 columns]

# %%
si.get_day_losers()
# Out:
#    Symbol                                               Name  \
# 0   MPCFF              Metro Pacific Investments Corporation
# 1   PHJMF                   PT Hanjaya Mandala Sampoerna Tbk
# 2    SFBS                       ServisFirst Bancshares, Inc.
# 3    PTCT                             PTC Therapeutics, Inc.
# 4    ASAI                          Sendas Distribuidora S.A.
# 5    CANO                                  Cano Health, Inc.
# 6   WYNMY                                Wynn Macau, Limited
# 7   GARPF                          Golden Agri-Resources Ltd
# 8   KUASF                                Kuaishou Technology
# 9   WHITF                            Whitehaven Coal Limited
# 10    TAL                                TAL Education Group
# 11     GH                              Guardant Health, Inc.
# 12  BHPLF                                  BHP Group Limited
# 13  TSCDF                                          Tesco PLC
# 14   ALLY                                Ally Financial Inc.
# 15    ASX                   ASE Technology Holding Co., Ltd.
# 16  GLPEY                           Galp Energia, SGPS, S.A.
# 17  ESOCF                                           Enel SpA
# 18  ITVPY                                            ITV plc
# 19  FQVLF                        First Quantum Minerals Ltd.
# 20   COIN                              Coinbase Global, Inc.
# 21  CPYYY                                       Centrica plc
# 22  WXXWY                       WuXi Biologics (Cayman) Inc.
# 23    DAR                           Darling Ingredients Inc.
# 24   BEKE                                   KE Holdings Inc.
# 25   GOLF                            Acushnet Holdings Corp.
# 26   BNTX                                        BioNTech SE
# 27   MRNA                                      Moderna, Inc.
# 28  TOYOF                           Toyota Motor Corporation
# 29   NEOG                                 Neogen Corporation
# 30  TTNDY              Techtronic Industries Company Limited
# 31  SMNNY                                       Shimano Inc.
# 32    OMF                             OneMain Holdings, Inc.
# 33   EVEX                                  Eve Holding, Inc.
# 34     BZ                                    Kanzhun Limited
# 35  SSLZY                                     Santos Limited
# 36  ENAKF                                            E.ON SE
# 37   JOBY                                Joby Aviation, Inc.
# 38   AMRC                                     Ameresco, Inc.
# 39  PILBF                           Pilbara Minerals Limited
# 40   AZTA                                       Azenta, Inc.
# 41  BCCLF                              Becle, S.A.B. de C.V.
# 42  LUNMF                          Lundin Mining Corporation
# 43    TLK  Perusahaan Perseroan (Persero) PT Telekomunika...
# 44  PPCCY         PICC Property and Casualty Company Limited
# 45    ZGN                             Ermenegildo Zegna N.V.
# 46    HAS                                       Hasbro, Inc.
# 47   BPMC                    Blueprint Medicines Corporation
# 48  TOSYY                                Toshiba Corporation
# 49  ACDSF                           CapitaLand Ascendas REIT
# 50  DNPLY                      Dai Nippon Printing Co., Ltd.
# 51   CBSH                          Commerce Bancshares, Inc.
# 52   DXCM                                       DexCom, Inc.
# 53  HLDCY         Henderson Land Development Company Limited
# 54  IVPAF                                 Ivanhoe Mines Ltd.
# 55   DNLI                           Denali Therapeutics Inc.
# 56  IPXHY                                  Inpex Corporation
# 57    TFC                       Truist Financial Corporation
#
#     Price (Intraday)   Change  % Change      Volume  Avg Vol (3 month)  \
# 0             0.0500  -0.0340    -40.48    135000.0            21210.0
# 1             0.0500  -0.0095    -15.97     67246.0           108645.0
# 2            74.6700 -12.1800    -14.02    655828.0           138507.0
# 3            48.7800  -6.0100    -10.97   2030000.0           592868.0
# 4            17.0500  -1.5500     -8.33    697426.0           264812.0
# 5             4.3900  -0.3400     -7.19  25008000.0          6662000.0
# 6             5.0600  -0.3900     -7.16     21827.0            19404.0
# 7             0.1809  -0.0132     -6.80    140500.0            13421.0
# 8             6.3300  -0.4300     -6.36    126330.0             3693.0
# 9             6.4700  -0.3900     -5.69     27214.0            58340.0
# 10            4.0000  -0.2100     -4.99   6115000.0          5962000.0
# 11           47.2700  -2.7700     -5.54   2459000.0           947548.0
# 12           24.2600  -1.2700     -4.97    153722.0           174320.0
# 13            2.2400  -0.1100     -4.68     38900.0            33931.0
# 14           28.7100  -1.4000     -4.65  13884000.0          4236000.0
# 15            4.8100  -0.2300     -4.56   9431000.0          8075000.0
# 16            4.7100  -0.2180     -4.42    118995.0           102876.0
# 17            4.0750  -0.1875     -4.40     32087.0            45328.0
# 18            7.3500  -0.3300     -4.30     22536.0            62448.0
# 19           16.6800  -0.7500     -4.29     27159.0            34398.0
# 20           66.2100  -2.9600     -4.28  13875000.0         13414000.0
# 21            3.0950  -0.1350     -4.18     22426.0            14271.0
# 22           12.5700  -0.5400     -4.12     55457.0           164598.0
# 23           73.9900  -3.0200     -3.92   2590000.0          1272000.0
# 24           12.1800  -0.5000     -3.94  19579000.0         10786000.0
# 25           43.9600  -1.8000     -3.93    483064.0           267228.0
# 26          133.6800  -5.2600     -3.79    858790.0           849118.0
# 27          134.0900  -5.1600     -3.71   5084000.0          4754000.0
# 28           13.2800  -0.5100     -3.68    315889.0            86964.0
# 29           11.3200  -0.4300     -3.66   4491000.0          6862000.0
# 30           46.8500  -1.7500     -3.60     70148.0            81160.0
# 31           14.7200  -0.5400     -3.54   1061000.0           201146.0
# 32           32.0800  -1.1600     -3.49   2173000.0          1329000.0
# 33            8.0500  -0.2800     -3.36     24055.0           103035.0
# 34           15.8500  -0.5500     -3.35   1476000.0          2374000.0
# 35            4.7000  -0.1600     -3.29    316679.0           288895.0
# 36            7.6800  -0.2600     -3.27     24727.0             9323.0
# 37            4.3400  -0.1400     -3.12   3854000.0          3756000.0
# 38           62.7400  -2.0000     -3.09    414177.0           345896.0
# 39            3.0000  -0.0950     -3.07    186778.0           344450.0
# 40           39.6500  -1.2500     -3.06    891300.0           717032.0
# 41            1.7500  -0.0550     -3.05     41291.0            93662.0
# 42            4.8300  -0.1500     -3.01     43133.0            72753.0
# 43           27.2000  -0.7500     -2.68    415696.0           266823.0
# 44           26.3200  -0.8100     -2.99     42485.0             4357.0
# 45           10.7300  -0.1600     -1.47     64383.0            61507.0
# 46           65.7600  -1.9500     -2.88   3024000.0          1195000.0
# 47           52.2700  -1.5400     -2.86    637956.0           809764.0
# 48           17.9100  -0.5200     -2.85     76202.0            59103.0
# 49            1.8120  -0.0530     -2.84     52156.0            16940.0
# 50            9.7800  -0.2800     -2.83     37960.0            34501.0
# 51           70.5500  -2.0500     -2.82    520310.0           392865.0
# 52           96.9300  -2.8000     -2.81   3681000.0          2788000.0
# 53            2.7900  -0.0800     -2.79   1120000.0           542185.0
# 54            6.3600  -0.1800     -2.75     22564.0            86535.0
# 55           32.8100  -0.8900     -2.64    346742.0           688167.0
# 56            9.5900  -0.2600     -2.64     89296.0           136476.0
# 57           43.3700  -1.0600     -2.39  10753000.0          5485000.0
#
#       Market Cap  PE Ratio (TTM)
# 0   1.023000e+09            5.00
# 1   5.795000e+09             NaN
# 2   4.055000e+09           17.95
# 3   3.490000e+09             NaN
# 4   4.891000e+09           16.39
# 5   2.344000e+09             NaN
# 6   2.649000e+09             NaN
# 7   2.239000e+09            3.01
# 8   2.501200e+10             NaN
# 9   6.210000e+09            5.39
# 10  2.595000e+09             NaN
# 11  4.832000e+09             NaN
# 12  1.790140e+11            6.08
# 13  1.690100e+10           16.00
# 14  8.858000e+09            4.11
# 15  9.737000e+09            5.59
# 16  7.789000e+09           15.19
# 17  3.902300e+10           14.05
# 18  2.686000e+09            5.61
# 19  1.145400e+10            8.56
# 20  1.734000e+10            6.77
# 21  4.394000e+09            6.59
# 22  2.680000e+10           43.34
# 23  1.186600e+10           17.01
# 24  1.534100e+10             NaN
# 25  3.128000e+09           20.26
# 26  3.244200e+10            2.98
# 27  5.089800e+10            3.95
# 28  1.817700e+11           10.14
# 29  2.446000e+09           35.38
# 30  1.712300e+10           14.92
# 31  1.335100e+10           15.66
# 32  3.967000e+09            3.84
# 33  2.144000e+09             NaN
# 34  6.907000e+09            5.78
# 35  1.623400e+10           10.00
# 36  1.972500e+10            4.68
# 37  2.637000e+09             NaN
# 38  3.252000e+09           33.02
# 39  9.182000e+09           27.27
# 40  2.975000e+09            1.34
# 41  6.596000e+09           21.88
# 42  3.701000e+09            5.14
# 43  2.704600e+10           15.81
# 44  2.311800e+10            6.75
# 45  2.605000e+09             NaN
# 46  9.081000e+09           16.95
# 47  3.122000e+09             NaN
# 48  1.549300e+10           11.55
# 49  7.612000e+09           10.66
# 50  5.219000e+09            8.09
# 51  8.458000e+09           18.28
# 52  3.776200e+10          225.42
# 53  1.330900e+10            9.30
# 54  7.651000e+09           15.90
# 55  4.047000e+09             NaN
# 56  1.301600e+10            5.67
# 57  5.754200e+10            9.97

# %%
si.get_day_most_active()
# Out:
#    Symbol                              Name  Price (Intraday)  Change  \
# 0     CCL        Carnival Corporation & plc              8.08    0.81
# 1     AMD      Advanced Micro Devices, Inc.             57.92   -0.04
# 2    AAPL                        Apple Inc.            143.75    1.34
# 3     BAC       Bank of America Corporation             34.88    1.26
# 4    TSLA                       Tesla, Inc.            220.19    0.84
# ..    ...                               ...               ...     ...
# 95     DB  Deutsche Bank Aktiengesellschaft              8.68    0.27
# 96   LYFT                        Lyft, Inc.             13.29    0.63
# 97     IS                   ironSource Ltd.              3.39    0.02
# 98   AGNC             AGNC Investment Corp.              8.09    0.13
# 99    MPW    Medical Properties Trust, Inc.             11.06   -0.11
#
#     % Change       Volume  Avg Vol (3 month)      Market Cap  PE Ratio (TTM)
# 0      11.14  114959000.0         62057000.0   10494000000.0             NaN
# 1      -0.07  102160000.0         83449000.0   93501000000.0           23.84
# 2       0.94   99137000.0         81341000.0           2.31T           23.76
# 3       3.75   78258000.0         40388000.0  280269000000.0           10.90
# 4       0.38   75892000.0         73864000.0  689959000000.0           74.39
# ..       ...          ...                ...             ...             ...
# 95      3.21   13048000.0          5550000.0   17635000000.0            7.75
# 96      4.98   12350000.0         14700000.0    4688000000.0             NaN
# 97      0.59   12146000.0         14380000.0    3480000000.0           56.50
# 98      1.63   12735000.0         12224000.0    4273000000.0             NaN
# 99     -0.98   12032000.0         11571000.0    6625000000.0            5.53
#
# [100 rows x 9 columns]

# %% [markdown]
# ## III.  EPS recall

# %% [markdown]
# ### 0) get_analysts_info()
# - get the analysts' predictions

# %%
a = si.get_analysts_info('MSFT')
print(a)
# Out:
# {'Earnings Estimate':   Earnings Estimate  Current Qtr. (Sep 2022)  Next Qtr. (Dec 2022)  \
# 0   No. of Analysts                    32.00                 32.00
# 1     Avg. Estimate                     2.31                  2.57
# 2      Low Estimate                     2.25                  2.39
# 3     High Estimate                     2.38                  2.83
# 4      Year Ago EPS                     2.27                  2.48
#
#    Current Year (2023)  Next Year (2024)
# 0                43.00             42.00
# 1                10.07             11.87
# 2                 9.54             10.88
# 3                10.64             13.12
# 4                 9.21             10.07  , 'Revenue Estimate':           Revenue Estimate Current Qtr. (Sep 2022) Next Qtr. (Dec 2022)  \
# 0          No. of Analysts                      31                   31
# 1            Avg. Estimate                  49.81B               56.44B
# 2             Low Estimate                  48.66B               53.84B
# 3            High Estimate                  51.97B               60.38B
# 4           Year Ago Sales                     NaN                  NaN
# 5  Sales Growth (year/est)                     NaN                  NaN
#
#   Current Year (2023) Next Year (2024)
# 0                  46               43
# 1             220.02B          250.31B
# 2                210B          236.22B
# 3             235.36B          262.56B
# 4             198.27B          220.02B
# 5              11.00%           13.80%  , 'Earnings History':   Earnings History 9/29/2021 12/30/2021 3/30/2022 6/29/2022
# 0         EPS Est.      2.07       2.31      2.18      2.29
# 1       EPS Actual      2.27       2.48      2.22      2.23
# 2       Difference       0.2       0.17      0.04     -0.06
# 3       Surprise %     9.70%      7.40%     1.80%    -2.60%, 'EPS Trend':           EPS Trend  Current Qtr. (Sep 2022)  Next Qtr. (Dec 2022)  \
# 0  Current Estimate                     2.31                  2.57
# 1        7 Days Ago                     2.32                  2.58
# 2       30 Days Ago                     2.32                  2.59
# 3       60 Days Ago                     2.32                  2.59
# 4       90 Days Ago                     2.48                  2.74
#
#    Current Year (2023)  Next Year (2024)
# 0                10.07             11.87
# 1                10.10             11.90
# 2                10.13             11.95
# 3                10.13             11.93
# 4                10.69             12.46  , 'EPS Revisions':        EPS Revisions  Current Qtr. (Sep 2022)  Next Qtr. (Dec 2022)  \
# 0     Up Last 7 Days                      NaN                   1.0
# 1    Up Last 30 Days                      1.0                   2.0
# 2   Down Last 7 Days                      NaN                   NaN
# 3  Down Last 30 Days                      4.0                   3.0
#
#    Current Year (2023)  Next Year (2024)
# 0                  NaN               NaN
# 1                  NaN               NaN
# 2                  NaN               NaN
# 3                  4.0               4.0  , 'Growth Estimates':            Growth Estimates    MSFT  Industry  Sector(s)  S&P 500
# 0              Current Qtr.   1.80%       NaN        NaN      NaN
# 1                 Next Qtr.   3.60%       NaN        NaN      NaN
# 2              Current Year   9.30%       NaN        NaN      NaN
# 3                 Next Year  17.90%       NaN        NaN      NaN
# 4  Next 5 Years (per annum)  14.93%       NaN        NaN      NaN
# 5  Past 5 Years (per annum)  24.54%       NaN        NaN      NaN}

# %% [markdown]
# ### 1) get_stats_valuation()
# - current PE ratio

# %%
si.get_stats_valuation('MSFT')
# Out:
#                            0      1
# 0      Market Cap (intraday)  1.77T
# 1           Enterprise Value  1.73T
# 2               Trailing P/E  24.61
# 3                Forward P/E  23.64
# 4  PEG Ratio (5 yr expected)   1.77
# 5          Price/Sales (ttm)   9.03
# 6           Price/Book (mrq)  10.64
# 7   Enterprise Value/Revenue   8.72
# 8    Enterprise Value/EBITDA  17.24

# %% [markdown]
# ### 2) get_next_earnings_date()
# - It will returns the upcoming earnings date

# %%
si.get_next_earnings_date('MSFT')
# Out:
# datetime.datetime(2022, 10, 25, 20, 0)

# %%
si.get_next_earnings_date('AAPL')
# Out:
# datetime.datetime(2022, 10, 26, 20, 0)

# %% [markdown]
# ### 3) get_earnings()
# - the command will recalls the earnings of campany

# %%
si.get_earnings('MSFT')
# Out:
# {'quarterly_results':      date  actual  estimate
#  0  3Q2021    2.27      2.07
#  1  4Q2021    2.48      2.31
#  2  1Q2022    2.22      2.18
#  3  2Q2022    2.23      2.29,
#  'yearly_revenue_earnings':    date       revenue     earnings
#  0  2019  125843000000  39240000000
#  1  2020  143015000000  44281000000
#  2  2021  168088000000  61271000000
#  3  2022  198270000000  72738000000,
#  'quarterly_revenue_earnings':      date      revenue     earnings
#  0  3Q2021  45317000000  20505000000
#  1  4Q2021  51728000000  18765000000
#  2  1Q2022  49360000000  16728000000
#  3  2Q2022  51865000000  16740000000}

# %% [markdown]
# ### 4) get_earnings_history()
# - recalls the company's earnings data
# - data frame fromat -> dictionary in list
# - X[n]['key'] n=0 the most future one

# %%
TSLA_per_his = si.get_earnings_history('TSLA')
MSFT_per_his = si.get_earnings_history('MSFT')
BRKB_per_his = si.get_earnings_history('BRKB')

# %%
BRKB_per_his
# Out:
# [{'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2022-08-08T06:26:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 3.33,
#   'epsactual': 4.21,
#   'epssurprisepct': 26.54,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2022-04-30T08:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 2.8,
#   'epsactual': 3.18,
#   'epssurprisepct': 13.57,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2022-02-28T06:32:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 2.88,
#   'epsactual': 3.27,
#   'epssurprisepct': 13.42,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2021-11-07T23:51:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 2.99,
#   'epsactual': 2.87,
#   'epssurprisepct': -3.92,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2021-08-07T08:09:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 2.6,
#   'epsactual': 2.93,
#   'epssurprisepct': 12.69,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2021-05-01T08:05:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 2.53,
#   'epsactual': 3.05,
#   'epssurprisepct': 20.41,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2021-02-27T08:26:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 2.27,
#   'epsactual': 2.15,
#   'epssurprisepct': -5.16,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2020-11-07T10:33:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 2.42,
#   'epsactual': 2.3,
#   'epssurprisepct': -4.84,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2020-08-08T09:05:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 2.24,
#   'epsactual': 2.28,
#   'epssurprisepct': 1.65,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2020-05-02T08:09:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 2.51,
#   'epsactual': 2.41,
#   'epssurprisepct': -3.98,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2020-02-22T08:17:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 2.34,
#   'epsactual': 1.81,
#   'epssurprisepct': -22.75,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2019-11-03T21:13:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 2.84,
#   'epsactual': 3.07,
#   'epssurprisepct': 7.98,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2019-11-02T06:46:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 4405.16,
#   'epsactual': 4699.29,
#   'epssurprisepct': 6.68,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2019-08-03T08:29:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 2.58,
#   'epsactual': 2.5,
#   'epssurprisepct': -3.03,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2019-05-04T08:20:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 2.29,
#   'epsactual': 2.26,
#   'epssurprisepct': -1.31,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2019-02-23T08:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 1.85,
#   'epsactual': 2.32,
#   'epssurprisepct': 25.61,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2018-11-03T08:06:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 2.49,
#   'epsactual': 2.79,
#   'epssurprisepct': 11.96,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2018-08-04T08:15:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 2.24,
#   'epsactual': 2.79,
#   'epssurprisepct': 24.78,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2018-05-05T08:07:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 2.07,
#   'epsactual': 2.14,
#   'epssurprisepct': 3.58,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2018-02-24T08:29:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 1.76,
#   'epsactual': 1.35,
#   'epssurprisepct': -23.38,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2017-11-03T16:15:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 1.58,
#   'epsactual': 1.4,
#   'epssurprisepct': -11.28,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2017-08-04T17:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 1.88,
#   'epsactual': 1.67,
#   'epssurprisepct': -10.93,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2017-05-05T17:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 1.76,
#   'epsactual': 1.44,
#   'epssurprisepct': -18.09,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2017-02-25T08:05:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 1.83,
#   'epsactual': 1.78,
#   'epssurprisepct': -2.73,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2016-11-04T16:48:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 1.99,
#   'epsactual': 1.97,
#   'epssurprisepct': -1.01,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2016-08-05T16:41:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 1.86,
#   'epsactual': 1.87,
#   'epssurprisepct': 0.7,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2016-05-06T19:05:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 1.81,
#   'epsactual': 1.52,
#   'epssurprisepct': -16.16,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2016-02-27T08:02:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 1.75,
#   'epsactual': 1.9,
#   'epssurprisepct': 8.57,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2015-11-06T16:15:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 1.85,
#   'epsactual': 1.85,
#   'epssurprisepct': -0.22,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2015-08-07T17:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 2.03,
#   'epsactual': 1.58,
#   'epssurprisepct': -22.07,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2015-05-01T17:05:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 1.62,
#   'epsactual': 1.72,
#   'epssurprisepct': 6.3,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2015-02-28T08:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 1.77,
#   'epsactual': 1.61,
#   'epssurprisepct': -8.9,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2014-11-07T17:05:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 1.68,
#   'epsactual': 1.92,
#   'epssurprisepct': 14.45,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2014-08-01T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 2481.98,
#   'epsactual': 2634,
#   'epssurprisepct': 6.12,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2014-05-02T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 2172.04,
#   'epsactual': 2149,
#   'epssurprisepct': -1.06,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2014-03-01T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 2203.91,
#   'epsactual': 2297,
#   'epssurprisepct': 4.22,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2013-11-01T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 2402.23,
#   'epsactual': 2228,
#   'epssurprisepct': -7.25,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2013-08-02T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 2169.53,
#   'epsactual': 2385,
#   'epssurprisepct': 9.93,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2013-05-03T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 1995.5,
#   'epsactual': 2302,
#   'epssurprisepct': 15.36,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2013-03-01T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 1755.12,
#   'epsactual': 1704,
#   'epssurprisepct': -2.91,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2012-11-02T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 2062.56,
#   'epsactual': 2057,
#   'epssurprisepct': -0.27,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2012-08-03T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 1776.64,
#   'epsactual': 2252,
#   'epssurprisepct': 26.76,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2012-05-04T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 1779.89,
#   'epsactual': 1615,
#   'epssurprisepct': -9.26,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2012-02-27T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 1850.67,
#   'epsactual': 1615,
#   'epssurprisepct': -12.73,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2011-11-04T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 1796,
#   'epsactual': 2309,
#   'epssurprisepct': 28.56,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2011-08-05T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 1663.67,
#   'epsactual': 1640,
#   'epssurprisepct': -1.42,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2011-05-06T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 1163,
#   'epsactual': 966,
#   'epssurprisepct': -16.94,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2011-02-26T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 1691.67,
#   'epsactual': 1826,
#   'epssurprisepct': 7.94,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2010-11-05T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 1676.67,
#   'epsactual': 1692,
#   'epssurprisepct': 0.91,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2010-08-06T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 1360.44,
#   'epsactual': 1866,
#   'epssurprisepct': 37.16,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2010-05-07T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 1101.83,
#   'epsactual': 1390,
#   'epssurprisepct': 26.15,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2010-02-27T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 1208.33,
#   'epsactual': 1308,
#   'epssurprisepct': 8.25,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2009-11-06T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 1308.25,
#   'epsactual': 1325,
#   'epssurprisepct': 1.28,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2009-08-07T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 1238.38,
#   'epsactual': 1147,
#   'epssurprisepct': -7.38,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2009-05-08T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 1443,
#   'epsactual': 1100,
#   'epssurprisepct': -23.77,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2009-02-25T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 1486.5,
#   'epsactual': 2175,
#   'epssurprisepct': 46.32,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2008-11-07T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 1429.19,
#   'epsactual': 1336,
#   'epssurprisepct': -6.52,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2008-08-08T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 1370.33,
#   'epsactual': 1465,
#   'epssurprisepct': 6.91,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2008-05-02T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 1476.98,
#   'epsactual': 1247,
#   'epssurprisepct': -15.57,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2008-02-29T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 1606,
#   'epsactual': 1518,
#   'epssurprisepct': -5.48,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2007-11-02T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 1509.33,
#   'epsactual': 1655,
#   'epssurprisepct': 9.65,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2007-08-03T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 1457.78,
#   'epsactual': 1625,
#   'epssurprisepct': 11.47,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2007-05-04T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 1447.22,
#   'epsactual': 1434,
#   'epssurprisepct': -0.91,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2007-03-01T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 1452.36,
#   'epsactual': 1859,
#   'epssurprisepct': 28,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2006-11-03T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 1243.69,
#   'epsactual': 1685,
#   'epssurprisepct': 35.48,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2006-08-04T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 1084,
#   'epsactual': 1332,
#   'epssurprisepct': 22.88,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2006-05-05T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 1102,
#   'epsactual': 1160,
#   'epssurprisepct': 5.26,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2006-03-04T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 932.5,
#   'epsactual': 1196,
#   'epssurprisepct': 28.26,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2005-11-04T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 1006,
#   'epsactual': 69,
#   'epssurprisepct': -93.14,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2005-08-05T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 941.5,
#   'epsactual': 1045,
#   'epssurprisepct': 10.99,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2005-05-09T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 910,
#   'epsactual': 886,
#   'epssurprisepct': -2.64,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2005-03-15T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 914,
#   'epsactual': 1197,
#   'epssurprisepct': 30.96,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2004-11-05T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 748.5,
#   'epsactual': 402,
#   'epssurprisepct': -46.29,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2004-08-06T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 844.5,
#   'epsactual': 946,
#   'epssurprisepct': 12.02,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2004-05-07T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 924,
#   'epsactual': 738,
#   'epssurprisepct': -20.13,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2004-03-01T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 867,
#   'epsactual': 1004,
#   'epssurprisepct': 15.8,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2003-11-07T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 787,
#   'epsactual': 881,
#   'epssurprisepct': 11.94,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2003-08-08T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 779.5,
#   'epsactual': 862,
#   'epssurprisepct': 10.58,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2003-05-09T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 705,
#   'epsactual': 784,
#   'epssurprisepct': 11.21,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2003-03-08T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 717.5,
#   'epsactual': 610,
#   'epssurprisepct': -14.98,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2002-11-08T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 603,
#   'epsactual': 726,
#   'epssurprisepct': 20.4,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2002-08-09T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 550,
#   'epsactual': 673,
#   'epssurprisepct': 22.36,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2002-05-10T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 446.5,
#   'epsactual': 534,
#   'epssurprisepct': 19.6,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2002-03-12T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': -4,
#   'epsactual': 22,
#   'epssurprisepct': 650,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2001-11-09T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 310,
#   'epsactual': -586,
#   'epssurprisepct': -289.03,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2001-08-10T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 290,
#   'epsactual': 231,
#   'epssurprisepct': -20.34,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2000-11-10T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 162,
#   'epsactual': 197,
#   'epssurprisepct': 21.6,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'BRKB',
#   'companyshortname': 'Berkshire Hathaway Inc.',
#   'startdatetime': '2000-08-11T00:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 180,
#   'epsactual': 161,
#   'epssurprisepct': -10.56,
#   'timeZoneShortName': 'UTC',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'}]

# %%
print('eps(actual)   :' , MSFT_per_his[99]['epsactual'])
print('eps(estimate) :' , MSFT_per_his[99]['epsestimate'])
print('date :', MSFT_per_his[99]['startdatetime'],MSFT_per_his[99]['timeZoneShortName'])
# Out:
# eps(actual)   : 0.18
# eps(estimate) : 0.15
# date : 1999-01-19T05:00:00.000Z EST

# %%
print(len(MSFT_per_his))
print(len(TSLA_per_his))
# Out:
# 100
# 53

# %% [markdown]
# -Get t

# %%
for i in range(len(BRKB_per_his)):
  print('eps(actual)   :' , MSFT_per_his[i]['epsactual'])
  print('eps(estimate) :' , MSFT_per_his[i]['epsestimate'])
  print('date :', MSFT_per_his[i]['startdatetime'],MSFT_per_his[i]['timeZoneShortName'])
  print('\n')
# Out:
# eps(actual)   : None
# eps(estimate) : None
# date : 2023-07-24T10:59:00.000Z EDT
#
#
# eps(actual)   : None
# eps(estimate) : None
# date : 2023-04-24T10:59:00.000Z EDT
#
#
# eps(actual)   : None
# eps(estimate) : None
# date : 2023-01-23T10:59:00.000Z EST
#
#
# eps(actual)   : None
# eps(estimate) : 2.31
# date : 2022-10-25T21:30:00.000Z EDT
#
#
# eps(actual)   : None
# eps(estimate) : 2.31
# date : 2022-10-25T20:00:00.000Z EDT
#
#
# eps(actual)   : 2.23
# eps(estimate) : 2.29
# date : 2022-07-26T16:09:00.000Z EDT
#
#
# eps(actual)   : 2.22
# eps(estimate) : 2.19
# date : 2022-04-26T16:04:00.000Z EDT
#
#
# eps(actual)   : 2.48
# eps(estimate) : 2.31
# date : 2022-01-25T16:04:00.000Z EST
#
#
# eps(actual)   : 2.27
# eps(estimate) : 2.08
# date : 2021-10-26T16:05:00.000Z EDT
#
#
# eps(actual)   : 2.17
# eps(estimate) : 1.92
# date : 2021-07-27T16:02:00.000Z EDT
#
#
# eps(actual)   : 2.03
# eps(estimate) : 1.78
# date : 2021-04-27T16:03:00.000Z EDT
#
#
# eps(actual)   : 2.03
# eps(estimate) : 1.64
# date : 2021-01-26T16:04:00.000Z EST
#
#
# eps(actual)   : 1.82
# eps(estimate) : 1.54
# date : 2020-10-27T16:13:00.000Z EDT
#
#
# eps(actual)   : 1.46
# eps(estimate) : 1.34
# date : 2020-07-22T16:03:00.000Z EDT
#
#
# eps(actual)   : 1.4
# eps(estimate) : 1.26
# date : 2020-04-29T16:03:00.000Z EDT
#
#
# eps(actual)   : 1.51
# eps(estimate) : 1.32
# date : 2020-01-29T16:05:00.000Z EST
#
#
# eps(actual)   : 1.38
# eps(estimate) : 1.25
# date : 2019-10-23T16:08:00.000Z EDT
#
#
# eps(actual)   : 1.37
# eps(estimate) : 1.21
# date : 2019-07-18T16:07:00.000Z EDT
#
#
# eps(actual)   : 1.14
# eps(estimate) : 1
# date : 2019-04-24T16:07:00.000Z EDT
#
#
# eps(actual)   : 1.1
# eps(estimate) : 1.09
# date : 2019-01-30T16:06:00.000Z EST
#
#
# eps(actual)   : 1.14
# eps(estimate) : 0.96
# date : 2018-10-24T16:07:00.000Z EDT
#
#
# eps(actual)   : 1.13
# eps(estimate) : 1.08
# date : 2018-07-19T16:05:00.000Z EDT
#
#
# eps(actual)   : 0.95
# eps(estimate) : 0.85
# date : 2018-04-26T16:04:00.000Z EDT
#
#
# eps(actual)   : 0.96
# eps(estimate) : 0.87
# date : 2018-01-31T16:05:00.000Z EST
#
#
# eps(actual)   : 0.84
# eps(estimate) : 0.72
# date : 2017-10-26T16:02:00.000Z EDT
#
#
# eps(actual)   : 0.98
# eps(estimate) : 0.71
# date : 2017-07-20T16:06:00.000Z EDT
#
#
# eps(actual)   : 0.73
# eps(estimate) : 0.7
# date : 2017-04-27T16:05:00.000Z EDT
#
#
# eps(actual)   : 0.83
# eps(estimate) : 0.79
# date : 2017-01-26T16:09:00.000Z EST
#
#
# eps(actual)   : 0.76
# eps(estimate) : 0.68
# date : 2016-10-20T16:05:00.000Z EDT
#
#
# eps(actual)   : 0.69
# eps(estimate) : 0.58
# date : 2016-07-19T16:05:00.000Z EDT
#
#
# eps(actual)   : 0.62
# eps(estimate) : 0.64
# date : 2016-04-21T16:05:00.000Z EDT
#
#
# eps(actual)   : 0.78
# eps(estimate) : 0.71
# date : 2016-01-28T16:06:00.000Z EST
#
#
# eps(actual)   : 0.67
# eps(estimate) : 0.59
# date : 2015-10-22T16:05:00.000Z EDT
#
#
# eps(actual)   : 0.6
# eps(estimate) : 0.56
# date : 2015-07-21T16:05:00.000Z EDT
#
#
# eps(actual)   : 0.61
# eps(estimate) : 0.51
# date : 2015-04-23T16:02:00.000Z EDT
#
#
# eps(actual)   : 0.71
# eps(estimate) : 0.71
# date : 2015-01-26T16:10:00.000Z EST
#
#
# eps(actual)   : 0.54
# eps(estimate) : 0.49
# date : 2014-10-23T16:02:00.000Z EDT
#
#
# eps(actual)   : 0.55
# eps(estimate) : 0.6
# date : 2014-07-22T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.68
# eps(estimate) : 0.63
# date : 2014-04-24T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.78
# eps(estimate) : 0.68
# date : 2014-01-23T05:00:00.000Z EST
#
#
# eps(actual)   : 0.62
# eps(estimate) : 0.54
# date : 2013-10-24T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.66
# eps(estimate) : 0.75
# date : 2013-07-18T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.72
# eps(estimate) : 0.68
# date : 2013-04-18T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.76
# eps(estimate) : 0.75
# date : 2013-01-24T05:00:00.000Z EST
#
#
# eps(actual)   : 0.53
# eps(estimate) : 0.56
# date : 2012-10-18T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.67
# eps(estimate) : 0.62
# date : 2012-07-19T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.6
# eps(estimate) : 0.57
# date : 2012-04-19T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.78
# eps(estimate) : 0.76
# date : 2012-01-19T05:00:00.000Z EST
#
#
# eps(actual)   : 0.68
# eps(estimate) : 0.68
# date : 2011-10-20T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.69
# eps(estimate) : 0.58
# date : 2011-07-21T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.61
# eps(estimate) : 0.56
# date : 2011-04-28T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.77
# eps(estimate) : 0.68
# date : 2011-01-27T05:00:00.000Z EST
#
#
# eps(actual)   : 0.62
# eps(estimate) : 0.55
# date : 2010-10-28T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.51
# eps(estimate) : 0.46
# date : 2010-07-22T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.45
# eps(estimate) : 0.42
# date : 2010-04-22T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.74
# eps(estimate) : 0.59
# date : 2010-01-28T05:00:00.000Z EST
#
#
# eps(actual)   : 0.4
# eps(estimate) : 0.32
# date : 2009-10-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.36
# eps(estimate) : 0.36
# date : 2009-07-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.39
# eps(estimate) : 0.39
# date : 2009-04-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.47
# eps(estimate) : 0.49
# date : 2009-01-22T05:00:00.000Z EST
#
#
# eps(actual)   : 0.48
# eps(estimate) : 0.47
# date : 2008-10-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.46
# eps(estimate) : 0.47
# date : 2008-07-17T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.47
# eps(estimate) : 0.44
# date : 2008-04-24T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.5
# eps(estimate) : 0.46
# date : 2008-01-24T05:00:00.000Z EST
#
#
# eps(actual)   : 0.45
# eps(estimate) : 0.39
# date : 2007-10-25T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.39
# eps(estimate) : 0.39
# date : 2007-07-19T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.49
# eps(estimate) : 0.46
# date : 2007-04-26T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.26
# eps(estimate) : 0.23
# date : 2007-01-25T05:00:00.000Z EST
#
#
# eps(actual)   : 0.35
# eps(estimate) : 0.31
# date : 2006-10-26T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.31
# eps(estimate) : 0.3
# date : 2006-07-20T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.32
# eps(estimate) : 0.33
# date : 2006-04-27T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.33
# eps(estimate) : 0.33
# date : 2006-01-26T05:00:00.000Z EST
#
#
# eps(actual)   : 0.31
# eps(estimate) : 0.3
# date : 2005-10-27T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.32
# eps(estimate) : 0.31
# date : 2005-07-21T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.32
# eps(estimate) : 0.32
# date : 2005-04-28T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.35
# eps(estimate) : 0.33
# date : 2005-01-27T05:00:00.000Z EST
#
#
# eps(actual)   : 0.31
# eps(estimate) : 0.3
# date : 2004-10-21T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.28
# eps(estimate) : 0.29
# date : 2004-07-22T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.34
# eps(estimate) : 0.29
# date : 2004-04-22T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.34
# eps(estimate) : 0.3
# date : 2004-01-22T05:00:00.000Z EST
#
#
# eps(actual)   : 0.3
# eps(estimate) : 0.29
# date : 2003-10-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.23
# eps(estimate) : 0.24
# date : 2003-07-17T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.27
# eps(estimate) : 0.24
# date : 2003-04-15T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.27
# eps(estimate) : 0.23
# date : 2003-01-16T05:00:00.000Z EST
#
#
# eps(actual)   : 0.28
# eps(estimate) : 0.21
# date : 2002-10-17T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.21
# eps(estimate) : 0.21
# date : 2002-07-18T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.25
# eps(estimate) : 0.25
# date : 2002-04-18T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.25
# eps(estimate) : 0.21
# date : 2002-01-17T05:00:00.000Z EST

# %%
for i in range(len(TSLA_per_his)):
  print('eps(actual)   :' , TSLA_per_his[i]['epsactual'])
  print('eps(estimate) :' , TSLA_per_his[i]['epsestimate'])
  print('date :', TSLA_per_his[i]['startdatetime'],TSLA_per_his[i]['timeZoneShortName'])
  print('\n')
# Out:
# eps(actual)   : None
# eps(estimate) : None
# date : 2023-07-18T20:00:00.000Z EDT
#
#
# eps(actual)   : None
# eps(estimate) : None
# date : 2023-04-18T10:59:00.000Z EDT
#
#
# eps(actual)   : None
# eps(estimate) : None
# date : 2023-01-24T10:59:00.000Z EST
#
#
# eps(actual)   : None
# eps(estimate) : 1
# date : 2022-10-19T21:30:00.000Z EDT
#
#
# eps(actual)   : None
# eps(estimate) : 1
# date : 2022-10-19T20:00:00.000Z EDT
#
#
# eps(actual)   : 0.76
# eps(estimate) : 0.61
# date : 2022-07-20T16:07:00.000Z EDT
#
#
# eps(actual)   : 1.07
# eps(estimate) : 0.75
# date : 2022-04-20T16:09:00.000Z EDT
#
#
# eps(actual)   : 0.85
# eps(estimate) : 0.79
# date : 2022-01-26T16:07:00.000Z EST
#
#
# eps(actual)   : 0.62
# eps(estimate) : 0.53
# date : 2021-10-20T16:08:00.000Z EDT
#
#
# eps(actual)   : 0.48
# eps(estimate) : 0.33
# date : 2021-07-26T16:07:00.000Z EDT
#
#
# eps(actual)   : 0.31
# eps(estimate) : 0.26
# date : 2021-04-26T16:00:00.000Z EDT
#
#
# eps(actual)   : 0.27
# eps(estimate) : 0.34
# date : 2021-01-27T16:08:00.000Z EST
#
#
# eps(actual)   : 0.25
# eps(estimate) : 0.19
# date : 2020-10-21T16:07:00.000Z EDT
#
#
# eps(actual)   : 0.44
# eps(estimate) : -0.04
# date : 2020-07-22T16:23:00.000Z EDT
#
#
# eps(actual)   : 0.23
# eps(estimate) : -0.06
# date : 2020-04-29T16:12:00.000Z EDT
#
#
# eps(actual)   : 0.41
# eps(estimate) : 0.35
# date : 2020-01-29T16:17:00.000Z EST
#
#
# eps(actual)   : 0.37
# eps(estimate) : -0.08
# date : 2019-10-23T16:54:00.000Z EDT
#
#
# eps(actual)   : -0.22
# eps(estimate) : -0.07
# date : 2019-07-24T16:48:00.000Z EDT
#
#
# eps(actual)   : -0.58
# eps(estimate) : -0.14
# date : 2019-04-24T17:17:00.000Z EDT
#
#
# eps(actual)   : 0.39
# eps(estimate) : 0.44
# date : 2019-01-30T16:13:00.000Z EST
#
#
# eps(actual)   : 0.58
# eps(estimate) : -0.04
# date : 2018-10-24T16:23:00.000Z EDT
#
#
# eps(actual)   : -3.06
# eps(estimate) : -2.92
# date : 2018-08-01T16:06:00.000Z EDT
#
#
# eps(actual)   : -3.35
# eps(estimate) : -3.58
# date : 2018-05-02T16:13:00.000Z EDT
#
#
# eps(actual)   : -3.04
# eps(estimate) : -3.09
# date : 2018-02-07T16:13:00.000Z EST
#
#
# eps(actual)   : -2.92
# eps(estimate) : -2.2
# date : 2017-11-01T16:16:00.000Z EDT
#
#
# eps(actual)   : -1.33
# eps(estimate) : -1.82
# date : 2017-08-02T16:13:00.000Z EDT
#
#
# eps(actual)   : -1.33
# eps(estimate) : -0.81
# date : 2017-05-03T16:05:00.000Z EDT
#
#
# eps(actual)   : -0.69
# eps(estimate) : -0.43
# date : 2017-02-22T14:41:00.000Z EST
#
#
# eps(actual)   : 0.71
# eps(estimate) : -0.54
# date : 2016-10-26T16:05:00.000Z EDT
#
#
# eps(actual)   : -1.61
# eps(estimate) : -0.51
# date : 2016-08-03T16:01:00.000Z EDT
#
#
# eps(actual)   : -1.45
# eps(estimate) : -0.58
# date : 2016-05-04T16:03:00.000Z EDT
#
#
# eps(actual)   : -0.87
# eps(estimate) : 0.1
# date : 2016-02-10T16:15:00.000Z EST
#
#
# eps(actual)   : -0.58
# eps(estimate) : -0.49
# date : 2015-11-03T16:04:00.000Z EST
#
#
# eps(actual)   : -0.48
# eps(estimate) : -0.6
# date : 2015-08-05T16:44:00.000Z EDT
#
#
# eps(actual)   : -0.36
# eps(estimate) : -0.5
# date : 2015-05-06T16:26:00.000Z EDT
#
#
# eps(actual)   : -0.13
# eps(estimate) : 0.31
# date : 2015-02-11T16:05:00.000Z EST
#
#
# eps(actual)   : 0.02
# eps(estimate) : -0.01
# date : 2014-11-05T17:00:00.000Z EST
#
#
# eps(actual)   : 0.11
# eps(estimate) : 0.04
# date : 2014-07-31T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.12
# eps(estimate) : 0.1
# date : 2014-05-07T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.33
# eps(estimate) : 0.21
# date : 2014-02-19T05:00:00.000Z EST
#
#
# eps(actual)   : 0.12
# eps(estimate) : 0.11
# date : 2013-11-05T05:00:00.000Z EST
#
#
# eps(actual)   : 0.2
# eps(estimate) : -0.17
# date : 2013-08-07T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.12
# eps(estimate) : 0.04
# date : 2013-05-08T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.65
# eps(estimate) : -0.53
# date : 2013-02-20T05:00:00.000Z EST
#
#
# eps(actual)   : -0.92
# eps(estimate) : -0.9
# date : 2012-11-05T05:00:00.000Z EST
#
#
# eps(actual)   : -0.89
# eps(estimate) : -0.92
# date : 2012-07-25T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.76
# eps(estimate) : -0.69
# date : 2012-05-09T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.69
# eps(estimate) : -0.63
# date : 2012-02-15T05:00:00.000Z EST
#
#
# eps(actual)   : -0.55
# eps(estimate) : -0.59
# date : 2011-11-02T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.53
# eps(estimate) : -0.51
# date : 2011-08-03T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.44
# eps(estimate) : -0.51
# date : 2011-05-04T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.47
# eps(estimate) : -0.5
# date : 2011-02-15T05:00:00.000Z EST
#
#
# eps(actual)   : -0.37
# eps(estimate) : -0.43
# date : 2010-11-09T05:00:00.000Z EST

# %%
si.get_earnings_history('MSFT')
# Out:
# [{'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corp',
#   'startdatetime': '2023-07-24T10:59:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': None,
#   'epsactual': None,
#   'epssurprisepct': None,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corp',
#   'startdatetime': '2023-04-24T10:59:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': None,
#   'epsactual': None,
#   'epssurprisepct': None,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corp',
#   'startdatetime': '2023-01-23T10:59:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': None,
#   'epsactual': None,
#   'epssurprisepct': None,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corp',
#   'startdatetime': '2022-10-25T21:30:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 2.31,
#   'epsactual': None,
#   'epssurprisepct': None,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corp',
#   'startdatetime': '2022-10-25T20:00:00.000Z',
#   'startdatetimetype': 'AMC',
#   'epsestimate': 2.31,
#   'epsactual': None,
#   'epssurprisepct': None,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2022-07-26T16:09:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 2.29,
#   'epsactual': 2.23,
#   'epssurprisepct': -2.75,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2022-04-26T16:04:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 2.19,
#   'epsactual': 2.22,
#   'epssurprisepct': 1.6,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2022-01-25T16:04:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 2.31,
#   'epsactual': 2.48,
#   'epssurprisepct': 7.27,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2021-10-26T16:05:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 2.08,
#   'epsactual': 2.27,
#   'epssurprisepct': 9.4,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2021-07-27T16:02:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 1.92,
#   'epsactual': 2.17,
#   'epssurprisepct': 13.26,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2021-04-27T16:03:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 1.78,
#   'epsactual': 2.03,
#   'epssurprisepct': 14.11,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2021-01-26T16:04:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 1.64,
#   'epsactual': 2.03,
#   'epssurprisepct': 23.63,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2020-10-27T16:13:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 1.54,
#   'epsactual': 1.82,
#   'epssurprisepct': 17.88,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2020-07-22T16:03:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 1.34,
#   'epsactual': 1.46,
#   'epssurprisepct': 8.71,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2020-04-29T16:03:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 1.26,
#   'epsactual': 1.4,
#   'epssurprisepct': 10.67,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2020-01-29T16:05:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 1.32,
#   'epsactual': 1.51,
#   'epssurprisepct': 14.48,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2019-10-23T16:08:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 1.25,
#   'epsactual': 1.38,
#   'epssurprisepct': 10.84,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2019-07-18T16:07:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 1.21,
#   'epsactual': 1.37,
#   'epssurprisepct': 12.94,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2019-04-24T16:07:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 1,
#   'epsactual': 1.14,
#   'epssurprisepct': 14.11,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2019-01-30T16:06:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 1.09,
#   'epsactual': 1.1,
#   'epssurprisepct': 0.73,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2018-10-24T16:07:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.96,
#   'epsactual': 1.14,
#   'epssurprisepct': 18.38,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2018-07-19T16:05:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 1.08,
#   'epsactual': 1.13,
#   'epssurprisepct': 5.02,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2018-04-26T16:04:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.85,
#   'epsactual': 0.95,
#   'epssurprisepct': 11.9,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2018-01-31T16:05:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.87,
#   'epsactual': 0.96,
#   'epssurprisepct': 10.98,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2017-10-26T16:02:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.72,
#   'epsactual': 0.84,
#   'epssurprisepct': 16.5,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2017-07-20T16:06:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.71,
#   'epsactual': 0.98,
#   'epssurprisepct': 39.01,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2017-04-27T16:05:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.7,
#   'epsactual': 0.73,
#   'epssurprisepct': 4.73,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2017-01-26T16:09:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.79,
#   'epsactual': 0.83,
#   'epssurprisepct': 4.93,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2016-10-20T16:05:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.68,
#   'epsactual': 0.76,
#   'epssurprisepct': 11.27,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2016-07-19T16:05:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.58,
#   'epsactual': 0.69,
#   'epssurprisepct': 18.76,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2016-04-21T16:05:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.64,
#   'epsactual': 0.62,
#   'epssurprisepct': -2.67,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2016-01-28T16:06:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.71,
#   'epsactual': 0.78,
#   'epssurprisepct': 9.4,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2015-10-22T16:05:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.59,
#   'epsactual': 0.67,
#   'epssurprisepct': 14.33,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2015-07-21T16:05:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.56,
#   'epsactual': 0.6,
#   'epssurprisepct': 6.57,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2015-04-23T16:02:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.51,
#   'epsactual': 0.61,
#   'epssurprisepct': 20.55,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2015-01-26T16:10:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.71,
#   'epsactual': 0.71,
#   'epssurprisepct': -0.42,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2014-10-23T16:02:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.49,
#   'epsactual': 0.54,
#   'epssurprisepct': 11.11,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2014-07-22T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.6,
#   'epsactual': 0.55,
#   'epssurprisepct': -8.65,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2014-04-24T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.63,
#   'epsactual': 0.68,
#   'epssurprisepct': 8.02,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2014-01-23T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.68,
#   'epsactual': 0.78,
#   'epssurprisepct': 14.83,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2013-10-24T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.54,
#   'epsactual': 0.62,
#   'epssurprisepct': 15.1,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2013-07-18T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.75,
#   'epsactual': 0.66,
#   'epssurprisepct': -11.96,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2013-04-18T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.68,
#   'epsactual': 0.72,
#   'epssurprisepct': 5.97,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2013-01-24T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.75,
#   'epsactual': 0.76,
#   'epssurprisepct': 1.93,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2012-10-18T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.56,
#   'epsactual': 0.53,
#   'epssurprisepct': -5.47,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2012-07-19T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.62,
#   'epsactual': 0.67,
#   'epssurprisepct': 8.48,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2012-04-19T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.57,
#   'epsactual': 0.6,
#   'epssurprisepct': 4.38,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2012-01-19T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.76,
#   'epsactual': 0.78,
#   'epssurprisepct': 2.93,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2011-10-20T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.68,
#   'epsactual': 0.68,
#   'epssurprisepct': 0.38,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2011-07-21T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.58,
#   'epsactual': 0.69,
#   'epssurprisepct': 19.88,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2011-04-28T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.56,
#   'epsactual': 0.61,
#   'epssurprisepct': 9.74,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2011-01-27T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.68,
#   'epsactual': 0.77,
#   'epssurprisepct': 12.57,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2010-10-28T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.55,
#   'epsactual': 0.62,
#   'epssurprisepct': 12.98,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2010-07-22T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.46,
#   'epsactual': 0.51,
#   'epssurprisepct': 9.82,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2010-04-22T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.42,
#   'epsactual': 0.45,
#   'epssurprisepct': 6.95,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2010-01-28T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.59,
#   'epsactual': 0.74,
#   'epssurprisepct': 24.79,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2009-10-23T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.32,
#   'epsactual': 0.4,
#   'epssurprisepct': 25.76,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2009-07-23T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.36,
#   'epsactual': 0.36,
#   'epssurprisepct': 0.22,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2009-04-23T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.39,
#   'epsactual': 0.39,
#   'epssurprisepct': 0.26,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2009-01-22T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.49,
#   'epsactual': 0.47,
#   'epssurprisepct': -4.84,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2008-10-23T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.47,
#   'epsactual': 0.48,
#   'epssurprisepct': 1.84,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2008-07-17T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.47,
#   'epsactual': 0.46,
#   'epssurprisepct': -2.13,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2008-04-24T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.44,
#   'epsactual': 0.47,
#   'epssurprisepct': 6.74,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2008-01-24T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.46,
#   'epsactual': 0.5,
#   'epssurprisepct': 9.33,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2007-10-25T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.39,
#   'epsactual': 0.45,
#   'epssurprisepct': 15.38,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2007-07-19T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.39,
#   'epsactual': 0.39,
#   'epssurprisepct': 0.3,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2007-04-26T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.46,
#   'epsactual': 0.49,
#   'epssurprisepct': 6.86,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2007-01-25T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.23,
#   'epsactual': 0.26,
#   'epssurprisepct': 11.48,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2006-10-26T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.31,
#   'epsactual': 0.35,
#   'epssurprisepct': 13.02,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2006-07-20T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.3,
#   'epsactual': 0.31,
#   'epssurprisepct': 2.63,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2006-04-27T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.33,
#   'epsactual': 0.32,
#   'epssurprisepct': -2.93,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2006-01-26T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.33,
#   'epsactual': 0.33,
#   'epssurprisepct': -0.08,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2005-10-27T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.3,
#   'epsactual': 0.31,
#   'epssurprisepct': 4.14,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2005-07-21T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.31,
#   'epsactual': 0.32,
#   'epssurprisepct': 2.4,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2005-04-28T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.32,
#   'epsactual': 0.32,
#   'epssurprisepct': 0.93,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2005-01-27T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.33,
#   'epsactual': 0.35,
#   'epssurprisepct': 6.81,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2004-10-21T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.3,
#   'epsactual': 0.31,
#   'epssurprisepct': 2.89,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2004-07-22T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.29,
#   'epsactual': 0.28,
#   'epssurprisepct': -1.87,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2004-04-22T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.29,
#   'epsactual': 0.34,
#   'epssurprisepct': 19.1,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2004-01-22T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.3,
#   'epsactual': 0.34,
#   'epssurprisepct': 13.46,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2003-10-23T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.29,
#   'epsactual': 0.3,
#   'epssurprisepct': 3.56,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2003-07-17T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.24,
#   'epsactual': 0.23,
#   'epssurprisepct': -2.84,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2003-04-15T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.24,
#   'epsactual': 0.27,
#   'epssurprisepct': 13.16,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2003-01-16T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.23,
#   'epsactual': 0.27,
#   'epssurprisepct': 14.22,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2002-10-17T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.21,
#   'epsactual': 0.28,
#   'epssurprisepct': 29.06,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2002-07-18T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.21,
#   'epsactual': 0.21,
#   'epssurprisepct': 0.8,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2002-04-18T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.25,
#   'epsactual': 0.25,
#   'epssurprisepct': -3.56,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2002-01-17T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.21,
#   'epsactual': 0.25,
#   'epssurprisepct': 15.25,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2001-10-18T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.2,
#   'epsactual': 0.22,
#   'epssurprisepct': 9.5,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2001-07-19T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.21,
#   'epsactual': 0.22,
#   'epssurprisepct': 0.75,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2001-04-19T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.21,
#   'epsactual': 0.22,
#   'epssurprisepct': 5.33,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2001-01-18T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.23,
#   'epsactual': 0.24,
#   'epssurprisepct': 1.44,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2000-10-18T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.21,
#   'epsactual': 0.23,
#   'epssurprisepct': 11.48,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2000-07-18T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.21,
#   'epsactual': 0.22,
#   'epssurprisepct': 5.81,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2000-04-20T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.2,
#   'epsactual': 0.22,
#   'epssurprisepct': 5.27,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '2000-01-18T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.21,
#   'epsactual': 0.24,
#   'epssurprisepct': 11.27,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '1999-10-19T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.17,
#   'epsactual': 0.19,
#   'epssurprisepct': 10.38,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '1999-07-19T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.18,
#   'epsactual': 0.2,
#   'epssurprisepct': 12.03,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '1999-04-20T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.16,
#   'epsactual': 0.19,
#   'epssurprisepct': 21.78,
#   'timeZoneShortName': 'EDT',
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'MSFT',
#   'companyshortname': 'Microsoft Corporation',
#   'startdatetime': '1999-01-19T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 0.15,
#   'epsactual': 0.18,
#   'epssurprisepct': 23.47,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY'}]

# %% [markdown]
# ##IV.Checking multiple companies by using 'for' statment

# %% [markdown]
# ### 1) To get the current PE ratio by 'for' statement

# %%
error_N = 0

for i in soxx_etf_holdings:
  try:
    sleep(random.uniform(1,2))
    print( i ,si.get_stats_valuation(i))
  except IndexError as e :
    print('cannot recall for now :',f'{i}')
    error_N +=1
    print('N of Eerror = ', error_N)
# Out:
# AVGO                            0        1
# 0      Market Cap (intraday)  172.98B
# 1           Enterprise Value  202.52B
# 2               Trailing P/E    18.44
# 3                Forward P/E    10.48
# 4  PEG Ratio (5 yr expected)     0.67
# 5          Price/Sales (ttm)     5.84
# 6           Price/Book (mrq)     8.29
# 7   Enterprise Value/Revenue     6.39
# 8    Enterprise Value/EBITDA    11.24
# AMD                            0       1
# 0      Market Cap (intraday)  93.57B
# 1           Enterprise Value  90.77B
# 2               Trailing P/E   24.66
# 3                Forward P/E   11.95
# 4  PEG Ratio (5 yr expected)    0.60
# 5          Price/Sales (ttm)    3.69
# 6           Price/Book (mrq)    1.70
# 7   Enterprise Value/Revenue    4.21
# 8    Enterprise Value/EBITDA   15.85
# NVDA                            0        1
# 0      Market Cap (intraday)  279.55B
# 1           Enterprise Value  274.21B
# 2               Trailing P/E    36.69
# 3                Forward P/E    24.75
# 4  PEG Ratio (5 yr expected)     2.15
# 5          Price/Sales (ttm)     9.56
# 6           Price/Book (mrq)    11.72
# 7   Enterprise Value/Revenue     9.22
# 8    Enterprise Value/EBITDA    29.31
# INTC                            0        1
# 0      Market Cap (intraday)  108.48B
# 1           Enterprise Value  116.87B
# 2               Trailing P/E     5.67
# 3                Forward P/E     9.21
# 4  PEG Ratio (5 yr expected)     3.17
# 5          Price/Sales (ttm)     1.48
# 6           Price/Book (mrq)     1.07
# 7   Enterprise Value/Revenue     1.59
# 8    Enterprise Value/EBITDA     3.45
# QCOM                            0        1
# 0      Market Cap (intraday)  125.32B
# 1           Enterprise Value  134.01B
# 2               Trailing P/E     9.89
# 3                Forward P/E     8.55
# 4  PEG Ratio (5 yr expected)     0.51
# 5          Price/Sales (ttm)     3.02
# 6           Price/Book (mrq)     7.81
# 7   Enterprise Value/Revenue     3.18
# 8    Enterprise Value/EBITDA     7.89
# TXN                            0        1
# 0      Market Cap (intraday)  137.96B
# 1           Enterprise Value  136.82B
# 2               Trailing P/E    16.52
# 3                Forward P/E    16.89
# 4  PEG Ratio (5 yr expected)     2.05
# 5          Price/Sales (ttm)     7.20
# 6           Price/Book (mrq)     9.79
# 7   Enterprise Value/Revenue     6.98
# 8    Enterprise Value/EBITDA    12.37
# ADI                            0       1
# 0      Market Cap (intraday)  71.56B
# 1           Enterprise Value  76.28B
# 2               Trailing P/E   41.16
# 3                Forward P/E   14.31
# 4  PEG Ratio (5 yr expected)    1.28
# 5          Price/Sales (ttm)    6.47
# 6           Price/Book (mrq)    1.95
# 7   Enterprise Value/Revenue    6.87
# 8    Enterprise Value/EBITDA   17.72
# KLAC                            0       1
# 0      Market Cap (intraday)  37.33B
# 1           Enterprise Value  41.39B
# 2               Trailing P/E   12.01
# 3                Forward P/E   11.19
# 4  PEG Ratio (5 yr expected)    1.22
# 5          Price/Sales (ttm)    4.33
# 6           Price/Book (mrq)   26.64
# 7   Enterprise Value/Revenue    4.49
# 8    Enterprise Value/EBITDA   10.31
# MCHP                            0       1
# 0      Market Cap (intraday)  32.56B
# 1           Enterprise Value  39.78B
# 2               Trailing P/E   21.67
# 3                Forward P/E   10.34
# 4  PEG Ratio (5 yr expected)    1.04
# 5          Price/Sales (ttm)    4.62
# 6           Price/Book (mrq)    5.45
# 7   Enterprise Value/Revenue    5.51
# 8    Enterprise Value/EBITDA   12.48
# NXPI                            0       1
# 0      Market Cap (intraday)  36.26B
# 1           Enterprise Value  43.88B
# 2               Trailing P/E   15.12
# 3                Forward P/E    9.63
# 4  PEG Ratio (5 yr expected)    0.88
# 5          Price/Sales (ttm)    2.99
# 6           Price/Book (mrq)    5.21
# 7   Enterprise Value/Revenue    3.55
# 8    Enterprise Value/EBITDA    9.69
# LRCX                            0       1
# 0      Market Cap (intraday)  43.16B
# 1           Enterprise Value  44.50B
# 2               Trailing P/E    9.63
# 3                Forward P/E    8.64
# 4  PEG Ratio (5 yr expected)    1.01
# 5          Price/Sales (ttm)    2.57
# 6           Price/Book (mrq)    6.87
# 7   Enterprise Value/Revenue    2.58
# 8    Enterprise Value/EBITDA    7.79
# AMAT                            0       1
# 0      Market Cap (intraday)  64.02B
# 1           Enterprise Value  66.32B
# 2               Trailing P/E    9.96
# 3                Forward P/E   10.21
# 4  PEG Ratio (5 yr expected)    1.92
# 5          Price/Sales (ttm)    2.63
# 6           Price/Book (mrq)    5.30
# 7   Enterprise Value/Revenue    2.64
# 8    Enterprise Value/EBITDA    7.98
# MRVL                            0       1
# 0      Market Cap (intraday)  32.29B
# 1           Enterprise Value  36.44B
# 2               Trailing P/E   22.15
# 3                Forward P/E   12.84
# 4  PEG Ratio (5 yr expected)    0.77
# 5          Price/Sales (ttm)    5.79
# 6           Price/Book (mrq)    2.08
# 7   Enterprise Value/Revenue    6.60
# 8    Enterprise Value/EBITDA   23.62
# MU                            0       1
# 0      Market Cap (intraday)  57.32B
# 1           Enterprise Value  55.50B
# 2               Trailing P/E    6.80
# 3                Forward P/E   46.51
# 4  PEG Ratio (5 yr expected)     NaN
# 5          Price/Sales (ttm)    1.92
# 6           Price/Book (mrq)    1.15
# 7   Enterprise Value/Revenue    1.80
# 8    Enterprise Value/EBITDA    3.29
# TSM                            0        1
# 0      Market Cap (intraday)  321.78B
# 1           Enterprise Value  304.43B
# 2               Trailing P/E    14.15
# 3                Forward P/E    11.39
# 4  PEG Ratio (5 yr expected)     0.71
# 5          Price/Sales (ttm)     5.71
# 6           Price/Book (mrq)     4.30
# 7   Enterprise Value/Revenue     0.16
# 8    Enterprise Value/EBITDA     0.23

# %%
error_N = 0

for i in faang_etf_holdings:
  try:
    sleep(random.uniform(1,2))
    print( i ,si.get_stats_valuation(i))
  except IndexError as e :
    print('cannot recall for now :',f'{i}')
    error_N +=1
    print('N of Eerror = ', error_N)
# Out:
# FB                            0        1
# 0      Market Cap (intraday)  360.24B
# 1           Enterprise Value  335.82B
# 2               Trailing P/E    11.11
# 3                Forward P/E    11.65
# 4  PEG Ratio (5 yr expected)     1.65
# 5          Price/Sales (ttm)     3.12
# 6           Price/Book (mrq)     2.86
# 7   Enterprise Value/Revenue     2.81
# 8    Enterprise Value/EBITDA     6.99
# AAPL                            0      1
# 0      Market Cap (intraday)  2.29T
# 1           Enterprise Value  2.36T
# 2               Trailing P/E  23.54
# 3                Forward P/E  22.62
# 4  PEG Ratio (5 yr expected)   2.56
# 5          Price/Sales (ttm)   6.05
# 6           Price/Book (mrq)  39.39
# 7   Enterprise Value/Revenue   6.09
# 8    Enterprise Value/EBITDA  17.92
# AMZN                            0       1
# 0      Market Cap (intraday)   1.16T
# 1           Enterprise Value   1.22T
# 2               Trailing P/E  102.47
# 3                Forward P/E   47.17
# 4  PEG Ratio (5 yr expected)    4.53
# 5          Price/Sales (ttm)    2.40
# 6           Price/Book (mrq)    8.82
# 7   Enterprise Value/Revenue    2.52
# 8    Enterprise Value/EBITDA   24.13
# NFLX                            0        1
# 0      Market Cap (intraday)  109.00B
# 1           Enterprise Value  117.41B
# 2               Trailing P/E    21.79
# 3                Forward P/E    20.96
# 4  PEG Ratio (5 yr expected)     2.11
# 5          Price/Sales (ttm)     3.58
# 6           Price/Book (mrq)     5.71
# 7   Enterprise Value/Revenue     3.78
# 8    Enterprise Value/EBITDA     5.88
# GOOG                            0      1
# 0      Market Cap (intraday)  1.31T
# 1           Enterprise Value  1.21T
# 2               Trailing P/E  18.77
# 3                Forward P/E  16.69
# 4  PEG Ratio (5 yr expected)   1.25
# 5          Price/Sales (ttm)   4.85
# 6           Price/Book (mrq)   5.15
# 7   Enterprise Value/Revenue   4.36
# 8    Enterprise Value/EBITDA  12.10
# NVDA                            0        1
# 0      Market Cap (intraday)  279.55B
# 1           Enterprise Value  274.21B
# 2               Trailing P/E    36.69
# 3                Forward P/E    24.75
# 4  PEG Ratio (5 yr expected)     2.15
# 5          Price/Sales (ttm)     9.56
# 6           Price/Book (mrq)    11.72
# 7   Enterprise Value/Revenue     9.22
# 8    Enterprise Value/EBITDA    29.31
# cannot recall for now : TSAL
# N of Eerror =  1
# TWTR                            0       1
# 0      Market Cap (intraday)  38.83B
# 1           Enterprise Value  39.43B
# 2               Trailing P/E   21.91
# 3                Forward P/E   62.11
# 4  PEG Ratio (5 yr expected)     NaN
# 5          Price/Sales (ttm)    7.63
# 6           Price/Book (mrq)    6.55
# 7   Enterprise Value/Revenue    7.54
# 8    Enterprise Value/EBITDA   63.00
# BABA                            0        1
# 0      Market Cap (intraday)  197.64B
# 1           Enterprise Value  154.29B
# 2               Trailing P/E    37.25
# 3                Forward P/E     9.81
# 4  PEG Ratio (5 yr expected)     3.99
# 5          Price/Sales (ttm)     1.75
# 6           Price/Book (mrq)     1.52
# 7   Enterprise Value/Revenue     0.18
# 8    Enterprise Value/EBITDA     2.06
# BIDU                            0       1
# 0      Market Cap (intraday)  36.77B
# 1           Enterprise Value  25.24B
# 2               Trailing P/E     NaN
# 3                Forward P/E   11.34
# 4  PEG Ratio (5 yr expected)    0.64
# 5          Price/Sales (ttm)    2.09
# 6           Price/Book (mrq)    1.16
# 7   Enterprise Value/Revenue    0.21
# 8    Enterprise Value/EBITDA   -2.42

# %% [markdown]
# ### 2) To get the date of coming earnings for multiple companies
# - get_next_earnings_date()

# %%
error_N=0
for i in soxx_etf_holdings:
  try:
    sleep(random.uniform(1,2))
    print( i ,si.get_next_earnings_date(i))
  except IndexError as e:
    print('cannot recall the data : ', f'{i}')
    error_N +=1
    print('error_N = ', error_N)
# Out:
# AVGO 2022-12-07 10:59:00
# AMD 2022-11-01 20:00:00
# NVDA 2022-11-15 10:59:00
# INTC 2022-10-27 20:00:00
# QCOM 2022-11-02 20:00:00
# TXN 2022-10-25 10:59:00
# ADI 2022-11-21 12:00:00
# KLAC 2022-10-26 21:00:00
# MCHP 2022-11-03 20:00:00
# NXPI 2022-10-31 15:00:00
# LRCX 2022-10-19 20:00:00
# AMAT 2022-11-17 10:59:00
# MRVL 2022-11-30 21:00:00
# MU 2022-12-21 21:00:00
# cannot recall the data :  TSM
# error_N =  1

# %%
error_N=0
for i in faang_etf_holdings:
  try:
    sleep(random.uniform(1,2))
    print( i ,si.get_next_earnings_date(i))
  except IndexError as e:
    print('cannot recall the data : ', f'{i}')
    error_N +=1
    print('error_N = ', error_N)
# Out:
# FB 2022-10-26 20:00:00
# AAPL 2022-10-26 20:00:00
# AMZN 2022-10-27 20:00:00
# NFLX 2023-01-18 21:00:00
# GOOG 2022-10-24 20:00:00
# NVDA 2022-11-15 10:59:00
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-353a36750175> in <module>
#       3   try:
#       4     sleep(random.uniform(1,2))
# ----> 5     print( i ,si.get_next_earnings_date(i))
#       6   except IndexError as e:
#       7     print('cannot recall the data : ', f'{i}')
#
# /usr/local/lib/python3.7/dist-packages/yahoo_fin/stock_info.py in get_next_earnings_date(ticker)
#     821     parsed_result = _parse_earnings_json(new_url)
#     822
# --> 823     temp = parsed_result['context']['dispatcher']['stores']['QuoteSummaryStore']['calendarEvents']['earnings']['earningsDate'][0]['raw']
#     824
#     825     return datetime.datetime.fromtimestamp(temp)
#
# KeyError: 'QuoteSummaryStore'

# %% [markdown]
# ### 3)To get the date of earnings by 'for' satement
# - get_earnings()

# %%
for i in soxx_etf_holdings:
  sleep(random.uniform(1,2))
  print( i, si.get_earnings(i))
# Out:
# AVGO {'quarterly_results':      date  actual  estimate
# 0  4Q2021    7.81      7.74
# 1  1Q2022    8.39      8.08
# 2  2Q2022    9.07      8.70
# 3  3Q2022    9.73      9.56, 'yearly_revenue_earnings':    date      revenue     earnings
# 0  2018  20848000000  12259000000
# 1  2019  22597000000   2724000000
# 2  2020  23888000000   2960000000
# 3  2021  27450000000   6736000000, 'quarterly_revenue_earnings':      date     revenue    earnings
# 0  4Q2021  7407000000  1989000000
# 1  1Q2022  7706000000  2472000000
# 2  2Q2022  8103000000  2590000000
# 3  3Q2022  8464000000  3074000000}
# AMD {'quarterly_results':      date  actual  estimate
# 0  3Q2021    0.73      0.67
# 1  4Q2021    0.92      0.76
# 2  1Q2022    1.13      0.91
# 3  2Q2022    1.05      1.03, 'yearly_revenue_earnings':    date      revenue    earnings
# 0  2018   6475000000   337000000
# 1  2019   6731000000   341000000
# 2  2020   9763000000  2490000000
# 3  2021  16434000000  3162000000, 'quarterly_revenue_earnings':      date     revenue   earnings
# 0  3Q2021  4313000000  923000000
# 1  4Q2021  4826000000  974000000
# 2  1Q2022           0          0
# 3  2Q2022  6550000000  447000000}
# NVDA {'quarterly_results':      date  actual  estimate
# 0  4Q2021    1.17      1.11
# 1  1Q2022    1.32      1.22
# 2  2Q2022    1.36      1.29
# 3  3Q2022    0.51      1.25, 'yearly_revenue_earnings':    date      revenue    earnings
# 0  2019  11716000000  4141000000
# 1  2020  10918000000  2796000000
# 2  2021  16675000000  4332000000
# 3  2022  26914000000  9752000000, 'quarterly_revenue_earnings':      date     revenue    earnings
# 0  4Q2021  7103000000  2464000000
# 1  1Q2022  7643000000  3003000000
# 2  2Q2022  8288000000  1618000000
# 3  3Q2022  6704000000   656000000}
# INTC {'quarterly_results':      date  actual  estimate
# 0  3Q2021    1.71      1.11
# 1  4Q2021    1.09      0.91
# 2  1Q2022    0.87      0.80
# 3  2Q2022    0.29      0.70, 'yearly_revenue_earnings':    date      revenue     earnings
# 0  2018  70848000000  21053000000
# 1  2019  71965000000  21048000000
# 2  2020  77867000000  20899000000
# 3  2021  79024000000  19868000000, 'quarterly_revenue_earnings':      date      revenue    earnings
# 0  3Q2021  19192000000  6823000000
# 1  4Q2021  20528000000  4623000000
# 2  2Q2022  18353000000  8113000000
# 3  3Q2022  15321000000  -454000000}
# QCOM {'quarterly_results':      date  actual  estimate
# 0  3Q2021    2.55      2.26
# 1  4Q2021    3.23      3.01
# 2  1Q2022    3.21      2.91
# 3  2Q2022    2.96      2.87, 'yearly_revenue_earnings':    date      revenue    earnings
# 0  2018  22611000000 -4964000000
# 1  2019  24273000000  4386000000
# 2  2020  23531000000  5198000000
# 3  2021  33566000000  9043000000, 'quarterly_revenue_earnings':      date      revenue    earnings
# 0  3Q2021   9336000000  2798000000
# 1  4Q2021  10705000000  3399000000
# 2  1Q2022  11164000000  2934000000
# 3  2Q2022  10936000000  3730000000}
# TXN {'quarterly_results':      date  actual  estimate
# 0  3Q2021    2.07      2.05
# 1  4Q2021    2.27      1.94
# 2  1Q2022    2.35      2.18
# 3  2Q2022    2.45      2.12, 'yearly_revenue_earnings':    date      revenue    earnings
# 0  2018  15784000000  5580000000
# 1  2019  14383000000  5017000000
# 2  2020  14461000000  5595000000
# 3  2021  18344000000  7769000000, 'quarterly_revenue_earnings':      date     revenue    earnings
# 0  3Q2021  4643000000  1947000000
# 1  4Q2021  4832000000  2138000000
# 2  1Q2022  4905000000  2201000000
# 3  2Q2022  5212000000  2291000000}
# ADI {'quarterly_results':      date  actual  estimate
# 0  4Q2021    1.73      1.70
# 1  1Q2022    1.94      1.78
# 2  2Q2022    2.40      2.11
# 3  3Q2022    2.52      2.43, 'yearly_revenue_earnings':    date     revenue    earnings
# 0  2018  6224689000  1506980000
# 1  2019  5991065000  1363011000
# 2  2020  5603056000  1220761000
# 3  2021  7318286000  1390422000, 'quarterly_revenue_earnings':      date     revenue   earnings
# 0  4Q2021  2339568000   75687000
# 1  1Q2022  2684293000  280077000
# 2  2Q2022  2972064000  783273000
# 3  3Q2022  3109880000  748985000}
# KLAC {'quarterly_results':      date  actual  estimate
# 0  3Q2021    4.64      4.52
# 1  4Q2021    5.59      5.45
# 2  1Q2022    5.13      4.82
# 3  2Q2022    5.81      5.50, 'yearly_revenue_earnings':    date     revenue    earnings
# 0  2019  4568904000  1175617000
# 1  2020  5806424000  1216785000
# 2  2021  6918734000  2078292000
# 3  2022  9211883000  3321807000, 'quarterly_revenue_earnings':      date     revenue    earnings
# 0  3Q2021  2083838000  1068417000
# 1  4Q2021  2352630000   717444000
# 2  1Q2022  2288676000   730572000
# 3  2Q2022  2486739000   805374000}
# MCHP {'quarterly_results':      date  actual  estimate
# 0  3Q2021    1.07      1.06
# 1  4Q2021    1.20      1.17
# 2  1Q2022    1.35      1.25
# 3  2Q2022    1.37      1.34, 'yearly_revenue_earnings':    date     revenue    earnings
# 0  2019  5349500000   355900000
# 1  2020  5274200000   570600000
# 2  2021  5438400000   349400000
# 3  2022  6820900000  1285500000, 'quarterly_revenue_earnings':      date     revenue   earnings
# 0  3Q2021  1649800000  242000000
# 1  4Q2021  1757500000  352800000
# 2  1Q2022  1844200000  437900000
# 3  2Q2022  1963600000  507200000}
# NXPI {'quarterly_results':      date  actual  estimate
# 0  3Q2021    2.84      2.72
# 1  4Q2021    3.20      2.99
# 2  1Q2022    3.34      3.17
# 3  2Q2022    3.52      3.35, 'yearly_revenue_earnings':    date      revenue    earnings
# 0  2018   9407000000  2208000000
# 1  2019   8877000000   243000000
# 2  2020   8612000000    52000000
# 3  2021  11063000000  1871000000, 'quarterly_revenue_earnings':      date     revenue   earnings
# 0  4Q2021  2861000000  519000000
# 1  4Q2021  3039000000  602000000
# 2  2Q2022           0          0
# 3  3Q2022  3312000000  670000000}
# LRCX {'quarterly_results':      date  actual  estimate
# 0  3Q2021    8.36      8.21
# 1  4Q2021    8.53      8.51
# 2  1Q2022    7.40      7.51
# 3  2Q2022    8.83      7.32, 'yearly_revenue_earnings':    date      revenue    earnings
# 0  2019   9653559000  2191430000
# 1  2020  10044736000  2251753000
# 2  2021  14626150000  3908458000
# 3  2022  17227039000  4605286000, 'quarterly_revenue_earnings':      date     revenue    earnings
# 0  3Q2021  4304465000  1179744000
# 1  4Q2021  4226604000  1194830000
# 2  1Q2022  4060416000  1021778000
# 3  2Q2022  4635554000  1208934000}
# AMAT {'quarterly_results':      date  actual  estimate
# 0  4Q2021    1.94      1.95
# 1  1Q2022    1.89      1.85
# 2  2Q2022    1.85      1.90
# 3  3Q2022    1.94      1.79, 'yearly_revenue_earnings':    date      revenue    earnings
# 0  2018  16705000000  3038000000
# 1  2019  14608000000  2706000000
# 2  2020  17202000000  3619000000
# 3  2021  23063000000  5888000000, 'quarterly_revenue_earnings':      date     revenue    earnings
# 0  4Q2021  6123000000  1712000000
# 1  1Q2022  6271000000  1792000000
# 2  2Q2022  6245000000  1536000000
# 3  3Q2022  6520000000  1606000000}
# MRVL {'quarterly_results':      date  actual  estimate
# 0  4Q2021    0.43      0.38
# 1  1Q2022    0.50      0.48
# 2  2Q2022    0.52      0.51
# 3  3Q2022    0.57      0.56, 'yearly_revenue_earnings':    date     revenue    earnings
# 0  2019  2865791000  -179094000
# 1  2020  2699161000  1584391000
# 2  2021  2968900000  -277298000
# 3  2022  4462383000  -421034000, 'quarterly_revenue_earnings':      date     revenue   earnings
# 0  4Q2021  1211245000  -62532000
# 1  1Q2022  1342978000    6168000
# 2  2Q2022  1446900000 -165700000
# 3  3Q2022  1516900000    4300000}
# MU {'quarterly_results':      date  actual  estimate
# 0  4Q2021    2.16      2.11
# 1  1Q2022    2.14      1.97
# 2  2Q2022    2.59      2.43
# 3  3Q2022    1.45      1.30, 'yearly_revenue_earnings':    date      revenue    earnings
# 0  2019  23406000000  6313000000
# 1  2020  21435000000  2687000000
# 2  2021  27705000000  5861000000
# 3  2022  30758000000  8687000000, 'quarterly_revenue_earnings':      date     revenue    earnings
# 0  4Q2021  7687000000  2306000000
# 1  1Q2022  7786000000  2263000000
# 2  2Q2022  8642000000  2626000000
# 3  3Q2022  6643000000  1492000000}
# TSM {'quarterly_results':      date  actual  estimate
# 0  4Q2021    1.15      1.14
# 1  1Q2022    1.39      1.33
# 2  2Q2022    1.55      1.51
# 3  3Q2022    1.79      1.41, 'yearly_revenue_earnings':    date        revenue      earnings
# 0  2018  1031473600000  363052700000
# 1  2019  1069985400000  353948000000
# 2  2020  1339254800000  510744000000
# 3  2021  1587415000000  592359200000, 'quarterly_revenue_earnings':      date       revenue      earnings
# 0  4Q2021  438189269000  162051478000
# 1  1Q2022  491076000000  202733000000
# 2  2Q2022  534140808000  237027317000
# 3  3Q2022  613142000000  280866000000}

# %% [markdown]
# ### 4) To get earnings history for mulitple companies

# %%
test_Co = ['AVGO','AMD','NVDA','INTC','QCOM','TXN','ADI','KLAC','MCHP','NXPI','LRCX','AMAT','MRVL','MU','TSM']

error_N = 0
for j in test_Co:
  try:
    sleep(random.uniform(1,2)) 
    company_eps = si.get_earnings_history(f'{j}')
    print('------company abbreviation : ', j,'------')
    print('total data N : ' , len(company_eps))
    print('\n')


    for i in range(len(company_eps)):

        print('eps(actual)   :' , company_eps[i]['epsactual'])
        print('eps(estimate) :' , company_eps[i]['epsestimate'])
        print('date :', company_eps[i]['startdatetime'],company_eps[i]['timeZoneShortName'])
        print('\n')
  except IndexError as e :
    print(f'{j}', '<--error') 
    error_N +=1
    print('error_number = ', error_N)
# Out:
# Streaming output truncated to the last 5000 lines.
# eps(actual)   : 0.82
# eps(estimate) : 0.72
# date : 2011-01-26T05:00:00.000Z EST
#
#
# eps(actual)   : 0.68
# eps(estimate) : 0.59
# date : 2010-11-03T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.57
# eps(estimate) : 0.54
# date : 2010-07-21T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.59
# eps(estimate) : 0.56
# date : 2010-04-21T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.62
# eps(estimate) : 0.56
# date : 2010-01-27T05:00:00.000Z EST
#
#
# eps(actual)   : 0.64
# eps(estimate) : 0.52
# date : 2009-11-04T05:00:00.000Z EST
#
#
# eps(actual)   : 0.54
# eps(estimate) : 0.52
# date : 2009-07-22T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.41
# eps(estimate) : 0.41
# date : 2009-04-27T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.31
# eps(estimate) : 0.47
# date : 2009-01-28T05:00:00.000Z EST
#
#
# eps(actual)   : 0.63
# eps(estimate) : 0.6
# date : 2008-11-06T05:00:00.000Z EST
#
#
# eps(actual)   : 0.55
# eps(estimate) : 0.55
# date : 2008-07-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.54
# eps(estimate) : 0.52
# date : 2008-04-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.52
# eps(estimate) : 0.53
# date : 2008-01-23T05:00:00.000Z EST
#
#
# eps(actual)   : 0.54
# eps(estimate) : 0.53
# date : 2007-11-08T05:00:00.000Z EST
#
#
# eps(actual)   : 0.55
# eps(estimate) : 0.52
# date : 2007-07-25T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.5
# eps(estimate) : 0.48
# date : 2007-04-25T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.43
# eps(estimate) : 0.42
# date : 2007-01-24T05:00:00.000Z EST
#
#
# eps(actual)   : 0.42
# eps(estimate) : 0.41
# date : 2006-11-02T05:00:00.000Z EST
#
#
# eps(actual)   : 0.42
# eps(estimate) : 0.42
# date : 2006-07-19T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.41
# eps(estimate) : 0.4
# date : 2006-04-19T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.39
# eps(estimate) : 0.38
# date : 2006-01-25T05:00:00.000Z EST
#
#
# eps(actual)   : 0.32
# eps(estimate) : 0.33
# date : 2005-11-02T05:00:00.000Z EST
#
#
# eps(actual)   : 0.28
# eps(estimate) : 0.25
# date : 2005-07-20T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.29
# eps(estimate) : 0.27
# date : 2005-04-20T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.28
# eps(estimate) : 0.27
# date : 2005-01-19T05:00:00.000Z EST
#
#
# eps(actual)   : 0.29
# eps(estimate) : 0.29
# date : 2004-11-03T05:00:00.000Z EST
#
#
# eps(actual)   : 0.28
# eps(estimate) : 0.26
# date : 2004-07-21T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.27
# eps(estimate) : 0.24
# date : 2004-04-21T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.26
# eps(estimate) : 0.24
# date : 2004-01-21T05:00:00.000Z EST
#
#
# eps(actual)   : 0.14
# eps(estimate) : 0.14
# date : 2003-11-05T05:00:00.000Z EST
#
#
# eps(actual)   : 0.17
# eps(estimate) : 0.15
# date : 2003-07-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.19
# eps(estimate) : 0.18
# date : 2003-04-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.21
# eps(estimate) : 0.19
# date : 2003-01-22T05:00:00.000Z EST
#
#
# eps(actual)   : 0.16
# eps(estimate) : 0.14
# date : 2002-11-07T05:00:00.000Z EST
#
#
# eps(actual)   : 0.12
# eps(estimate) : 0.11
# date : 2002-07-25T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.1
# eps(estimate) : 0.1
# date : 2002-04-24T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.12
# eps(estimate) : 0.11
# date : 2002-01-24T05:00:00.000Z EST
#
#
# eps(actual)   : 0.12
# eps(estimate) : 0.12
# date : 2001-11-06T05:00:00.000Z EST
#
#
# eps(actual)   : 0.11
# eps(estimate) : 0.1
# date : 2001-07-26T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.14
# eps(estimate) : 0.15
# date : 2001-04-25T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.14
# eps(estimate) : 0.14
# date : 2001-01-25T05:00:00.000Z EST
#
#
# eps(actual)   : 0.13
# eps(estimate) : 0.14
# date : 2000-11-02T05:00:00.000Z EST
#
#
# eps(actual)   : 0.14
# eps(estimate) : 0.14
# date : 2000-07-19T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.13
# eps(estimate) : 0.12
# date : 2000-04-18T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.13
# eps(estimate) : 0.12
# date : 2000-01-25T05:00:00.000Z EST
#
#
# eps(actual)   : 0.11
# eps(estimate) : 0.11
# date : 1999-11-02T05:00:00.000Z EST
#
#
# eps(actual)   : 0.09
# eps(estimate) : 0.08
# date : 1999-07-19T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.05
# eps(estimate) : 0.04
# date : 1999-04-20T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.04
# eps(estimate) : 0.04
# date : 1999-01-19T05:00:00.000Z EST
#
#
# ------company abbreviation :  TXN ------
# total data N :  100
#
#
# eps(actual)   : None
# eps(estimate) : None
# date : 2023-07-24T10:59:00.000Z EDT
#
#
# eps(actual)   : None
# eps(estimate) : None
# date : 2023-04-24T10:59:00.000Z EDT
#
#
# eps(actual)   : None
# eps(estimate) : None
# date : 2023-01-23T10:59:00.000Z EST
#
#
# eps(actual)   : None
# eps(estimate) : 2.39
# date : 2022-10-25T20:30:00.000Z EDT
#
#
# eps(actual)   : None
# eps(estimate) : 2.39
# date : 2022-10-25T10:59:00.000Z EDT
#
#
# eps(actual)   : 2.45
# eps(estimate) : 2.12
# date : 2022-07-26T16:01:00.000Z EDT
#
#
# eps(actual)   : 2.35
# eps(estimate) : 2.18
# date : 2022-04-26T16:01:00.000Z EDT
#
#
# eps(actual)   : 2.27
# eps(estimate) : 1.94
# date : 2022-01-25T16:01:00.000Z EST
#
#
# eps(actual)   : 2.07
# eps(estimate) : 2.05
# date : 2021-10-26T16:01:00.000Z EDT
#
#
# eps(actual)   : 2.05
# eps(estimate) : 1.84
# date : 2021-07-21T16:03:00.000Z EDT
#
#
# eps(actual)   : 1.87
# eps(estimate) : 1.58
# date : 2021-04-27T16:01:00.000Z EDT
#
#
# eps(actual)   : 1.64
# eps(estimate) : 1.34
# date : 2021-01-26T16:01:00.000Z EST
#
#
# eps(actual)   : 1.45
# eps(estimate) : 1.28
# date : 2020-10-20T16:01:00.000Z EDT
#
#
# eps(actual)   : 1.48
# eps(estimate) : 0.88
# date : 2020-07-21T16:01:00.000Z EDT
#
#
# eps(actual)   : 1.24
# eps(estimate) : 1
# date : 2020-04-21T16:01:00.000Z EDT
#
#
# eps(actual)   : 1.12
# eps(estimate) : 1.02
# date : 2020-01-22T16:01:00.000Z EST
#
#
# eps(actual)   : 1.49
# eps(estimate) : 1.42
# date : 2019-10-22T16:01:00.000Z EDT
#
#
# eps(actual)   : 1.36
# eps(estimate) : 1.22
# date : 2019-07-23T16:01:00.000Z EDT
#
#
# eps(actual)   : 1.26
# eps(estimate) : 1.13
# date : 2019-04-23T16:01:00.000Z EDT
#
#
# eps(actual)   : 1.27
# eps(estimate) : 1.24
# date : 2019-01-23T16:02:00.000Z EST
#
#
# eps(actual)   : 1.58
# eps(estimate) : 1.53
# date : 2018-10-23T16:01:00.000Z EDT
#
#
# eps(actual)   : 1.4
# eps(estimate) : 1.32
# date : 2018-07-24T16:01:00.000Z EDT
#
#
# eps(actual)   : 1.35
# eps(estimate) : 1.11
# date : 2018-04-24T16:01:00.000Z EDT
#
#
# eps(actual)   : 1.09
# eps(estimate) : 1.09
# date : 2018-01-23T16:01:00.000Z EST
#
#
# eps(actual)   : 1.26
# eps(estimate) : 1.12
# date : 2017-10-24T16:01:00.000Z EDT
#
#
# eps(actual)   : 1.03
# eps(estimate) : 0.96
# date : 2017-07-25T16:01:00.000Z EDT
#
#
# eps(actual)   : 0.97
# eps(estimate) : 0.83
# date : 2017-04-25T16:30:00.000Z EDT
#
#
# eps(actual)   : 0.87
# eps(estimate) : 0.82
# date : 2017-01-24T16:30:00.000Z EST
#
#
# eps(actual)   : 0.94
# eps(estimate) : 0.86
# date : 2016-10-26T16:30:00.000Z EDT
#
#
# eps(actual)   : 0.76
# eps(estimate) : 0.73
# date : 2016-07-25T16:30:00.000Z EDT
#
#
# eps(actual)   : 0.65
# eps(estimate) : 0.62
# date : 2016-04-27T16:30:00.000Z EDT
#
#
# eps(actual)   : 0.8
# eps(estimate) : 0.69
# date : 2016-01-27T16:30:00.000Z EST
#
#
# eps(actual)   : 0.76
# eps(estimate) : 0.68
# date : 2015-10-21T16:30:00.000Z EDT
#
#
# eps(actual)   : 0.65
# eps(estimate) : 0.65
# date : 2015-07-22T16:30:00.000Z EDT
#
#
# eps(actual)   : 0.61
# eps(estimate) : 0.62
# date : 2015-04-22T16:30:00.000Z EDT
#
#
# eps(actual)   : 0.76
# eps(estimate) : 0.69
# date : 2015-01-26T16:30:00.000Z EST
#
#
# eps(actual)   : 0.76
# eps(estimate) : 0.71
# date : 2014-10-20T16:30:00.000Z EDT
#
#
# eps(actual)   : 0.62
# eps(estimate) : 0.59
# date : 2014-07-21T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.42
# eps(estimate) : 0.41
# date : 2014-04-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.46
# eps(estimate) : 0.46
# date : 2014-01-21T05:00:00.000Z EST
#
#
# eps(actual)   : 0.56
# eps(estimate) : 0.53
# date : 2013-10-21T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.58
# eps(estimate) : 0.41
# date : 2013-07-22T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.32
# eps(estimate) : 0.3
# date : 2013-04-22T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.36
# eps(estimate) : 0.34
# date : 2013-01-22T05:00:00.000Z EST
#
#
# eps(actual)   : 0.52
# eps(estimate) : 0.46
# date : 2012-10-22T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.44
# eps(estimate) : 0.41
# date : 2012-07-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.32
# eps(estimate) : 0.29
# date : 2012-04-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.48
# eps(estimate) : 0.39
# date : 2012-01-23T05:00:00.000Z EST
#
#
# eps(actual)   : 0.51
# eps(estimate) : 0.57
# date : 2011-10-24T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.56
# eps(estimate) : 0.53
# date : 2011-07-25T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.55
# eps(estimate) : 0.58
# date : 2011-04-18T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.64
# eps(estimate) : 0.63
# date : 2011-01-24T05:00:00.000Z EST
#
#
# eps(actual)   : 0.71
# eps(estimate) : 0.69
# date : 2010-10-25T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.62
# eps(estimate) : 0.62
# date : 2010-07-19T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.52
# eps(estimate) : 0.51
# date : 2010-04-26T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.52
# eps(estimate) : 0.49
# date : 2010-01-25T05:00:00.000Z EST
#
#
# eps(actual)   : 0.42
# eps(estimate) : 0.39
# date : 2009-10-19T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.2
# eps(estimate) : 0.19
# date : 2009-07-20T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.01
# eps(estimate) : -0.02
# date : 2009-04-20T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.21
# eps(estimate) : 0.13
# date : 2009-01-26T05:00:00.000Z EST
#
#
# eps(actual)   : 0.43
# eps(estimate) : 0.44
# date : 2008-10-20T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.44
# eps(estimate) : 0.46
# date : 2008-07-21T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.49
# eps(estimate) : 0.43
# date : 2008-04-21T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.54
# eps(estimate) : 0.52
# date : 2008-01-22T05:00:00.000Z EST
#
#
# eps(actual)   : 0.52
# eps(estimate) : 0.5
# date : 2007-10-22T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.42
# eps(estimate) : 0.42
# date : 2007-07-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.35
# eps(estimate) : 0.31
# date : 2007-04-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.45
# eps(estimate) : 0.38
# date : 2007-01-22T05:00:00.000Z EST
#
#
# eps(actual)   : 0.45
# eps(estimate) : 0.45
# date : 2006-10-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.47
# eps(estimate) : 0.46
# date : 2006-07-24T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.33
# eps(estimate) : 0.32
# date : 2006-04-18T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.43
# eps(estimate) : 0.42
# date : 2006-01-23T05:00:00.000Z EST
#
#
# eps(actual)   : 0.41
# eps(estimate) : 0.4
# date : 2005-10-24T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.32
# eps(estimate) : 0.29
# date : 2005-07-25T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.24
# eps(estimate) : 0.23
# date : 2005-04-18T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.28
# eps(estimate) : 0.26
# date : 2005-01-25T05:00:00.000Z EST
#
#
# eps(actual)   : 0.32
# eps(estimate) : 0.27
# date : 2004-10-18T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.25
# eps(estimate) : 0.25
# date : 2004-07-20T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.21
# eps(estimate) : 0.21
# date : 2004-04-14T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.22
# eps(estimate) : 0.19
# date : 2004-01-26T05:00:00.000Z EST
#
#
# eps(actual)   : 0.12
# eps(estimate) : 0.09
# date : 2003-10-20T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.07
# eps(estimate) : 0.06
# date : 2003-07-21T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.07
# eps(estimate) : 0.06
# date : 2003-04-15T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.06
# eps(estimate) : 0.03
# date : 2003-01-22T05:00:00.000Z EST
#
#
# eps(actual)   : 0.09
# eps(estimate) : 0.1
# date : 2002-10-21T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.06
# eps(estimate) : 0.06
# date : 2002-07-22T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.01
# eps(estimate) : 0
# date : 2002-04-15T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.06
# eps(estimate) : -0.09
# date : 2002-01-28T05:00:00.000Z EST
#
#
# eps(actual)   : -0.03
# eps(estimate) : -0.04
# date : 2001-10-17T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.03
# eps(estimate) : 0.02
# date : 2001-07-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.18
# eps(estimate) : 0.18
# date : 2001-04-17T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.31
# eps(estimate) : 0.34
# date : 2001-01-22T05:00:00.000Z EST
#
#
# eps(actual)   : 0.33
# eps(estimate) : 0.33
# date : 2000-10-18T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.31
# eps(estimate) : 0.3
# date : 2000-07-24T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.28
# eps(estimate) : 0.27
# date : 2000-04-17T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.26
# eps(estimate) : 0.24
# date : 2000-01-24T05:00:00.000Z EST
#
#
# eps(actual)   : 0.26
# eps(estimate) : 0.21
# date : 1999-10-19T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.23
# eps(estimate) : 0.2
# date : 1999-07-20T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.16
# eps(estimate) : 0.15
# date : 1999-04-20T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.15
# eps(estimate) : 0.14
# date : 1999-01-20T05:00:00.000Z EST
#
#
# ------company abbreviation :  ADI ------
# total data N :  100
#
#
# eps(actual)   : None
# eps(estimate) : None
# date : 2023-08-15T11:00:00.000Z EDT
#
#
# eps(actual)   : None
# eps(estimate) : None
# date : 2023-05-16T11:00:00.000Z EDT
#
#
# eps(actual)   : None
# eps(estimate) : None
# date : 2023-02-14T12:00:00.000Z EST
#
#
# eps(actual)   : None
# eps(estimate) : 2.59
# date : 2022-11-21T12:00:00.000Z EST
#
#
# eps(actual)   : 2.52
# eps(estimate) : 2.43
# date : 2022-08-17T06:59:00.000Z EDT
#
#
# eps(actual)   : 2.4
# eps(estimate) : 2.11
# date : 2022-05-18T07:00:00.000Z EDT
#
#
# eps(actual)   : 1.94
# eps(estimate) : 1.78
# date : 2022-02-16T07:00:00.000Z EST
#
#
# eps(actual)   : 1.73
# eps(estimate) : 1.7
# date : 2021-11-23T07:00:00.000Z EST
#
#
# eps(actual)   : 1.72
# eps(estimate) : 1.63
# date : 2021-08-18T07:00:00.000Z EDT
#
#
# eps(actual)   : 1.54
# eps(estimate) : 1.45
# date : 2021-05-19T07:00:00.000Z EDT
#
#
# eps(actual)   : 1.44
# eps(estimate) : 1.32
# date : 2021-02-17T08:00:00.000Z EST
#
#
# eps(actual)   : 1.44
# eps(estimate) : 1.33
# date : 2020-11-24T08:00:00.000Z EST
#
#
# eps(actual)   : 1.36
# eps(estimate) : 1.28
# date : 2020-08-19T08:00:00.000Z EDT
#
#
# eps(actual)   : 1.08
# eps(estimate) : 1.03
# date : 2020-05-20T07:30:00.000Z EDT
#
#
# eps(actual)   : 1.03
# eps(estimate) : 1
# date : 2020-02-19T08:00:00.000Z EST
#
#
# eps(actual)   : 1.19
# eps(estimate) : 1.22
# date : 2019-11-26T08:00:00.000Z EST
#
#
# eps(actual)   : 1.26
# eps(estimate) : 1.22
# date : 2019-08-21T08:00:00.000Z EDT
#
#
# eps(actual)   : 1.36
# eps(estimate) : 1.3
# date : 2019-05-22T07:32:00.000Z EDT
#
#
# eps(actual)   : 1.33
# eps(estimate) : 1.28
# date : 2019-02-20T08:00:00.000Z EST
#
#
# eps(actual)   : 1.55
# eps(estimate) : 1.52
# date : 2018-11-20T08:00:00.000Z EST
#
#
# eps(actual)   : 1.53
# eps(estimate) : 1.46
# date : 2018-08-22T08:00:00.000Z EDT
#
#
# eps(actual)   : 1.45
# eps(estimate) : 1.38
# date : 2018-05-30T08:00:00.000Z EDT
#
#
# eps(actual)   : 1.42
# eps(estimate) : 1.29
# date : 2018-02-28T09:06:00.000Z EST
#
#
# eps(actual)   : 1.45
# eps(estimate) : 1.36
# date : 2017-11-21T08:00:00.000Z EST
#
#
# eps(actual)   : 1.26
# eps(estimate) : 1.15
# date : 2017-08-30T08:00:00.000Z EDT
#
#
# eps(actual)   : 1.03
# eps(estimate) : 0.84
# date : 2017-05-31T08:00:00.000Z EDT
#
#
# eps(actual)   : 0.94
# eps(estimate) : 0.74
# date : 2017-02-15T08:00:00.000Z EST
#
#
# eps(actual)   : 1.05
# eps(estimate) : 0.89
# date : 2016-11-22T08:00:00.000Z EST
#
#
# eps(actual)   : 0.82
# eps(estimate) : 0.76
# date : 2016-08-17T08:00:00.000Z EDT
#
#
# eps(actual)   : 0.64
# eps(estimate) : 0.62
# date : 2016-05-18T08:00:00.000Z EDT
#
#
# eps(actual)   : 0.56
# eps(estimate) : 0.53
# date : 2016-02-17T08:00:00.000Z EST
#
#
# eps(actual)   : 1.03
# eps(estimate) : 0.83
# date : 2015-11-24T08:00:00.000Z EST
#
#
# eps(actual)   : 0.77
# eps(estimate) : 0.74
# date : 2015-08-18T16:01:00.000Z EDT
#
#
# eps(actual)   : 0.73
# eps(estimate) : 0.72
# date : 2015-05-19T16:00:00.000Z EDT
#
#
# eps(actual)   : 0.63
# eps(estimate) : 0.61
# date : 2015-02-17T16:05:00.000Z EST
#
#
# eps(actual)   : 0.69
# eps(estimate) : 0.68
# date : 2014-11-25T16:00:00.000Z EST
#
#
# eps(actual)   : 0.63
# eps(estimate) : 0.63
# date : 2014-08-26T16:00:00.000Z EDT
#
#
# eps(actual)   : 0.59
# eps(estimate) : 0.56
# date : 2014-05-20T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.49
# eps(estimate) : 0.48
# date : 2014-02-18T05:00:00.000Z EST
#
#
# eps(actual)   : 0.63
# eps(estimate) : 0.58
# date : 2013-11-26T05:00:00.000Z EST
#
#
# eps(actual)   : 0.57
# eps(estimate) : 0.54
# date : 2013-08-20T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.51
# eps(estimate) : 0.52
# date : 2013-05-21T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.44
# eps(estimate) : 0.45
# date : 2013-02-20T05:00:00.000Z EST
#
#
# eps(actual)   : 0.58
# eps(estimate) : 0.56
# date : 2012-11-27T05:00:00.000Z EST
#
#
# eps(actual)   : 0.56
# eps(estimate) : 0.56
# date : 2012-08-21T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.53
# eps(estimate) : 0.51
# date : 2012-05-22T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.46
# eps(estimate) : 0.48
# date : 2012-02-22T05:00:00.000Z EST
#
#
# eps(actual)   : 0.6
# eps(estimate) : 0.63
# date : 2011-11-21T05:00:00.000Z EST
#
#
# eps(actual)   : 0.71
# eps(estimate) : 0.73
# date : 2011-08-16T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.75
# eps(estimate) : 0.68
# date : 2011-05-17T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.66
# eps(estimate) : 0.65
# date : 2011-02-15T05:00:00.000Z EST
#
#
# eps(actual)   : 0.73
# eps(estimate) : 0.7
# date : 2010-11-22T05:00:00.000Z EST
#
#
# eps(actual)   : 0.65
# eps(estimate) : 0.6
# date : 2010-08-17T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.55
# eps(estimate) : 0.5
# date : 2010-05-18T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.43
# eps(estimate) : 0.38
# date : 2010-02-17T05:00:00.000Z EST
#
#
# eps(actual)   : 0.36
# eps(estimate) : 0.26
# date : 2009-11-23T05:00:00.000Z EST
#
#
# eps(actual)   : 0.22
# eps(estimate) : 0.2
# date : 2009-08-18T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.21
# eps(estimate) : 0.09
# date : 2009-05-19T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.18
# eps(estimate) : 0.16
# date : 2009-02-18T05:00:00.000Z EST
#
#
# eps(actual)   : 0.49
# eps(estimate) : 0.43
# date : 2008-11-24T05:00:00.000Z EST
#
#
# eps(actual)   : 0.44
# eps(estimate) : 0.45
# date : 2008-08-19T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.44
# eps(estimate) : 0.41
# date : 2008-05-20T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.4
# eps(estimate) : 0.39
# date : 2008-02-20T05:00:00.000Z EST
#
#
# eps(actual)   : 0.31
# eps(estimate) : 0.39
# date : 2007-11-27T05:00:00.000Z EST
#
#
# eps(actual)   : 0.37
# eps(estimate) : 0.36
# date : 2007-08-21T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.37
# eps(estimate) : 0.35
# date : 2007-05-22T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.44
# eps(estimate) : 0.41
# date : 2007-02-21T05:00:00.000Z EST
#
#
# eps(actual)   : 0.39
# eps(estimate) : 0.4
# date : 2006-11-14T05:00:00.000Z EST
#
#
# eps(actual)   : 0.43
# eps(estimate) : 0.45
# date : 2006-08-10T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.41
# eps(estimate) : 0.4
# date : 2006-05-11T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.37
# eps(estimate) : 0.36
# date : 2006-02-09T05:00:00.000Z EST
#
#
# eps(actual)   : 0.36
# eps(estimate) : 0.34
# date : 2005-11-15T05:00:00.000Z EST
#
#
# eps(actual)   : 0.32
# eps(estimate) : 0.31
# date : 2005-08-11T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.31
# eps(estimate) : 0.3
# date : 2005-05-12T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.28
# eps(estimate) : 0.29
# date : 2005-02-10T05:00:00.000Z EST
#
#
# eps(actual)   : 0.34
# eps(estimate) : 0.33
# date : 2004-11-23T05:00:00.000Z EST
#
#
# eps(actual)   : 0.43
# eps(estimate) : 0.45
# date : 2004-08-12T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.39
# eps(estimate) : 0.35
# date : 2004-05-13T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.3
# eps(estimate) : 0.28
# date : 2004-02-12T05:00:00.000Z EST
#
#
# eps(actual)   : 0.25
# eps(estimate) : 0.23
# date : 2003-11-18T05:00:00.000Z EST
#
#
# eps(actual)   : 0.21
# eps(estimate) : 0.21
# date : 2003-08-14T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.19
# eps(estimate) : 0.18
# date : 2003-05-14T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.16
# eps(estimate) : 0.16
# date : 2003-02-13T05:00:00.000Z EST
#
#
# eps(actual)   : 0.16
# eps(estimate) : 0.16
# date : 2002-11-19T05:00:00.000Z EST
#
#
# eps(actual)   : 0.15
# eps(estimate) : 0.15
# date : 2002-08-15T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.13
# eps(estimate) : 0.12
# date : 2002-05-16T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.11
# eps(estimate) : 0.11
# date : 2002-02-14T05:00:00.000Z EST
#
#
# eps(actual)   : 0.14
# eps(estimate) : 0.12
# date : 2001-11-20T05:00:00.000Z EST
#
#
# eps(actual)   : 0.17
# eps(estimate) : 0.17
# date : 2001-08-16T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.31
# eps(estimate) : 0.31
# date : 2001-05-17T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.5
# eps(estimate) : 0.5
# date : 2001-02-15T05:00:00.000Z EST
#
#
# eps(actual)   : 0.54
# eps(estimate) : 0.5
# date : 2000-11-14T05:00:00.000Z EST
#
#
# eps(actual)   : 0.43
# eps(estimate) : 0.37
# date : 2000-08-15T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.32
# eps(estimate) : 0.29
# date : 2000-05-17T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.25
# eps(estimate) : 0.22
# date : 2000-02-16T05:00:00.000Z EST
#
#
# eps(actual)   : 0.2
# eps(estimate) : 0.18
# date : 1999-12-01T05:00:00.000Z EST
#
#
# eps(actual)   : 0.15
# eps(estimate) : 0.15
# date : 1999-08-18T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.13
# eps(estimate) : 0.11
# date : 1999-05-19T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.1
# eps(estimate) : 0.09
# date : 1999-02-17T05:00:00.000Z EST
#
#
# eps(actual)   : 0.08
# eps(estimate) : 0.07
# date : 1998-12-02T05:00:00.000Z EST
#
#
# ------company abbreviation :  KLAC ------
# total data N :  100
#
#
# eps(actual)   : None
# eps(estimate) : None
# date : 2023-07-26T10:59:00.000Z EDT
#
#
# eps(actual)   : None
# eps(estimate) : None
# date : 2023-04-26T10:59:00.000Z EDT
#
#
# eps(actual)   : None
# eps(estimate) : None
# date : 2023-01-25T10:59:00.000Z EST
#
#
# eps(actual)   : None
# eps(estimate) : 6.24
# date : 2022-10-26T23:00:00.000Z EDT
#
#
# eps(actual)   : None
# eps(estimate) : 6.24
# date : 2022-10-26T21:00:00.000Z EDT
#
#
# eps(actual)   : 5.81
# eps(estimate) : 5.5
# date : 2022-07-28T16:05:00.000Z EDT
#
#
# eps(actual)   : 5.13
# eps(estimate) : 4.82
# date : 2022-04-28T16:05:00.000Z EDT
#
#
# eps(actual)   : 5.59
# eps(estimate) : 5.45
# date : 2022-01-27T16:05:00.000Z EST
#
#
# eps(actual)   : 4.64
# eps(estimate) : 4.52
# date : 2021-10-27T16:05:00.000Z EDT
#
#
# eps(actual)   : 4.43
# eps(estimate) : 3.99
# date : 2021-07-29T16:05:00.000Z EDT
#
#
# eps(actual)   : 3.85
# eps(estimate) : 3.62
# date : 2021-04-29T16:05:00.000Z EDT
#
#
# eps(actual)   : 3.24
# eps(estimate) : 3.2
# date : 2021-02-03T16:05:00.000Z EST
#
#
# eps(actual)   : 3.03
# eps(estimate) : 2.77
# date : 2020-10-28T16:05:00.000Z EDT
#
#
# eps(actual)   : 2.73
# eps(estimate) : 2.42
# date : 2020-08-03T16:05:00.000Z EDT
#
#
# eps(actual)   : 2.47
# eps(estimate) : 2.28
# date : 2020-05-05T16:05:00.000Z EDT
#
#
# eps(actual)   : 2.66
# eps(estimate) : 2.59
# date : 2020-02-04T16:05:00.000Z EST
#
#
# eps(actual)   : 2.48
# eps(estimate) : 2.2
# date : 2019-10-30T16:05:00.000Z EDT
#
#
# eps(actual)   : 1.78
# eps(estimate) : 1.74
# date : 2019-08-05T16:15:00.000Z EDT
#
#
# eps(actual)   : 1.8
# eps(estimate) : 1.67
# date : 2019-05-06T16:15:00.000Z EDT
#
#
# eps(actual)   : 2.44
# eps(estimate) : 2.2
# date : 2019-01-29T16:15:00.000Z EST
#
#
# eps(actual)   : 2.46
# eps(estimate) : 2.21
# date : 2018-10-29T16:15:00.000Z EDT
#
#
# eps(actual)   : 2.22
# eps(estimate) : 2.14
# date : 2018-07-30T16:26:00.000Z EDT
#
#
# eps(actual)   : 2.02
# eps(estimate) : 1.99
# date : 2018-04-26T16:15:00.000Z EDT
#
#
# eps(actual)   : 1.97
# eps(estimate) : 1.73
# date : 2018-01-25T16:15:00.000Z EST
#
#
# eps(actual)   : 1.8
# eps(estimate) : 1.64
# date : 2017-10-26T16:15:00.000Z EDT
#
#
# eps(actual)   : 1.64
# eps(estimate) : 1.59
# date : 2017-07-27T16:15:00.000Z EDT
#
#
# eps(actual)   : 1.62
# eps(estimate) : 1.55
# date : 2017-04-27T16:15:00.000Z EDT
#
#
# eps(actual)   : 1.52
# eps(estimate) : 1.39
# date : 2017-01-26T16:15:00.000Z EST
#
#
# eps(actual)   : 1.16
# eps(estimate) : 1.03
# date : 2016-10-20T16:15:00.000Z EDT
#
#
# eps(actual)   : 1.77
# eps(estimate) : 1.42
# date : 2016-07-28T08:30:00.000Z EDT
#
#
# eps(actual)   : 1.15
# eps(estimate) : 0.98
# date : 2016-04-26T16:15:00.000Z EDT
#
#
# eps(actual)   : 1.04
# eps(estimate) : 0.86
# date : 2016-01-28T16:16:00.000Z EST
#
#
# eps(actual)   : 0.71
# eps(estimate) : 0.56
# date : 2015-10-21T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.99
# eps(estimate) : 0.91
# date : 2015-07-30T16:15:00.000Z EDT
#
#
# eps(actual)   : 0.84
# eps(estimate) : 0.76
# date : 2015-04-23T16:15:00.000Z EDT
#
#
# eps(actual)   : 0.68
# eps(estimate) : 0.52
# date : 2015-01-22T16:15:00.000Z EST
#
#
# eps(actual)   : 0.47
# eps(estimate) : 0.46
# date : 2014-10-23T16:15:00.000Z EDT
#
#
# eps(actual)   : 0.8
# eps(estimate) : 0.86
# date : 2014-07-24T04:00:00.000Z EDT
#
#
# eps(actual)   : 1.23
# eps(estimate) : 1.12
# date : 2014-04-24T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.85
# eps(estimate) : 0.8
# date : 2014-01-23T05:00:00.000Z EST
#
#
# eps(actual)   : 0.68
# eps(estimate) : 0.66
# date : 2013-10-24T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.82
# eps(estimate) : 0.79
# date : 2013-07-25T04:00:00.000Z EDT
#
#
# eps(actual)   : 1.01
# eps(estimate) : 0.86
# date : 2013-04-25T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.63
# eps(estimate) : 0.56
# date : 2013-01-24T05:00:00.000Z EST
#
#
# eps(actual)   : 0.84
# eps(estimate) : 0.89
# date : 2012-10-25T04:00:00.000Z EDT
#
#
# eps(actual)   : 1.49
# eps(estimate) : 1.31
# date : 2012-07-26T04:00:00.000Z EDT
#
#
# eps(actual)   : 1.27
# eps(estimate) : 1.1
# date : 2012-04-26T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.72
# eps(estimate) : 0.66
# date : 2012-01-26T05:00:00.000Z EST
#
#
# eps(actual)   : 1.17
# eps(estimate) : 1.17
# date : 2011-10-27T04:00:00.000Z EDT
#
#
# eps(actual)   : 1.5
# eps(estimate) : 1.37
# date : 2011-07-28T04:00:00.000Z EDT
#
#
# eps(actual)   : 1.31
# eps(estimate) : 1.24
# date : 2011-04-28T04:00:00.000Z EDT
#
#
# eps(actual)   : 1.1
# eps(estimate) : 1.05
# date : 2011-01-27T05:00:00.000Z EST
#
#
# eps(actual)   : 0.99
# eps(estimate) : 0.86
# date : 2010-10-28T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.7
# eps(estimate) : 0.6
# date : 2010-07-29T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.41
# eps(estimate) : 0.35
# date : 2010-04-29T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.28
# eps(estimate) : 0.27
# date : 2010-01-28T05:00:00.000Z EST
#
#
# eps(actual)   : 0.15
# eps(estimate) : 0.02
# date : 2009-10-29T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.09
# eps(estimate) : -0.15
# date : 2009-07-23T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.34
# eps(estimate) : -0.26
# date : 2009-04-23T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.12
# eps(estimate) : -0.07
# date : 2009-01-29T05:00:00.000Z EST
#
#
# eps(actual)   : 0.32
# eps(estimate) : 0.34
# date : 2008-10-30T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.6
# eps(estimate) : 0.57
# date : 2008-07-31T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.67
# eps(estimate) : 0.63
# date : 2008-04-24T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.75
# eps(estimate) : 0.7
# date : 2008-01-24T05:00:00.000Z EST
#
#
# eps(actual)   : 0.76
# eps(estimate) : 0.76
# date : 2007-10-25T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.9
# eps(estimate) : 0.85
# date : 2007-07-26T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.84
# eps(estimate) : 0.78
# date : 2007-04-26T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.72
# eps(estimate) : 0.71
# date : 2007-02-05T05:00:00.000Z EST
#
#
# eps(actual)   : 0.65
# eps(estimate) : 0.61
# date : 2007-01-29T05:00:00.000Z EST
#
#
# eps(actual)   : 0.63
# eps(estimate) : 0.56
# date : 2006-04-27T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.5
# eps(estimate) : 0.47
# date : 2006-01-26T05:00:00.000Z EST
#
#
# eps(actual)   : 0.5
# eps(estimate) : 0.48
# date : 2005-10-27T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.52
# eps(estimate) : 0.48
# date : 2005-07-28T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.61
# eps(estimate) : 0.56
# date : 2005-04-28T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.61
# eps(estimate) : 0.59
# date : 2005-01-20T05:00:00.000Z EST
#
#
# eps(actual)   : 0.58
# eps(estimate) : 0.57
# date : 2004-10-21T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.48
# eps(estimate) : 0.45
# date : 2004-07-29T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.33
# eps(estimate) : 0.29
# date : 2004-04-21T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.22
# eps(estimate) : 0.19
# date : 2004-01-22T05:00:00.000Z EST
#
#
# eps(actual)   : 0.18
# eps(estimate) : 0.17
# date : 2003-10-22T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.15
# eps(estimate) : 0.15
# date : 2003-07-24T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.14
# eps(estimate) : 0.12
# date : 2003-04-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.15
# eps(estimate) : 0.14
# date : 2003-01-23T05:00:00.000Z EST
#
#
# eps(actual)   : 0.23
# eps(estimate) : 0.23
# date : 2002-10-22T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.23
# eps(estimate) : 0.2
# date : 2002-07-30T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.17
# eps(estimate) : 0.15
# date : 2002-04-18T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.25
# eps(estimate) : 0.24
# date : 2002-01-23T05:00:00.000Z EST
#
#
# eps(actual)   : 0.44
# eps(estimate) : 0.43
# date : 2001-10-18T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.29
# eps(estimate) : 0.26
# date : 2001-07-31T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.48
# eps(estimate) : 0.44
# date : 2001-04-18T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.57
# eps(estimate) : 0.55
# date : 2001-01-17T05:00:00.000Z EST
#
#
# eps(actual)   : 0.54
# eps(estimate) : 0.51
# date : 2000-10-12T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.47
# eps(estimate) : 0.43
# date : 2000-07-27T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.38
# eps(estimate) : 0.32
# date : 2000-04-13T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.26
# eps(estimate) : 0.24
# date : 2000-01-13T05:00:00.000Z EST
#
#
# eps(actual)   : 0.19
# eps(estimate) : 0.16
# date : 1999-10-14T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.14
# eps(estimate) : 0.13
# date : 1999-07-28T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.12
# eps(estimate) : 0.07
# date : 1999-04-14T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.06
# eps(estimate) : 0.05
# date : 1999-01-19T05:00:00.000Z EST
#
#
# eps(actual)   : 0.06
# eps(estimate) : 0.07
# date : 1998-10-15T04:00:00.000Z EDT
#
#
# ------company abbreviation :  MCHP ------
# total data N :  100
#
#
# eps(actual)   : None
# eps(estimate) : None
# date : 2023-07-31T10:59:00.000Z EDT
#
#
# eps(actual)   : None
# eps(estimate) : None
# date : 2023-05-08T20:00:00.000Z EDT
#
#
# eps(actual)   : None
# eps(estimate) : None
# date : 2023-02-01T10:59:00.000Z EST
#
#
# eps(actual)   : None
# eps(estimate) : 1.44
# date : 2022-11-03T21:00:00.000Z EDT
#
#
# eps(actual)   : None
# eps(estimate) : 1.44
# date : 2022-11-03T20:00:00.000Z EDT
#
#
# eps(actual)   : 1.37
# eps(estimate) : 1.34
# date : 2022-08-02T16:40:00.000Z EDT
#
#
# eps(actual)   : 1.35
# eps(estimate) : 1.25
# date : 2022-05-09T16:15:00.000Z EDT
#
#
# eps(actual)   : 1.2
# eps(estimate) : 1.17
# date : 2022-02-03T16:26:00.000Z EST
#
#
# eps(actual)   : 1.07
# eps(estimate) : 1.06
# date : 2021-11-04T17:02:00.000Z EDT
#
#
# eps(actual)   : 0.99
# eps(estimate) : 0.95
# date : 2021-08-03T16:27:00.000Z EDT
#
#
# eps(actual)   : 0.93
# eps(estimate) : 0.87
# date : 2021-05-06T16:15:00.000Z EDT
#
#
# eps(actual)   : 0.81
# eps(estimate) : 0.79
# date : 2021-02-04T15:46:00.000Z EST
#
#
# eps(actual)   : 0.78
# eps(estimate) : 0.72
# date : 2020-11-05T16:41:00.000Z EST
#
#
# eps(actual)   : 0.78
# eps(estimate) : 0.72
# date : 2020-08-04T16:26:00.000Z EDT
#
#
# eps(actual)   : 0.73
# eps(estimate) : 0.68
# date : 2020-05-07T16:14:00.000Z EDT
#
#
# eps(actual)   : 0.66
# eps(estimate) : 0.63
# date : 2020-02-04T16:15:00.000Z EST
#
#
# eps(actual)   : 0.72
# eps(estimate) : 0.72
# date : 2019-11-05T16:10:00.000Z EST
#
#
# eps(actual)   : 1.41
# eps(estimate) : 1.37
# date : 2019-08-06T16:10:00.000Z EDT
#
#
# eps(actual)   : 1.48
# eps(estimate) : 1.4
# date : 2019-05-07T20:45:00.000Z EDT
#
#
# eps(actual)   : 1.66
# eps(estimate) : 1.58
# date : 2019-02-05T16:10:00.000Z EST
#
#
# eps(actual)   : 1.81
# eps(estimate) : 1.73
# date : 2018-11-07T18:16:00.000Z EST
#
#
# eps(actual)   : 1.61
# eps(estimate) : 1.48
# date : 2018-08-09T16:15:00.000Z EDT
#
#
# eps(actual)   : 1.4
# eps(estimate) : 1.34
# date : 2018-05-08T08:00:00.000Z EDT
#
#
# eps(actual)   : 1.36
# eps(estimate) : 1.35
# date : 2018-02-06T17:00:00.000Z EST
#
#
# eps(actual)   : 1.41
# eps(estimate) : 1.35
# date : 2017-11-06T16:00:00.000Z EST
#
#
# eps(actual)   : 1.31
# eps(estimate) : 1.23
# date : 2017-08-03T17:00:00.000Z EDT
#
#
# eps(actual)   : 1.16
# eps(estimate) : 1.06
# date : 2017-05-09T16:27:00.000Z EDT
#
#
# eps(actual)   : 1.05
# eps(estimate) : 0.86
# date : 2017-02-07T16:15:00.000Z EST
#
#
# eps(actual)   : 0.94
# eps(estimate) : 0.87
# date : 2016-11-07T16:00:00.000Z EST
#
#
# eps(actual)   : 0.84
# eps(estimate) : 0.75
# date : 2016-08-08T17:39:00.000Z EDT
#
#
# eps(actual)   : 0.7
# eps(estimate) : 0.68
# date : 2016-05-04T16:15:00.000Z EDT
#
#
# eps(actual)   : 0.64
# eps(estimate) : 0.62
# date : 2016-02-03T16:15:00.000Z EST
#
#
# eps(actual)   : 0.66
# eps(estimate) : 0.63
# date : 2015-11-04T16:15:00.000Z EST
#
#
# eps(actual)   : 0.69
# eps(estimate) : 0.71
# date : 2015-08-03T16:45:00.000Z EDT
#
#
# eps(actual)   : 0.68
# eps(estimate) : 0.67
# date : 2015-05-07T16:05:00.000Z EDT
#
#
# eps(actual)   : 0.64
# eps(estimate) : 0.62
# date : 2015-01-29T16:15:00.000Z EST
#
#
# eps(actual)   : 0.67
# eps(estimate) : 0.67
# date : 2014-10-30T16:15:00.000Z EDT
#
#
# eps(actual)   : 0.68
# eps(estimate) : 0.66
# date : 2014-07-31T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.64
# eps(estimate) : 0.61
# date : 2014-05-06T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.61
# eps(estimate) : 0.6
# date : 2014-01-30T05:00:00.000Z EST
#
#
# eps(actual)   : 0.63
# eps(estimate) : 0.6
# date : 2013-10-30T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.57
# eps(estimate) : 0.54
# date : 2013-07-31T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.52
# eps(estimate) : 0.47
# date : 2013-05-02T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.41
# eps(estimate) : 0.37
# date : 2013-02-07T05:00:00.000Z EST
#
#
# eps(actual)   : 0.48
# eps(estimate) : 0.48
# date : 2012-11-08T05:00:00.000Z EST
#
#
# eps(actual)   : 0.48
# eps(estimate) : 0.48
# date : 2012-08-02T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.46
# eps(estimate) : 0.45
# date : 2012-05-01T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.42
# eps(estimate) : 0.42
# date : 2012-02-02T05:00:00.000Z EST
#
#
# eps(actual)   : 0.46
# eps(estimate) : 0.46
# date : 2011-11-03T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.55
# eps(estimate) : 0.54
# date : 2011-08-04T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.59
# eps(estimate) : 0.57
# date : 2011-05-05T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.58
# eps(estimate) : 0.57
# date : 2011-01-27T05:00:00.000Z EST
#
#
# eps(actual)   : 0.63
# eps(estimate) : 0.58
# date : 2010-11-04T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.58
# eps(estimate) : 0.51
# date : 2010-08-05T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.4
# eps(estimate) : 0.37
# date : 2010-05-05T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.37
# eps(estimate) : 0.29
# date : 2010-02-03T05:00:00.000Z EST
#
#
# eps(actual)   : 0.24
# eps(estimate) : 0.21
# date : 2009-11-04T05:00:00.000Z EST
#
#
# eps(actual)   : 0.15
# eps(estimate) : 0.13
# date : 2009-08-06T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.11
# eps(estimate) : 0.11
# date : 2009-05-07T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.19
# eps(estimate) : 0.22
# date : 2009-01-29T05:00:00.000Z EST
#
#
# eps(actual)   : 0.41
# eps(estimate) : 0.41
# date : 2008-10-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.4
# eps(estimate) : 0.4
# date : 2008-07-24T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.38
# eps(estimate) : 0.37
# date : 2008-04-28T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.35
# eps(estimate) : 0.35
# date : 2008-01-24T05:00:00.000Z EST
#
#
# eps(actual)   : 0.35
# eps(estimate) : 0.35
# date : 2007-10-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.36
# eps(estimate) : 0.36
# date : 2007-07-26T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.34
# eps(estimate) : 0.33
# date : 2007-04-26T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.33
# eps(estimate) : 0.33
# date : 2007-01-31T05:00:00.000Z EST
#
#
# eps(actual)   : 0.36
# eps(estimate) : 0.36
# date : 2006-10-25T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.35
# eps(estimate) : 0.36
# date : 2006-07-20T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.35
# eps(estimate) : 0.35
# date : 2006-04-25T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.33
# eps(estimate) : 0.32
# date : 2006-01-19T05:00:00.000Z EST
#
#
# eps(actual)   : 0.31
# eps(estimate) : 0.3
# date : 2005-10-20T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.29
# eps(estimate) : 0.28
# date : 2005-07-26T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.27
# eps(estimate) : 0.25
# date : 2005-04-27T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.25
# eps(estimate) : 0.25
# date : 2005-01-25T05:00:00.000Z EST
#
#
# eps(actual)   : 0.29
# eps(estimate) : 0.29
# date : 2004-10-21T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.27
# eps(estimate) : 0.26
# date : 2004-07-20T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.22
# eps(estimate) : 0.2
# date : 2004-04-22T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.19
# eps(estimate) : 0.19
# date : 2004-01-22T05:00:00.000Z EST
#
#
# eps(actual)   : 0.17
# eps(estimate) : 0.17
# date : 2003-10-16T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.16
# eps(estimate) : 0.15
# date : 2003-07-17T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.16
# eps(estimate) : 0.16
# date : 2003-04-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.18
# eps(estimate) : 0.17
# date : 2003-01-23T05:00:00.000Z EST
#
#
# eps(actual)   : 0.17
# eps(estimate) : 0.17
# date : 2002-10-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.15
# eps(estimate) : 0.15
# date : 2002-07-17T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.13
# eps(estimate) : 0.13
# date : 2002-04-25T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.11
# eps(estimate) : 0.11
# date : 2002-01-22T05:00:00.000Z EST
#
#
# eps(actual)   : 0.11
# eps(estimate) : 0.11
# date : 2001-10-24T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.11
# eps(estimate) : 0.1
# date : 2001-07-20T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.13
# eps(estimate) : 0.15
# date : 2001-04-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.23
# eps(estimate) : 0.22
# date : 2001-01-25T05:00:00.000Z EST
#
#
# eps(actual)   : 0.22
# eps(estimate) : 0.18
# date : 2000-10-12T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.2
# eps(estimate) : 0.18
# date : 2000-07-13T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.11
# eps(estimate) : 0.16
# date : 2000-04-19T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.15
# eps(estimate) : 0.14
# date : 2000-01-13T05:00:00.000Z EST
#
#
# eps(actual)   : 0.13
# eps(estimate) : 0.12
# date : 1999-10-14T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.11
# eps(estimate) : 0.11
# date : 1999-07-15T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.11
# eps(estimate) : 0.1
# date : 1999-04-22T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.1
# eps(estimate) : 0.1
# date : 1999-01-14T05:00:00.000Z EST
#
#
# ------company abbreviation :  NXPI ------
# total data N :  55
#
#
# eps(actual)   : None
# eps(estimate) : None
# date : 2023-07-24T20:00:00.000Z EDT
#
#
# eps(actual)   : None
# eps(estimate) : None
# date : 2023-05-01T10:59:00.000Z EDT
#
#
# eps(actual)   : None
# eps(estimate) : None
# date : 2023-01-31T10:59:00.000Z EST
#
#
# eps(actual)   : None
# eps(estimate) : None
# date : 2023-01-30T21:00:00.000Z EST
#
#
# eps(actual)   : None
# eps(estimate) : 3.65
# date : 2022-11-01T10:59:00.000Z EDT
#
#
# eps(actual)   : None
# eps(estimate) : 3.65
# date : 2022-10-31T15:00:00.000Z EDT
#
#
# eps(actual)   : 3.52
# eps(estimate) : 3.35
# date : 2022-07-26T12:00:00.000Z EDT
#
#
# eps(actual)   : 3.52
# eps(estimate) : 3.36
# date : 2022-07-25T16:01:00.000Z EDT
#
#
# eps(actual)   : 3.34
# eps(estimate) : 3.17
# date : 2022-05-02T16:10:00.000Z EDT
#
#
# eps(actual)   : 3.2
# eps(estimate) : 2.99
# date : 2022-01-31T16:13:00.000Z EST
#
#
# eps(actual)   : 2.84
# eps(estimate) : 2.72
# date : 2021-11-01T16:07:00.000Z EDT
#
#
# eps(actual)   : 2.44
# eps(estimate) : 2.31
# date : 2021-08-02T16:07:00.000Z EDT
#
#
# eps(actual)   : 2.31
# eps(estimate) : 2.21
# date : 2021-04-26T18:01:00.000Z EDT
#
#
# eps(actual)   : 2.22
# eps(estimate) : 2.1
# date : 2021-02-01T16:01:00.000Z EST
#
#
# eps(actual)   : 1.62
# eps(estimate) : 1.54
# date : 2020-10-26T17:00:00.000Z EDT
#
#
# eps(actual)   : 0.94
# eps(estimate) : 0.85
# date : 2020-07-27T17:00:00.000Z EDT
#
#
# eps(actual)   : 1.38
# eps(estimate) : 1.38
# date : 2020-04-27T17:00:00.000Z EDT
#
#
# eps(actual)   : 1.99
# eps(estimate) : 2.02
# date : 2020-02-03T17:00:00.000Z EST
#
#
# eps(actual)   : 2.02
# eps(estimate) : 1.93
# date : 2019-10-28T17:00:00.000Z EDT
#
#
# eps(actual)   : 1.91
# eps(estimate) : 1.78
# date : 2019-07-29T20:00:00.000Z EDT
#
#
# eps(actual)   : 1.66
# eps(estimate) : 1.55
# date : 2019-04-29T20:00:00.000Z EDT
#
#
# eps(actual)   : 2.13
# eps(estimate) : 2.08
# date : 2019-02-06T20:00:00.000Z EST
#
#
# eps(actual)   : 2.01
# eps(estimate) : 1.9
# date : 2018-10-31T20:00:00.000Z EDT
#
#
# eps(actual)   : 1.5
# eps(estimate) : 1.65
# date : 2018-07-26T05:06:00.000Z EDT
#
#
# eps(actual)   : 1.55
# eps(estimate) : 1.61
# date : 2018-05-03T06:32:00.000Z EDT
#
#
# eps(actual)   : 1.96
# eps(estimate) : 1.8
# date : 2018-02-07T20:00:00.000Z EST
#
#
# eps(actual)   : 1.85
# eps(estimate) : 1.69
# date : 2017-10-25T20:00:00.000Z EDT
#
#
# eps(actual)   : 1.51
# eps(estimate) : 1.52
# date : 2017-08-02T20:00:00.000Z EDT
#
#
# eps(actual)   : 1.4
# eps(estimate) : 1.35
# date : 2017-05-03T20:01:00.000Z EDT
#
#
# eps(actual)   : 1.75
# eps(estimate) : 1.65
# date : 2017-02-01T20:01:00.000Z EST
#
#
# eps(actual)   : 1.65
# eps(estimate) : 1.6
# date : 2016-10-26T20:00:00.000Z EDT
#
#
# eps(actual)   : 1.39
# eps(estimate) : 1.35
# date : 2016-07-27T20:01:00.000Z EDT
#
#
# eps(actual)   : 1.14
# eps(estimate) : 1.09
# date : 2016-04-25T20:02:00.000Z EDT
#
#
# eps(actual)   : 1.25
# eps(estimate) : 1.07
# date : 2016-02-03T20:00:00.000Z EST
#
#
# eps(actual)   : 1.57
# eps(estimate) : 1.5
# date : 2015-10-28T20:00:00.000Z EDT
#
#
# eps(actual)   : 1.44
# eps(estimate) : 1.38
# date : 2015-07-29T20:00:00.000Z EDT
#
#
# eps(actual)   : 1.35
# eps(estimate) : 1.3
# date : 2015-04-29T20:00:00.000Z EDT
#
#
# eps(actual)   : 1.35
# eps(estimate) : 1.32
# date : 2015-02-04T20:04:00.000Z EST
#
#
# eps(actual)   : 1.35
# eps(estimate) : 1.3
# date : 2014-10-22T20:00:00.000Z EDT
#
#
# eps(actual)   : 1.09
# eps(estimate) : 1.05
# date : 2014-07-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.98
# eps(estimate) : 0.91
# date : 2014-04-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.99
# eps(estimate) : 0.95
# date : 2014-02-05T05:00:00.000Z EST
#
#
# eps(actual)   : 0.85
# eps(estimate) : 0.82
# date : 2013-10-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.71
# eps(estimate) : 0.66
# date : 2013-07-31T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.66
# eps(estimate) : 0.49
# date : 2013-04-22T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.5
# eps(estimate) : 0.47
# date : 2013-01-30T05:00:00.000Z EST
#
#
# eps(actual)   : 0.56
# eps(estimate) : 0.56
# date : 2012-10-24T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.45
# eps(estimate) : 0.4
# date : 2012-07-24T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.19
# eps(estimate) : 0.18
# date : 2012-04-26T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.24
# eps(estimate) : 0.24
# date : 2012-02-09T05:00:00.000Z EST
#
#
# eps(actual)   : 0.5
# eps(estimate) : 0.51
# date : 2011-11-01T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.51
# eps(estimate) : 0.52
# date : 2011-07-28T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.46
# eps(estimate) : 0.42
# date : 2011-05-04T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.37
# eps(estimate) : 0.47
# date : 2011-02-15T05:00:00.000Z EST
#
#
# eps(actual)   : 0.49
# eps(estimate) : 0.46
# date : 2010-11-02T04:00:00.000Z EDT
#
#
# ------company abbreviation :  LRCX ------
# total data N :  100
#
#
# eps(actual)   : None
# eps(estimate) : None
# date : 2023-07-25T10:59:00.000Z EDT
#
#
# eps(actual)   : None
# eps(estimate) : None
# date : 2023-04-18T10:59:00.000Z EDT
#
#
# eps(actual)   : None
# eps(estimate) : None
# date : 2023-01-24T10:59:00.000Z EST
#
#
# eps(actual)   : None
# eps(estimate) : 9.53
# date : 2022-10-19T21:00:00.000Z EDT
#
#
# eps(actual)   : None
# eps(estimate) : 9.53
# date : 2022-10-19T20:00:00.000Z EDT
#
#
# eps(actual)   : 8.83
# eps(estimate) : 7.32
# date : 2022-07-27T16:05:00.000Z EDT
#
#
# eps(actual)   : 7.4
# eps(estimate) : 7.51
# date : 2022-04-20T16:05:00.000Z EDT
#
#
# eps(actual)   : 8.53
# eps(estimate) : 8.51
# date : 2022-01-26T16:05:00.000Z EST
#
#
# eps(actual)   : 8.36
# eps(estimate) : 8.21
# date : 2021-10-20T16:05:00.000Z EDT
#
#
# eps(actual)   : 8.09
# eps(estimate) : 7.55
# date : 2021-07-28T16:05:00.000Z EDT
#
#
# eps(actual)   : 7.49
# eps(estimate) : 6.62
# date : 2021-04-21T16:05:00.000Z EDT
#
#
# eps(actual)   : 6.03
# eps(estimate) : 5.73
# date : 2021-01-27T16:05:00.000Z EST
#
#
# eps(actual)   : 5.67
# eps(estimate) : 5.2
# date : 2020-10-21T16:05:00.000Z EDT
#
#
# eps(actual)   : 4.78
# eps(estimate) : 4.05
# date : 2020-07-29T16:05:00.000Z EDT
#
#
# eps(actual)   : 3.98
# eps(estimate) : 3.98
# date : 2020-04-22T16:12:00.000Z EDT
#
#
# eps(actual)   : 4.01
# eps(estimate) : 3.85
# date : 2020-01-29T16:05:00.000Z EST
#
#
# eps(actual)   : 3.18
# eps(estimate) : 3.01
# date : 2019-10-23T16:05:00.000Z EDT
#
#
# eps(actual)   : 3.62
# eps(estimate) : 3.42
# date : 2019-07-31T16:05:00.000Z EDT
#
#
# eps(actual)   : 3.7
# eps(estimate) : 3.38
# date : 2019-04-24T16:05:00.000Z EDT
#
#
# eps(actual)   : 3.87
# eps(estimate) : 3.66
# date : 2019-01-23T16:05:00.000Z EST
#
#
# eps(actual)   : 3.36
# eps(estimate) : 3.22
# date : 2018-10-16T16:05:00.000Z EDT
#
#
# eps(actual)   : 5.31
# eps(estimate) : 4.94
# date : 2018-07-26T16:31:00.000Z EDT
#
#
# eps(actual)   : 4.79
# eps(estimate) : 4.38
# date : 2018-04-17T16:30:00.000Z EDT
#
#
# eps(actual)   : 4.34
# eps(estimate) : 3.68
# date : 2018-01-24T16:08:00.000Z EST
#
#
# eps(actual)   : 3.46
# eps(estimate) : 3.28
# date : 2017-10-17T16:05:00.000Z EDT
#
#
# eps(actual)   : 3.11
# eps(estimate) : 3.03
# date : 2017-07-26T16:05:00.000Z EDT
#
#
# eps(actual)   : 2.8
# eps(estimate) : 2.55
# date : 2017-04-18T16:03:00.000Z EDT
#
#
# eps(actual)   : 2.24
# eps(estimate) : 2.19
# date : 2017-01-25T16:00:00.000Z EST
#
#
# eps(actual)   : 1.81
# eps(estimate) : 1.78
# date : 2016-10-19T16:05:00.000Z EDT
#
#
# eps(actual)   : 1.8
# eps(estimate) : 1.64
# date : 2016-07-27T16:05:00.000Z EDT
#
#
# eps(actual)   : 1.18
# eps(estimate) : 1.1
# date : 2016-04-20T16:05:00.000Z EDT
#
#
# eps(actual)   : 1.57
# eps(estimate) : 1.43
# date : 2016-01-27T16:05:00.000Z EST
#
#
# eps(actual)   : 1.82
# eps(estimate) : 1.71
# date : 2015-10-21T04:00:00.000Z EDT
#
#
# eps(actual)   : 1.5
# eps(estimate) : 1.47
# date : 2015-07-29T16:05:00.000Z EDT
#
#
# eps(actual)   : 1.4
# eps(estimate) : 1.3
# date : 2015-04-20T16:05:00.000Z EDT
#
#
# eps(actual)   : 1.19
# eps(estimate) : 1.13
# date : 2015-01-28T16:05:00.000Z EST
#
#
# eps(actual)   : 0.96
# eps(estimate) : 0.93
# date : 2014-10-22T16:05:00.000Z EDT
#
#
# eps(actual)   : 1.25
# eps(estimate) : 1.23
# date : 2014-07-30T04:00:00.000Z EDT
#
#
# eps(actual)   : 1.26
# eps(estimate) : 1.17
# date : 2014-04-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 1.1
# eps(estimate) : 1.03
# date : 2014-01-29T05:00:00.000Z EST
#
#
# eps(actual)   : 0.81
# eps(estimate) : 0.71
# date : 2013-10-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.8
# eps(estimate) : 0.71
# date : 2013-07-31T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.44
# eps(estimate) : 0.37
# date : 2013-04-24T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.45
# eps(estimate) : 0.44
# date : 2013-01-23T05:00:00.000Z EST
#
#
# eps(actual)   : 0.53
# eps(estimate) : 0.41
# date : 2012-10-17T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.6
# eps(estimate) : 0.64
# date : 2012-07-25T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.5
# eps(estimate) : 0.46
# date : 2012-04-18T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.34
# eps(estimate) : 0.3
# date : 2012-01-25T05:00:00.000Z EST
#
#
# eps(actual)   : 0.63
# eps(estimate) : 0.65
# date : 2011-10-19T04:00:00.000Z EDT
#
#
# eps(actual)   : 1.14
# eps(estimate) : 1.09
# date : 2011-07-27T04:00:00.000Z EDT
#
#
# eps(actual)   : 1.45
# eps(estimate) : 1.36
# date : 2011-04-20T04:00:00.000Z EDT
#
#
# eps(actual)   : 1.74
# eps(estimate) : 1.57
# date : 2011-01-26T05:00:00.000Z EST
#
#
# eps(actual)   : 1.52
# eps(estimate) : 1.38
# date : 2010-10-20T04:00:00.000Z EDT
#
#
# eps(actual)   : 1.17
# eps(estimate) : 0.97
# date : 2010-07-28T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.94
# eps(estimate) : 0.82
# date : 2010-04-21T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.47
# eps(estimate) : 0.4
# date : 2010-01-27T05:00:00.000Z EST
#
#
# eps(actual)   : 0.03
# eps(estimate) : -0.08
# date : 2009-10-21T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.45
# eps(estimate) : -0.46
# date : 2009-07-29T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.71
# eps(estimate) : -0.66
# date : 2009-04-22T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.09
# eps(estimate) : -0.05
# date : 2009-01-28T05:00:00.000Z EST
#
#
# eps(actual)   : 0.26
# eps(estimate) : 0.25
# date : 2008-10-22T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.6
# eps(estimate) : 0.4
# date : 2008-07-29T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.87
# eps(estimate) : 0.94
# date : 2008-04-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 1.28
# eps(estimate) : 1.28
# date : 2008-03-31T04:00:00.000Z EDT
#
#
# eps(actual)   : 1.15
# eps(estimate) : 1.06
# date : 2007-04-12T04:00:00.000Z EDT
#
#
# eps(actual)   : 1.15
# eps(estimate) : 1.11
# date : 2007-01-17T05:00:00.000Z EST
#
#
# eps(actual)   : 1.13
# eps(estimate) : 1.03
# date : 2006-10-11T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.96
# eps(estimate) : 0.83
# date : 2006-07-19T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.65
# eps(estimate) : 0.62
# date : 2006-04-12T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.55
# eps(estimate) : 0.38
# date : 2006-01-18T05:00:00.000Z EST
#
#
# eps(actual)   : 0.35
# eps(estimate) : 0.3
# date : 2005-10-12T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.47
# eps(estimate) : 0.44
# date : 2005-07-20T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.44
# eps(estimate) : 0.43
# date : 2005-04-13T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.59
# eps(estimate) : 0.53
# date : 2005-01-20T05:00:00.000Z EST
#
#
# eps(actual)   : 0.64
# eps(estimate) : 0.58
# date : 2004-10-13T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.37
# eps(estimate) : 0.26
# date : 2004-07-21T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.14
# eps(estimate) : 0.1
# date : 2004-04-14T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.07
# eps(estimate) : 0.05
# date : 2004-01-21T05:00:00.000Z EST
#
#
# eps(actual)   : 0.04
# eps(estimate) : 0.03
# date : 2003-10-15T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.02
# eps(estimate) : 0.02
# date : 2003-07-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.03
# eps(estimate) : 0
# date : 2003-04-16T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.02
# eps(estimate) : 0
# date : 2003-01-22T05:00:00.000Z EST
#
#
# eps(actual)   : 0.02
# eps(estimate) : 0
# date : 2002-10-17T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.06
# eps(estimate) : -0.07
# date : 2002-07-23T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.12
# eps(estimate) : -0.17
# date : 2002-04-17T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.03
# eps(estimate) : 0
# date : 2002-01-24T05:00:00.000Z EST
#
#
# eps(actual)   : 0.21
# eps(estimate) : 0.15
# date : 2001-10-09T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.28
# eps(estimate) : 0.14
# date : 2001-07-25T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.33
# eps(estimate) : 0.37
# date : 2001-04-11T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.58
# eps(estimate) : 0.52
# date : 2001-01-23T05:00:00.000Z EST
#
#
# eps(actual)   : 0.48
# eps(estimate) : 0.43
# date : 2000-10-12T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.45
# eps(estimate) : 0.43
# ...
#
#
# eps(actual)   : 0
# eps(estimate) : 0
# date : 2000-08-24T04:00:00.000Z EDT
#
#
# ------company abbreviation :  MU ------
# total data N :  100
#
#
# eps(actual)   : None
# eps(estimate) : None
# date : 2023-09-27T10:59:00.000Z EDT
#
#
# eps(actual)   : None
# eps(estimate) : None
# date : 2023-06-28T10:59:00.000Z EDT
#
#
# eps(actual)   : None
# eps(estimate) : None
# date : 2023-03-27T10:59:00.000Z EDT
#
#
# eps(actual)   : None
# eps(estimate) : 0.04
# date : 2022-12-21T21:30:00.000Z EST
#
#
# eps(actual)   : None
# eps(estimate) : 0.04
# date : 2022-12-21T21:00:00.000Z EST
#
#
# eps(actual)   : 1.45
# eps(estimate) : 1.3
# date : 2022-09-29T16:02:00.000Z EDT
#
#
# eps(actual)   : 2.59
# eps(estimate) : 2.43
# date : 2022-06-30T16:01:00.000Z EDT
#
#
# eps(actual)   : 2.14
# eps(estimate) : 1.97
# date : 2022-03-29T16:06:00.000Z EDT
#
#
# eps(actual)   : 2.16
# eps(estimate) : 2.11
# date : 2021-12-20T16:02:00.000Z EST
#
#
# eps(actual)   : 2.42
# eps(estimate) : 2.33
# date : 2021-09-28T16:01:00.000Z EDT
#
#
# eps(actual)   : 1.88
# eps(estimate) : 1.72
# date : 2021-06-30T16:08:00.000Z EDT
#
#
# eps(actual)   : 0.98
# eps(estimate) : 0.95
# date : 2021-03-31T16:05:00.000Z EDT
#
#
# eps(actual)   : 0.78
# eps(estimate) : 0.71
# date : 2021-01-07T16:03:00.000Z EST
#
#
# eps(actual)   : 1.08
# eps(estimate) : 0.99
# date : 2020-09-29T16:04:00.000Z EDT
#
#
# eps(actual)   : 0.82
# eps(estimate) : 0.78
# date : 2020-06-29T16:01:00.000Z EDT
#
#
# eps(actual)   : 0.45
# eps(estimate) : 0.37
# date : 2020-03-25T16:01:00.000Z EDT
#
#
# eps(actual)   : 0.48
# eps(estimate) : 0.47
# date : 2019-12-18T16:01:00.000Z EST
#
#
# eps(actual)   : 0.56
# eps(estimate) : 0.49
# date : 2019-09-26T16:01:00.000Z EDT
#
#
# eps(actual)   : 1.05
# eps(estimate) : 0.79
# date : 2019-06-25T16:05:00.000Z EDT
#
#
# eps(actual)   : 1.71
# eps(estimate) : 1.67
# date : 2019-03-20T16:01:00.000Z EDT
#
#
# eps(actual)   : 2.97
# eps(estimate) : 2.96
# date : 2018-12-18T16:01:00.000Z EST
#
#
# eps(actual)   : 3.53
# eps(estimate) : 3.34
# date : 2018-09-20T16:01:00.000Z EDT
#
#
# eps(actual)   : 3.15
# eps(estimate) : 3.14
# date : 2018-06-20T16:01:00.000Z EDT
#
#
# eps(actual)   : 2.82
# eps(estimate) : 2.73
# date : 2018-03-22T16:00:00.000Z EDT
#
#
# eps(actual)   : 2.45
# eps(estimate) : 2.21
# date : 2017-12-19T16:00:00.000Z EST
#
#
# eps(actual)   : 2.02
# eps(estimate) : 1.84
# date : 2017-09-26T16:00:00.000Z EDT
#
#
# eps(actual)   : 1.62
# eps(estimate) : 1.51
# date : 2017-06-29T16:00:00.000Z EDT
#
#
# eps(actual)   : 0.9
# eps(estimate) : 0.86
# date : 2017-03-23T16:04:00.000Z EDT
#
#
# eps(actual)   : 0.32
# eps(estimate) : 0.28
# date : 2016-12-21T16:05:00.000Z EST
#
#
# eps(actual)   : -0.05
# eps(estimate) : -0.12
# date : 2016-10-04T16:03:00.000Z EDT
#
#
# eps(actual)   : -0.08
# eps(estimate) : -0.09
# date : 2016-06-30T16:07:00.000Z EDT
#
#
# eps(actual)   : -0.05
# eps(estimate) : -0.08
# date : 2016-03-30T16:04:00.000Z EDT
#
#
# eps(actual)   : 0.24
# eps(estimate) : 0.23
# date : 2015-12-22T16:03:00.000Z EST
#
#
# eps(actual)   : 0.37
# eps(estimate) : 0.32
# date : 2015-10-01T16:03:00.000Z EDT
#
#
# eps(actual)   : 0.54
# eps(estimate) : 0.56
# date : 2015-06-25T16:03:00.000Z EDT
#
#
# eps(actual)   : 0.81
# eps(estimate) : 0.73
# date : 2015-04-01T16:02:00.000Z EDT
#
#
# eps(actual)   : 0.97
# eps(estimate) : 0.92
# date : 2015-01-06T16:01:00.000Z EST
#
#
# eps(actual)   : 0.82
# eps(estimate) : 0.81
# date : 2014-09-25T16:01:00.000Z EDT
#
#
# eps(actual)   : 0.79
# eps(estimate) : 0.7
# date : 2014-06-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.85
# eps(estimate) : 0.76
# date : 2014-04-03T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.72
# eps(estimate) : 0.43
# date : 2014-01-07T05:00:00.000Z EST
#
#
# eps(actual)   : 0.2
# eps(estimate) : 0.25
# date : 2013-10-10T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.04
# eps(estimate) : 0.02
# date : 2013-06-19T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.28
# eps(estimate) : -0.19
# date : 2013-03-21T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.27
# eps(estimate) : -0.2
# date : 2012-12-20T05:00:00.000Z EST
#
#
# eps(actual)   : -0.24
# eps(estimate) : -0.23
# date : 2012-09-27T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.32
# eps(estimate) : -0.2
# date : 2012-06-20T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.29
# eps(estimate) : -0.19
# date : 2012-03-22T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.19
# eps(estimate) : -0.08
# date : 2011-12-21T05:00:00.000Z EST
#
#
# eps(actual)   : -0.14
# eps(estimate) : 0.01
# date : 2011-09-29T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.07
# eps(estimate) : 0.16
# date : 2011-06-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.07
# eps(estimate) : 0.02
# date : 2011-03-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.15
# eps(estimate) : 0.28
# date : 2010-12-22T05:00:00.000Z EST
#
#
# eps(actual)   : 0.32
# eps(estimate) : 0.38
# date : 2010-10-07T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.45
# eps(estimate) : 0.43
# date : 2010-06-28T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.39
# eps(estimate) : 0.24
# date : 2010-03-31T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.23
# eps(estimate) : 0.07
# date : 2009-12-22T05:00:00.000Z EST
#
#
# eps(actual)   : -0.09
# eps(estimate) : -0.18
# date : 2009-09-29T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.57
# eps(estimate) : -0.43
# date : 2009-06-25T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.82
# eps(estimate) : -0.64
# date : 2009-04-02T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.72
# eps(estimate) : -0.45
# date : 2008-12-23T05:00:00.000Z EST
#
#
# eps(actual)   : -0.27
# eps(estimate) : -0.24
# date : 2008-10-01T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.3
# eps(estimate) : -0.28
# date : 2008-06-26T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.41
# eps(estimate) : -0.36
# date : 2008-04-02T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.34
# eps(estimate) : -0.2
# date : 2007-12-20T05:00:00.000Z EST
#
#
# eps(actual)   : -0.21
# eps(estimate) : -0.22
# date : 2007-10-02T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.29
# eps(estimate) : -0.24
# date : 2007-06-28T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.07
# eps(estimate) : -0.01
# date : 2007-04-04T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.15
# eps(estimate) : 0.2
# date : 2006-12-21T05:00:00.000Z EST
#
#
# eps(actual)   : 0.08
# eps(estimate) : 0.14
# date : 2006-10-05T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.12
# eps(estimate) : 0.09
# date : 2006-06-28T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.04
# eps(estimate) : 0.06
# date : 2006-04-10T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.09
# eps(estimate) : 0.11
# date : 2005-12-21T05:00:00.000Z EST
#
#
# eps(actual)   : 0.07
# eps(estimate) : -0.08
# date : 2005-09-29T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.2
# eps(estimate) : 0.02
# date : 2005-06-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.17
# eps(estimate) : 0.15
# date : 2005-03-29T05:00:00.000Z EST
#
#
# eps(actual)   : 0.23
# eps(estimate) : 0.22
# date : 2004-12-22T05:00:00.000Z EST
#
#
# eps(actual)   : 0.14
# eps(estimate) : 0.2
# date : 2004-09-29T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.13
# eps(estimate) : 0.09
# date : 2004-06-23T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.04
# eps(estimate) : -0.06
# date : 2004-03-24T05:00:00.000Z EST
#
#
# eps(actual)   : 0
# eps(estimate) : -0.06
# date : 2003-12-23T05:00:00.000Z EST
#
#
# eps(actual)   : -0.2
# eps(estimate) : -0.25
# date : 2003-09-24T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.36
# eps(estimate) : -0.52
# date : 2003-06-18T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.83
# eps(estimate) : -0.46
# date : 2003-03-20T05:00:00.000Z EST
#
#
# eps(actual)   : -0.52
# eps(estimate) : -0.23
# date : 2002-12-17T05:00:00.000Z EST
#
#
# eps(actual)   : -0.18
# eps(estimate) : -0.18
# date : 2002-09-24T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.04
# eps(estimate) : 0.06
# date : 2002-06-25T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.05
# eps(estimate) : -0.05
# date : 2002-03-21T05:00:00.000Z EST
#
#
# eps(actual)   : -0.44
# eps(estimate) : -0.39
# date : 2001-12-18T05:00:00.000Z EST
#
#
# eps(actual)   : -0.28
# eps(estimate) : -0.34
# date : 2001-09-25T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.23
# eps(estimate) : -0.15
# date : 2001-06-21T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.01
# eps(estimate) : -0.02
# date : 2001-03-29T05:00:00.000Z EST
#
#
# eps(actual)   : 0.58
# eps(estimate) : 0.58
# date : 2000-12-20T05:00:00.000Z EST
#
#
# eps(actual)   : 1.2
# eps(estimate) : 0.96
# date : 2000-10-04T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.47
# eps(estimate) : 0.35
# date : 2000-06-22T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.29
# eps(estimate) : 0.36
# date : 2000-03-21T05:00:00.000Z EST
#
#
# eps(actual)   : 0.6
# eps(estimate) : 0.4
# date : 1999-12-22T05:00:00.000Z EST
#
#
# eps(actual)   : -0.04
# eps(estimate) : -0.09
# date : 1999-10-04T04:00:00.000Z EDT
#
#
# eps(actual)   : -0.05
# eps(estimate) : 0.01
# date : 1999-06-23T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.04
# eps(estimate) : 0
# date : 1999-03-24T05:00:00.000Z EST
#
#
# ------company abbreviation :  TSM ------
# total data N :  97
#
#
# eps(actual)   : 1.79
# eps(estimate) : 1.41
# date : 2022-10-13T07:24:00.000Z EDT
#
#
# eps(actual)   : 1.55
# eps(estimate) : 1.51
# date : 2022-07-14T05:28:00.000Z EDT
#
#
# eps(actual)   : 1.39
# eps(estimate) : 1.33
# date : 2022-04-14T04:38:00.000Z EDT
#
#
# eps(actual)   : 1.15
# eps(estimate) : 1.14
# date : 2022-01-28T13:07:00.000Z EST
#
#
# eps(actual)   : 1.08
# eps(estimate) : 1.04
# date : 2021-10-14T03:20:00.000Z EDT
#
#
# eps(actual)   : 0.93
# eps(estimate) : 0.93
# date : 2021-07-15T05:15:00.000Z EDT
#
#
# eps(actual)   : 0.96
# eps(estimate) : 0.94
# date : 2021-04-15T09:10:00.000Z EDT
#
#
# eps(actual)   : 0.97
# eps(estimate) : 0.95
# date : 2021-01-14T23:57:00.000Z EST
#
#
# eps(actual)   : 0.9
# eps(estimate) : 0.77
# date : 2020-10-15T03:54:00.000Z EDT
#
#
# eps(actual)   : 0.78
# eps(estimate) : 0.77
# date : 2020-07-16T22:21:00.000Z EDT
#
#
# eps(actual)   : 0.75
# eps(estimate) : 0.73
# date : 2020-04-16T18:58:00.000Z EDT
#
#
# eps(actual)   : 0.73
# eps(estimate) : 0.73
# date : 2020-01-16T13:57:00.000Z EST
#
#
# eps(actual)   : 0.62
# eps(estimate) : 0.63
# date : 2019-11-08T17:10:00.000Z EST
#
#
# eps(actual)   : 0.41
# eps(estimate) : 0.41
# date : 2019-07-25T14:59:00.000Z EDT
#
#
# eps(actual)   : 0.39
# eps(estimate) : 0.38
# date : 2019-04-19T04:32:00.000Z EDT
#
#
# eps(actual)   : 0.63
# eps(estimate) : 0.63
# date : 2019-01-22T02:26:00.000Z EST
#
#
# eps(actual)   : 0.56
# eps(estimate) : 0.56
# date : 2018-10-18T06:31:00.000Z EDT
#
#
# eps(actual)   : 0.47
# eps(estimate) : 0.47
# date : 2018-07-20T04:01:00.000Z EDT
#
#
# eps(actual)   : 0.59
# eps(estimate) : 0.6
# date : 2018-04-19T04:47:00.000Z EDT
#
#
# eps(actual)   : 0.64
# eps(estimate) : 0.62
# date : 2018-01-18T03:45:00.000Z EST
#
#
# eps(actual)   : 0.57
# eps(estimate) : 0.57
# date : 2017-10-19T21:45:00.000Z EDT
#
#
# eps(actual)   : 0.43
# eps(estimate) : 0.42
# date : 2017-08-14T17:30:00.000Z EDT
#
#
# eps(actual)   : 0.54
# eps(estimate) : 0.54
# date : 2017-04-13T21:55:00.000Z EDT
#
#
# eps(actual)   : 0.61
# eps(estimate) : 0.59
# date : 2017-01-12T22:17:00.000Z EST
#
#
# eps(actual)   : 0.59
# eps(estimate) : 0.57
# date : 2016-10-13T17:40:00.000Z EDT
#
#
# eps(actual)   : 0.43
# eps(estimate) : 0.41
# date : 2016-07-14T21:54:00.000Z EDT
#
#
# eps(actual)   : 0.38
# eps(estimate) : 0.38
# date : 2016-04-19T22:06:00.000Z EDT
#
#
# eps(actual)   : 0.43
# eps(estimate) : 0.4
# date : 2016-01-14T17:01:00.000Z EST
#
#
# eps(actual)   : 0.46
# eps(estimate) : 0.45
# date : 2015-10-16T05:42:00.000Z EDT
#
#
# eps(actual)   : 0.5
# eps(estimate) : 0.47
# date : 2015-08-11T17:28:00.000Z EDT
#
#
# eps(actual)   : 0.48
# eps(estimate) : 0.48
# date : 2015-04-16T17:05:00.000Z EDT
#
#
# eps(actual)   : 0.5
# eps(estimate) : 0.49
# date : 2015-01-15T20:45:00.000Z EST
#
#
# eps(actual)   : 0.49
# eps(estimate) : 0.48
# date : 2014-10-16T11:44:00.000Z EDT
#
#
# eps(actual)   : 0.38
# eps(estimate) : 0.37
# date : 2014-07-16T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.31
# eps(estimate) : 0.3
# date : 2014-04-17T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.29
# eps(estimate) : 0.27
# date : 2014-01-16T05:00:00.000Z EST
#
#
# eps(actual)   : 0.34
# eps(estimate) : 0.33
# date : 2013-10-17T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.33
# eps(estimate) : 0.32
# date : 2013-07-18T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.26
# eps(estimate) : 0.25
# date : 2013-04-18T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.28
# eps(estimate) : 0.28
# date : 2013-01-17T05:00:00.000Z EST
#
#
# eps(actual)   : 0.32
# eps(estimate) : 0.31
# date : 2012-10-25T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.27
# eps(estimate) : 0.27
# date : 2012-07-19T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.22
# eps(estimate) : 0.19
# date : 2012-04-26T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.2
# eps(estimate) : 0.2
# date : 2012-01-18T05:00:00.000Z EST
#
#
# eps(actual)   : 0.2
# eps(estimate) : 0.2
# date : 2011-10-27T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.24
# eps(estimate) : 0.25
# date : 2011-07-28T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.24
# eps(estimate) : 0.24
# date : 2011-04-29T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.26
# eps(estimate) : 0.26
# date : 2011-02-03T05:00:00.000Z EST
#
#
# eps(actual)   : 0.28
# eps(estimate) : 0.24
# date : 2010-10-28T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.24
# eps(estimate) : 0.23
# date : 2010-07-30T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.2
# eps(estimate) : 0.19
# date : 2010-04-28T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.19
# eps(estimate) : 0.19
# date : 2010-01-28T05:00:00.000Z EST
#
#
# eps(actual)   : 0.18
# eps(estimate) : 0.18
# date : 2009-10-29T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.14
# eps(estimate) : 0.13
# date : 2009-07-30T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.01
# eps(estimate) : 0
# date : 2009-04-30T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.07
# eps(estimate) : 0.07
# date : 2009-01-22T05:00:00.000Z EST
#
#
# eps(actual)   : 0.19
# eps(estimate) : 0.2
# date : 2008-10-30T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.18
# eps(estimate) : 0.18
# date : 2008-07-31T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.17
# eps(estimate) : 0.16
# date : 2008-04-29T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.2
# eps(estimate) : 0.19
# date : 2008-01-31T05:00:00.000Z EST
#
#
# eps(actual)   : 0.17
# eps(estimate) : 0.18
# date : 2007-10-25T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.15
# eps(estimate) : 0.14
# date : 2007-07-26T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.11
# eps(estimate) : 0.11
# date : 2007-04-26T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.16
# eps(estimate) : 0.15
# date : 2007-01-25T05:00:00.000Z EST
#
#
# eps(actual)   : 0.19
# eps(estimate) : 0.19
# date : 2006-10-26T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.2
# eps(estimate) : 0.19
# date : 2006-07-27T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.19
# eps(estimate) : 0.17
# date : 2006-04-27T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.2
# eps(estimate) : 0.19
# date : 2006-01-26T05:00:00.000Z EST
#
#
# eps(actual)   : 0.14
# eps(estimate) : 0.14
# date : 2005-10-27T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.11
# eps(estimate) : 0.11
# date : 2005-07-26T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.1
# eps(estimate) : 0.1
# date : 2005-04-26T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.14
# eps(estimate) : 0.12
# date : 2005-01-27T05:00:00.000Z EST
#
#
# eps(actual)   : 0.16
# eps(estimate) : 0.14
# date : 2004-10-26T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.14
# eps(estimate) : 0.12
# date : 2004-07-29T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.11
# eps(estimate) : 0.1
# date : 2004-04-21T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.1
# eps(estimate) : 0.09
# date : 2004-01-29T05:00:00.000Z EST
#
#
# eps(actual)   : 0.09
# eps(estimate) : 0.08
# date : 2003-10-28T05:00:00.000Z EST
#
#
# eps(actual)   : 0.06
# eps(estimate) : 0.05
# date : 2003-07-24T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.02
# eps(estimate) : 0.01
# date : 2003-04-29T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.01
# eps(estimate) : 0.02
# date : 2003-01-28T05:00:00.000Z EST
#
#
# eps(actual)   : 0.01
# eps(estimate) : 0.04
# date : 2002-10-22T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.05
# eps(estimate) : 0.06
# date : 2002-07-25T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.04
# eps(estimate) : 0.04
# date : 2002-05-09T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.03
# eps(estimate) : 0.03
# date : 2002-01-28T05:00:00.000Z EST
#
#
# eps(actual)   : 0.01
# eps(estimate) : 0.01
# date : 2001-10-26T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.14
# eps(estimate) : 0.13
# date : 2001-03-30T05:00:00.000Z EST
#
#
# eps(actual)   : 0.13
# eps(estimate) : 0.12
# date : 2000-10-19T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.1
# eps(estimate) : 0.08
# date : 2000-07-31T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.08
# eps(estimate) : 0.07
# date : 2000-04-27T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.06
# eps(estimate) : 0.06
# date : 2000-01-27T05:00:00.000Z EST
#
#
# eps(actual)   : 0.05
# eps(estimate) : 0.05
# date : 1999-10-25T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.05
# eps(estimate) : 0.04
# date : 1999-09-10T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.04
# eps(estimate) : 0.02
# date : 1999-04-21T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.03
# eps(estimate) : 0.02
# date : 1999-01-27T05:00:00.000Z EST
#
#
# eps(actual)   : 0.03
# eps(estimate) : 0.03
# date : 1999-01-11T05:00:00.000Z EST
#
#
# eps(actual)   : 0.04
# eps(estimate) : 0.04
# date : 1998-04-27T04:00:00.000Z EDT
#
#
# eps(actual)   : 0.04
# eps(estimate) : 0.03
# date : 1998-03-11T05:00:00.000Z EST

# %% [markdown]
# ## V.Create and store earnings history of multiple companies

# %% [markdown]
# ### - checking

# %%
MSFT_per_his = si.get_earnings_history('MSFT')

# %%
MSFT_per_his
# Out:
# [{'companyshortname': 'Microsoft Corp',
#   'epsactual': None,
#   'epsestimate': None,
#   'epssurprisepct': None,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2023-04-24T10:59:00.000Z',
#   'startdatetimetype': 'TNS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corp',
#   'epsactual': None,
#   'epsestimate': None,
#   'epssurprisepct': None,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2023-01-23T10:59:00.000Z',
#   'startdatetimetype': 'TNS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corp',
#   'epsactual': None,
#   'epsestimate': None,
#   'epssurprisepct': None,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2022-10-24T10:59:00.000Z',
#   'startdatetimetype': 'TNS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corp',
#   'epsactual': None,
#   'epsestimate': 2.33,
#   'epssurprisepct': None,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2022-07-25T10:59:00.000Z',
#   'startdatetimetype': 'TNS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 2.22,
#   'epsestimate': 2.19,
#   'epssurprisepct': 1.6,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2022-04-26T16:04:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 2.48,
#   'epsestimate': 2.31,
#   'epssurprisepct': 7.27,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2022-01-25T16:04:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 2.27,
#   'epsestimate': 2.08,
#   'epssurprisepct': 9.4,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2021-10-26T16:05:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 2.17,
#   'epsestimate': 1.92,
#   'epssurprisepct': 13.26,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2021-07-27T16:02:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 2.03,
#   'epsestimate': 1.78,
#   'epssurprisepct': 14.11,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2021-04-27T16:03:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 2.03,
#   'epsestimate': 1.64,
#   'epssurprisepct': 23.63,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2021-01-26T16:04:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 1.82,
#   'epsestimate': 1.54,
#   'epssurprisepct': 17.88,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2020-10-27T16:13:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 1.46,
#   'epsestimate': 1.34,
#   'epssurprisepct': 8.71,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2020-07-22T16:03:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 1.4,
#   'epsestimate': 1.26,
#   'epssurprisepct': 10.67,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2020-04-29T16:03:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 1.51,
#   'epsestimate': 1.32,
#   'epssurprisepct': 14.48,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2020-01-29T16:05:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 1.38,
#   'epsestimate': 1.25,
#   'epssurprisepct': 10.84,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2019-10-23T16:08:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 1.37,
#   'epsestimate': 1.21,
#   'epssurprisepct': 12.94,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2019-07-18T16:07:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 1.14,
#   'epsestimate': 1,
#   'epssurprisepct': 14.11,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2019-04-24T16:07:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 1.1,
#   'epsestimate': 1.09,
#   'epssurprisepct': 0.73,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2019-01-30T16:06:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 1.14,
#   'epsestimate': 0.96,
#   'epssurprisepct': 18.38,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2018-10-24T16:07:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 1.13,
#   'epsestimate': 1.08,
#   'epssurprisepct': 5.02,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2018-07-19T16:05:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.95,
#   'epsestimate': 0.85,
#   'epssurprisepct': 11.9,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2018-04-26T16:04:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.96,
#   'epsestimate': 0.87,
#   'epssurprisepct': 10.98,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2018-01-31T16:05:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.84,
#   'epsestimate': 0.72,
#   'epssurprisepct': 16.5,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2017-10-26T16:02:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.98,
#   'epsestimate': 0.71,
#   'epssurprisepct': 39.01,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2017-07-20T16:06:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.73,
#   'epsestimate': 0.7,
#   'epssurprisepct': 4.73,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2017-04-27T16:05:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.83,
#   'epsestimate': 0.79,
#   'epssurprisepct': 4.93,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2017-01-26T16:09:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.76,
#   'epsestimate': 0.68,
#   'epssurprisepct': 11.27,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2016-10-20T16:05:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.69,
#   'epsestimate': 0.58,
#   'epssurprisepct': 18.76,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2016-07-19T16:05:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.62,
#   'epsestimate': 0.64,
#   'epssurprisepct': -2.67,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2016-04-21T16:05:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.78,
#   'epsestimate': 0.71,
#   'epssurprisepct': 9.4,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2016-01-28T16:06:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.67,
#   'epsestimate': 0.59,
#   'epssurprisepct': 14.33,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2015-10-22T16:05:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.6,
#   'epsestimate': 0.56,
#   'epssurprisepct': 6.57,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2015-07-21T16:05:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.61,
#   'epsestimate': 0.51,
#   'epssurprisepct': 20.55,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2015-04-23T16:02:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.71,
#   'epsestimate': 0.71,
#   'epssurprisepct': -0.42,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2015-01-26T16:10:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.54,
#   'epsestimate': 0.49,
#   'epssurprisepct': 11.11,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2014-10-23T16:02:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.55,
#   'epsestimate': 0.6,
#   'epssurprisepct': -8.65,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2014-07-22T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.68,
#   'epsestimate': 0.63,
#   'epssurprisepct': 8.02,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2014-04-24T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.78,
#   'epsestimate': 0.68,
#   'epssurprisepct': 14.83,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2014-01-23T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.62,
#   'epsestimate': 0.54,
#   'epssurprisepct': 15.1,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2013-10-24T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.66,
#   'epsestimate': 0.75,
#   'epssurprisepct': -11.96,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2013-07-18T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.72,
#   'epsestimate': 0.68,
#   'epssurprisepct': 5.97,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2013-04-18T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.76,
#   'epsestimate': 0.75,
#   'epssurprisepct': 1.93,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2013-01-24T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.53,
#   'epsestimate': 0.56,
#   'epssurprisepct': -5.47,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2012-10-18T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.67,
#   'epsestimate': 0.62,
#   'epssurprisepct': 8.48,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2012-07-19T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.6,
#   'epsestimate': 0.57,
#   'epssurprisepct': 4.38,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2012-04-19T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.78,
#   'epsestimate': 0.76,
#   'epssurprisepct': 2.93,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2012-01-19T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.68,
#   'epsestimate': 0.68,
#   'epssurprisepct': 0.38,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2011-10-20T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.69,
#   'epsestimate': 0.58,
#   'epssurprisepct': 19.88,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2011-07-21T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.61,
#   'epsestimate': 0.56,
#   'epssurprisepct': 9.74,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2011-04-28T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.77,
#   'epsestimate': 0.68,
#   'epssurprisepct': 12.57,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2011-01-27T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.62,
#   'epsestimate': 0.55,
#   'epssurprisepct': 12.98,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2010-10-28T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.51,
#   'epsestimate': 0.46,
#   'epssurprisepct': 9.82,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2010-07-22T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.45,
#   'epsestimate': 0.42,
#   'epssurprisepct': 6.95,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2010-04-22T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.74,
#   'epsestimate': 0.59,
#   'epssurprisepct': 24.79,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2010-01-28T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.4,
#   'epsestimate': 0.32,
#   'epssurprisepct': 25.76,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2009-10-23T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.36,
#   'epsestimate': 0.36,
#   'epssurprisepct': 0.22,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2009-07-23T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.39,
#   'epsestimate': 0.39,
#   'epssurprisepct': 0.26,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2009-04-23T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.47,
#   'epsestimate': 0.49,
#   'epssurprisepct': -4.84,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2009-01-22T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.48,
#   'epsestimate': 0.47,
#   'epssurprisepct': 1.84,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2008-10-23T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.46,
#   'epsestimate': 0.47,
#   'epssurprisepct': -2.13,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2008-07-17T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.47,
#   'epsestimate': 0.44,
#   'epssurprisepct': 6.74,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2008-04-24T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.5,
#   'epsestimate': 0.46,
#   'epssurprisepct': 9.33,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2008-01-24T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.45,
#   'epsestimate': 0.39,
#   'epssurprisepct': 15.38,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2007-10-25T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.39,
#   'epsestimate': 0.39,
#   'epssurprisepct': 0.3,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2007-07-19T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.49,
#   'epsestimate': 0.46,
#   'epssurprisepct': 6.86,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2007-04-26T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.26,
#   'epsestimate': 0.23,
#   'epssurprisepct': 11.48,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2007-01-25T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.35,
#   'epsestimate': 0.31,
#   'epssurprisepct': 13.02,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2006-10-26T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.31,
#   'epsestimate': 0.3,
#   'epssurprisepct': 2.63,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2006-07-20T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.32,
#   'epsestimate': 0.33,
#   'epssurprisepct': -2.93,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2006-04-27T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.33,
#   'epsestimate': 0.33,
#   'epssurprisepct': -0.08,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2006-01-26T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.31,
#   'epsestimate': 0.3,
#   'epssurprisepct': 4.14,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2005-10-27T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.32,
#   'epsestimate': 0.31,
#   'epssurprisepct': 2.4,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2005-07-21T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.32,
#   'epsestimate': 0.32,
#   'epssurprisepct': 0.93,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2005-04-28T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.35,
#   'epsestimate': 0.33,
#   'epssurprisepct': 6.81,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2005-01-27T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.31,
#   'epsestimate': 0.3,
#   'epssurprisepct': 2.89,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2004-10-21T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.28,
#   'epsestimate': 0.29,
#   'epssurprisepct': -1.87,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2004-07-22T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.34,
#   'epsestimate': 0.29,
#   'epssurprisepct': 19.1,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2004-04-22T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.34,
#   'epsestimate': 0.3,
#   'epssurprisepct': 13.46,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2004-01-22T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.3,
#   'epsestimate': 0.29,
#   'epssurprisepct': 3.56,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2003-10-23T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.23,
#   'epsestimate': 0.24,
#   'epssurprisepct': -2.84,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2003-07-17T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.27,
#   'epsestimate': 0.24,
#   'epssurprisepct': 13.16,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2003-04-15T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.27,
#   'epsestimate': 0.23,
#   'epssurprisepct': 14.22,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2003-01-16T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.28,
#   'epsestimate': 0.21,
#   'epssurprisepct': 29.06,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2002-10-17T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.21,
#   'epsestimate': 0.21,
#   'epssurprisepct': 0.8,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2002-07-18T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.25,
#   'epsestimate': 0.25,
#   'epssurprisepct': -3.56,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2002-04-18T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.25,
#   'epsestimate': 0.21,
#   'epssurprisepct': 15.25,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2002-01-17T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.22,
#   'epsestimate': 0.2,
#   'epssurprisepct': 9.5,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2001-10-18T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.22,
#   'epsestimate': 0.21,
#   'epssurprisepct': 0.75,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2001-07-19T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.22,
#   'epsestimate': 0.21,
#   'epssurprisepct': 5.33,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2001-04-19T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.24,
#   'epsestimate': 0.23,
#   'epssurprisepct': 1.44,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2001-01-18T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.23,
#   'epsestimate': 0.21,
#   'epssurprisepct': 11.48,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2000-10-18T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.22,
#   'epsestimate': 0.21,
#   'epssurprisepct': 5.81,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2000-07-18T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.22,
#   'epsestimate': 0.2,
#   'epssurprisepct': 5.27,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2000-04-20T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.24,
#   'epsestimate': 0.21,
#   'epssurprisepct': 11.27,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '2000-01-18T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.19,
#   'epsestimate': 0.17,
#   'epssurprisepct': 10.38,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '1999-10-19T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.2,
#   'epsestimate': 0.18,
#   'epssurprisepct': 12.03,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '1999-07-19T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.19,
#   'epsestimate': 0.16,
#   'epssurprisepct': 21.78,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '1999-04-20T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.18,
#   'epsestimate': 0.15,
#   'epssurprisepct': 23.47,
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '1999-01-19T05:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EST'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.14,
#   'epsestimate': 0.12,
#   'epssurprisepct': 13.84,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '1998-10-20T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'},
#  {'companyshortname': 'Microsoft Corporation',
#   'epsactual': 0.13,
#   'epsestimate': 0.12,
#   'epssurprisepct': 4.99,
#   'gmtOffsetMilliSeconds': -14400000,
#   'quoteType': 'EQUITY',
#   'startdatetime': '1998-07-16T04:00:00.000Z',
#   'startdatetimetype': 'TAS',
#   'ticker': 'MSFT',
#   'timeZoneShortName': 'EDT'}]

# %% [markdown]
# ### 1) create dataframe - single company
# -define empty array
#
# -add on the data
#
# -define DataFrame

# %%
eps_his_msft_array = []

company_eps = si.get_earnings_history('MSFT')

for i in range(len(company_eps)):

      # print('eps(actual)   :' , company_eps[i]['epsactual'])
      # print('eps(estimate) :' , company_eps[i]['epsestimate'])
      # print('date :', company_eps[i]['startdatetime'],company_eps[i]['timeZoneShortName'])
      # print('\n')

      a = company_eps[i]['startdatetime']
      b = company_eps[i]['epsactual']
      c = company_eps[i]['epsestimate']
      X = [a,b,c]
      eps_his_msft_array.append(X)
MSFT_eps_his = pd.DataFrame(eps_his_msft_array)
MSFT_eps_his.columns = ['date','actual_eps','estimate_eps']

# %%
MSFT_eps_his
# Out:
#                         date  actual_eps  estimate_eps
# 0   2023-07-24T10:59:00.000Z         NaN           NaN
# 1   2023-04-24T10:59:00.000Z         NaN           NaN
# 2   2023-01-23T10:59:00.000Z         NaN           NaN
# 3   2022-10-25T21:30:00.000Z         NaN          2.31
# 4   2022-10-25T20:00:00.000Z         NaN          2.31
# ..                       ...         ...           ...
# 95  2000-01-18T05:00:00.000Z        0.24          0.21
# 96  1999-10-19T04:00:00.000Z        0.19          0.17
# 97  1999-07-19T04:00:00.000Z        0.20          0.18
# 98  1999-04-20T04:00:00.000Z        0.19          0.16
# 99  1999-01-19T05:00:00.000Z        0.18          0.15
#
# [100 rows x 3 columns]

# %% [markdown]
# ### 2) create dataframe - multiple companies

# %%
test_Co = ['AVGO','AMD','NVDA','INTC','QCOM','TXN','ADI','KLAC','MCHP','NXPI','LRCX','AMAT','MRVL','MU','TSM']    

for j in test_Co:
  
    eps_his_array = []
    sleep(random.uniform(1,2))
    company_eps = si.get_earnings_history(j)
    print('------company abbreviation : ', j,'------')
    print('total data N : ' , len(company_eps))

    for i in range(len(company_eps)):


          # print('eps(actual)   :' , company_eps[i]['epsactual'])
          # print('eps(estimate) :' , company_eps[i]['epsestimate'])
          # print('date :', company_eps[i]['startdatetime'],company_eps[i]['timeZoneShortName'])
          # print('\n')

          a = company_eps[i]['startdatetime']
          b = company_eps[i]['epsactual']
          c = company_eps[i]['epsestimate']
          X = [a,b,c]
          eps_his_array.append(X)

    globals()[f'{j}_eps_his'] = pd.DataFrame(eps_his_array)
    globals()[f'{j}_eps_his'].columns = ['date','actual_eps','estimate_eps']
    print('complete creating dataframe: ', f'{j}_eps_his')
    print('\n')
# Out:
# ------company abbreviation :  AVGO ------
# total data N :  54
# complete creating dataframe:  AVGO_eps_his
#
#
# ------company abbreviation :  AMD ------
# total data N :  100
# complete creating dataframe:  AMD_eps_his
#
#
# ------company abbreviation :  NVDA ------
# total data N :  95
# complete creating dataframe:  NVDA_eps_his
#
#
# ------company abbreviation :  INTC ------
# total data N :  100
# complete creating dataframe:  INTC_eps_his
#
#
# ------company abbreviation :  QCOM ------
# total data N :  100
# complete creating dataframe:  QCOM_eps_his
#
#
# ------company abbreviation :  TXN ------
# total data N :  100
# complete creating dataframe:  TXN_eps_his
#
#
# ------company abbreviation :  ADI ------
# total data N :  100
# complete creating dataframe:  ADI_eps_his
#
#
# ------company abbreviation :  KLAC ------
# total data N :  100
# complete creating dataframe:  KLAC_eps_his
#
#
# ------company abbreviation :  MCHP ------
# total data N :  100
# complete creating dataframe:  MCHP_eps_his
#
#
# ------company abbreviation :  NXPI ------
# total data N :  51
# complete creating dataframe:  NXPI_eps_his
#
#
# ------company abbreviation :  LRCX ------
# total data N :  100
# complete creating dataframe:  LRCX_eps_his
#
#
# ------company abbreviation :  AMAT ------
# total data N :  100
# complete creating dataframe:  AMAT_eps_his
#
#
# ------company abbreviation :  MRVL ------
# total data N :  88
# complete creating dataframe:  MRVL_eps_his
#
#
# ------company abbreviation :  MU ------
# total data N :  100
# complete creating dataframe:  MU_eps_his
#
#
# ------company abbreviation :  TSM ------
# total data N :  95
# complete creating dataframe:  TSM_eps_his

# %% [markdown]
# ### 3) storing the data

# %%
test_Co = ['AVGO','AMD','NVDA','INTC','QCOM','TXN','ADI','KLAC','MCHP','NXPI','LRCX','AMAT','MRVL','MU','TSM']  

for j in test_Co:
  
    eps_his_array = []
    sleep(random.uniform(1,2))
    company_eps = si.get_earnings_history(j)
    print('------company abbreviation : ', j,'------')
    print('total data N : ' , len(company_eps))

    for i in range(len(company_eps)):
      
        try:


          # print('eps(actual)   :' , company_eps[i]['epsactual'])
          # print('eps(estimate) :' , company_eps[i]['epsestimate'])
          # print('date :', company_eps[i]['startdatetime'],company_eps[i]['timeZoneShortName'])
          # print('\n')

          a = company_eps[i]['startdatetime']
          b = company_eps[i]['epsactual']
          c = company_eps[i]['epsestimate']
          X = [a,b,c]
          eps_his_array.append(X)

        except IndexError as e:
          print(f'{j}', 'error')

    globals()[f'{j}_eps_his'] = pd.DataFrame(eps_his_array)
    globals()[f'{j}_eps_his'].columns = ['date','actual_eps','estimate_eps']
    globals()[f'{j}_eps_his'].to_csv(f'/content/drive/MyDrive/Colab Notebooks/datasets/stock_market/companies_eps_his/{j}_eps_his.csv')
    print('complete creating dataframe: ', f'{j}_eps_his')
    print('storing dataframe in (csv): ', f'{j}_eps_his')
    print('\n')
# Out:
# ------company abbreviation :  AVGO ------
# total data N :  52
# complete creating dataframe:  AVGO_eps_his
# storning dataframe in (csv):  AVGO_eps_his
#
#
# ------company abbreviation :  AMD ------
# total data N :  100
# complete creating dataframe:  AMD_eps_his
# storning dataframe in (csv):  AMD_eps_his
#
#
# ------company abbreviation :  NVDA ------
# total data N :  93
# complete creating dataframe:  NVDA_eps_his
# storning dataframe in (csv):  NVDA_eps_his
#
#
# ------company abbreviation :  INTC ------
# total data N :  100
# complete creating dataframe:  INTC_eps_his
# storning dataframe in (csv):  INTC_eps_his
#
#
# ------company abbreviation :  QCOM ------
# total data N :  100
# complete creating dataframe:  QCOM_eps_his
# storning dataframe in (csv):  QCOM_eps_his
#
#
# ------company abbreviation :  TXN ------
# total data N :  100
# complete creating dataframe:  TXN_eps_his
# storning dataframe in (csv):  TXN_eps_his
#
#
# ------company abbreviation :  ADI ------
# total data N :  100
# complete creating dataframe:  ADI_eps_his
# storning dataframe in (csv):  ADI_eps_his
#
#
# ------company abbreviation :  KLAC ------
# total data N :  100
# complete creating dataframe:  KLAC_eps_his
# storning dataframe in (csv):  KLAC_eps_his
#
#
# ------company abbreviation :  MCHP ------
# total data N :  100
# complete creating dataframe:  MCHP_eps_his
# storning dataframe in (csv):  MCHP_eps_his
#
#
# ------company abbreviation :  NXPI ------
# total data N :  49
# complete creating dataframe:  NXPI_eps_his
# storning dataframe in (csv):  NXPI_eps_his
#
#
# ------company abbreviation :  LRCX ------
# total data N :  100
# complete creating dataframe:  LRCX_eps_his
# storning dataframe in (csv):  LRCX_eps_his
#
#
# ------company abbreviation :  AMAT ------
# total data N :  100
# complete creating dataframe:  AMAT_eps_his
# storning dataframe in (csv):  AMAT_eps_his
#
#
# ------company abbreviation :  MRVL ------
# total data N :  85
# complete creating dataframe:  MRVL_eps_his
# storning dataframe in (csv):  MRVL_eps_his
#
#
# ------company abbreviation :  MU ------
# total data N :  100
# complete creating dataframe:  MU_eps_his
# storning dataframe in (csv):  MU_eps_his
#
#
# ------company abbreviation :  TSM ------
# total data N :  95
# complete creating dataframe:  TSM_eps_his
# storning dataframe in (csv):  TSM_eps_his

# %% [markdown]
# ## VI.Visualiztion

# %% [markdown]
# - create X:data , Y: actual estimate eps chart

# %% [markdown]
# ### 1)-2 PE ratio calculation

# %%
si.get_stats_valuation('KLAC')
# Out:
#                            0       1
# 0      Market Cap (intraday)  37.33B
# 1           Enterprise Value  41.39B
# 2               Trailing P/E   12.01
# 3                Forward P/E   11.19
# 4  PEG Ratio (5 yr expected)    1.22
# 5          Price/Sales (ttm)    4.33
# 6           Price/Book (mrq)   26.64
# 7   Enterprise Value/Revenue    4.49
# 8    Enterprise Value/EBITDA   10.31

# %%
# test_Co = ['AVGO','AMD','NVDA','INTC','QCOM','TXN','ADI','KLAC','MCHP','NXPI','LRCX','AMAT','MRVL','MU','TSM']  
test_Co = ['FB','AAPL','AMZN','NFLX','GOOG','NVDA','TSAL','TWTR','BABA','BIDU']

per_array = []
success_N = 0
error_N = 0
for j in test_Co:
  
    try:
#      sleep(random.uniform(1,2))
      company_per = si.get_stats_valuation(j)
      print('------company abbreviation : ', j,'------')
      print(company_per.iloc[2,1])
      print('\n')

      a = j
      b = float(company_per.iloc[2,1])

      X = [a,b]
      per_array.append(X)

      success_N +=1

    except IndexError as e:
      print(f'{j}', 'error')
      error_N +=1

print('recalled_data_N = ', success_N)
print('error_N = ', error_N)




    #       a = company_eps[i]['startdatetime']
    #       b = company_eps[i]['epsactual']
    #       c = company_eps[i]['epsestimate']
    #       X = [a,b,c]
    #       eps_his_array.append(X)

    # globals()[f'{j}_eps_his'] = pd.DataFrame(eps_his_array)
    # globals()[f'{j}_eps_his'].columns = ['date','actual_eps','estimate_eps']
    # globals()[f'{j}_eps_his'].to_csv(f'/content/drive/MyDrive/Colab Notebooks/datasets/stock_market/companies_eps_his/{j}_eps_his.csv')
    # print('complete creating dataframe: ', f'{j}_eps_his')
    # print('storning dataframe in (csv): ', f'{j}_eps_his')
    # print('\n')
# Out:
# ------company abbreviation :  FB ------
# 11.11
#
#
# ------company abbreviation :  AAPL ------
# 23.54
#
#
# ------company abbreviation :  AMZN ------
# 102.47
#
#
# ------company abbreviation :  NFLX ------
# 21.79
#
#
# ------company abbreviation :  GOOG ------
# 18.77
#
#
# ------company abbreviation :  NVDA ------
# 36.69
#
#
# TSAL error
# ------company abbreviation :  TWTR ------
# 21.91
#
#
# ------company abbreviation :  BABA ------
# 37.25
#
#
# ------company abbreviation :  BIDU ------
# nan
#
#
# recalled_data_N =  9
# error_N =  1

# %%
per_array
# Out:
# [['FB', 11.11],
#  ['AAPL', 23.54],
#  ['AMZN', 102.47],
#  ['NFLX', 21.79],
#  ['GOOG', 18.77],
#  ['NVDA', 36.69],
#  ['TWTR', 21.91],
#  ['BABA', 37.25],
#  ['BIDU', nan]]

# %%
df = pd.DataFrame(per_array)

# %%
globals()[f'{j}_eps_his'].columns = ['date','actual_eps','estimate_eps']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-d974e34d01c5> in <module>
# ----> 1 globals()[f'{j}_eps_his'].columns = ['date','actual_eps','estimate_eps']
#
# KeyError: 'BIDU_eps_his'

# %%
df.clumns = ['abb','per']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   """Entry point for launching an IPython kernel.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       9 non-null      object
#  1   1       8 non-null      float64
# dtypes: float64(1), object(1)
# memory usage: 272.0+ bytes

# %%
df.describe()
# Out:
#                 1
# count    8.000000
# mean    34.191250
# std     28.948762
# min     11.110000
# 25%     21.035000
# 50%     22.725000
# 75%     36.830000
# max    102.470000
