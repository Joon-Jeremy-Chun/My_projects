# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# !pip install konlpy
# Out:
# Collecting konlpy
#   Downloading konlpy-0.5.2-py2.py3-none-any.whl (19.4 MB)
#      |████████████████████████████████| 19.4 MB 1.2 MB/s
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Collecting beautifulsoup4==4.6.0
#   Downloading beautifulsoup4-4.6.0-py3-none-any.whl (86 kB)
#      |████████████████████████████████| 86 kB 6.7 MB/s
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.2.6)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.19.5)
# Requirement already satisfied: tweepy>=3.7.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (3.10.0)
# Collecting JPype1>=0.7.0
#   Downloading JPype1-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (448 kB)
#      |████████████████████████████████| 448 kB 73.2 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from JPype1>=0.7.0->konlpy) (3.10.0.2)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.15.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (2.23.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.3.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->tweepy>=3.7.0->konlpy) (3.1.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2021.10.8)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.7.1)
# Installing collected packages: JPype1, colorama, beautifulsoup4, konlpy
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# Successfully installed JPype1-1.3.0 beautifulsoup4-4.6.0 colorama-0.4.4 konlpy-0.5.2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import urllib.request
from konlpy.tag import Okt
from tqdm import tqdm
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %% [markdown]
# ## 데이터 불러오기

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
alt = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/datasets/cryptocurrency_sentiment/crypto_labeling_Korean/alt.xlsx')
btc = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/datasets/cryptocurrency_sentiment/crypto_labeling_Korean/btc.xlsx')
eth = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/datasets/cryptocurrency_sentiment/crypto_labeling_Korean/eth.xlsx')
xrp = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/datasets/cryptocurrency_sentiment/crypto_labeling_Korean/xrp.xlsx')

# %% [markdown]
# ## 데이터 합치기

# %%
all = pd.concat([alt, btc, eth, xrp])
all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16000 entries, 0 to 3999
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   title       15999 non-null  object
#  1   body        8061 non-null   object
#  2   date_time   16000 non-null  object
#  3   labeling    16000 non-null  int64
#  4   Unnamed: 4  4 non-null      object
# dtypes: int64(1), object(4)
# memory usage: 750.0+ KB

# %% [markdown]
# * 열 삭제

# %%
all.drop(['Unnamed: 4'], axis=1, inplace=True)
all.columns
# Out:
# Index(['title', 'body', 'date_time', 'labeling'], dtype='object')

# %% [markdown]
# * 코인과 상관없는 글 (3) 삭제
# * 0 긍정, 1 중립, 2 부정

# %%
# 한번 생각해보기!
all = all[all['labeling'] != 3]
all['labeling'].value_counts()
# Out:
# 0    5257
# 2    3554
# 1    3308
# Name: labeling, dtype: int64

# %%
all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12119 entries, 1 to 3999
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   title      12119 non-null  object
#  1   body       6148 non-null   object
#  2   date_time  12119 non-null  object
#  3   labeling   12119 non-null  int64
# dtypes: int64(1), object(3)
# memory usage: 473.4+ KB

# %% [markdown]
# * 제목과 내용 합치기

# %%
all = all.replace(np.nan, "")

# %%
all['title'] = all['title'].astype(str)
all['body'] = all['body'].astype(str)

# %%
all = all.replace(np.nan, "")
all['text'] = all['title']+ " " + all['body']

# %%
all.head()
# Out:
#                        title  ...                                               text
# 1      코박토큰 어제 12시에 존나 날라가더만  ...                             코박토큰 어제 12시에 존나 날라가더만
# 2         시총 144 억 코박이 하고 놀자  ...                                시총 144 억 코박이 하고 놀자
# 3                  쿼크가면 코박간다  ...                                         쿼크가면 코박간다
# 4              불나방 안했으면 좋겠다.  ...                                     불나방 안했으면 좋겠다.
# 5  코박 바닥찍고 반등중!! 바닥에서 잡아놔라!!  ...  코박 바닥찍고 반등중!! 바닥에서 잡아놔라!! 코박 바닥찍고 반등중!! 바닥에서 잡...
#
# [5 rows x 5 columns]

# %%
all.drop(['title', 'body'], axis=1, inplace=True)
all.columns
# Out:
# Index(['date_time', 'labeling', 'text'], dtype='object')

# %% [markdown]
# ## train_test_split

# %%
from sklearn.model_selection import train_test_split

train_data, test_data = train_test_split(all, test_size = 0.2,
                                         random_state = 2045,
                                         stratify = all['labeling'])

# %% [markdown]
# ## 데이터 정제하기

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9695 entries, 2842 to 2280
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date_time  9695 non-null   object
#  1   labeling   9695 non-null   int64
#  2   text       9695 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 303.0+ KB

# %%
train_data['text'].nunique(), train_data['labeling'].nunique()
# Out:
# (9555, 3)

# %%
train_data.drop_duplicates(subset=['text'], inplace=True)

# %%
print('총 샘플의 수 :', len(train_data))
# Out:
# 총 샘플의 수 : 9555

# %%
train_data['labeling'].value_counts().plot(kind='bar')

# %%
print(train_data.groupby('labeling').size().reset_index(name='count'))
# Out:
#    labeling  count
# 0         0   4136
# 1         1   2600
# 2         2   2819

# %%
print(train_data.isnull().values.any())
# Out:
# False

# %% [markdown]
# ## 한글 외 문자 제거

# %%
train_data['text'] = train_data['text'].str.replace('[^ㄱ-ㅎㅏ-ㅣ가-힣 ]', '')
train_data.head()
# Out:
#                date_time  ...                                               text
# 2842  2021.06.17 / 22:29  ...                                   유튜브 분석 결과 리플 가격
# 2867  2021.07.11 / 15:36  ...                              고체인 손절 오키드 손절 바운스 손절
# 2903  2019.01.14 / 02:04  ...                                              이더 야
# 3561  2021.05.29 / 23:26  ...  절대매수하지마시고 시드지키세요 개속쏘셔서 물리게만들고 손절치게만듬니다이렇게 멘탈나가...
# 1003  2021.02.18 / 16:37  ...                             비트형은 이상황에서 왜 머가리를 잡고그래
#
# [5 rows x 3 columns]

# %%
train_data['text'] = train_data['text'].str.replace('^ +', '')
train_data['text'].replace('', np.nan, inplace=True)
print(train_data.isnull().sum())
# Out:
# date_time    0
# labeling     0
# text         7
# dtype: int64

# %%
train_data = train_data.dropna(how = 'any')
print(len(train_data))
# Out:
# 9548

# %%
test_data.drop_duplicates(subset = ['text'], inplace = True)
test_data['text'] = test_data['text'].str.replace('[^ㄱ-ㅎㅏ-ㅣ가-힣]', '')
test_data['text'] = test_data['text'].str.replace('^ +', '')
test_data['text'].replace('', np.nan, inplace=True)
test_data = test_data.dropna(how='any')
print('전처리 후 테스트용 샘플의 개수 :', len(test_data))
# Out:
# 전처리 후 테스트용 샘플의 개수 : 2391

# %% [markdown]
# ## 토큰화

# %%
stopwords = ['의', '가', '은', '들', '는', '좀', '잘', '걍',\
             '과', '도', '를', '으로', '자', '에', '와', '한', '하다']

# %%
okt = Okt()

# %%
X_train = []
for sentence in tqdm(train_data['text']):
    tokenized_sentence = okt.morphs(sentence, stem=True)
    stopwords_removed_sentence = [word for word in tokenized_sentence \
                                  if not word in stopwords]
    X_train.append(stopwords_removed_sentence)

print(X_train[:3])
# Out:
# 100%|██████████| 9548/9548 [01:43<00:00, 91.88it/s]
# [['유튜브', '분석', '결과', '리플', '가격'], ['고체', '인', '손절', '오', '키드', '손절', '바운스', '손절'], ['이', '더', '야']]

# %%
X_test = []
for sentence in tqdm(test_data['text']):
    tokenized_sentence = okt.morphs(sentence, stem=True)
    stopwords_removed_sentence = [word for word in tokenized_sentence \
                                  if not word in stopwords]
    X_test.append(stopwords_removed_sentence)
# Out:
#  47%|████▋     | 1112/2391 [19:27<05:21,  3.98it/s]

# %% [markdown]
# ## 정수 인코딩

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_train)

print(tokenizer.word_index)
# Out:
# {'이': 1, '을': 2, '있다': 3, '되다': 4, '더': 5, '이다': 6, '에서': 7, '로': 8, '보다': 9, '비트코인': 10, '코인': 11, '비트': 12, '적': 13, '것': 14, '리플': 15, '수': 16, '만': 17, '같다': 18, '인': 19, '다': 20, '없다': 21, '리움': 22, '고': 23, '않다': 24, '가다': 25, '하고': 26, '코박': 27, '생각': 28, '일': 29, '까지': 30, '차트': 31, '아니다': 32, '들다': 33, '상승': 34, '좋다': 35, '년': 36, '오다': 37, '저': 38, '월': 39, '가격': 40, '체인': 41, '그': 42, '점': 43, '하락': 44, '나오다': 45, '때': 46, '시': 47, '지금': 48, '글': 49, '나': 50, '현재': 51, '아': 52, '토큰': 53, '오르다': 54, '시간': 55, '되어다': 56, '개': 57, '사람': 58, '안': 59, '및': 60, '장': 61, '중': 62, '지': 63, '많다': 64, '만원': 65, '요': 66, '받다': 67, '때문': 68, '말': 69, '투자': 70, '하': 71, '오늘': 72, '늘다': 73, '정도': 74, '못': 75, '내': 76, '시장': 77, '전': 78, '크다': 79, '블록': 80, '거래소': 81, '달러': 82, '원': 83, '면': 84, '불': 85, '화폐': 86, '제': 87, '그렇다': 88, '거래': 89, '다시': 90, '형': 91, '알다': 92, '위': 93, '분': 94, '암호': 95, '매수': 96, '성': 97, '서': 98, '알트': 99, '대한': 100, '드리다': 101, '등': 102, '한번': 103, '시작': 104, '이번': 105, '게': 106, '계속': 107, '왜': 108, '이후': 109, '움직임': 110, '자산': 111, '억': 112, '올리다': 113, '분석': 114, '거': 115, '반등': 116, '부터': 117, '이제': 118, '어떻다': 119, '돈': 120, '발생': 121, '해주다': 122, '라': 123, '인데': 124, '또': 125, '수익': 126, '다른': 127, '보이다': 128, '내다': 129, '우리': 130, '차': 131, '신호': 132, '개인': 133, '해보다': 134, '이상': 135, '상': 136, '이유': 137, '어제': 138, '선': 139, '함': 140, '위해': 141, '에는': 142, '기준': 143, '자다': 144, '먹다': 145, '사용': 146, '많이': 147, '기술': 148, '갈다': 149, '진짜': 150, '네': 151, '그리고': 152, '후': 153, '아직': 154, '화': 155, '이나': 156, '모든': 157, '정보': 158, '포지션': 159, '가치': 160, '임': 161, '주': 162, '제공': 163, '네트워크': 164, '주다': 165, '하나': 166, '가능하다': 167, '채굴': 168, '통해': 169, '기': 170, '에게': 171, '대해': 172, '돌파': 173, '몇': 174, '상장': 175, '리': 176, '뭐': 177, '떨어지다': 178, '플랫폼': 179, '그냥': 180, '경우': 181, '가장': 182, '모르다': 183, '대': 184, '가지': 185, '니': 186, '구간': 187, '따르다': 188, '다음': 189, '총': 190, 'ㅋㅋ': 191, '일봉': 192, '이렇다': 193, '코': 194, '만들다': 195, '상황': 196, '선물': 197, '프로젝트': 198, '이라고': 199, '메다': 200, '트이다': 201, '참고': 202, '추세': 203, '맞다': 204, '들어가다': 205, '진입': 206, '내용': 207, '조정': 208, '높다': 209, '언제': 210, '라고': 211, '강하다': 212, '확인': 213, '올라가다': 214, '가능성': 215, '이고': 216, '추가': 217, '에서는': 218, '싶다': 219, '관련': 220, '간다': 221, '배': 222, '보고': 223, '개발': 224, '부분': 225, '모두': 226, '진행': 227, '예상': 228, '크게': 229, '사용자': 230, '바라다': 231, '업': 232, '간': 233, '넘다': 234, '게임': 235, '결국': 236, '데이터': 237, '서비스': 238, '유지': 239, '아래': 240, '최근': 241, '미국': 242, '너무': 243, '처럼': 244, '어느': 245, '약': 246, '여기': 247, '투자자': 248, 'ㅋㅋㅋ': 249, '하지만': 250, '두': 251, '매도': 252, '알': 253, '자리': 254, '기다리다': 255, '빠지다': 256, '시점': 257, '송버드': 258, '사다': 259, '안되다': 260, '야': 261, 'ㅋ': 262, '매매': 263, '세계': 264, '매': 265, '지지': 266, '스테이': 267, '에도': 268, '기반': 269, '저항': 270, '하단': 271, '풀': 272, '이라': 273, '앞': 274, '보유': 275, '또한': 276, '문제': 277, '치다': 278, '세력': 279, '타다': 280, '찍다': 281, '중요하다': 282, '크로스': 283, '시키다': 284, '깨지다': 285, '프로토콜': 286, '보상': 287, '킹': 288, '디지털': 289, '잡다': 290, '남다': 291, '개미': 292, '사실': 293, '판': 294, '조금': 295, '봉': 296, '금융': 297, '물론': 298, '세': 299, '없이': 300, '시스템': 301, '이미': 302, '근데': 303, '분산': 304, '님': 305, '번': 306, '겁니다': 307, '쓰다': 308, '달': 309, '나다': 310, '지원': 311, '라는': 312, '장이': 313, '감사하다': 314, '이며': 315, '바닥': 316, '믿다': 317, 'ㅠㅠ': 318, '예정': 319, '알파': 320, '새롭다': 321, '지갑': 322, '포크': 323, '양': 324, '설명': 325, '천': 326, '말씀드리다': 327, '물리다': 328, '가즈': 329, '보시': 330, '돼다': 331, '박다': 332, '관심': 333, '중앙': 334, '해드리다': 335, '두다': 336, '동안': 337, '손절': 338, '이라는': 339, '미래': 340, '하드': 341, '역시': 342, '소송': 343, '안녕하다': 344, '김치': 345, '떡': 346, '빠르다': 347, '한국': 348, '출시': 349, '어디': 350, '이르다': 351, '말다': 352, '량': 353, '걸': 354, '들이다': 355, '끝나다': 356, '내일': 357, '각': 358, '물량': 359, '분들': 360, '이벤트': 361, '같이': 362, '얘기': 363, '데': 364, '내리다': 365, '쉬다': 366, '커뮤니티': 367, '존버': 368, '대다': 369, '거의': 370, '수수료': 371, '바로': 372, '목표': 373, '쏘다': 374, '정리 ...

# %%
threshold = 3
total_cnt = len(tokenizer.word_index) # 단어의 수
rare_cnt = 0  # 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0  # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0 # 등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합

# 단어와 빈도수의 쌍(pair)을 key와 value로 받는다.
for key, value in tokenizer.word_counts.items():
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if (value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('단어 집합(vocabulary)의 크기 : ', total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수 : %s'%(threshold -1, rare_cnt))
print('단어 집합에서 희귀 단어의 비율 : ', (rare_cnt / total_cnt)*100)
print('전체 등장 빈도에서 희귀 단어 등장 빈도 비율 : ', (rare_freq / total_freq)*100)
# Out:
# 단어 집합(vocabulary)의 크기 :  18196
# 등장 빈도가 2번 이하인 희귀 단어의 수 : 9767
# 단어 집합에서 희귀 단어의 비율 :  53.67663222686304
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율 :  2.7010621484888886

# %%
# 전체 단어 개수 중 빈도수 2이하인 단어는 제거.
# 0번 패딩 토큰을 고려하여 + 1
vocab_size = total_cnt - rare_cnt + 1
print('단어 집합의 크기 : ', vocab_size)
# Out:
# 단어 집합의 크기 :  8430

# %%
tokenizer = Tokenizer(vocab_size)
tokenizer.fit_on_texts(X_train)
X_train = tokenizer.texts_to_sequences(X_train)
X_test = tokenizer.texts_to_sequences(X_test)

print(X_train[:3])
# Out:
# [[12, 91, 274, 3680, 300, 1, 5, 4406, 25], [1, 5, 22, 7097, 1673], [380, 108, 59, 1440]]

# %%
y_train = np.array(train_data['labeling'])
y_test = np.array(test_data['labeling'])

# %%
# 긍정,중립,부정 3분류 3_class
word_index = tokenizer.word_index

import json
json = json.dumps(word_index)
f3 = open('/content/drive/MyDrive/Colab Notebooks/datasets/cryptocurrency_sentiment/crypto_labeling_Korean/korIndex_3_class.json', 'w')
f3.write(json)
f3.close()

# %%
# # 긍정,중립,부정,배제 4분류 4_class
# word_index = tokenizer.word_index

# import json
# json = json.dumps(word_index)
# f3 = open('/content/drive/MyDrive/Colab Notebooks/datasets/cryptocurrency_sentiment/crypto_labeling_Korean/korIndex_4_class.json', 'w')
# f3.write(json)
# f3.close()

# %% [markdown]
# ## 빈 샘플 (empty samples) 제거

# %%
drop_train = [index for index, sentence in enumerate(X_train) \
              if len(sentence) < 1]

# %%
X_train = np.delete(X_train, drop_train, axis = 0)
y_train = np.delete(y_train, drop_train, axis = 0)
print(len(X_train))
print(len(y_train))
# Out:
# 12124
# 12124

# %% [markdown]
# ## 패딩

# %%
print('리뷰의 최대 길이 : ', max(len(l) for l in X_train))
print('리뷰의 평균 길이 : ', sum(map(len, X_train))/len(X_train))
plt.hist([len(s) for s in X_train], bins=50)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()
# Out:
# 리뷰의 최대 길이 :  2644
# 리뷰의 평균 길이 :  36.35821511052458

# %%
def below_threshold_len(max_len, nested_list):
    count = 0
    for sentence in nested_list:
        if(len(sentence) <= max_len):
            count = count + 1
    print('전체 샘플 중 길이가 %s 이하인 샘플의 비율 : %s'\
          %(max_len, (count / len(nested_list))*100))

# %%
max_len = 100
below_threshold_len(max_len, X_train)
# Out:
# 전체 샘플 중 길이가 100 이하인 샘플의 비율 : 92.6674364896074

# %%
X_train = pad_sequences(X_train, maxlen = max_len)
X_test = pad_sequences(X_test, maxlen = max_len)

# %%
type(X_train)
# Out:
# numpy.ndarray

# %%
np.save('/content/drive/MyDrive/Colab Notebooks/datasets/cryptocurrency_sentiment/crypto_labeling_Korean/X_train.npy', X_train)
np.save('/content/drive/MyDrive/Colab Notebooks/datasets/cryptocurrency_sentiment/crypto_labeling_Korean/X_test.npy', X_test)
np.save('/content/drive/MyDrive/Colab Notebooks/datasets/cryptocurrency_sentiment/crypto_labeling_Korean/y_train.npy', y_train)
np.save('/content/drive/MyDrive/Colab Notebooks/datasets/cryptocurrency_sentiment/crypto_labeling_Korean/y_test.npy', y_test)

# %% [markdown]
# ## ndarray 불러오기

# %%
X_train = np.load('/content/drive/MyDrive/Colab Notebooks/datasets/cryptocurrency_sentiment/crypto_labeling_Korean/X_train.npy')
X_test = np.load('/content/drive/MyDrive/Colab Notebooks/datasets/cryptocurrency_sentiment/crypto_labeling_Korean/X_test.npy')
y_train = np.load('/content/drive/MyDrive/Colab Notebooks/datasets/cryptocurrency_sentiment/crypto_labeling_Korean/y_train.npy')
y_test = np.load('/content/drive/MyDrive/Colab Notebooks/datasets/cryptocurrency_sentiment/crypto_labeling_Korean/y_test.npy')

# %%
y_train
# Out:
# array([2, 3, 2, ..., 3, 0, 2])

# %%
print(np.concatenate((y_train, y_test), axis=0))
# Out:
# [2 3 2 ... 2 0 3]

# %%
X = np.concatenate((X_train, X_test), axis=0)
y = np.concatenate((y_train, y_test), axis=0)

# %% [markdown]
# ## LSTM 감성 분류

# %%
from tensorflow.keras.layers import Embedding, Dense, LSTM
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
from sklearn.model_selection import GridSearchCV
from keras.wrappers.scikit_learn import KerasClassifier

# %%
# vocab_size = 6638
vocab_size = 8430
embedding_dim = [50, 100, 200, 400]
hidden_units = [32, 64, 128, 256, 512]
epochs = [400]
batch_size = [16, 32, 64, 128]
validation_split = [0.1,0.2]

recoding = []

for i in embedding_dim :
  for j in hidden_units :
    model = Sequential()
    model.add(Embedding(vocab_size, i))
    model.add(LSTM(j))
    model.add(Dense(3, activation='softmax'))

    es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=8)
    # mc = ModelCheckpoint('/content/drive/MyDrive/Colab Notebooks/datasets/cryptocurrency_sentiment/crypto_labeling_Korean/K_4_class_best_model_1210.h5',
    mc = ModelCheckpoint('/content/drive/MyDrive/Colab Notebooks/datasets/cryptocurrency_sentiment/crypto_labeling_Korean/K_3_class_best_model_1210.h5',
                     monitor='val_acc', mode='max', verbose=1, save_best_only=True)
    
    for a in epochs:
      for b in batch_size:
        for c in validation_split:
          model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy', metrics=['acc'])
          history = model.fit(X_train, y_train, epochs=a, callbacks=[es, mc],
                                          batch_size=b, validation_split=c)
          
          # loaded_model = load_model('/content/drive/MyDrive/Colab Notebooks/datasets/cryptocurrency_sentiment/crypto_labeling_Korean/K_4_class_best_model_1210.h5')
          loaded_model = load_model('/content/drive/MyDrive/Colab Notebooks/datasets/cryptocurrency_sentiment/crypto_labeling_Korean/K_3_class_best_model_1210.h5')
          print('\n 테스트 정확도 : %.4f' % (loaded_model.evaluate(X_test, y_test)[1]))
          y = '%.4f' % (loaded_model.evaluate(X_test, y_test)[1])

          x_embedding_dim = i
          x_hidden_units = j
          x_epochs = a
          x_batch_size = b
          x_validation_split = c

          X = [x_embedding_dim, x_hidden_units ,x_epochs , x_batch_size, x_validation_split,y]
          recoding.append(X)
# Out:
# Epoch 1/400
# 680/682 [============================>.] - ETA: 0s - loss: nan - acc: 0.3401
# Epoch 00001: val_acc improved from -inf to 0.34213, saving model to /content/drive/MyDrive/Colab Notebooks/datasets/cryptocurrency_sentiment/crypto_labeling_Korean/K_best_model_1210.h5
# 682/682 [==============================] - 21s 21ms/step - loss: nan - acc: 0.3397 - val_loss: nan - val_acc: 0.3421
# Epoch 2/400
# 681/682 [============================>.] - ETA: 0s - loss: nan - acc: 0.3400
# Epoch 00002: val_acc did not improve from 0.34213
# 682/682 [==============================] - 13s 20ms/step - loss: nan - acc: 0.3400 - val_loss: nan - val_acc: 0.3421
# Epoch 3/400
# 681/682 [============================>.] - ETA: 0s - loss: nan - acc: 0.3401
# Epoch 00003: val_acc did not improve from 0.34213
# 682/682 [==============================] - 14s 20ms/step - loss: nan - acc: 0.3400 - val_loss: nan - val_acc: 0.3421
# Epoch 4/400
# 682/682 [==============================] - ETA: 0s - loss: nan - acc: 0.3400
# Epoch 00004: val_acc did not improve from 0.34213
# 682/682 [==============================] - 13s 20ms/step - loss: nan - acc: 0.3400 - val_loss: nan - val_acc: 0.3421
# Epoch 5/400
# 681/682 [============================>.] - ETA: 0s - loss: nan - acc: 0.3398
# Epoch 00005: val_acc did not improve from 0.34213
# 682/682 [==============================] - 14s 20ms/step - loss: nan - acc: 0.3400 - val_loss: nan - val_acc: 0.3421
# Epoch 6/400
# 681/682 [============================>.] - ETA: 0s - loss: nan - acc: 0.3400
# Epoch 00006: val_acc did not improve from 0.34213
# 682/682 [==============================] - 14s 20ms/step - loss: nan - acc: 0.3400 - val_loss: nan - val_acc: 0.3421
# Epoch 7/400
# 682/682 [==============================] - ETA: 0s - loss: nan - acc: 0.3400
# Epoch 00007: val_acc did not improve from 0.34213
# 682/682 [==============================] - 14s 20ms/step - loss: nan - acc: 0.3400 - val_loss: nan - val_acc: 0.3421
# Epoch 8/400
# 682/682 [==============================] - ETA: 0s - loss: nan - acc: 0.3400
# Epoch 00008: val_acc did not improve from 0.34213
# 682/682 [==============================] - 13s 20ms/step - loss: nan - acc: 0.3400 - val_loss: nan - val_acc: 0.3421
# Epoch 00008: early stopping
# 96/96 [==============================] - 1s 9ms/step - loss: nan - acc: 0.3376
#
#  테스트 정확도 : 0.3376
# 96/96 [==============================] - 1s 9ms/step - loss: nan - acc: 0.3376
# Epoch 1/400
# 607/607 [==============================] - ETA: 0s - loss: nan - acc: 0.3410
# Epoch 00001: val_acc did not improve from 0.34213
# 607/607 [==============================] - 16s 22ms/step - loss: nan - acc: 0.3410 - val_loss: nan - val_acc: 0.3373
# Epoch 2/400
# 605/607 [============================>.] - ETA: 0s - loss: nan - acc: 0.3409
# Epoch 00002: val_acc did not improve from 0.34213
# 607/607 [==============================] - 13s 21ms/step - loss: nan - acc: 0.3410 - val_loss: nan - val_acc: 0.3373
# Epoch 3/400
# 605/607 [============================>.] - ETA: 0s - loss: nan - acc: 0.3410
# Epoch 00003: val_acc did not improve from 0.34213
# 607/607 [==============================] - 13s 21ms/step - loss: nan - acc: 0.3410 - val_loss: nan - val_acc: 0.3373
# Epoch 4/400
# 606/607 [============================>.] - ETA: 0s - loss: nan - acc: 0.3410
# Epoch 00004: val_acc did not improve from 0.34213
# 607/607 [==============================] - 13s 21ms/step - loss: nan - acc: 0.3410 - val_loss: nan - val_acc: 0.3373
# Epoch 5/400
# 607/607 [==============================] - ETA: 0s - loss: nan - acc: 0.3410
# Epoch 00005: val_acc did not improve from 0.34213
# 607/607 [==============================] - 12s 21ms/step - loss: nan - acc: 0.3410 - val_loss: nan - val_acc: 0.3373
# Epoch 6/400
# 606/607 [============================>.] - ETA: 0s - loss: nan - acc: 0.3409
# Epoch 00006: val_acc did not improve from 0.34213
# 607/607 [==============================] - 13s 21ms/step - loss: nan - acc: 0.3410 - val_loss: nan - val_acc: 0.3373
# Epoch 7/400
# 606/607 [============================>.] - ETA: 0s - loss: nan - acc: 0.3410
# Epoch 00007: val_acc did not improve from 0.34213
# 607/607 [==============================] - 13s 21ms/step - loss: nan - acc: 0.3410 - val_loss: nan - val_acc: 0.3373
# Epoch 8/400
# 607/607 [==============================] - ETA: 0s - loss: nan - acc: 0.3410
# Epoch 00008: val_acc did not improve from 0.34213
# 607/607 [==============================] - 13s 21ms/step - loss: nan - acc: 0.3410 - val_loss: nan - val_acc: 0.3373
# Epoch 00008: early stopping
# 96/96 [==============================] - 1s 9ms/step - loss: nan - acc: 0.3376
#
#  테스트 정확도 : 0.3376
# 96/96 [==============================] - 1s 9ms/step - loss: nan - acc: 0.3376
# Epoch 1/400
# 340/341 [============================>.] - ETA: 0s - loss: nan - acc: 0.3395
# Epoch 00001: val_acc did not improve from 0.34213
# 341/341 [==============================] - 10s 23ms/step - loss: nan - acc: 0.3400 - val_loss: nan - val_acc: 0.3421
# Epoch 2/400
# 340/341 [============================>.] - ETA: 0s - loss: nan - acc: 0.3399
# Epoch 00002: val_acc did not improve from 0.34213
# 341/341 [==============================] - 7s 20ms/step - loss: nan - acc: 0.3400 - val_loss: nan - val_acc: 0.3421
# Epoch 3/400
# 340/341 [============================>.] - ETA: 0s - loss: nan - acc: 0.3402
# Epoch 00003: val_acc did not improve from 0.34213
# 341/341 [==============================] - 7s 20ms/step - loss: nan - acc: 0.3400 - val_loss: nan - val_acc: 0.3421
# Epoch 4/400
# 340/341 [============================>.] - ETA: 0s - loss: nan - acc: 0.3403
# Epoch 00004: val_acc did not improve from 0.34213
# 341/341 [==============================] - 7s 20ms/step - loss: nan - acc: 0.3400 - val_loss: nan - val_acc: 0.3421
# Epoch 5/400
# 339/341 [============================>.] - ETA: 0s - loss: nan - acc: 0.3400
# Epoch 00005: val_acc did not improve from 0.34213
# 341/341 [==============================] - 7s 20ms/step - loss: nan - acc: 0.3400 - val_loss: nan - val_acc: 0.3421
# Epoch 6/400
# 340/341 [============================>.] - ETA: 0s - loss: nan - acc: 0.3401
# Epoch 00006: val_acc did not improve from 0.34213
# 341/341 [==============================] - 7s 20ms/step - loss: nan - acc: 0.3400 - val_loss: nan - val_acc: 0.3421
# Epoch 7/400
# 340/341 [============================>.] - ETA: 0s - loss: nan - acc: 0.3398
# Epoch 00007: val_acc did not improve from 0.34213
# 341/341 [==============================] - 7s 20ms/step - loss: nan - acc: 0.3400 - val_loss: nan - val_acc: 0.3421
# Epoch 8/400
# 339/341 [============================>.] - ETA: 0s - loss: nan - acc: 0.3405
# Epoch 00008: val_acc did not improve from 0.34213
# 341/341 [==============================] - 7s 20ms/step - loss: nan - acc: 0.3400 - val_loss: nan - val_acc: 0.3421
# Epoch 00008: early stopping
# 96/96 [==============================] - 1s 9ms/step - loss: nan - acc: 0.3376
#
#  테스트 정확도 : 0.3376
# 96/96 [==============================] - 1s 9ms/step - loss: nan - acc: 0.3376
# Epoch 1/400
# 304/304 [==============================] - ETA: 0s - loss: nan - acc: 0.3410
# Epoch 00001: val_acc did not improve from 0.34213
# 304/304 [==============================] - 10s 23ms/step - loss: nan - acc: 0.3410 - val_loss: nan - val_acc: 0.3373
# Epoch 2/400
# 304/304 [==============================] - ETA: 0s - loss: nan - acc: 0.3410
# Epoch 00002: val_acc did not improve from 0.34213
# 304/304 [==============================] - 6s 21ms/step - loss: nan - acc: 0.3410 - val_loss: nan - val_acc: 0.3373
# Epoch 3/400
# 304/304 [==============================] - ETA: 0s - loss: nan - acc: 0.3410
# Epoch 00003: val_acc did not improve from 0.34213
# 304/304 [==============================] - 6s 21ms/step - loss: nan - acc: 0.3410 - val_loss: nan - val_acc: 0.3373
# Epoch 4/400
# 304/304 [==============================] - ETA: 0s - loss: nan - acc: 0.3410
# Epoch 00004: val_acc did not improve from 0.34213
# 304/304 [==============================] - 6s 21ms/step - loss: nan - acc: 0.3410 - val_loss: nan - val_acc: 0.3373
# Epoch 5/400
# 304/304 [==============================] - ETA: 0s - loss: nan - acc: 0.3410
# Epoch 00005: val_acc did not improve from 0.34213
# 304/304 [==============================] - 7s 21ms/step - loss: nan - acc: 0.3410 - val_loss: nan - val_acc: 0.3373
# Epoch 6/400
# 304/304 [==============================] - ETA: 0s - loss: nan - acc: 0.3410
# Epoch 00006: val_acc did not improve from 0.34213
# 304/304 [==============================] - 6s 21ms/step - loss: nan - acc: 0.3410 - val_loss: nan - val_acc: 0.3373
# Epoch 7/400
# 304/304 [==============================] - ETA: 0s - loss: nan - acc: 0.3410
# Epoch 00007: val_acc did not improve from 0.34213
# 304/304 [==============================] - 6s 21ms/step - loss: nan - acc: 0.3410 - val_loss: nan - val_acc: 0.3373
# Epoch 8/400
# 304/304 [==============================] - ETA: 0s - loss: nan - acc: 0.3410
# Epoch 00008: val_acc did not improve from 0.34213
# 304/304 [==============================] - 7s 22ms/step - loss: nan - acc: 0.3410 - val_loss: nan - val_acc: 0.3373
# Epoch 00008: early stopping
# 96/96 [==============================] - 1s 9ms/step - loss: nan - acc: 0.3376
#
#  테스트 정확도 : 0.3376
# 96/96 [==============================] - 1s 9ms/step - loss: nan - acc: 0.3376
# Epoch 1/400
# 169/171 [============================>.] - ETA: 0s - loss: nan - acc: 0.3397
# Epoch 00001: val_acc did not improve from 0.34213
# 171/171 [==============================] - 7s 26ms/step - loss: nan - acc: 0.3400 - val_loss: nan - val_acc: 0.3421
# Epoch 2/400
# 169/171 [============================>.] - ETA: 0s - loss: nan - acc: 0.3400
# Epoch 00002: val_acc did not improve from 0.34213
# 171/171 [==============================] - 4s 20ms/step - loss: nan - acc: 0.3400 - val_loss: nan - val_acc: 0.3421
# Epoch 3/400
# 171/171 [==============================] - ETA: 0s - loss: nan - acc: 0.3400
# Epoch 00003: val_acc did not improve from 0.34213
# 171/171 [==============================] - 4s 21ms/step - loss: nan - acc: 0.3400 - val_loss: nan - val_acc: 0.3421
# Epoch 4/400
# 170/171 [============================>.] - ETA: 0s - loss: nan - acc: 0.3401
# Epoch 00004: val_acc did not improve from 0.34213
# 171/171 [==============================] - 4s 22ms/step - loss: nan - acc: 0.3400 - val_loss: nan - val_acc: 0.3421
# Epoch 5/400
# 169/171 [============================>.] - ETA: 0s - loss: nan - acc: 0.3401
# Epoch 00005: val_acc did not improve from 0.34213
# 171/171 [==============================] - 4s 21ms/step - loss: nan - acc: 0.3400 - val_loss: nan - val_acc: 0.3421
# Epoch 6/400
# 169/171 [============================>.] - ETA: 0s - loss: nan - acc: 0.3401
# Epoch 00006: val_acc did not improve from 0.34213
# 171/171 [==============================] - 4s 21ms/step - loss: nan - acc: 0.3400 - val_loss: nan - val_acc: 0.3421
# Epoch 7/400
# 169/171 [============================>.] - ETA: 0s - loss: nan - acc: 0.3399
# Epoch 00007: val_acc did not improve from 0.34213
# 171/171 [==============================] - 4s 21ms/step - loss: nan - acc: 0.3400 - val_loss: nan - val_acc: 0.3421
# Epoch 8/400
# 169/171 [============================>.] - ETA: 0s - loss: nan - acc: 0.3395
# Epoch 00008: val_acc did not improve from 0.34213
# 171/171 [==============================] - 4s 21ms/step - loss: nan - acc: 0.3400 - val_loss: nan - val_acc: 0.3421
# Epoch 00008: early stopping
# 96/96 [==============================] - 1s 9ms/step - loss: nan - acc: 0.3376
#
#  테스트 정확도 : 0.3376
# 96/96 [==============================] - 1s 9ms/step - loss: nan - acc: 0.3376
# Epoch 1/400
# 150/152 [============================>.] - ETA: 0s - loss: nan - acc: 0.3406
# Epoch 00001: val_acc did not improve from 0.34213
# 152/152 [==============================] - 8s 30ms/step - loss: nan - acc: 0.3410 - val_loss: nan - val_acc: 0.3373
# Epoch 2/400
# 150/152 [============================>.] - ETA: 0s - loss: nan - acc: 0.3410
# Epoch 00002: val_acc did not improve from 0.34213
# 152/152 [==============================] - 3s 22ms/step - loss: nan - acc: 0.3410 - val_loss: nan - val_acc: 0.3373
# Epoch 3/400
# 151/152 [============================>.] - ETA: 0s - loss: nan - acc: 0.3412
# Epoch 00003: val_acc did not improve from 0.34213
# 152/152 [==============================] - 3s 22ms/step - loss: nan - acc: 0.3410 - val_loss: nan - val_acc: 0.3373
# Epoch 4/400
# 151/152 [============================>.] - ETA: 0s - loss: nan - acc: 0.3406
# Epoch 00004: val_acc did not improve from 0.34213
# 152/152 [==============================] - 3s 22ms/step - loss: nan - acc: 0.3410 - val_loss: nan - val_acc: 0.3373
# Epoch 5/400
# 151/152 [============================>.] - ETA: 0s - loss: nan - acc: 0.3416
# Epoch 00005: val_acc did not improve from 0.34213
# 152/152 [==============================] - 3s 22ms/step - loss: nan - acc: 0.3410 - val_loss: nan - val_acc: 0.3373
# Epoch 6/400
# 151/152 [============================>.] - ETA: 0s - loss: nan - acc: 0.3406
# Epoch 00006: val_acc did not improve from 0.34213
# 152/152 [==============================] - 3s 22ms/step - loss: nan - acc: 0.3410 - val_loss: nan - val_acc: 0.3373
# Epoch 7/400
# 150/152 [============================>.] - ETA: 0s - loss: nan - acc: 0.3408
# Epoch 00007: val_acc did not improve from 0.34213
# 152/152 [==============================] - 3s 22ms/step - loss: nan - acc: 0.3410 - val_loss: nan - val_acc: 0.3373
# Epoch 8/400
# 151/152 [============================>.] - ETA: 0s - loss: nan - acc: 0.3412
# Epoch 00008: val_acc did not improve from 0.34213
# 152/152 [==============================] - 3s 22ms/step - loss: nan - acc: 0.3410 - val_loss: nan - val_acc: 0.3373
# Epoch 00008: early stopping
# 96/96 [==============================] - 1s 9ms/step - loss: nan - acc: 0.3376
#
#  테스트 정확도 : 0.3376
# 96/96 [==============================] - 1s 9ms/step - loss: nan - acc: 0.3376
# Epoch 1/400
# 84/86 [============================>.] - ETA: 0s - loss: nan - acc: 0.3406
# Epoch 00001: val_acc did not improve from 0.34213
# 86/86 [==============================] - 5s 34ms/step - loss: nan - acc: 0.3400 - val_loss: nan - val_acc: 0.3421
# Epoch 2/400
# 84/86 [============================>.] - ETA: 0s - loss: nan - acc: 0.3398
# Epoch 00002: val_acc did not improve from 0.34213
# 86/86 [==============================] - 2s 22ms/step - loss: nan - acc: 0.3400 - val_loss: nan - val_acc: 0.3421
# Epoch 3/400
# 86/86 [==============================] - ETA: 0s - loss: nan - acc: 0.3400
# Epoch 00003: val_acc did not improve from 0.34213
# 86/86 [==============================] - 2s 22ms/step - loss: nan - acc: 0.3400 - val_loss: nan - val_acc: 0.3421
# Epoch 4/400
# 85/86 [============================>.] - ETA: 0s - loss: nan - acc: 0.3400
# Epoch 00004: val_acc did not improve from 0.34213
# 86/86 [==============================] - 2s 22ms/step - loss: nan - acc: 0.3400 - val_loss: nan - val_acc: 0.3421
# Epoch 5/400
# 86/86 [==============================] - ETA: 0s - loss: nan - acc: 0.3400
# Epoch 00005: val_acc did not improve from 0.34213
# 86/86 [==============================] - 2s 22ms/step - loss: nan - acc: 0.3400 - val_loss: nan - val_acc: 0.3421
# Epoch 6/400
# 86/86 [==============================] - ETA: 0s - loss: nan - acc: 0.3400
# Epoch 00006: val_acc did not improve from 0.34213
# 86/86 [==============================] - 2s 22ms/step - loss: nan - acc: 0.3400 - val_loss: nan - val_acc: 0.3421
# Epoch 7/400
# 85/86 [============================>.] - ETA: 0s - loss: nan - acc: 0.3403
# Epoch 00007: val_acc did not improve from 0.34213
# 86/86 [==============================] - 2s 22ms/step - loss: nan - acc: 0.3400 - val_loss: nan - val_acc: 0.3421
# Epoch 8/400
# 85/86 [============================>.] - ETA: 0s - loss: nan - acc: 0.3401
# Epoch 00008: val_acc did not improve from 0.34213
# 86/86 [==============================] - 2s 22ms/step - loss: nan - acc: 0.3400 - val_loss: nan - val_acc: 0.3421
# Epoch 00008: early stopping
# 96/96 [==============================] - 1s 9ms/step - loss: nan - acc: 0.3376
#
#  테스트 정확도 : 0.3376
# 96/96 [==============================] - 1s 9ms/step - loss: nan - acc: 0.3376
# Epoch 1/400
# 74/76 [============================>.] - ETA: 0s - loss: nan - acc: 0.3414
# Epoch 00001: val_acc did not improve from 0.34213
# 76/76 [==============================] - 7s 36ms/step - loss: nan - acc: 0.3410 - val_loss: nan - val_acc: 0.3373
# Epoch 2/400
# 76/76 [==============================] - ETA: 0s - loss: nan - acc: 0.3410
# Epoch 00002: val_acc did not improve from 0.34213
# 76/76 [==============================] - 2s 23ms/step - loss: nan - acc: 0.3410 - val_loss: nan - val_acc: 0.3373
# Epoch 3/400
# 75/76 [============================>.] - ETA: 0s - loss: nan - acc: 0.3410
# Epoch 00003: val_acc did not improve from 0.34213
# 76/76 [==============================] - 2s 23ms/step - loss: nan - acc: 0.3410 - val_loss: nan - val_acc: 0.3373
# Epoch 4/400
# 76/76 [==============================] - ETA: 0s - loss: nan - acc: 0.3410
# Epoch 00004: val_acc did not improve from 0.34213
# 76/76 [==============================] - 2s 23ms/step - loss: nan - acc: 0.3410 - val_loss: nan - val_acc: 0.3373
# Epoch 5/400
# 76/76 [==============================] - ETA: 0s - loss: nan - acc: 0.3410
# Epoch 00005: val_acc did not improve from 0.34213
# 76/76 [==============================] - 2s 24ms/step - loss: nan - acc: 0.3410 - val_loss: nan - val_acc: 0.3373
# Epoch 6/400
# 75/76 [============================>.] - ETA: 0s - loss: nan - acc: 0.3414
# Epoch 00006: val_acc did not improve from 0.34213
# 76/76 [==============================] - 2s 23ms/step - loss: nan - acc: 0.3410 - val_loss: nan - val_acc: 0.3373
# Epoch 7/400
# 75/76 [============================>.] - ETA: 0s - loss: nan - acc: 0.3405
# Epoch 00007: val_acc did not improve from 0.34213
# 76/76 [==============================] - 2s 23ms/step - loss: nan - acc: 0.3410 - val_loss: nan - val_acc: 0.3373
# Epoch 8/400
# 75/76 [============================>.] - ETA: 0s - loss: nan - acc: 0.3411
# Epoch 00008: val_acc did not improve from 0.34213
# 76/76 [==============================] - 2s 23ms/step - loss: nan - acc: 0.3410 - val_loss: nan - val_acc: 0.3373
# Epoch 00008: early stopping
# 96/96 [==============================] - 2s 9ms/step - loss: nan - acc: 0.3376
#
#  테스트 정확도 : 0.3376
# 96/96 [==============================] - 1s 9ms/step - loss: nan - acc: 0.3376
# Epoch 1/400
# 682/682 [==============================] - ETA: 0s - loss: nan - acc: 0.3398
# Epoch 00001: val_acc improved from -inf to 0.34213, saving model to /content/drive/MyDrive/Colab Notebooks/datasets/cryptocurrency_sentiment/crypto_labeling_Korean/K_best_model_1210.h5
# 682/682 [==============================] - 21s 26ms/step - loss: nan - acc: 0.3398 - val_loss: nan - val_acc: 0.3421
# Epoch 2/400
# 681/682 [============================>.] - ETA: 0s - loss: nan - acc: 0.3400
# Epoch 00002: val_acc did not improve from 0.34213
# 682/682 [==============================] - 16s 24ms/step - loss: nan - acc: 0.3400 - val_loss: nan - val_acc: 0.3421
# Epoch 3/400
# 682/682 [==============================] - ETA: 0s - loss: nan - acc: 0.3400
# Epoch 00003: val_acc did not improve from 0.34213
# 682/682 [==============================] - 17s 24ms/step - loss: nan - acc: 0.3400 - val_loss: nan - val_acc: 0.3421
# Epoch 4/400
# 681/682 [============================>.] - ETA: 0s - loss: nan - acc: 0.3401
# Epoch 00004: val_acc did not improve from 0.34213
# 682/682 [==============================] - 16s 24ms/step - loss: nan - acc: 0.3400 - val_loss: nan - val_acc: 0.3421
# Epoch 5/400
#  52/682 [=>............................] - ETA: 14s - loss: nan - acc: 0.3257
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-51-512ca8a4eec6> in <module>()
#      25           model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy', metrics=['acc'])
#      26           history = model.fit(X_train, y_train, epochs=a, callbacks=[es, mc],
# ---> 27                                           batch_size=b, validation_split=c)
#      28
#      29           loaded_model = load_model('/content/drive/MyDrive/Colab Notebooks/datasets/cryptocurrency_sentiment/crypto_labeling_Korean/K_best_model_1210.h5')
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1219               logs = tmp_logs  # No error, now safe to assign to logs.
#    1220               end_step = step + data_handler.step_increment
# -> 1221               callbacks.on_train_batch_end(end_step, logs)
#    1222               if self.stop_training:
#    1223                 break
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#     434     """
#     435     if self._should_call_train_batch_hooks:
# --> 436       self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#     437
#     438   def on_test_batch_begin(self, batch, logs=None):
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     293       self._call_batch_begin_hook(mode, batch, logs)
#     294     elif hook == 'end':
# --> 295       self._call_batch_end_hook(mode, batch, logs)
#     296     else:
#     297       raise ValueError(
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     314       self._batch_times.append(batch_time)
#     315
# --> 316     self._call_batch_hook_helper(hook_name, batch, logs)
#     317
#     318     if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     352     for callback in self.callbacks:
#     353       hook = getattr(callback, hook_name)
# --> 354       hook(batch, logs)
#     355
#     356     if self._check_timing:
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#    1030
#    1031   def on_train_batch_end(self, batch, logs=None):
# -> 1032     self._batch_update_progbar(batch, logs)
#    1033
#    1034   def on_test_batch_end(self, batch, logs=None):
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _batch_update_progbar(self, batch, logs)
#    1102     if self.verbose == 1:
#    1103       # Only block async when verbose = 1.
# -> 1104       logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1105       self.progbar.update(self.seen, list(logs.items()), finalize=False)
#    1106
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/tf_utils.py in sync_to_numpy_or_python_type(tensors)
#     552     return t  # Don't turn ragged or sparse tensors to NumPy.
#     553
# --> 554   return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     555
#     556
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     867
#     868   return pack_sequence_as(
# --> 869       structure[0], [func(*x) for x in entries],
#     870       expand_composites=expand_composites)
#     871
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     867
#     868   return pack_sequence_as(
# --> 869       structure[0], [func(*x) for x in entries],
#     870       expand_composites=expand_composites)
#     871
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/tf_utils.py in _to_single_numpy_or_python_type(t)
#     548   def _to_single_numpy_or_python_type(t):
#     549     if isinstance(t, tf.Tensor):
# --> 550       x = t.numpy()
#     551       return x.item() if np.ndim(x) == 0 else x
#     552     return t  # Don't turn ragged or sparse tensors to NumPy.
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/ops.py in numpy(self)
#    1147     """
#    1148     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1149     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1150     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1151
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/ops.py in _numpy(self)
#    1113   def _numpy(self):
#    1114     try:
# -> 1115       return self._numpy_internal()
#    1116     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1117       raise core._status_to_exception(e) from None  # pylint: disable=protected-access
#
# KeyboardInterrupt:

# %%
dfr = pd.DataFrame(recoding)
dfr.columns = ['embedding_dim', 'hidden_units', 'epochs', 'batch_size',
               'validation_split', 'accuracy']
dfr.to_csv('/content/drive/MyDrive/Colab Notebooks/3rd project/history/best_model_1130.csv', index =False)

# %%
embedding_dim = 100
hidden_units = 128

model = Sequential()
model.add(Embedding(vocab_size, embedding_dim))
model.add(LSTM(hidden_units))
model.add(Dense(3, activation = 'softmax'))

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=4)
mc = ModelCheckpoint('/content/drive/MyDrive/Colab Notebooks/3rd project/history/best_model_scc.h5',
                     monitor='val_acc', mode='max', verbose=1, save_best_only=True)

# %%
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy', metrics=['acc'])
history = model.fit(X_train, y_train, epochs=15, callbacks=[es, mc],
                    batch_size=64, validation_split=0.2)
# Out:
# Epoch 1/15
# 120/120 [==============================] - 6s 35ms/step - loss: 1.0255 - acc: 0.4787 - val_loss: 1.3536 - val_acc: 0.5068
#
# Epoch 00001: val_acc improved from -inf to 0.50682, saving model to /content/drive/MyDrive/Colab Notebooks/3rd project/history/best_model_scc.h5
# Epoch 2/15
# 120/120 [==============================] - 4s 30ms/step - loss: 0.8779 - acc: 0.6141 - val_loss: 0.9643 - val_acc: 0.5393
#
# Epoch 00002: val_acc improved from 0.50682 to 0.53935, saving model to /content/drive/MyDrive/Colab Notebooks/3rd project/history/best_model_scc.h5
# Epoch 3/15
# 120/120 [==============================] - 3s 28ms/step - loss: 0.7765 - acc: 0.6615 - val_loss: 0.9796 - val_acc: 0.5451
#
# Epoch 00003: val_acc improved from 0.53935 to 0.54512, saving model to /content/drive/MyDrive/Colab Notebooks/3rd project/history/best_model_scc.h5
# Epoch 4/15
# 120/120 [==============================] - 3s 28ms/step - loss: 0.7056 - acc: 0.7038 - val_loss: 1.0353 - val_acc: 0.5346
#
# Epoch 00004: val_acc did not improve from 0.54512
# Epoch 5/15
# 120/120 [==============================] - 3s 27ms/step - loss: 0.6495 - acc: 0.7300 - val_loss: 1.0521 - val_acc: 0.5409
#
# Epoch 00005: val_acc did not improve from 0.54512
# Epoch 6/15
# 120/120 [==============================] - 3s 26ms/step - loss: 0.5959 - acc: 0.7535 - val_loss: 1.1670 - val_acc: 0.5477
#
# Epoch 00006: val_acc improved from 0.54512 to 0.54774, saving model to /content/drive/MyDrive/Colab Notebooks/3rd project/history/best_model_scc.h5
# Epoch 00006: early stopping

# %%
loaded_model = load_model('/content/drive/MyDrive/Colab Notebooks/3rd project/history/best_model_scc.h5')
print('\n 테스트 정확도 : %.4f' % (loaded_model.evaluate(X_test, y_test)[1]))
# Out:
# 75/75 [==============================] - 3s 34ms/step - loss: 1.1295 - acc: 0.5391
#
#  테스트 정확도 : 0.5391

# %% [markdown]
# ## 리뷰 예측

# %%
def sentiment_predict(input, stopwords, vocab_size, word_index, loaded_model):
    input = input.replace(np.nan, "")
    input['text'] = input['title'] + ' ' + input['body']
    input.drop(['title', 'body'], axis=1, inplace=True)
    input['text'] = input['text'].str.replace('[^ㄱ-ㅎㅏ-ㅣ가-힣 ]', '')

    new_sentence = []
    for sentence in tqdm(input['text']):
        tokenized_sentence = okt.morphs(sentence, stem=True)
        stopwords_removed_sentence = [word for word in tokenized_sentence \
                                      if not word in stopwords]
        new_sentence.append(stopwords_removed_sentence)

    tokenizer = Tokenizer(vocab_size)
    tokenizer.word_index = word_index
    encoded = tokenizer.texts_to_sequences(new_sentence)
    pad_new = pad_sequences(encoded, maxlen = max_len)
    # input['sentiment'] = loaded_model.predict(pad_new)

    # input['s'] = 1
    # input.loc[input['sentiment'] < 0.67, 's'] = 0
    # input.loc[input['sentiment'] >= 1.34, 's'] = 2

# %%
input = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/3rd project/data/kor/alt_x.csv', sep=',', encoding='cp949')

import json
with open('/content/drive/MyDrive/Colab Notebooks/3rd project/korIndex.json') as json_file:
    word_index = json.load(json_file)

from keras.models import load_model
loaded_model = load_model('/content/drive/MyDrive/Colab Notebooks/3rd project/history/best_model_mse.h5')

# %%
sentiment_predict(input, stopwords, vocab_size, word_index, loaded_model)
# Out:
# 100%|██████████| 4198/4198 [00:53<00:00, 78.32it/s]

# %%
input.head()
# Out:
#                      title  ...           date_time
# 0  공식 어플 설치하고 코인정보를 받아보세요!  ...  2016.05.31 / 21:19
# 1    코박토큰 어제 12시에 존나 날라가더만  ...  2021.10.30 / 17:17
# 2       시총 144 억 코박이 하고 놀자  ...  2021.10.30 / 15:27
# 3                쿼크가면 코박간다  ...  2021.10.30 / 13:05
# 4            불나방 안했으면 좋겠다.  ...  2021.10.30 / 12:54
#
# [5 rows x 3 columns]
